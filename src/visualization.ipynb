# %% [markdown]
# # Visualization

# %% [markdown]
# ## Import libraries

# %%
from visualizer.visualizer import Visualizer

# %%
my_visualizer = Visualizer()

# %%
my_visualizer.test_data()
# Out:
#     year  quarter agriculture_share industry_share service_share  \
# 0   2000        4              None           None          None
# 1   2001        4              None           None          None
# 2   2002        4              None           None          None
# 3   2003        4              None           None          None
# 4   2004        4              None           None          None
# ..   ...      ...               ...            ...           ...
# 81  2024        1             11.77          35.73         43.48
# 82  2024        2             11.55          36.44         43.35
# 83  2024        3             11.64           37.1          42.8
# 84  2024        4              None           None          None
# 85  2025        1             11.56          36.31         43.44
#
#    gdp_true_growth_acc agriculture_true_growth_acc industry_true_growth_acc  \
# 0                 6.79                        None                     None
# ...

# %%
my_visualizer.test_visualize()
