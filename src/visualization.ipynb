# %% [markdown]
# # Visualization

# %% [markdown]
# ## Import libraries

# %%
from visualizer.visualizer import Visualizer
from utils.constants import SCRAPER_START_DATE, SCRAPER_END_DATE
from utils.enums import GenerateDateTimeType

# %%
my_visualizer = Visualizer()

# %%
my_visualizer.generate_date_time_series(generate_date_time_type=GenerateDateTimeType.YEAR, start_date=SCRAPER_START_DATE, end_date=SCRAPER_END_DATE)
# Out:
# 0    2000-12-31
# 1    2001-12-31
# 2    2002-12-31
# 3    2003-12-31
# 4    2004-12-31
# 5    2005-12-31
# 6    2006-12-31
# 7    2007-12-31
# 8    2008-12-31
# 9    2009-12-31
# 10   2010-12-31
# 11   2011-12-31
# 12   2012-12-31
# 13   2013-12-31
# 14   2014-12-31
# 15   2015-12-31
# 16   2016-12-31
# 17   2017-12-31
# 18   2018-12-31
# 19   2019-12-31
# 20   2020-12-31
# 21   2021-12-31
# 22   2022-12-31
# 23   2023-12-31
# 24   2024-12-31
# dtype: datetime64[ns]

# %%
my_visualizer.generate_date_time_series(generate_date_time_type=GenerateDateTimeType.QUARTER, start_date=SCRAPER_START_DATE, end_date=SCRAPER_END_DATE)
# Out:
# 0     2000-03-31
# 1     2000-06-30
# 2     2000-09-30
# 3     2000-12-31
# 4     2001-03-31
#          ...
# 97    2024-06-30
# 98    2024-09-30
# 99    2024-12-31
# 100   2025-03-31
# 101   2025-06-30
# Length: 102, dtype: datetime64[ns]

# %%
my_visualizer.generate_date_time_series(generate_date_time_type=GenerateDateTimeType.MONTH, start_date=SCRAPER_START_DATE, end_date=SCRAPER_END_DATE)
# Out:
# 0     2000-01-31
# 1     2000-02-29
# 2     2000-03-31
# 3     2000-04-30
# 4     2000-05-31
#          ...
# 301   2025-02-28
# 302   2025-03-31
# 303   2025-04-30
# 304   2025-05-31
# 305   2025-06-30
# Length: 306, dtype: datetime64[ns]

# %%
my_visualizer.generate_date_time_series(generate_date_time_type=GenerateDateTimeType.DAY, start_date=SCRAPER_START_DATE, end_date=SCRAPER_END_DATE)
# Out:
# 0      2000-01-01
# 1      2000-01-02
# 2      2000-01-03
# 3      2000-01-04
# 4      2000-01-05
#           ...
# 9308   2025-06-26
# 9309   2025-06-27
# 9310   2025-06-28
# 9311   2025-06-29
# 9312   2025-06-30
# Length: 9313, dtype: datetime64[ns]
