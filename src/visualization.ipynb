# %% [markdown]
# # Visualization

# %% [markdown]
# ## Import libraries

# %%
import os
import pandas as pd

from visualizer.visualizer import Visualizer
from utils.constants import SCRAPER_START_DATE, SCRAPER_END_DATE
from utils.enums import GenerateDateTimeType

# %%
my_visualizer = Visualizer()
my_visualizer.connect_to_database(database_name=os.getenv("SILVER_POSTGRES_DATABASE"))
# Out:
# <DatabaseExecutionStatus.SUCCESS: 'success'>

# %% [markdown]
# ## silver_gdp

# %%
silver_gdp = my_visualizer.select(schema_name="macroeconomics", table_name="gdp")
silver_gdp
# Out:
#     year  quarter  agriculture  industry  services  gdp_growth   gdp_real
# 0   2005        1          NaN       NaN       NaN        7.20        NaN
# 1   2006        1          NaN       NaN       NaN        7.20        NaN
# 2   2007        1          NaN       NaN       NaN        7.70        NaN
# 3   2008        1          NaN       NaN       NaN        7.43        NaN
# 4   2008        2          NaN       NaN       NaN        5.70        NaN
# 5   2009        1          NaN       NaN       0.0        3.10        NaN
# 6   2010        1          0.0       0.0       0.0        5.83        0.0
# 7   2011        1          0.0       NaN       NaN        5.43        NaN
# 8   2011        2          0.0       0.0       0.0        5.67        0.0
# 9   2011        3          NaN       NaN       NaN        6.07        NaN
# 10  2012        1          NaN       NaN       NaN        4.00        NaN
# 11  2013        1      65298.0  192430.0  222727.0        4.76   480455.0
# 12  2013        2     138831.0  230162.0  245909.0        5.00   614902.0
# 13  2013        3     109506.0  241824.0  292298.0        5.54   643601.0
# 14  2013        4     133399.0  316673.0  354528.0        6.04   804599.0
# 15  2014        1      66844.0  200860.0  235979.0        5.06   503683.0
# 16  2015        1      66940.0  184644.0  216604.0        6.03   534573.0
# 17  2016        1      66186.0  197759.0  229578.0        5.46   564255.0
# 18  2017        1      49119.0  206847.0  244194.0        5.10   593170.0
# 19  2017        2     117499.0  189759.0  278136.0        6.17   775495.0
# 20  2017        3      83555.0  235636.0  334750.0        7.46   836270.0
# 21  2018        1      70244.0  227596.0  260157.0        7.38   637244.0
# 22  2018        2     223482.0  826087.5  558608.0        6.79  2358942.5
# 23  2018        3     345561.1  513350.0  915734.7        6.88  1466960.0
# 24  2018        4     154845.0  415876.0  440185.0        7.31  1134963.0
# 25  2019        1      72261.0  247733.0  276919.0        6.79   681010.0
# 26  2019        2     156090.0  311394.0  318984.0        6.71   884508.0
# 27  2019        3     124487.0  344648.0  381359.0        7.31   957109.0
# 28  2019        4     157354.0  448832.0  475814.0        6.97  1214052.0
# 29  2020        1      72406.0  260602.0  285964.0        3.82   707223.0
# 30  2020        2     158542.0  315686.0  313378.0        0.36   887862.0
# 31  2020        3     128735.0  355168.0  392479.0        2.62   983730.0
# 32  2020        4     164726.0  473978.0  496223.0        4.48  1268385.0
# 33  2021        1     125510.0  434967.0  508697.0        4.48  1189216.0
# 34  2021        2     137147.0  478718.0  515232.0        6.61  1248813.0
# 35  2021        3     156017.0  450933.0  481371.0       -6.17  1201066.0
# 36  2021        4     157234.0  547529.0  634633.0        5.22  1467490.0
# 37  2022        1     130990.0  462710.0  535754.0        5.03  1255312.0
# 38  2022        2     141144.0  521538.0  558903.0        7.72  1346821.0
# 39  2022        3     148123.0  516567.0  587647.0       13.67  1376321.0
# 40  2022        4     178958.0  562396.0  666854.0        5.92  1538951.0
# 41  2023        1     140836.0  459243.0  590817.0        3.32  1320755.0
# 42  2023        2     143521.0  512383.0  623253.0        4.14  1407473.0
# 43  2023        3     154316.0  539924.0  626848.0        5.33  1450322.0
# 44  2023        4     184545.0  605975.0  716362.0        6.72  1643902.0
# 45  2024        1     145600.0  488208.0  627420.0        5.66  1396660.0
# 46  2024        2     151303.0  545237.0  677030.0        6.93  1508387.0
# 47  2024        3     161767.0  588545.0  680490.0        7.43  1567923.0
# 48  2024        4     192991.0  657896.0  776143.0        7.55  1773652.0
# 49  2025        1     153001.0  526666.0  681303.0        6.93  1502807.0
# 50  2025        2     156992.0  599879.0  742776.0        7.96  1643317.0

# %%
std_silver_gdp = my_visualizer.make_date_time_index_for_dataframe(silver_gdp)
std_silver_gdp
# Out:
#           date  agriculture  industry  services  gdp_growth   gdp_real
# 0   2000-03-31          NaN       NaN       NaN         NaN        NaN
# 1   2000-06-30          NaN       NaN       NaN         NaN        NaN
# 2   2000-09-30          NaN       NaN       NaN         NaN        NaN
# 3   2000-12-31          NaN       NaN       NaN         NaN        NaN
# 4   2001-03-31          NaN       NaN       NaN         NaN        NaN
# ..         ...          ...       ...       ...         ...        ...
# 97  2024-06-30     151303.0  545237.0  677030.0        6.93  1508387.0
# 98  2024-09-30     161767.0  588545.0  680490.0        7.43  1567923.0
# 99  2024-12-31     192991.0  657896.0  776143.0        7.55  1773652.0
# 100 2025-03-31     153001.0  526666.0  681303.0        6.93  1502807.0
# 101 2025-06-30     156992.0  599879.0  742776.0        7.96  1643317.0
#
# [102 rows x 6 columns]

# %%
std_silver_gdp_fig = my_visualizer.plot_line_chart(
    std_silver_gdp,
    x_column="date",
    y_columns=["gdp_growth"],
    title="GDP Growth",
    y_axis_title="Rate",
    y_unit="%",
)

# %% [markdown]
# ## silver_cpi

# %%
silver_cpi = my_visualizer.select(schema_name="macroeconomics", table_name="cpi")
silver_cpi
# Out:
#      year  month  beverage_and_cigarette  consumer_price_index  \
# 0    2009      7                  100.47                100.52
# 1    2009      8                  100.11                100.24
# 2    2009      9                  100.75                100.62
# 3    2009     10                  100.14                100.37
# 4    2009     11                  100.44                100.55
# ..    ...    ...                     ...                   ...
# 194  2022      1                  100.57                100.19
# 195  2022      2                  100.37                101.00
# 196  2022      3                  100.06                100.70
# 197  2022      4                  100.22                100.18
# 198  2022      5                  100.33                100.38
#
#      culture_entertainment_and_tourism  eating_outside  education    food  \
# 0                               100.45             NaN     100.21   99.08
# 1                               100.12             NaN     100.15   99.58
# 2                               100.25          100.77     104.33   99.15
# 3                               100.02          100.24     100.73  100.03
# 4                               100.03          100.33     100.06  102.22
# ..                                 ...             ...        ...     ...
# 194                             100.16          100.18     100.03  100.08
# 195                             100.51          101.68     100.51  100.35
# 196                             100.21          100.08     100.10  100.17
# 197                             101.16          100.51     100.96  100.21
# 198                             100.74          100.40     100.17  100.28
#
#      food_and_foodstuff  foodstuff  garment_footwear_hat  \
# 0                 99.95      99.95                100.29
# 1                 99.92      99.91                100.52
# 2                100.05     100.17                100.67
# 3                100.32     100.49                100.27
# 4                100.87     100.62                100.32
# ..                  ...        ...                   ...
# 194              100.00      99.91                100.26
# 195              101.54     101.69                100.07
# 196               99.73      99.52                100.12
# 197               99.95      99.68                100.12
# 198              100.27     100.22                100.18
#
#      household_appliances_and_goods  housing_and_construction_materials  \
# 0                            100.37                              101.89
# 1                            100.30                              100.93
# 2                            100.37                              100.87
# 3                            100.22                              100.55
# 4                            100.22                              100.75
# ..                              ...                                 ...
# 194                          100.18                              100.07
# 195                          100.19                              100.92
# 196                          100.19                              101.49
# 197                          100.32                              100.58
# 198                          100.22                               99.87
#
#      medicine_and_health_care  other_goods_and_services  \
# 0                      100.36                    100.45
# 1                      100.16                    100.40
# 2                      100.19                    100.48
# 3                      100.16                    100.48
# 4                      100.09                    100.54
# ..                        ...                       ...
# 194                    100.03                    100.39
# 195                    100.03                    100.22
# 196                    100.06                    100.46
# 197                    100.03                    100.18
# 198                    100.03                    100.19
#
#      postal_services_and_telecommunication  traffic
# 0                                    99.63   103.05
# 1                                    99.96   101.31
# 2                                    99.97   102.37
# 3                                   100.00   100.77
# 4                                    99.95   100.42
# ..                                     ...      ...
# 194                                  99.97   101.18
# 195                                  99.96   102.35
# 196                                 100.02   104.80
# 197                                  99.88    99.41
# 198                                 100.01   102.34
#
# [199 rows x 17 columns]

# %%
std_silver_cpi = my_visualizer.make_date_time_index_for_dataframe(silver_cpi)
std_silver_cpi
# Out:
#           date  beverage_and_cigarette  consumer_price_index  \
# 0   2000-01-31                     NaN                   NaN
# 1   2000-02-29                     NaN                   NaN
# 2   2000-03-31                     NaN                   NaN
# 3   2000-04-30                     NaN                   NaN
# 4   2000-05-31                     NaN                   NaN
# ..         ...                     ...                   ...
# 301 2025-02-28                  100.12                100.34
# 302 2025-03-31                   99.96                 99.97
# 303 2025-04-30                  100.11                100.07
# 304 2025-05-31                  100.14                100.16
# 305 2025-06-30                  100.20                100.48
#
#      culture_entertainment_and_tourism  eating_outside  education   food  \
# 0                                  NaN             NaN        NaN    NaN
# 1                                  NaN             NaN        NaN    NaN
# 2                                  NaN             NaN        NaN    NaN
# 3                                  NaN             NaN        NaN    NaN
# 4                                  NaN             NaN        NaN    NaN
# ..                                 ...             ...        ...    ...
# 301                             100.17          100.75     100.02  99.76
# 302                             100.18           99.97     100.02  99.17
# 303                             100.01          100.32     100.00  99.35
# 304                             100.28          100.28     100.01  99.82
# 305                             100.27          100.30     100.01  99.69
#
#      food_and_foodstuff  foodstuff  garment_footwear_hat  \
# 0                   NaN        NaN                   NaN
# 1                   NaN        NaN                   NaN
# 2                   NaN        NaN                   NaN
# 3                   NaN        NaN                   NaN
# 4                   NaN        NaN                   NaN
# ..                  ...        ...                   ...
# 301              100.43     100.41                 99.89
# 302               99.95     100.08                100.05
# 303              100.12     100.17                100.06
# 304              100.03      99.96                100.05
# 305              100.06     100.02                100.10
#
#      household_appliances_and_goods  housing_and_construction_materials  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
# ..                              ...                                 ...
# 301                          100.05                              100.55
# 302                          100.13                              100.50
# 303                          100.10                              100.62
# 304                          100.19                              100.73
# 305                          100.13                              101.42
#
#      medicine_and_health_care  other_goods_and_services  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# ..                        ...                       ...
# 301                    100.31                    100.18
# 302                    100.13                    100.21
# 303                    100.02                    100.15
# 304                    100.02                    100.43
# 305                    100.02                    100.09
#
#      postal_services_and_telecommunication  traffic
# 0                                      NaN      NaN
# 1                                      NaN      NaN
# 2                                      NaN      NaN
# 3                                      NaN      NaN
# 4                                      NaN      NaN
# ..                                     ...      ...
# 301                                  99.97   100.63
# 302                                 100.02    98.59
# 303                                  99.85    98.95
# 304                                 100.21    99.58
# 305                                  99.98   101.66
#
# [306 rows x 16 columns]

# %%
std_silver_cpi_fig = my_visualizer.plot_line_chart(
    std_silver_cpi,
    x_column="date",
    y_columns=["consumer_price_index"],
    title="Consumer Price Index",
    y_axis_title="Rate",
    y_unit="%",
)
