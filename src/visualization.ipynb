# %% [markdown]
# # Visualization

# %% [markdown]
# ## Import libraries

# %%
import os
import pandas as pd

from visualizer.visualizer import Visualizer
from utils.constants import *
from utils.enums import *
from models.tabular_database_driver_models.tabular_database_driver_models import *

# %% [markdown]
# ## Initialize the Visualizer

# %%
my_visualizer = Visualizer()

# %% [markdown]
# ## MACROECONOMICS

# %%
my_visualizer.connect_to_database(database_name=os.getenv("SILVER_POSTGRES_DATABASE"))
my_visualizer.set_chart_dir(CHARTS_DIR_MACROECONOMICS)

# %% [markdown]
# ### silver_gdp

# %%
silver_gdp = my_visualizer.select(schema_name="macroeconomics", table_name="gdp")
silver_gdp

# %%
std_silver_gdp = my_visualizer.make_date_time_index_for_dataframe(silver_gdp)
std_silver_gdp

# %%
std_silver_gdp_fig = my_visualizer.plot_lines_chart(
    std_silver_gdp,
    x_column="date",
    y_columns=["gdp_growth"],
    title="GDP Growth",
    y_axis_title="Rate",
    y_unit="%",
    prefix_figure_name="gdp",
)
std_silver_gdp_fig

# %% [markdown]
# ### silver_cpi

# %%
silver_cpi = my_visualizer.select(schema_name="macroeconomics", table_name="cpi")
silver_cpi

# %%
std_silver_cpi = my_visualizer.make_date_time_index_for_dataframe(silver_cpi)
std_silver_cpi

# %%
std_silver_cpi_fig = my_visualizer.plot_lines_chart(
    std_silver_cpi,
    x_column="date",
    y_columns=["consumer_price_index"],
    title="Consumer Price Index",
    y_axis_title="Rate",
    y_unit="%",
    prefix_figure_name="cpi",
)
std_silver_cpi_fig

# %% [markdown]
# ### silver_ppi

# %%
silver_ppi = my_visualizer.select(schema_name="macroeconomics", table_name="ppi")
silver_ppi

# %%
std_silver_ppi = my_visualizer.make_date_time_index_for_dataframe(silver_ppi)
std_silver_ppi

# %%
std_silver_ppi_fig = my_visualizer.plot_lines_chart(
    std_silver_ppi,
    x_column="date",
    y_columns=["general_index"],
    title="Producer Price Index",
    y_axis_title="Rate",
    y_unit="%",
    prefix_figure_name="ppi",
)
std_silver_ppi_fig

# %% [markdown]
# ### silver_ipi

# %%
silver_ipi = my_visualizer.select(schema_name="macroeconomics", table_name="ipi")
silver_ipi

# %%
std_silver_ipi = my_visualizer.make_date_time_index_for_dataframe(silver_ipi)
std_silver_ipi

# %%
std_silver_ipi_fig = my_visualizer.plot_lines_chart(
    std_silver_ipi,
    x_column="date",
    y_columns=["general_index"],
    title="Industrial Production Index",
    y_axis_title="Rate",
    y_unit="%",
    prefix_figure_name="ipi",
)
std_silver_ipi_fig

# %% [markdown]
# ### silver_xpi

# %%
silver_xpi = my_visualizer.select(schema_name="macroeconomics", table_name="xpi")
silver_xpi

# %%
std_silver_xpi = my_visualizer.make_date_time_index_for_dataframe(silver_xpi)
std_silver_xpi

# %%
std_silver_xpi_fig = my_visualizer.plot_lines_chart(
    std_silver_xpi,
    x_column="date",
    y_columns=["total_value"],
    title="Export Price Index",
    y_axis_title="Value",
    y_unit="thousand tons",
    prefix_figure_name="xpi",
)
std_silver_xpi_fig

# %% [markdown]
# ### silver_mpi

# %%
silver_mpi = my_visualizer.select(schema_name="macroeconomics", table_name="mpi")
silver_mpi

# %%
std_silver_mpi = my_visualizer.make_date_time_index_for_dataframe(silver_mpi)
std_silver_mpi

# %%
std_silver_mpi_fig = my_visualizer.plot_lines_chart(
    std_silver_mpi,
    x_column="date",
    y_columns=["total_value"],
    title="Import Price Index",
    y_axis_title="Value",
    y_unit="thousand tons",
    prefix_figure_name="mpi",
)
std_silver_mpi_fig

# %% [markdown]
# ### silver_population

# %%
silver_population = my_visualizer.select(
    schema_name="macroeconomics", table_name="population"
)
silver_population

# %%
std_silver_population = my_visualizer.make_date_time_index_for_dataframe(
    silver_population
)
std_silver_population

# %%
std_silver_population_fig = my_visualizer.plot_lines_chart(
    std_silver_population,
    x_column="date",
    y_columns=["population"],
    title="Population",
    y_axis_title="Value",
    y_unit="millions people",
    prefix_figure_name="population",
)
std_silver_population_fig

# %% [markdown]
# ### silver_labor

# %%
silver_labor = my_visualizer.select(schema_name="macroeconomics", table_name="labor")
silver_labor

# %%
std_silver_labor = my_visualizer.make_date_time_index_for_dataframe(silver_labor)
std_silver_labor

# %%
std_silver_labor_fig = my_visualizer.plot_lines_chart(
    std_silver_labor,
    x_column="date",
    y_columns=["employed_amount"],
    title="Employed Amount",
    y_axis_title="Value",
    y_unit="millions people",
    prefix_figure_name="labor",
)
std_silver_labor_fig

# %% [markdown]
# ### silver_pmi

# %%
silver_pmi = my_visualizer.select(schema_name="macroeconomics", table_name="pmi")
silver_pmi

# %%
std_silver_pmi = my_visualizer.make_date_time_index_for_dataframe(silver_pmi)
std_silver_pmi

# %%
std_silver_pmi_fig = my_visualizer.plot_lines_chart(
    std_silver_pmi,
    x_column="date",
    y_columns=["pmi"],
    title="Purchasing Managers Index",
    y_axis_title="Value",
    y_unit="point",
    prefix_figure_name="pmi",
)
std_silver_pmi_fig

# %% [markdown]
# ### silver_iip

# %%
silver_iip = my_visualizer.select(schema_name="macroeconomics", table_name="iip")
silver_iip

# %%
std_silver_iip = my_visualizer.make_date_time_index_for_dataframe(silver_iip)
std_silver_iip

# %%
std_silver_iip_fig = my_visualizer.plot_lines_chart(
    std_silver_iip,
    x_column="date",
    y_columns=["entire_industrial_sector"],
    title="Index of Industrial Production",
    y_axis_title="Rate",
    y_unit="%",
    prefix_figure_name="iip",
)
std_silver_iip_fig

# %% [markdown]
# ### silver_ipv

# %%
silver_ipv = my_visualizer.select(schema_name="macroeconomics", table_name="ipv")
silver_ipv

# %%
std_silver_ipv = my_visualizer.make_date_time_index_for_dataframe(silver_ipv)
std_silver_ipv

# %%
std_silver_ipv_fig = my_visualizer.plot_lines_chart(
    std_silver_ipv,
    x_column="date",
    y_columns=["extracted_crude_oil", "gasoline_oil"],
    title="Industrial Production Volume",
    y_axis_title="Value",
    y_unit="thousand tons",
    prefix_figure_name="ipv",
)
std_silver_ipv_fig

# %% [markdown]
# ### silver_mip

# %%
silver_mip = my_visualizer.select(schema_name="macroeconomics", table_name="mip")
silver_mip

# %%
std_silver_mip = my_visualizer.make_date_time_index_for_dataframe(silver_mip)
std_silver_mip

# %%
std_silver_mip_fig = my_visualizer.plot_lines_chart(
    std_silver_mip,
    x_column="date",
    y_columns=[
        "clean_coal",
        "crude_oil_extraction",
        "milled_rice",
        "cement",
        "generated_electricity",
    ],
    title="Some Major Industrial Products",
    y_axis_title="Value",
    y_unit="thousand tons / million KWh",
    prefix_figure_name="mip",
)
std_silver_mip_fig

# %% [markdown]
# ### silver_fa_by_house_types

# %%
silver_fa_by_house_types = my_visualizer.select(
    schema_name="macroeconomics", table_name="fa_by_house_types"
)
silver_fa_by_house_types

# %%
std_silver_fa_by_house_types = my_visualizer.make_date_time_index_for_dataframe(
    silver_fa_by_house_types
)
std_silver_fa_by_house_types

# %%
std_silver_fa_by_house_types_fig = my_visualizer.plot_lines_chart(
    std_silver_fa_by_house_types,
    x_column="date",
    y_columns=["total"],
    title="Floor Area",
    y_axis_title="Value",
    y_unit="thousand m2",
    prefix_figure_name="fa_by_house_types",
)
std_silver_fa_by_house_types_fig

# %% [markdown]
# ### silver_it_bop

# %%
silver_it_bop = my_visualizer.select(schema_name="macroeconomics", table_name="it_bop")
silver_it_bop

# %%
std_silver_it_bop = my_visualizer.make_date_time_index_for_dataframe(silver_it_bop)
std_silver_it_bop

# %%
std_silver_it_bop_fig = my_visualizer.plot_lines_chart(
    std_silver_it_bop,
    x_column="date",
    y_columns=[
        "a_current_account",
        "c_financial_account",
        "d_errors_and_omissions",
        "e_overall_balance",
    ],
    title="International Trade and Balance of Payments",
    y_axis_title="Value",
    y_unit="million US dollars",
    prefix_figure_name="it_bop",
)
std_silver_it_bop_fig

# %% [markdown]
# ### silver_tsbr

# %%
silver_tsbr = my_visualizer.select(schema_name="macroeconomics", table_name="tsbr")
silver_tsbr

# %%
std_silver_tsbr = my_visualizer.make_date_time_index_for_dataframe(silver_tsbr)
std_silver_tsbr

# %%
std_silver_tsbr_fig = my_visualizer.plot_lines_chart(
    std_silver_tsbr,
    x_column="date",
    y_columns=["total_state_budget_revenue"],
    title="Total State Budget Revenue",
    y_axis_title="Value",
    y_unit="billion Dong",
    prefix_figure_name="tsbr",
)
std_silver_tsbr_fig

# %% [markdown]
# ### silver_tsbe

# %%
silver_tsbe = my_visualizer.select(schema_name="macroeconomics", table_name="tsbe")
silver_tsbe

# %%
std_silver_tsbe = my_visualizer.make_date_time_index_for_dataframe(silver_tsbe)
std_silver_tsbe

# %%
std_silver_tsbe_fig = my_visualizer.plot_lines_chart(
    std_silver_tsbe,
    x_column="date",
    y_columns=["total_state_budget_expenditure"],
    title="Total State Budget Expenditure",
    y_axis_title="Value",
    y_unit="billion Dong",
    prefix_figure_name="tsbe",
)
std_silver_tsbe_fig

# %% [markdown]
# ### silver_gd

# %%
silver_gd = my_visualizer.select(schema_name="macroeconomics", table_name="gd")
silver_gd

# %%
std_silver_gd = my_visualizer.make_date_time_index_for_dataframe(silver_gd)
std_silver_gd

# %%
std_silver_gd_fig = my_visualizer.plot_lines_chart(
    std_silver_gd,
    x_column="date",
    y_columns=["debt_balance", "domestic_debt", "foreign_debt"],
    title="Gorvernment Debt",
    y_axis_title="Value",
    y_unit="billion Dong",
    prefix_figure_name="gd",
)
std_silver_gd_fig

# %% [markdown]
# ### silver_brd

# %%
silver_brd = my_visualizer.select(schema_name="macroeconomics", table_name="brd")
silver_brd

# %%
std_silver_brd = my_visualizer.make_date_time_index_for_dataframe(silver_brd)
std_silver_brd

# %%
std_silver_brd_fig = my_visualizer.plot_lines_chart(
    std_silver_brd,
    x_column="date",
    y_columns=[
        "newly_established_enterprises",
        "enterprises_temporarily_suspended_awaiting_dissolution",
        "enterprises_resuming_operations",
        "enterprises_completing_dissolution",
    ],
    title="Business Registered Dissolved",
    y_axis_title="Value",
    y_unit="enterprises",
    prefix_figure_name="brd",
)
std_silver_brd_fig

# %% [markdown]
# ### silver_iisd

# %%
silver_iisd = my_visualizer.select(schema_name="macroeconomics", table_name="iisd")
silver_iisd

# %%
std_silver_iisd = my_visualizer.make_date_time_index_for_dataframe(silver_iisd)
std_silver_iisd

# %%
std_silver_iisd_fig = my_visualizer.plot_lines_chart(
    std_silver_iisd,
    x_column="date",
    y_columns=[
        "total",
        "investment_capital_from_the_state_budget",
        "investment_capital_from_residents_and_private_individuals",
        "foreign_direct_investment_capital",
    ],
    title="Investing In Social Development",
    y_axis_title="Value",
    y_unit="thousand billion Dong",
    prefix_figure_name="iisd",
)
std_silver_iisd_fig

# %% [markdown]
# ### silver_treg

# %%
silver_treg = my_visualizer.select(schema_name="macroeconomics", table_name="treg")
silver_treg

# %%
std_silver_treg = my_visualizer.make_date_time_index_for_dataframe(silver_treg)
std_silver_treg

# %%
std_silver_treg_fig = my_visualizer.plot_lines_chart(
    std_silver_treg,
    x_column="date",
    y_columns=[
        "international_liquidity_total_reserves_excluding_gold_us_dollar",
    ],
    title="Total Reserves excluding gold (USD)",
    y_axis_title="Value",
    y_unit="million USD",
    prefix_figure_name="treg",
    marker=None,
)
std_silver_treg_fig

# %% [markdown]
# ### silver_credit

# %%
silver_credit = my_visualizer.select(schema_name="macroeconomics", table_name="credit")
silver_credit

# %%
std_silver_credit = my_visualizer.make_date_time_index_for_dataframe(silver_credit)
std_silver_credit

# %%
std_silver_credit_fig = my_visualizer.plot_lines_chart(
    std_silver_credit,
    x_column="date",
    y_columns=["credit", "money_supply_m2"],
    title="Credit statistics",
    y_axis_title="Value",
    y_unit="billion Dong",
    prefix_figure_name="credit",
    marker=None,
)
std_silver_credit_fig

# %%
std_silver_credit_fig = my_visualizer.plot_lines_chart(
    std_silver_credit,
    x_column="date",
    y_columns=["credit_growth_ytd", "money_supply_growth_m2_ytd"],
    title="Credit growth statistics",
    y_axis_title="Value",
    y_unit="billion Dong",
    prefix_figure_name="credit",
    marker=None,
)
std_silver_credit_fig

# %% [markdown]
# ### silver_mobilization

# %%
silver_mobilization = my_visualizer.select(
    schema_name="macroeconomics", table_name="mobilization"
)
silver_mobilization

# %%
std_silver_mobilization = my_visualizer.make_date_time_index_for_dataframe(
    silver_mobilization
)
std_silver_mobilization

# %%
std_silver_mobilization_fig = my_visualizer.plot_lines_chart(
    std_silver_mobilization,
    x_column="date",
    y_columns=[
        "deposits_from_economic_organizations",
        "deposits_from_residents",
        "total_payment_instruments",
    ],
    title="mobilization statistics",
    y_axis_title="Value",
    y_unit="billion Dong",
    prefix_figure_name="mobilization",
    marker=None,
)
std_silver_mobilization_fig

# %% [markdown]
# ### silver_exchange_rate

# %%
silver_exchange_rate = my_visualizer.select(
    schema_name="macroeconomics", table_name="exchange_rate"
)
silver_exchange_rate

# %%
std_silver_exchange_rate = my_visualizer.make_date_time_index_for_dataframe(
    silver_exchange_rate
)
std_silver_exchange_rate

# %%
std_silver_exchange_rate_fig = my_visualizer.plot_lines_chart(
    std_silver_exchange_rate,
    x_column="date",
    y_columns=["central_rate"],
    title="Exchange rate statistics",
    y_axis_title="Value",
    y_unit="VND/USD",
    prefix_figure_name="exchange_rate",
    marker=None,
)
std_silver_exchange_rate_fig

# %% [markdown]
# ### silver_iir

# %%
silver_iir = my_visualizer.select(schema_name="macroeconomics", table_name="iir")
silver_iir

# %%
std_silver_iir = my_visualizer.make_date_time_index_for_dataframe(silver_iir)
std_silver_iir

# %%
rename_dict = {
    "_3_months": "three_months",
    "_6_months": "six_months",
    "_9_months": "nine_months",
}

# Apply renaming
std_silver_iir = std_silver_iir.rename(columns=rename_dict)
std_silver_iir

# %%
std_silver_iir_fig = my_visualizer.plot_lines_chart(
    std_silver_iir,
    x_column="date",
    y_columns=["overnight", "three_months", "six_months", "nine_months"],
    title="Interbank interest rates",
    y_axis_title="Value",
    y_unit="%",
    prefix_figure_name="iir",
    marker=None,
)
std_silver_iir_fig

# %% [markdown]
# ### silver_rrrr

# %%
std_silver_rrrr = my_visualizer.select(schema_name="macroeconomics", table_name="rrrr")
std_silver_rrrr

# %%
std_silver_rrrr_fig = my_visualizer.plot_lines_chart(
    std_silver_rrrr,
    x_column="date",
    y_columns=["discount_rate", "refinancing_rate"],
    title="Rediscount rate, Refinancing rate",
    y_axis_title="Rate",
    y_unit="%",
    prefix_figure_name="rrrr",
    marker=None,
)
std_silver_rrrr_fig

# %% [markdown]
# ### silver_fdi_sector

# %%
silver_fdi_sector = my_visualizer.select(
    schema_name="macroeconomics", table_name="fdi_sector"
)
silver_fdi_sector

# %%
std_silver_fdi_sector = my_visualizer.make_date_time_index_for_dataframe(
    silver_fdi_sector
)
std_silver_fdi_sector

# %%
std_silver_fdi_sector_fig = my_visualizer.plot_lines_chart(
    std_silver_fdi_sector,
    x_column="date",
    y_columns=[
        "administrative_and_support_service_activities",
        "agriculture_forestry_and_fishery",
        "construction",
        "education_and_training",
        "healthcare_and_social_assistance_activities",
        "information_and_communication",
        "mining_and_quarrying",
    ],
    title="Foreign Direct Investment by Sector 1",
    y_axis_title="Value",
    y_unit="Million US Dollars",
    prefix_figure_name="fdi_sector",
    marker=None,
)
std_silver_fdi_sector_fig

# %%
std_silver_fdi_sector_fig = my_visualizer.plot_lines_chart(
    std_silver_fdi_sector,
    x_column="date",
    y_columns=[
        "manufacturing_and_processing_industry",
        "real_estate_business_activities",
        "production_and_distribution_of_electricity_gas_water_and_air_co",
    ],
    title="Foreign Direct Investment by Sector 2",
    y_axis_title="Value",
    y_unit="Million US Dollars",
    prefix_figure_name="fdi_sector",
    marker=None,
)
std_silver_fdi_sector_fig

# %% [markdown]
# ### silver_fdi_rd

# %%
silver_fdi_rd = my_visualizer.select(schema_name="macroeconomics", table_name="fdi_rd")
silver_fdi_rd

# %%
std_silver_fdi_rd = my_visualizer.make_date_time_index_for_dataframe(silver_fdi_rd)
std_silver_fdi_rd

# %%
std_silver_fdi_rd_fig = my_visualizer.plot_lines_chart(
    std_silver_fdi_rd,
    x_column="date",
    y_columns=[
        "fdi_disbursement",
        "register",
    ],
    title="Foreign Direct Investment Registration Disbursement",
    y_axis_title="Value",
    y_unit="Billion US Dollars",
    prefix_figure_name="fdi_rd",
    marker=None,
)
std_silver_fdi_rd_fig

# %% [markdown]
# ### silver_export

# %%
silver_export = my_visualizer.select(schema_name="macroeconomics", table_name="export")
silver_export

# %%
std_silver_export = my_visualizer.make_date_time_index_for_dataframe(silver_export)
std_silver_export

# %%
std_silver_export_fig = my_visualizer.plot_lines_chart(
    std_silver_export,
    x_column="date",
    y_columns=[
        "asean",
        "united_arab_emirates",
        "eu",
        "netherlands",
        "south_korea",
        "hong_kong",
        "usa",
        "japan",
        "china",
    ],
    title="Export statistics by countries",
    y_axis_title="Value",
    y_unit="Million US Dollars",
    prefix_figure_name="export",
    marker=None,
)
std_silver_export_fig

# %% [markdown]
# ### silver_import

# %%
silver_import = my_visualizer.select(schema_name="macroeconomics", table_name="import")
silver_import

# %%
std_silver_import = my_visualizer.make_date_time_index_for_dataframe(silver_import)
std_silver_import

# %%
std_silver_import_fig = my_visualizer.plot_lines_chart(
    std_silver_import,
    x_column="date",
    y_columns=[
        "asean",
        "united_arab_emirates",
        "eu",
        "netherlands",
        "south_korea",
        "hong_kong",
        "usa",
        "japan",
        "china",
    ],
    title="Import statistics by countries",
    y_axis_title="Value",
    y_unit="Million US Dollars",
    prefix_figure_name="import",
    marker=None,
)
std_silver_import_fig

# %% [markdown]
# ### silver_gold_price

# %%
silver_gold_price = my_visualizer.select(
    schema_name="macroeconomics", table_name="gold_price"
)
silver_gold_price = silver_gold_price.astype(
    {
        **{col: "float" for col in silver_gold_price.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
silver_gold_price

# %%
std_silver_gold_price_fig = my_visualizer.plot_lines_bars_chart(
    silver_gold_price,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["volume"],
    title="Gold Price close",
    y_line_axis_title="USD",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="gold_price",
    marker=None,
)
std_silver_gold_price_fig

# %% [markdown]
# ### silver_oil_price

# %%
silver_oil_price = my_visualizer.select(
    schema_name="macroeconomics", table_name="oil_price"
)
silver_oil_price = silver_oil_price.astype(
    {
        **{col: "float" for col in silver_oil_price.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
silver_oil_price

# %%
std_silver_oil_price_fig = my_visualizer.plot_lines_bars_chart(
    silver_oil_price,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["volume"],
    title="Oil Price close",
    y_line_axis_title="USD",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="oil_price",
    marker=None,
)
std_silver_oil_price_fig

# %% [markdown]
# ### silver_dow_jones

# %%
silver_dow_jones = my_visualizer.select(
    schema_name="macroeconomics", table_name="dow_jones"
)
silver_dow_jones = silver_dow_jones.astype(
    {
        **{col: "float" for col in silver_dow_jones.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
silver_dow_jones

# %%
std_silver_dow_jones_fig = my_visualizer.plot_lines_bars_chart(
    silver_dow_jones,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["volume"],
    title="Dow Jones close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="dow_jones",
    marker=None,
)
std_silver_dow_jones_fig

# %% [markdown]
# ### silver_nyse_composite

# %%
silver_nyse_composite = my_visualizer.select(
    schema_name="macroeconomics", table_name="nyse_composite"
)
silver_nyse_composite = silver_nyse_composite.astype(
    {
        **{col: "float" for col in silver_nyse_composite.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
silver_nyse_composite

# %%
std_silver_nyse_composite_fig = my_visualizer.plot_lines_bars_chart(
    silver_nyse_composite,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["volume"],
    title="Nyse Composite close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="nyse_composite",
    marker=None,
)
std_silver_nyse_composite_fig

# %% [markdown]
# ### silver_snp_500

# %%
silver_snp_500 = my_visualizer.select(
    schema_name="macroeconomics", table_name="snp_500"
)
silver_snp_500 = silver_snp_500.astype(
    {
        **{col: "float" for col in silver_snp_500.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
silver_snp_500

# %%
std_silver_snp_500_fig = my_visualizer.plot_lines_bars_chart(
    silver_snp_500,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["volume"],
    title="SNP 500 close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="snp_500",
    marker=None,
)
std_silver_snp_500_fig

# %% [markdown]
# ### silver_nasdaq_composite

# %%
silver_nasdaq_composite = my_visualizer.select(
    schema_name="macroeconomics", table_name="nasdaq_composite"
)
silver_nasdaq_composite = silver_nasdaq_composite.astype(
    {
        **{col: "float" for col in silver_nasdaq_composite.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
silver_nasdaq_composite

# %%
std_silver_nasdaq_composite_fig = my_visualizer.plot_lines_bars_chart(
    silver_nasdaq_composite,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["volume"],
    title="Nasdaq Composite close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="nasdaq_composite",
    marker=None,
)
std_silver_nasdaq_composite_fig

# %% [markdown]
# ### silver_nasdaq_100

# %%
silver_nasdaq_100 = my_visualizer.select(
    schema_name="macroeconomics", table_name="nasdaq_100"
)
silver_nasdaq_100 = silver_nasdaq_100.astype(
    {
        **{col: "float" for col in silver_nasdaq_100.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
silver_nasdaq_100

# %%
std_silver_nasdaq_100_fig = my_visualizer.plot_lines_bars_chart(
    silver_nasdaq_100,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["volume"],
    title="Nasdaq 100 close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="nasdaq_100",
    marker=None,
)
std_silver_nasdaq_100_fig

# %% [markdown]
# ## STOCK MARKET

# %%
my_visualizer.connect_to_database(database_name=os.getenv("SILVER_POSTGRES_DATABASE"))
my_visualizer.set_chart_dir(CHARTS_DIR_STOCK_MARKET)

# %% [markdown]
# ### silver_vn_index

# %%
silver_vn_index = my_visualizer.select(
    schema_name="stock_market", table_name="vn_index"
)
silver_vn_index = silver_vn_index.astype(
    {
        **{col: "float" for col in silver_vn_index.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
silver_vn_index

# %%
std_silver_vn_index_fig = my_visualizer.plot_lines_bars_chart(
    silver_vn_index,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["volume"],
    title="VN Index close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="vn_index",
    marker=None,
)
std_silver_vn_index_fig

# %% [markdown]
# ### silver_hnx_index

# %%
silver_hnx_index = my_visualizer.select(
    schema_name="stock_market", table_name="hnx_index"
)
silver_hnx_index = silver_hnx_index.astype(
    {
        **{col: "float" for col in silver_hnx_index.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
silver_hnx_index

# %%
std_silver_hnx_index_fig = my_visualizer.plot_lines_bars_chart(
    silver_hnx_index,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["volume"],
    title="HNX Index close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="hnx_index",
    marker=None,
)
std_silver_hnx_index_fig

# %% [markdown]
# ### silver_vn_30_index

# %%
silver_vn_30_index = my_visualizer.select(
    schema_name="stock_market", table_name="vn_30_index"
)
silver_vn_30_index = silver_vn_30_index.astype(
    {
        **{col: "float" for col in silver_vn_30_index.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
silver_vn_30_index

# %%
std_silver_vn_30_index_fig = my_visualizer.plot_lines_bars_chart(
    silver_vn_30_index,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["matched_volume"],
    title="VN 30 Index close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="vn_30_index",
    marker=None,
)
std_silver_vn_30_index_fig

# %% [markdown]
# ### silver_vn_100_index

# %%
silver_vn_100_index = my_visualizer.select(
    schema_name="stock_market", table_name="vn_100_index"
)
silver_vn_100_index = silver_vn_100_index.astype(
    {
        **{col: "float" for col in silver_vn_100_index.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
silver_vn_100_index

# %%
std_silver_vn_100_index_fig = my_visualizer.plot_lines_bars_chart(
    silver_vn_100_index,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["matched_volume"],
    title="VN 100 Index close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="vn_100_index",
    marker=None,
)
std_silver_vn_100_index_fig

# %% [markdown]
# ### silver_hnx_30_index

# %%
silver_hnx_30_index = my_visualizer.select(
    schema_name="stock_market", table_name="hnx_30_index"
)
silver_hnx_30_index = silver_hnx_30_index.astype(
    {
        **{col: "float" for col in silver_hnx_30_index.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
silver_hnx_30_index

# %%
std_silver_hnx_30_index_fig = my_visualizer.plot_lines_bars_chart(
    silver_hnx_30_index,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["matched_volume"],
    title="HNX 30 Index close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="hnx_30_index",
    marker=None,
)
std_silver_hnx_30_index_fig

# %% [markdown]
# ### silver_upcom_index

# %%
silver_upcom_index = my_visualizer.select(
    schema_name="stock_market", table_name="upcom_index"
)
silver_upcom_index = silver_upcom_index.astype(
    {
        **{col: "float" for col in silver_upcom_index.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
silver_upcom_index

# %%
std_silver_upcom_index_fig = my_visualizer.plot_lines_bars_chart(
    silver_upcom_index,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["matched_volume"],
    title="UPCOM Index close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="upcom_index",
    marker=None,
)
std_silver_upcom_index_fig

# %% [markdown]
# ## ENTERPRISE

# %%
my_visualizer.connect_to_database(database_name=os.getenv("BRONZE_POSTGRES_DATABASE"))
my_visualizer.set_chart_dir(CHARTS_DIR_ENTERPRISE)

# %%
def get_code_table_and_plot(code: str):
    code = code.upper()

    if not code:
        print("Need to specify enterprise code before plotting.")
    else:
        silver_enterprise = my_visualizer.select(
            schema_name="enterprise",
            table_name="daily_price",
            conditions=[
                Condition(
                    column=Table.DAILY_PRICE.Column.CODE.value,
                    operator=SqlOperator.EQUAL_TO,
                    value=code,
                    data_type=DataType.VARCHAR,
                )
            ],
        )

        if len(silver_enterprise) == 0:
            print(f"No data found for code: {code}.")
            return

        silver_enterprise = silver_enterprise.astype(
            {
                Table.DAILY_PRICE.Column.DATE.value: "datetime64[ns]",
                Table.DAILY_PRICE.Column.CODE.value: "string",
                Table.DAILY_PRICE.Column.MARKET_ID.value: "int",
                **{
                    col: "float"
                    for col in silver_enterprise.columns
                    if col
                    not in [
                        Table.DAILY_PRICE.Column.DATE.value,
                        Table.DAILY_PRICE.Column.CODE.value,
                        Table.DAILY_PRICE.Column.MARKET_ID.value,
                    ]
                },
            }
        )

        display(silver_enterprise)

        silver_enterprise_fig = my_visualizer.plot_lines_bars_chart(
            silver_enterprise,
            x_column="date",
            y_line_columns=["close"],
            y_bar_columns=["volume"],
            title=f"{code} close",
            y_line_axis_title="Point",
            y_bar_axis_title="",
            y_unit="",
            prefix_figure_name=f"{code.lower()}",
            marker=None,
        )
        
        display(silver_enterprise_fig)

# %% [markdown]
# ### ACB

# %%
code = "ACB"
get_code_table_and_plot(code)
# Out:
#            date code  market_id     open     high      low    close  \
# 0    2020-12-25  ACB          1  10.2402  10.5028  10.2027  10.4865
# 1    2020-12-24  ACB          1  10.5403  10.6153   9.9402  10.2426
# 2    2020-12-23  ACB          1  10.8029  10.8216  10.5028  10.5428
# 3    2021-12-31  ACB          1  15.9426  16.2005  15.9426  16.1800
# 4    2021-12-30  ACB          1  15.8019  15.9426  15.7082  15.8986
# ...         ...  ...        ...      ...      ...      ...      ...
# 1156 2025-01-23  ACB          1  20.8040  21.2217  20.8040  21.1382
# 1157 2025-01-16  ACB          1  20.7622  20.9293  20.6369  20.7622
# 1158 2025-01-15  ACB          1  20.7622  20.8457  20.5951  20.8040
# 1159 2025-01-09  ACB          1  20.8432  20.8850  20.7597  20.8457
# 1160 2025-01-08  ACB          1  20.8875  20.8875  20.7204  20.8875
#
#           volume
# 0      9194080.0
# 1     15831250.0
# 2     11216860.0
# 3      5651800.0
# 4      1819600.0
# ...          ...
# 1156   8896800.0
# 1157   5005500.0
# 1158   7425100.0
# 1159   3839200.0
# 1160   4088100.0
#
# [1161 rows x 8 columns]

# %% [markdown]
# ### BCM

# %%
code = "BCM"
get_code_table_and_plot(code)
# Out:
#            date code  market_id     open     high      low    close    volume
# 0    2020-12-25  BCM          1  40.2475  40.5316  38.9691  40.1543  113980.0
# 1    2020-12-24  BCM          1  40.9104  42.1415  38.3535  40.2491   73930.0
# 2    2020-12-23  BCM          1  38.6376  41.4313  38.5429  40.5332  415660.0
# 3    2021-12-22  BCM          1  63.7204  66.5160  63.3348  65.8430  740200.0
# 4    2021-12-21  BCM          1  63.2384  67.1908  63.1420  65.4574  696100.0
# ...         ...  ...        ...      ...      ...      ...      ...       ...
# 1156 2025-01-23  BCM          1  67.4000  68.0000  67.3000  68.0000  177600.0
# 1157 2025-01-16  BCM          1  70.0000  70.0000  68.4000  69.3000  243000.0
# 1158 2025-01-15  BCM          1  70.9000  70.9000  69.2000  69.2000  182600.0
# 1159 2025-01-09  BCM          1  72.8000  73.3000  71.5000  71.5000  292500.0
# 1160 2025-01-08  BCM          1  73.1000  73.7000  72.5000  72.6000  362400.0
#
# [1161 rows x 8 columns]

# %% [markdown]
# ### BID

# %%
code = "BID"
get_code_table_and_plot(code)
# Out:
#            date code  market_id     open     high      low    close     volume
# 0    2014-12-26  BID          1   5.9553   5.9553   5.8637   5.8646    84170.0
# 1    2014-12-25  BID          1   5.9095   5.9553   5.8637   5.9562   102730.0
# 2    2014-12-24  BID          1   5.9553   6.0011   5.9095   5.9562    92620.0
# 3    2014-12-23  BID          1   6.0011   6.0469   5.9553   6.0020   146840.0
# 4    2014-12-22  BID          1   5.9095   6.0469   5.9095   6.0020   364470.0
# ...         ...  ...        ...      ...      ...      ...      ...        ...
# 2870 2025-01-17  BID          1  39.2000  39.5000  39.0500  39.5000  1572900.0
# 2871 2025-01-13  BID          1  39.1000  39.3500  38.4000  39.3000  2461400.0
# 2872 2025-01-10  BID          1  39.9000  39.9000  39.1000  39.1000  3114500.0
# 2873 2025-01-03  BID          1  38.2000  38.6000  38.2000  38.2000  3698500.0
# 2874 2025-01-02  BID          1  38.2000  38.6500  37.9000  38.2000  3160500.0
#
# [2875 rows x 8 columns]

# %% [markdown]
# ### CTG

# %%
code = "CTG"
get_code_table_and_plot(code)
# Out:
#            date code  market_id     open     high      low    close     volume
# 0    2009-12-01  CTG          1   8.0491   8.0491   8.0491   8.0496    54280.0
# 1    2009-11-30  CTG          1   7.6618   7.6895   7.6065   7.6900   367620.0
# 2    2009-11-27  CTG          1   6.7214   7.3299   6.7214   7.3304   257220.0
# 3    2009-11-26  CTG          1   7.0256   7.1916   6.9980   6.9984   505360.0
# 4    2009-11-25  CTG          1   7.4682   7.5235   7.3576   7.3580   239410.0
# ...         ...  ...        ...      ...      ...      ...      ...        ...
# 4005 2025-01-16  CTG          1  36.8500  37.2000  36.4000  36.8000  6641100.0
# 4006 2025-01-15  CTG          1  37.0000  37.1000  36.6000  36.7500  4980700.0
# 4007 2025-01-14  CTG          1  37.4500  37.9000  36.9000  36.9500  3716700.0
# 4008 2025-01-07  CTG          1  37.5000  38.0000  37.1500  37.4500  6267400.0
# 4009 2025-01-06  CTG          1  37.2500  37.6500  37.0500  37.2000  6045300.0
#
# [4010 rows x 8 columns]

# %% [markdown]
# ### DGC

# %%
code = "DGC"
get_code_table_and_plot(code)
# Out:
#            date code  market_id      open      high       low     close  \
# 0    2020-12-31  DGC          1   18.6112   18.7203   18.3931   18.5786
# 1    2020-12-30  DGC          1   18.6839   19.0474   18.6476   18.6513
# 2    2020-12-29  DGC          1   17.5571   18.6839   17.4480   18.6877
# 3    2020-12-17  DGC          1   17.3571   17.5934   17.3208   17.4515
# 4    2020-12-16  DGC          1   17.5025   17.7752   17.4662   17.6152
# ...         ...  ...        ...       ...       ...       ...       ...
# 1156 2025-01-21  DGC          1  109.6000  110.2000  108.9000  109.0000
# 1157 2025-01-15  DGC          1  109.1000  109.8000  108.8000  109.3000
# 1158 2025-01-14  DGC          1  110.5000  110.5000  108.8000  108.9000
# 1159 2025-01-07  DGC          1  112.5000  113.3000  112.1000  112.3000
# 1160 2025-01-06  DGC          1  115.1000  116.0000  112.1000  112.5000
#
#          volume
# 0      419350.0
# 1      829470.0
# 2     3283780.0
# 3      640490.0
# 4      583840.0
# ...         ...
# 1156   965100.0
# 1157   772900.0
# 1158   685300.0
# 1159  1040800.0
# 1160  2604800.0
#
# [1161 rows x 8 columns]

# %% [markdown]
# ### FPT

# %%
code = "FPT"
get_code_table_and_plot(code)
# Out:
#            date code  market_id      open      high       low     close  \
# 0    2007-12-20  FPT          1    8.5790    8.5790    8.3925    8.4056
# 1    2007-12-19  FPT          1    8.3552    8.5790    8.3552    8.5924
# 2    2007-12-18  FPT          1    8.5044    8.5044    8.2806    8.3682
# 3    2007-12-17  FPT          1    8.3179    8.3179    8.2433    8.2561
# 4    2007-12-14  FPT          1    8.2433    8.3925    8.2433    8.2935
# ...         ...  ...        ...       ...       ...       ...       ...
# 4641 2025-02-04  FPT          1  125.8812  126.7434  125.2777  126.0549
# 4642 2025-01-20  FPT          1  128.4678  129.6749  127.7780  129.3313
# 4643 2025-01-13  FPT          1  125.9674  128.0367  124.7603  127.2620
# 4644 2025-01-10  FPT          1  128.2954  128.5540  126.9158  127.0033
# 4645 2025-01-03  FPT          1  130.4509  130.4509  128.4678  128.4691
#
#          volume
# 0      236310.0
# 1      353490.0
# 2      264940.0
# 3      203240.0
# 4      204820.0
# ...         ...
# 4641  5467700.0
# 4642  2217700.0
# 4643  3488800.0
# 4644  2524700.0
# 4645  4336100.0
#
# [4646 rows x 8 columns]

# %% [markdown]
# ### GAS

# %%
code = "GAS"
get_code_table_and_plot(code)
# Out:
#            date code  market_id     open     high      low    close    volume
# 0    2012-12-20  GAS          1  17.6606  17.6606  17.4790  17.4794   77850.0
# 1    2012-12-19  GAS          1  17.6606  17.6606  17.5244  17.6156   35120.0
# 2    2012-12-18  GAS          1  17.6152  17.6606  17.5698  17.6610  194580.0
# 3    2012-12-17  GAS          1  17.5244  17.7060  17.4790  17.6156  112540.0
# 4    2012-12-14  GAS          1  17.7060  17.7060  17.5244  17.5248   58880.0
# ...         ...  ...        ...      ...      ...      ...      ...       ...
# 3295 2025-01-13  GAS          1  66.7000  67.1000  66.2000  66.4000  542400.0
# 3296 2025-01-10  GAS          1  67.0000  67.5000  66.7000  66.7000  422600.0
# 3297 2025-01-07  GAS          1  67.6000  67.9000  66.9000  67.0000  683200.0
# 3298 2025-01-06  GAS          1  68.0000  68.2000  67.3000  67.5000  673300.0
# 3299 2025-01-02  GAS          1  68.3000  68.5000  68.0000  68.1000  427800.0
#
# [3300 rows x 8 columns]

# %% [markdown]
# ### GVR

# %%
code = "GVR"
get_code_table_and_plot(code)
# Out:
#            date code  market_id     open     high      low    close     volume
# 0    2020-12-17  GVR          1  21.4567  22.9960  21.2701  22.3915  4909320.0
# 1    2020-12-16  GVR          1  21.6899  22.1564  21.5500  21.7384  3528920.0
# 2    2020-12-15  GVR          1  20.9903  22.1564  20.6637  21.6918  4905500.0
# 3    2020-12-14  GVR          1  19.5909  20.8503  19.5909  20.8521  5534040.0
# 4    2020-12-02  GVR          1  17.4452  17.8184  17.2587  17.5400  3181530.0
# ...         ...  ...        ...      ...      ...      ...      ...        ...
# 1345 2025-02-07  GVR          1  29.2000  29.9500  29.1000  29.4000  2297000.0
# 1346 2025-01-22  GVR          1  28.4500  28.6000  28.0000  28.0000  1362800.0
# 1347 2025-01-21  GVR          1  28.8500  29.0000  28.4000  28.4000  1030100.0
# 1348 2025-01-15  GVR          1  28.1500  28.2500  27.8500  28.2000   680400.0
# 1349 2025-01-14  GVR          1  28.1000  28.3500  27.7500  27.7500   901200.0
#
# [1350 rows x 8 columns]

# %% [markdown]
# ### HDB

# %%
code = "HDB"
get_code_table_and_plot(code)
# Out:
#            date code  market_id     open     high      low    close  \
# 0    2018-12-06  HDB          1   7.9903   7.9903   7.7086   7.8116
# 1    2018-12-05  HDB          1   7.9391   8.1184   7.8623   7.9908
# 2    2018-12-04  HDB          1   8.2464   8.2592   7.9775   8.1189
# 3    2018-12-03  HDB          1   7.7342   8.2080   7.7214   8.1957
# 4    2018-11-30  HDB          1   7.7470   7.7598   7.5934   7.6835
# ...         ...  ...        ...      ...      ...      ...      ...
# 1888 2025-01-21  HDB          1  23.2500  23.3500  22.3500  22.6500
# 1889 2025-01-15  HDB          1  21.1500  21.6500  21.1500  21.6500
# 1890 2025-01-14  HDB          1  21.7500  21.8000  21.1000  21.1500
# 1891 2025-01-07  HDB          1  24.5500  24.5500  24.1000  24.2500
# 1892 2025-01-06  HDB          1  24.4500  24.6000  24.1500  24.5000
#
#           volume
# 0      1717980.0
# 1      1881730.0
# 2      2077930.0
# 3      2937000.0
# 4      1497920.0
# ...          ...
# 1888  13007200.0
# 1889   7970900.0
# 1890  12557900.0
# 1891   8626500.0
# 1892   6407500.0
#
# [1893 rows x 8 columns]

# %% [markdown]
# ### HPG

# %%
code = "HPG"
get_code_table_and_plot(code)
# Out:
#            date code  market_id     open     high      low    close  \
# 0    2007-12-28  HPG          1   1.4946   1.5105   1.4946   1.5138
# 1    2007-12-27  HPG          1   1.4946   1.5105   1.4946   1.4979
# 2    2007-12-26  HPG          1   1.4469   1.4946   1.4469   1.4979
# 3    2007-12-25  HPG          1   1.5105   1.5185   1.4946   1.4979
# 4    2007-12-24  HPG          1   1.5185   1.5185   1.4946   1.5138
# ...         ...  ...        ...      ...      ...      ...      ...
# 4412 2025-01-21  HPG          1  22.1658  22.1658  21.8325  21.9158
# 4413 2025-01-13  HPG          1  21.2908  21.7075  21.2075  21.5825
# 4414 2025-01-10  HPG          1  21.6632  21.7465  21.2883  21.2908
# 4415 2025-01-06  HPG          1  22.1658  22.2491  21.7075  21.7075
# 4416 2025-01-03  HPG          1  22.4158  22.4991  22.1658  22.1658
#
#           volume
# 0        81580.0
# 1        86100.0
# 2       157680.0
# 3       109460.0
# 4       166920.0
# ...          ...
# 4412  10421500.0
# 4413  13576000.0
# 4414  14273600.0
# 4415  15250500.0
# 4416  13200100.0
#
# [4417 rows x 8 columns]

# %% [markdown]
# ### LPB

# %%
code = "LPB"
get_code_table_and_plot(code)
# Out:
#            date code  market_id     open     high      low    close  \
# 0    2017-11-13  LPB          1   3.7951   3.7951   3.7082   3.7670
# 1    2017-11-10  LPB          1   3.7951   3.8530   3.7661   3.7670
# 2    2017-11-09  LPB          1   3.7371   3.8820   3.7371   3.8249
# 3    2017-10-23  LPB          1   3.7661   3.7661   3.6502   3.6511
# 4    2017-10-20  LPB          1   3.7951   3.7951   3.7082   3.7670
# ...         ...  ...        ...      ...      ...      ...      ...
# 1209 2025-01-24  LPB          1  35.3500  36.1000  35.2500  35.8500
# 1210 2025-01-23  LPB          1  33.6000  35.6000  33.6000  35.3000
# 1211 2025-01-15  LPB          1  31.0500  31.1500  30.7500  31.0000
# 1212 2025-01-14  LPB          1  30.7000  31.3500  30.7000  30.8500
# 1213 2025-01-07  LPB          1  30.3500  31.0000  30.2500  30.7000
#
#           volume
# 0      1658710.0
# 1      2162571.0
# 2      2027331.0
# 3       989690.0
# 4       716310.0
# ...          ...
# 1209  14663700.0
# 1210   5486300.0
# 1211   1015700.0
# 1212   1098100.0
# 1213   1883800.0
#
# [1214 rows x 8 columns]

# %% [markdown]
# ### MBB

# %%
code = "MBB"
get_code_table_and_plot(code)
# Out:
#            date code  market_id     open     high      low    close  \
# 0    2011-12-30  MBB          1   1.9645   2.0009   1.9645   1.9654
# 1    2011-12-29  MBB          1   1.9463   1.9645   1.9281   1.9654
# 2    2011-12-28  MBB          1   1.9100   1.9463   1.8918   1.9290
# 3    2011-12-27  MBB          1   1.9827   1.9827   1.9100   1.9108
# 4    2011-12-26  MBB          1   2.0191   2.0373   1.9463   2.0018
# ...         ...  ...        ...      ...      ...      ...      ...
# 3432 2025-02-06  MBB          1  22.5500  22.9500  22.5500  22.6000
# 3433 2025-01-22  MBB          1  21.9500  21.9500  21.7500  21.8000
# 3434 2025-01-15  MBB          1  21.4500  21.5000  21.3000  21.3500
# 3435 2025-01-14  MBB          1  21.4000  21.5000  21.1500  21.3000
# 3436 2025-01-07  MBB          1  21.7000  21.7000  21.2000  21.6500
#
#           volume
# 0       510030.0
# 1      1019180.0
# 2      1741660.0
# 3      1727600.0
# 4      1035190.0
# ...          ...
# 3432  10756200.0
# 3433   5961800.0
# 3434   4726200.0
# 3435   5736000.0
# 3436  11801300.0
#
# [3437 rows x 8 columns]

# %% [markdown]
# ### MSN

# %%
code = "MSN"
get_code_table_and_plot(code)
# Out:
#            date code  market_id     open     high      low    close     volume
# 0    2009-12-17  MSN          1  18.7866  18.7866  17.9116  18.3761   276570.0
# 1    2009-12-16  MSN          1  18.6836  18.6836  17.7572  18.6850   411340.0
# 2    2009-12-15  MSN          1  18.0145  18.6836  17.7572  18.6850   256900.0
# 3    2009-12-14  MSN          1  17.0366  17.8601  17.0366  17.8614   121610.0
# 4    2009-12-11  MSN          1  17.1910  17.4998  17.0366  17.0378   164380.0
# ...         ...  ...        ...      ...      ...      ...      ...        ...
# 3927 2025-02-06  MSN          1  67.5000  68.1000  67.2000  67.4000  2799000.0
# 3928 2025-01-22  MSN          1  65.8000  66.2000  65.2000  65.2000  2338800.0
# 3929 2025-01-13  MSN          1  65.4000  65.5000  64.4000  65.0000  3672000.0
# 3930 2025-01-10  MSN          1  67.3000  67.4000  65.5000  65.5000  2905200.0
# 3931 2025-01-07  MSN          1  67.3000  68.2000  66.5000  66.8000  5735600.0
#
# [3932 rows x 8 columns]

# %% [markdown]
# ### PLX

# %%
code = "PLX"
get_code_table_and_plot(code)
# Out:
#            date code  market_id     open     high      low    close     volume
# 0    2017-12-29  PLX          1  54.2642  56.0975  53.5309  55.0022  1458000.0
# 1    2017-12-28  PLX          1  53.5309  54.6309  52.9443  54.2688  1381580.0
# 2    2017-12-27  PLX          1  54.2642  54.4842  52.7976  53.6821  1163520.0
# 3    2017-12-08  PLX          1  47.4445  49.0578  46.6379  48.3286   533660.0
# 4    2017-12-07  PLX          1  48.3978  48.7645  46.8579  47.2285   661200.0
# ...         ...  ...        ...      ...      ...      ...      ...        ...
# 2070 2025-01-21  PLX          1  38.6556  39.0427  38.1234  38.5589   873000.0
# 2071 2025-01-20  PLX          1  38.7040  38.7040  38.4621  38.5589   402200.0
# 2072 2025-01-09  PLX          1  37.2526  38.0267  37.0591  37.7364  1723700.0
# 2073 2025-01-08  PLX          1  36.7204  37.0591  36.0915  37.0591   914900.0
# 2074 2025-01-02  PLX          1  36.7166  37.1520  36.7166  36.9139   546600.0
#
# [2075 rows x 8 columns]

# %% [markdown]
# ### SAB

# %%
code = "SAB"
get_code_table_and_plot(code)
# Out:
#            date code  market_id     open     high      low    close    volume
# 0    2016-12-28  SAB          1  75.8041  75.8041  74.7797  75.4800   28530.0
# 1    2016-12-27  SAB          1  74.7418  75.8041  73.2621  75.1385   69880.0
# 2    2016-12-26  SAB          1  75.1212  75.1212  72.0860  74.7590  169870.0
# 3    2016-12-23  SAB          1  75.8611  75.8611  73.6563  74.7590   54810.0
# 4    2016-12-22  SAB          1  78.4396  78.4396  75.8611  75.8804   52460.0
# ...         ...  ...        ...      ...      ...      ...      ...       ...
# 2161 2025-01-22  SAB          1  50.7037  50.8919  50.4215  50.5156  201200.0
# 2162 2025-01-15  SAB          1  51.7385  51.7385  51.1741  51.7385  331800.0
# 2163 2025-01-14  SAB          1  50.7978  51.2682  50.7978  51.2682  329200.0
# 2164 2025-01-08  SAB          1  50.5156  50.7037  50.4215  50.5156  496600.0
# 2165 2025-01-07  SAB          1  50.5156  50.9859  50.5156  50.5156  403600.0
#
# [2166 rows x 8 columns]

# %% [markdown]
# ### SHB

# %%
code = "SHB"
get_code_table_and_plot(code)
# Out:
#           date code  market_id     open     high      low    close      volume
# 0   2021-12-29  SHB          1  13.3262  13.3875  13.1731  13.1735   6901500.0
# 1   2021-12-28  SHB          1  13.2343  13.3262  13.1118  13.1735  10031000.0
# 2   2021-12-27  SHB          1  13.4794  13.6938  13.1731  13.1735   9167500.0
# 3   2021-12-24  SHB          1  12.3765  13.1731  12.3765  13.1735  10433200.0
# 4   2021-12-23  SHB          1  12.7442  12.8361  12.2540  12.3157  12232100.0
# ..         ...  ...        ...      ...      ...      ...      ...         ...
# 952 2025-01-20  SHB          1   8.8536   8.8970   8.8102   8.8538   5468300.0
# 953 2025-01-15  SHB          1   8.8102   8.8536   8.7668   8.8104   5030800.0
# 954 2025-01-14  SHB          1   8.8102   8.8536   8.7668   8.7670   9053800.0
# 955 2025-01-08  SHB          1   8.8970   8.9404   8.8536   8.9406   3780900.0
# 956 2025-01-07  SHB          1   8.9404   8.9838   8.8970   8.8972   7884900.0
#
# [957 rows x 8 columns]

# %% [markdown]
# ### SSB

# %%
code = "SSB"
get_code_table_and_plot(code)
# Out:
#            date code  market_id     open     high      low    close     volume
# 0    2021-12-31  SSB          1  25.6110  26.1814  25.5539  26.0124  2256900.0
# 1    2021-12-30  SSB          1  25.7821  25.7821  25.0976  25.6986  2310800.0
# 2    2021-12-16  SSB          1  22.6164  22.6164  22.3026  22.6182  1833700.0
# 3    2021-12-15  SSB          1  22.6449  22.6734  22.3312  22.6752  2063400.0
# 4    2021-12-14  SSB          1  22.6449  22.6449  22.4167  22.6182  1789100.0
# ...         ...  ...        ...      ...      ...      ...      ...        ...
# 1090 2025-01-20  SSB          1  17.6500  18.0000  17.6500  18.0000  1936100.0
# 1091 2025-01-13  SSB          1  17.0500  17.6000  17.0500  17.5000  2534200.0
# 1092 2025-01-10  SSB          1  17.0500  17.4000  16.9500  17.4000  2155900.0
# 1093 2025-01-06  SSB          1  16.6500  16.7500  16.6000  16.7500  1709400.0
# 1094 2025-01-03  SSB          1  16.7500  16.8000  16.5000  16.8000  1760500.0
#
# [1095 rows x 8 columns]

# %% [markdown]
# ### SSI

# %%
code = "SSI"
get_code_table_and_plot(code)
# Out:
#            date code  market_id     open     high      low    close  \
# 0    2006-12-29  SSI          1   6.1204   6.6768   6.1204   6.6397
# 1    2006-12-28  SSI          1   7.1048   7.1476   6.4200   6.7254
# 2    2006-12-27  SSI          1   6.8480   7.2418   6.8480   6.8539
# 3    2006-12-26  SSI          1   5.8636   6.9336   5.8636   6.8110
# 4    2006-12-25  SSI          1   6.5099   6.5099   6.5099   6.5155
# ...         ...  ...        ...      ...      ...      ...      ...
# 4631 2025-01-23  SSI          1  24.4500  25.2500  24.4500  25.1500
# 4632 2025-01-17  SSI          1  24.4000  24.6000  24.2500  24.5500
# 4633 2025-01-16  SSI          1  24.4000  25.2000  24.3000  24.4000
# 4634 2025-01-09  SSI          1  24.7000  24.9500  24.4000  24.4000
# 4635 2025-01-02  SSI          1  26.0500  26.3500  25.9000  25.9500
#
#           volume
# 0       235500.0
# 1       162400.0
# 2       376200.0
# 3       435500.0
# 4       289000.0
# ...          ...
# 4631  18477200.0
# 4632   7043000.0
# 4633  18541100.0
# 4634   8907600.0
# 4635   8938200.0
#
# [4636 rows x 8 columns]

# %% [markdown]
# ### STB

# %%
code = "STB"
get_code_table_and_plot(code)
# Out:
#            date code  market_id     open     high      low    close  \
# 0    2006-11-14  STB          1   9.9613  10.2063   9.9613  10.2085
# 1    2006-11-13  STB          1   9.8797   9.9613   9.8797   9.9635
# 2    2006-11-10  STB          1   9.9613   9.9613   9.8797   9.8819
# 3    2006-11-09  STB          1   9.9613   9.9613   9.9613   9.9635
# 4    2006-11-08  STB          1   9.9613   9.9613   9.9613   9.9635
# ...         ...  ...        ...      ...      ...      ...      ...
# 4751 2025-01-23  STB          1  36.6500  37.5500  36.4500  37.0000
# 4752 2025-01-15  STB          1  35.4000  35.4500  35.1000  35.1000
# 4753 2025-01-14  STB          1  35.3000  35.4000  34.9000  35.4000
# 4754 2025-01-08  STB          1  36.7000  36.9000  36.5000  36.7000
# 4755 2025-01-07  STB          1  36.4500  37.0500  36.3500  36.9000
#
#           volume
# 0       275600.0
# 1       128790.0
# 2       187530.0
# 3       157120.0
# 4       150920.0
# ...          ...
# 4751  10155400.0
# 4752   6977700.0
# 4753   4412700.0
# 4754   6074100.0
# 4755   7377300.0
#
# [4756 rows x 8 columns]

# %% [markdown]
# ### TCB

# %%
code = "TCB"
get_code_table_and_plot(code)
# Out:
#            date code  market_id     open     high      low    close     volume
# 0    2018-12-28  TCB          1  12.7529  12.7529  12.5347  12.5347  1849440.0
# 1    2018-12-27  TCB          1  12.8472  12.9199  12.6290  12.6316  2093990.0
# 2    2018-12-26  TCB          1  12.7529  12.8983  12.5832  12.6074  1965260.0
# 3    2018-12-25  TCB          1  12.7044  12.8741  12.5104  12.8014  2408040.0
# 4    2018-12-24  TCB          1  13.2350  13.2835  13.0411  13.0438  1250440.0
# ...         ...  ...        ...      ...      ...      ...      ...        ...
# 1793 2025-01-21  TCB          1  24.4000  24.5000  24.1500  24.2000  8127000.0
# 1794 2025-01-20  TCB          1  24.4000  24.5000  24.2500  24.4000  5183100.0
# 1795 2025-01-13  TCB          1  23.2000  23.8000  23.1500  23.8000  7939900.0
# 1796 2025-01-10  TCB          1  24.0000  24.0000  23.4000  23.4000  6232100.0
# 1797 2025-01-02  TCB          1  24.6500  24.7000  24.3000  24.3500  7834500.0
#
# [1798 rows x 8 columns]

# %% [markdown]
# ### TPB

# %%
code = "TPB"
get_code_table_and_plot(code)
# Out:
#            date code  market_id     open     high      low    close     volume
# 0    2018-12-28  TPB          1   6.3640   6.4595   6.2367   6.3490   162260.0
# 1    2018-12-27  TPB          1   6.5231   6.5231   6.3481   6.3490   183410.0
# 2    2018-12-26  TPB          1   6.1413   6.3322   6.1413   6.2376   219770.0
# 3    2018-12-25  TPB          1   6.3640   6.3640   6.0458   6.1421   205270.0
# 4    2018-12-24  TPB          1   6.4276   6.4276   6.3640   6.3808   175850.0
# ...         ...  ...        ...      ...      ...      ...      ...        ...
# 1820 2025-01-17  TPB          1  16.0500  16.2000  16.0000  16.1500  4337800.0
# 1821 2025-01-16  TPB          1  16.1000  16.2000  16.0000  16.0500  6277100.0
# 1822 2025-01-10  TPB          1  16.1000  16.2500  15.8500  15.9000  8367400.0
# 1823 2025-01-09  TPB          1  16.3000  16.3000  16.0500  16.1000  4448700.0
# 1824 2025-01-02  TPB          1  16.7000  16.7000  16.4000  16.5500  5149600.0
#
# [1825 rows x 8 columns]

# %% [markdown]
# ### VCB

# %%
code = "VCB"
get_code_table_and_plot(code)
# Out:
#            date code  market_id     open     high      low    close     volume
# 0    2009-12-18  VCB          1   6.8985   7.0825   6.8985   7.0845   722180.0
# 1    2009-12-17  VCB          1   6.5612   6.8985   6.4386   6.7471   462480.0
# 2    2009-12-16  VCB          1   6.8832   6.8985   6.5919   6.5938   889550.0
# 3    2009-12-15  VCB          1   6.5612   6.8832   6.5153   6.8851   976610.0
# 4    2009-12-14  VCB          1   6.5612   6.5612   6.4079   6.5631   459670.0
# ...         ...  ...        ...      ...      ...      ...      ...        ...
# 4018 2025-01-16  VCB          1  61.4627  62.3322  61.3958  62.0070  2460200.0
# 4019 2025-01-10  VCB          1  61.4719  61.8064  61.1375  61.1375  1112500.0
# 4020 2025-01-09  VCB          1  61.5296  61.6634  61.3290  61.4719   738300.0
# 4021 2025-01-06  VCB          1  61.5296  62.4659  61.4627  62.1408  1936800.0
# 4022 2025-01-03  VCB          1  61.4719  61.8064  61.4719  61.5388  1402200.0
#
# [4023 rows x 8 columns]
# d:\DATA SCIENCE\GIT\master-thesis\src\visualizer\visualizer.py:263: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(figsize=(14, 10))

# %% [markdown]
# ### VHM

# %%
code = "VHM"
get_code_table_and_plot(code)
# Out:
#            date code  market_id     open     high      low    close     volume
# 0    2018-12-28  VHM          1  53.7264  54.2360  53.4352  53.4420   399190.0
# 1    2018-12-27  VHM          1  53.7992  53.7992  53.0712  53.3692   304690.0
# 2    2018-12-26  VHM          1  53.2168  53.5080  51.9792  52.4227   547940.0
# 3    2018-12-25  VHM          1  53.1440  53.8720  52.6344  53.5148   232270.0
# 4    2018-12-24  VHM          1  54.6000  55.3280  54.0904  54.1701   172180.0
# ...         ...  ...        ...      ...      ...      ...      ...        ...
# 1803 2025-01-15  VHM          1  40.0000  40.1000  39.8000  40.0000  2707200.0
# 1804 2025-01-14  VHM          1  39.7000  40.0000  39.4000  40.0000  5407600.0
# 1805 2025-01-10  VHM          1  40.4000  40.7000  39.9000  40.0000  2320000.0
# 1806 2025-01-09  VHM          1  40.0000  41.0500  40.0000  40.4000  4211400.0
# 1807 2025-01-02  VHM          1  40.1000  40.2000  39.9500  40.0000  3009900.0
#
# [1808 rows x 8 columns]

# %% [markdown]
# ### VIB

# %%
code = "VIB"
get_code_table_and_plot(code)
# Out:
#            date code  market_id     open     high      low    close     volume
# 0    2020-12-31  VIB          1   9.2037   9.2879   9.0914   9.0936  1390750.0
# 1    2020-12-30  VIB          1   9.2317   9.4001   9.2317   9.2620   860320.0
# 2    2020-12-29  VIB          1   9.1897   9.2317   9.1476   9.2339   360210.0
# 3    2020-12-17  VIB          1   9.1195   9.4001   8.9792   9.2059  2055240.0
# 4    2020-12-16  VIB          1   8.9652   9.1195   8.9511   9.0936   794690.0
# ...         ...  ...        ...      ...      ...      ...      ...        ...
# 1180 2025-01-22  VIB          1  17.0006  17.0006  16.7896  16.8334  6919300.0
# 1181 2025-01-15  VIB          1  16.4522  16.7053  16.3678  16.5803  6065800.0
# 1182 2025-01-14  VIB          1  16.3678  16.4522  16.2834  16.3693  3487800.0
# 1183 2025-01-08  VIB          1  16.3256  16.4522  16.1990  16.4115  4983100.0
# 1184 2025-01-07  VIB          1  16.1990  16.4100  16.1147  16.3271  7023600.0
#
# [1185 rows x 8 columns]

# %% [markdown]
# ### VIC

# %%
code = "VIC"
get_code_table_and_plot(code)
# Out:
#            date code  market_id     open     high      low    close     volume
# 0    2007-12-21  VIC          1   6.0528   6.0916   6.0528   6.1048   220330.0
# 1    2007-12-20  VIC          1   6.2080   6.2080   6.0528   6.1048   191390.0
# 2    2007-12-19  VIC          1   6.1304   6.1692   6.0916   6.1826   167140.0
# 3    2007-12-18  VIC          1   5.9752   6.0528   5.9752   6.0660   154370.0
# 4    2007-12-17  VIC          1   6.0140   6.0140   5.9752   6.0271   157580.0
# ...         ...  ...        ...      ...      ...      ...      ...        ...
# 4455 2025-01-24  VIC          1  40.2500  40.5000  40.2000  40.4000  1387900.0
# 4456 2025-01-17  VIC          1  40.5000  40.5500  40.2500  40.4500  1173800.0
# 4457 2025-01-16  VIC          1  40.3000  40.6500  40.1000  40.4500  1999800.0
# 4458 2025-01-10  VIC          1  40.7500  40.9000  40.4000  40.5000  1104600.0
# 4459 2025-01-09  VIC          1  40.5500  41.0000  40.5000  40.7500  1187900.0
#
# [4460 rows x 8 columns]

# %% [markdown]
# ### VJC

# %%
code = "VJC"
get_code_table_and_plot(code)
# Out:
#            date code  market_id      open      high       low     close  \
# 0    2017-12-29  VJC          1  116.8265  118.6796  116.8265  118.2789
# 1    2017-12-28  VJC          1  114.8123  117.0682  114.6511  116.8286
# 2    2017-12-27  VJC          1  115.2151  115.2957  114.4094  114.8143
# 3    2017-12-26  VJC          1  113.7648  115.5374  113.6037  115.2171
# 4    2017-12-08  VJC          1  102.8879  104.7410  102.1628  104.1789
# ...         ...  ...        ...       ...       ...       ...       ...
# 2107 2025-01-21  VJC          1   99.0000   99.3000   98.1000   98.8000
# 2108 2025-01-20  VJC          1   98.5000   99.0000   98.1000   98.8000
# 2109 2025-01-13  VJC          1   98.8000   99.2000   98.1000   98.6000
# 2110 2025-01-06  VJC          1   99.5000   99.9000   99.0000   99.7000
# 2111 2025-01-03  VJC          1   99.9000   99.9000   98.9000   99.5000
#
#          volume
# 0     1174600.0
# 1     1203930.0
# 2      873650.0
# 3      977150.0
# 4      885970.0
# ...         ...
# 2107   480800.0
# 2108   421100.0
# 2109   519700.0
# 2110   663900.0
# 2111   743700.0
#
# [2112 rows x 8 columns]

# %% [markdown]
# ### VNM

# %%
code = "VNM"
get_code_table_and_plot(code)
# Out:
#            date code  market_id     open     high      low    close     volume
# 0    2006-08-11  VNM          1   3.0149   3.0562   3.0149   3.0569   115900.0
# 1    2006-08-10  VNM          1   2.9736   2.9943   2.9736   2.9950    69590.0
# 2    2006-08-09  VNM          1   2.9943   2.9943   2.9943   2.9950   135820.0
# 3    2006-08-08  VNM          1   2.9323   2.9736   2.9323   2.9743   136030.0
# 4    2006-08-07  VNM          1   2.9736   2.9736   2.9736   2.8710   152230.0
# ...         ...  ...        ...      ...      ...      ...      ...        ...
# 4869 2025-01-24  VNM          1  59.7830  60.3625  59.6864  60.0728  1576400.0
# 4870 2025-01-17  VNM          1  60.0728  60.0728  59.8796  59.8796   889400.0
# 4871 2025-01-16  VNM          1  60.1631  60.4528  59.5837  59.7830  1684500.0
# 4872 2025-01-10  VNM          1  59.5837  59.7768  59.1974  59.2035  1189800.0
# 4873 2025-01-09  VNM          1  59.6803  59.7768  59.1974  59.6864  1500000.0
#
# [4874 rows x 8 columns]

# %% [markdown]
# ### VPB

# %%
code = "VPB"
get_code_table_and_plot(code)
# Out:
#            date code  market_id     open     high      low    close  \
# 0    2017-12-29  VPB          1   8.2253   8.3261   8.1850   8.2695
# 1    2017-12-28  VPB          1   8.1043   8.2253   8.1043   8.1687
# 2    2017-12-27  VPB          1   8.0640   8.1245   8.0438   8.0476
# 3    2017-12-26  VPB          1   8.0640   8.0842   8.0035   8.0275
# 4    2017-12-08  VPB          1   7.9834   8.0640   7.9430   7.9670
# ...         ...  ...        ...      ...      ...      ...      ...
# 1988 2025-01-22  VPB          1  17.9106  18.0079  17.7646  17.8637
# 1989 2025-01-15  VPB          1  17.8151  18.0098  17.7177  17.9124
# 1990 2025-01-14  VPB          1  17.7646  17.8619  17.5699  17.6690
# 1991 2025-01-06  VPB          1  18.2531  18.3992  18.2045  18.3018
# 1992 2025-01-03  VPB          1  18.5919  18.5919  18.2513  18.2531
#
#           volume
# 0      2133440.0
# 1      1336360.0
# 2      1096400.0
# 3       702040.0
# 4      1251580.0
# ...          ...
# 1988  10799900.0
# 1989   5618700.0
# 1990  11010000.0
# 1991   6917300.0
# 1992  10601500.0
#
# [1993 rows x 8 columns]

# %% [markdown]
# ### VRE

# %%
code = "VRE"
get_code_table_and_plot(code)
# Out:
#            date code  market_id     open     high      low    close     volume
# 0    2017-12-25  VRE          1  37.8958  38.0544  37.2616  37.2650   881540.0
# 1    2017-12-22  VRE          1  38.2130  38.7283  37.8958  37.8993   962890.0
# 2    2017-12-21  VRE          1  36.4688  38.2922  36.3102  38.2164  2896650.0
# 3    2017-12-20  VRE          1  36.2310  36.6274  36.1517  36.3135  1430200.0
# 4    2017-12-19  VRE          1  36.9841  37.2220  35.9931  36.7100  1297970.0
# ...         ...  ...        ...      ...      ...      ...      ...        ...
# 1929 2025-01-17  VRE          1  16.5000  16.6000  16.4500  16.5500  4432800.0
# 1930 2025-01-16  VRE          1  16.3500  16.7000  16.3500  16.5500  6720300.0
# 1931 2025-01-10  VRE          1  17.0000  17.0500  16.6500  16.8500  8897000.0
# 1932 2025-01-09  VRE          1  16.9000  17.1500  16.8000  17.0000  3344000.0
# 1933 2025-01-02  VRE          1  17.2000  17.4500  17.2000  17.3000  6915200.0
#
# [1934 rows x 8 columns]
