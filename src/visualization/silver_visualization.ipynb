# %% [markdown]
# # Silver Visualization

# %% [markdown]
# ## Import libraries

# %%
import os
import sys
import pandas as pd

# go one level up from where the notebook is running
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

from logger.logger import Logger
from visualizer.visualizer import Visualizer
from utils.constants import *
from utils.enums import *
from dtos.tabular_database_driver_dtos.tabular_database_driver_dtos import *

# %% [markdown]
# ## Initialize the Logger

# %%
my_logger = Logger(file_name=SILVER_VISUALIZATION_LOG_FILE_BASE)

# %% [markdown]
# ## Initialize the Visualizer

# %%
my_visualizer = Visualizer(logger=my_logger)

# %% [markdown]
# ## MACROECONOMICS

# %%
my_visualizer.connect_to_database(database_name=os.getenv("SILVER_POSTGRES_DATABASE"))
my_visualizer.set_chart_dir(CHARTS_DIR_MACROECONOMICS)

# %% [markdown]
# ### silver_gdp

# %%
silver_gdp = my_visualizer.select(schema_name="macroeconomics", table_name="gdp")
silver_gdp

# %%
std_silver_gdp = my_visualizer.make_date_time_index_for_dataframe(silver_gdp)
std_silver_gdp

# %%
std_silver_gdp_fig = my_visualizer.plot_lines_chart(
    std_silver_gdp,
    x_column="date",
    y_columns=["gdp_growth"],
    title="GDP Growth",
    y_axis_title="Rate",
    y_unit="%",
    prefix_figure_name="gdp",
)
std_silver_gdp_fig

# %% [markdown]
# ### silver_cpi

# %%
silver_cpi = my_visualizer.select(schema_name="macroeconomics", table_name="cpi")
silver_cpi

# %%
std_silver_cpi = my_visualizer.make_date_time_index_for_dataframe(silver_cpi)
std_silver_cpi

# %%
std_silver_cpi_fig = my_visualizer.plot_lines_chart(
    std_silver_cpi,
    x_column="date",
    y_columns=["consumer_price_index"],
    title="Consumer Price Index",
    y_axis_title="Rate",
    y_unit="%",
    prefix_figure_name="cpi",
)
std_silver_cpi_fig

# %% [markdown]
# ### silver_ppi

# %%
silver_ppi = my_visualizer.select(schema_name="macroeconomics", table_name="ppi")
silver_ppi

# %%
std_silver_ppi = my_visualizer.make_date_time_index_for_dataframe(silver_ppi)
std_silver_ppi

# %%
std_silver_ppi_fig = my_visualizer.plot_lines_chart(
    std_silver_ppi,
    x_column="date",
    y_columns=["general_index"],
    title="Producer Price Index",
    y_axis_title="Rate",
    y_unit="%",
    prefix_figure_name="ppi",
)
std_silver_ppi_fig

# %% [markdown]
# ### silver_ipi

# %%
silver_ipi = my_visualizer.select(schema_name="macroeconomics", table_name="ipi")
silver_ipi

# %%
std_silver_ipi = my_visualizer.make_date_time_index_for_dataframe(silver_ipi)
std_silver_ipi

# %%
std_silver_ipi_fig = my_visualizer.plot_lines_chart(
    std_silver_ipi,
    x_column="date",
    y_columns=["general_index"],
    title="Industrial Production Index",
    y_axis_title="Rate",
    y_unit="%",
    prefix_figure_name="ipi",
)
std_silver_ipi_fig

# %% [markdown]
# ### silver_xpi

# %%
silver_xpi = my_visualizer.select(schema_name="macroeconomics", table_name="xpi")
silver_xpi

# %%
std_silver_xpi = my_visualizer.make_date_time_index_for_dataframe(silver_xpi)
std_silver_xpi

# %%
std_silver_xpi_fig = my_visualizer.plot_lines_chart(
    std_silver_xpi,
    x_column="date",
    y_columns=["total_value"],
    title="Export Price Index",
    y_axis_title="Value",
    y_unit="thousand tons",
    prefix_figure_name="xpi",
)
std_silver_xpi_fig

# %% [markdown]
# ### silver_mpi

# %%
silver_mpi = my_visualizer.select(schema_name="macroeconomics", table_name="mpi")
silver_mpi

# %%
std_silver_mpi = my_visualizer.make_date_time_index_for_dataframe(silver_mpi)
std_silver_mpi

# %%
std_silver_mpi_fig = my_visualizer.plot_lines_chart(
    std_silver_mpi,
    x_column="date",
    y_columns=["total_value"],
    title="Import Price Index",
    y_axis_title="Value",
    y_unit="thousand tons",
    prefix_figure_name="mpi",
)
std_silver_mpi_fig

# %% [markdown]
# ### silver_population

# %%
silver_population = my_visualizer.select(
    schema_name="macroeconomics", table_name="population"
)
silver_population

# %%
std_silver_population = my_visualizer.make_date_time_index_for_dataframe(
    silver_population
)
std_silver_population

# %%
std_silver_population_fig = my_visualizer.plot_lines_chart(
    std_silver_population,
    x_column="date",
    y_columns=["population"],
    title="Population",
    y_axis_title="Value",
    y_unit="millions people",
    prefix_figure_name="population",
)
std_silver_population_fig

# %% [markdown]
# ### silver_labor

# %%
silver_labor = my_visualizer.select(schema_name="macroeconomics", table_name="labor")
silver_labor

# %%
std_silver_labor = my_visualizer.make_date_time_index_for_dataframe(silver_labor)
std_silver_labor

# %%
std_silver_labor_fig = my_visualizer.plot_lines_chart(
    std_silver_labor,
    x_column="date",
    y_columns=["employed_amount"],
    title="Employed Amount",
    y_axis_title="Value",
    y_unit="millions people",
    prefix_figure_name="labor",
)
std_silver_labor_fig

# %% [markdown]
# ### silver_pmi

# %%
silver_pmi = my_visualizer.select(schema_name="macroeconomics", table_name="pmi")
silver_pmi

# %%
std_silver_pmi = my_visualizer.make_date_time_index_for_dataframe(silver_pmi)
std_silver_pmi

# %%
std_silver_pmi_fig = my_visualizer.plot_lines_chart(
    std_silver_pmi,
    x_column="date",
    y_columns=["pmi"],
    title="Purchasing Managers Index",
    y_axis_title="Value",
    y_unit="point",
    prefix_figure_name="pmi",
)
std_silver_pmi_fig

# %% [markdown]
# ### silver_iip

# %%
silver_iip = my_visualizer.select(schema_name="macroeconomics", table_name="iip")
silver_iip

# %%
std_silver_iip = my_visualizer.make_date_time_index_for_dataframe(silver_iip)
std_silver_iip

# %%
std_silver_iip_fig = my_visualizer.plot_lines_chart(
    std_silver_iip,
    x_column="date",
    y_columns=["entire_industrial_sector"],
    title="Index of Industrial Production",
    y_axis_title="Rate",
    y_unit="%",
    prefix_figure_name="iip",
)
std_silver_iip_fig

# %% [markdown]
# ### silver_ipv

# %%
silver_ipv = my_visualizer.select(schema_name="macroeconomics", table_name="ipv")
silver_ipv

# %%
std_silver_ipv = my_visualizer.make_date_time_index_for_dataframe(silver_ipv)
std_silver_ipv

# %%
std_silver_ipv_fig = my_visualizer.plot_lines_chart(
    std_silver_ipv,
    x_column="date",
    y_columns=["extracted_crude_oil", "gasoline_oil"],
    title="Industrial Production Volume",
    y_axis_title="Value",
    y_unit="thousand tons",
    prefix_figure_name="ipv",
)
std_silver_ipv_fig

# %% [markdown]
# ### silver_mip

# %%
silver_mip = my_visualizer.select(schema_name="macroeconomics", table_name="mip")
silver_mip

# %%
std_silver_mip = my_visualizer.make_date_time_index_for_dataframe(silver_mip)
std_silver_mip

# %%
std_silver_mip_fig = my_visualizer.plot_lines_chart(
    std_silver_mip,
    x_column="date",
    y_columns=[
        "clean_coal",
        "crude_oil_extraction",
        "milled_rice",
        "cement",
        "generated_electricity",
    ],
    title="Some Major Industrial Products",
    y_axis_title="Value",
    y_unit="thousand tons / million KWh",
    prefix_figure_name="mip",
)
std_silver_mip_fig

# %% [markdown]
# ### silver_fa_by_house_types

# %%
silver_fa_by_house_types = my_visualizer.select(
    schema_name="macroeconomics", table_name="fa_by_house_types"
)
silver_fa_by_house_types

# %%
std_silver_fa_by_house_types = my_visualizer.make_date_time_index_for_dataframe(
    silver_fa_by_house_types
)
std_silver_fa_by_house_types

# %%
std_silver_fa_by_house_types_fig = my_visualizer.plot_lines_chart(
    std_silver_fa_by_house_types,
    x_column="date",
    y_columns=["total"],
    title="Floor Area",
    y_axis_title="Value",
    y_unit="thousand m2",
    prefix_figure_name="fa_by_house_types",
)
std_silver_fa_by_house_types_fig

# %% [markdown]
# ### silver_it_bop

# %%
silver_it_bop = my_visualizer.select(schema_name="macroeconomics", table_name="it_bop")
silver_it_bop

# %%
std_silver_it_bop = my_visualizer.make_date_time_index_for_dataframe(silver_it_bop)
std_silver_it_bop

# %%
std_silver_it_bop_fig = my_visualizer.plot_lines_chart(
    std_silver_it_bop,
    x_column="date",
    y_columns=[
        "a_current_account",
        "c_financial_account",
        "d_errors_and_omissions",
        "e_overall_balance",
    ],
    title="International Trade and Balance of Payments",
    y_axis_title="Value",
    y_unit="million US dollars",
    prefix_figure_name="it_bop",
)
std_silver_it_bop_fig

# %% [markdown]
# ### silver_tsbr

# %%
silver_tsbr = my_visualizer.select(schema_name="macroeconomics", table_name="tsbr")
silver_tsbr

# %%
std_silver_tsbr = my_visualizer.make_date_time_index_for_dataframe(silver_tsbr)
std_silver_tsbr

# %%
std_silver_tsbr_fig = my_visualizer.plot_lines_chart(
    std_silver_tsbr,
    x_column="date",
    y_columns=["total_state_budget_revenue"],
    title="Total State Budget Revenue",
    y_axis_title="Value",
    y_unit="billion Dong",
    prefix_figure_name="tsbr",
)
std_silver_tsbr_fig

# %% [markdown]
# ### silver_tsbe

# %%
silver_tsbe = my_visualizer.select(schema_name="macroeconomics", table_name="tsbe")
silver_tsbe

# %%
std_silver_tsbe = my_visualizer.make_date_time_index_for_dataframe(silver_tsbe)
std_silver_tsbe

# %%
std_silver_tsbe_fig = my_visualizer.plot_lines_chart(
    std_silver_tsbe,
    x_column="date",
    y_columns=["total_state_budget_expenditure"],
    title="Total State Budget Expenditure",
    y_axis_title="Value",
    y_unit="billion Dong",
    prefix_figure_name="tsbe",
)
std_silver_tsbe_fig

# %% [markdown]
# ### silver_gd

# %%
silver_gd = my_visualizer.select(schema_name="macroeconomics", table_name="gd")
silver_gd

# %%
std_silver_gd = my_visualizer.make_date_time_index_for_dataframe(silver_gd)
std_silver_gd

# %%
std_silver_gd_fig = my_visualizer.plot_lines_chart(
    std_silver_gd,
    x_column="date",
    y_columns=["debt_balance", "domestic_debt", "foreign_debt"],
    title="Gorvernment Debt",
    y_axis_title="Value",
    y_unit="billion Dong",
    prefix_figure_name="gd",
)
std_silver_gd_fig

# %% [markdown]
# ### silver_brd

# %%
silver_brd = my_visualizer.select(schema_name="macroeconomics", table_name="brd")
silver_brd

# %%
std_silver_brd = my_visualizer.make_date_time_index_for_dataframe(silver_brd)
std_silver_brd

# %%
std_silver_brd_fig = my_visualizer.plot_lines_chart(
    std_silver_brd,
    x_column="date",
    y_columns=[
        "newly_established_enterprises",
        "enterprises_temporarily_suspended_awaiting_dissolution",
        "enterprises_resuming_operations",
        "enterprises_completing_dissolution",
    ],
    title="Business Registered Dissolved",
    y_axis_title="Value",
    y_unit="enterprises",
    prefix_figure_name="brd",
)
std_silver_brd_fig

# %% [markdown]
# ### silver_iisd

# %%
silver_iisd = my_visualizer.select(schema_name="macroeconomics", table_name="iisd")
silver_iisd

# %%
std_silver_iisd = my_visualizer.make_date_time_index_for_dataframe(silver_iisd)
std_silver_iisd

# %%
std_silver_iisd_fig = my_visualizer.plot_lines_chart(
    std_silver_iisd,
    x_column="date",
    y_columns=[
        "total",
        "investment_capital_from_the_state_budget",
        "investment_capital_from_residents_and_private_individuals",
        "foreign_direct_investment_capital",
    ],
    title="Investing In Social Development",
    y_axis_title="Value",
    y_unit="thousand billion Dong",
    prefix_figure_name="iisd",
)
std_silver_iisd_fig

# %% [markdown]
# ### silver_treg

# %%
silver_treg = my_visualizer.select(schema_name="macroeconomics", table_name="treg")
silver_treg
# Out:
#      year  month  \
# 0    2000      3
# 1    2000      6
# 2    2000      9
# 3    2000     12
# 4    2001      1
# ..    ...    ...
# 292  2025      1
# 293  2025      2
# 294  2025      3
# 295  2025      4
# 296  2025      5
#
#      international_liquidity_total_reserves_excluding_gold_foreign_e  \
# 0                                              3589.29
# 1                                              3531.38
# 2                                              3537.72
# 3                                              3416.18
# 4                                              3435.00
# ..                                                 ...
# 292                                           78985.97
# 293                                           79471.09
# 294                                           80650.31
# 295                                           80096.30
# 296                                           79751.05
#
#      international_liquidity_total_reserves_excluding_gold_us_dollar
# 0                                              3591.62
# 1                                              3531.89
# 2                                              3541.17
# 3                                              3416.51
# 4                                              3445.07
# ..                                                 ...
# 292                                           80853.01
# 293                                           81345.68
# 294                                           82553.10
# 295                                           82038.34
# 296                                           81694.07
#
# [297 rows x 4 columns]

# %%
std_silver_treg = my_visualizer.make_date_time_index_for_dataframe(silver_treg)
std_silver_treg
# Out:
#           date  \
# 0   2000-01-31
# 1   2000-02-29
# 2   2000-03-31
# 3   2000-04-30
# 4   2000-05-31
# ..         ...
# 301 2025-02-28
# 302 2025-03-31
# 303 2025-04-30
# 304 2025-05-31
# 305 2025-06-30
#
#      international_liquidity_total_reserves_excluding_gold_foreign_e  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                              3589.29
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 301                                           79471.09
# 302                                           80650.31
# 303                                           80096.30
# 304                                           79751.05
# 305                                                NaN
#
#      international_liquidity_total_reserves_excluding_gold_us_dollar
# 0                                                  NaN
# 1                                                  NaN
# 2                                              3591.62
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 301                                           81345.68
# 302                                           82553.10
# 303                                           82038.34
# 304                                           81694.07
# 305                                                NaN
#
# [306 rows x 3 columns]

# %%
std_silver_treg_fig = my_visualizer.plot_lines_chart(
    std_silver_treg,
    x_column="date",
    y_columns=[
        "international_liquidity_total_reserves_excluding_gold_us_dollar",
    ],
    title="Total Reserves excluding gold (USD)",
    y_axis_title="Value",
    y_unit="million USD",
    prefix_figure_name="treg",
    marker=None,
)
std_silver_treg_fig

# %% [markdown]
# ### silver_credit

# %%
silver_credit = my_visualizer.select(schema_name="macroeconomics", table_name="credit")
silver_credit

# %%
std_silver_credit = my_visualizer.make_date_time_index_for_dataframe(silver_credit)
std_silver_credit

# %%
std_silver_credit_fig = my_visualizer.plot_lines_chart(
    std_silver_credit,
    x_column="date",
    y_columns=["credit", "money_supply_m2"],
    title="Credit statistics",
    y_axis_title="Value",
    y_unit="billion Dong",
    prefix_figure_name="credit",
    marker=None,
)
std_silver_credit_fig

# %%
std_silver_credit_fig = my_visualizer.plot_lines_chart(
    std_silver_credit,
    x_column="date",
    y_columns=["credit_growth_ytd", "money_supply_growth_m2_ytd"],
    title="Credit growth statistics",
    y_axis_title="Value",
    y_unit="billion Dong",
    prefix_figure_name="credit",
    marker=None,
)
std_silver_credit_fig

# %% [markdown]
# ### silver_mobilization

# %%
silver_mobilization = my_visualizer.select(
    schema_name="macroeconomics", table_name="mobilization"
)
silver_mobilization

# %%
std_silver_mobilization = my_visualizer.make_date_time_index_for_dataframe(
    silver_mobilization
)
std_silver_mobilization

# %%
std_silver_mobilization_fig = my_visualizer.plot_lines_chart(
    std_silver_mobilization,
    x_column="date",
    y_columns=[
        "deposits_from_economic_organizations",
        "deposits_from_residents",
        "total_payment_instruments",
    ],
    title="mobilization statistics",
    y_axis_title="Value",
    y_unit="billion Dong",
    prefix_figure_name="mobilization",
    marker=None,
)
std_silver_mobilization_fig

# %% [markdown]
# ### silver_exchange_rate

# %%
silver_exchange_rate = my_visualizer.select(
    schema_name="macroeconomics", table_name="exchange_rate"
)
silver_exchange_rate

# %%
std_silver_exchange_rate = my_visualizer.make_date_time_index_for_dataframe(
    silver_exchange_rate
)
std_silver_exchange_rate

# %%
std_silver_exchange_rate_fig = my_visualizer.plot_lines_chart(
    std_silver_exchange_rate,
    x_column="date",
    y_columns=["central_rate"],
    title="Exchange rate statistics",
    y_axis_title="Value",
    y_unit="VND/USD",
    prefix_figure_name="exchange_rate",
    marker=None,
)
std_silver_exchange_rate_fig

# %% [markdown]
# ### silver_iir

# %%
silver_iir = my_visualizer.select(schema_name="macroeconomics", table_name="iir")
silver_iir

# %%
std_silver_iir = my_visualizer.make_date_time_index_for_dataframe(silver_iir)
std_silver_iir

# %%
rename_dict = {
    "_3_months": "three_months",
    "_6_months": "six_months",
    "_9_months": "nine_months",
}

# Apply renaming
std_silver_iir = std_silver_iir.rename(columns=rename_dict)
std_silver_iir

# %%
std_silver_iir_fig = my_visualizer.plot_lines_chart(
    std_silver_iir,
    x_column="date",
    y_columns=["overnight", "three_months", "six_months", "nine_months"],
    title="Interbank interest rates",
    y_axis_title="Value",
    y_unit="%",
    prefix_figure_name="iir",
    marker=None,
)
std_silver_iir_fig

# %% [markdown]
# ### silver_rrrr

# %%
std_silver_rrrr = my_visualizer.select(schema_name="macroeconomics", table_name="rrrr")
std_silver_rrrr
# Out:
#             date  discount_rate  refinancing_rate
# 0     2000-01-02            NaN               NaN
# 1     2000-01-03            NaN               NaN
# 2     2000-01-04            NaN               NaN
# 3     2000-01-05            NaN               NaN
# 4     2000-01-06            NaN               NaN
# ...          ...            ...               ...
# 9308  2025-05-21            NaN               NaN
# 9309  2025-05-30            NaN               NaN
# 9310  2025-06-08            NaN               NaN
# 9311  2025-06-17            NaN               NaN
# 9312  2025-06-26            NaN               NaN
#
# [9313 rows x 3 columns]

# %%
std_silver_rrrr_fig = my_visualizer.plot_lines_chart(
    std_silver_rrrr,
    x_column="date",
    y_columns=["discount_rate", "refinancing_rate"],
    title="Rediscount rate, Refinancing rate",
    y_axis_title="Rate",
    y_unit="%",
    prefix_figure_name="rrrr",
)
std_silver_rrrr_fig

# %% [markdown]
# ### silver_fdi_sector

# %%
silver_fdi_sector = my_visualizer.select(
    schema_name="macroeconomics", table_name="fdi_sector"
)
silver_fdi_sector
# Out:
#     year  month  accommodation_and_food_services  \
# 0   2020      8                         12329.93
# 1   2020      9                         12329.71
# 2   2020     10                         12475.14
# 3   2020     11                         12516.35
# 4   2020     12                         12506.70
# 5   2021      1                         12506.83
# 6   2021      2                         12518.79
# 7   2021      3                         12519.16
# 8   2021      4                         12521.70
# 9   2021      5                         12521.62
# 10  2021      6                         12549.64
# 11  2021      7                         12549.44
# 12  2021      8                         12549.48
# 13  2021      9                         12550.98
# 14  2021     10                         12551.07
# 15  2021     11                         12541.67
# 16  2021     12                         12737.72
# 17  2022      1                         12735.37
# 18  2022      2                         12722.87
# 19  2022      3                         12728.04
# 20  2022      4                         12727.02
# 21  2022      5                         12727.66
# 22  2022      6                         12751.18
# 23  2022      7                         12751.66
# 24  2022      8                         12672.57
# 25  2022      9                         12674.77
# 26  2022     10                         12678.87
# 27  2022     11                         12679.14
# 28  2022     12                         12679.18
# 29  2023      1                         12681.66
# 30  2023      2                         12680.53
# 31  2023      3                         12685.79
# 32  2023      4                         12686.51
# 33  2023      5                         12727.36
# 34  2023      6                         12920.31
# 35  2023      7                         12920.68
# 36  2023      8                         12927.56
# 37  2023      9                         12902.08
# 38  2023     10                         12848.02
# 39  2023     11                         12847.38
# 40  2023     12                         14338.97
# 41  2024      1                         14345.85
# 42  2024      2                         14349.47
# 43  2024      3                         14353.69
# 44  2024      4                         14377.70
# 45  2024      5                         15387.89
# 46  2024      6                         15384.44
# 47  2024      7                         15415.21
# 48  2024      8                         15421.30
# 49  2024      9                         15427.24
# 50  2024     10                         13935.83
# 51  2024     11                         13836.31
# 52  2024     12                         13832.60
#
#     administrative_and_support_service_activities  \
# 0                                          990.33
# 1                                          990.08
# 2                                          990.27
# 3                                          961.05
# 4                                          963.38
# 5                                          975.87
# 6                                          975.86
# 7                                          975.98
# 8                                          977.10
# 9                                          978.50
# 10                                         980.46
# 11                                         983.51
# 12                                         973.56
# 13                                         974.00
# 14                                         985.90
# 15                                         986.03
# 16                                         987.98
# 17                                         991.57
# 18                                         992.86
# 19                                         993.23
# 20                                         994.68
# 21                                         999.50
# 22                                        1001.28
# 23                                        1001.87
# 24                                        1006.33
# 25                                        1010.00
# 26                                        1010.87
# 27                                        1014.57
# 28                                        1038.92
# 29                                        1039.81
# 30                                        1036.16
# 31                                        1036.22
# 32                                        1036.84
# 33                                        1036.74
# 34                                        1042.10
# 35                                        1050.63
# 36                                        1056.43
# 37                                        1056.82
# 38                                        1057.80
# 39                                        1060.60
# 40                                        1065.19
# 41                                        1070.67
# 42                                        1074.08
# 43                                        1076.70
# 44                                        1081.18
# 45                                        1083.61
# 46                                        1085.86
# 47                                        1086.14
# 48                                        1087.38
# 49                                        1106.63
# 50                                        1118.12
# 51                                        1116.74
# 52                                        1122.99
#
#     agriculture_forestry_and_fishery  arts_entertainment_and_recreation  \
# 0                            3615.61                            3391.38
# 1                            3616.51                            3391.38
# 2                            3661.50                            3392.66
# 3                            3664.02                            3392.21
# 4                            3701.25                            3391.52
# 5                            3769.90                            3391.52
# 6                            3779.19                            3391.52
# 7                            3779.19                            3391.52
# 8                            3683.19                            3391.27
# 9                            3687.23                            3393.57
# 10                           3678.56                            3393.57
# 11                           3689.17                            3393.57
# 12                           3681.74                            3392.34
# 13                           3696.42                            3392.34
# 14                           3714.67                            3392.34
# 15                           3719.67                            3392.34
# 16                           3723.72                            3392.34
# 17                           3729.94                            3392.34
# 18                           3731.25                            3392.34
# 19                           3744.60                            3392.24
# 20                           3742.51                            3416.24
# 21                           3839.96                            3416.24
# 22                           3851.96                            3416.24
# 23                           3855.11                            3416.24
# 24                           3848.11                            3416.30
# 25                           3849.75                            3416.45
# 26                           3846.74                            3418.60
# 27                           3846.74                            3418.60
# 28                           3850.11                            3418.60
# 29                           3859.57                            3418.60
# 30                           3861.66                            3418.60
# 31                           3858.51                            3423.20
# 32                           3858.36                            3423.20
# 33                           3860.69                            3423.20
# 34                           3844.07                            3423.20
# 35                           3849.67                            3424.44
# 36                           3856.27                            3165.07
# 37                           3866.89                            3165.51
# 38                           3883.96                            3165.99
# 39                           3881.29                            3165.99
# 40                           3869.87                            3165.99
# 41                           3903.86                            3169.84
# 42                           3910.60                            3169.84
# 43                           3915.55                            3231.41
# 44                           3907.58                            3226.41
# 45                           3907.58                            3226.41
# 46                           3867.83                            3230.53
# 47                           3867.83                            3231.28
# 48                           3881.52                            3231.28
# 49                           3879.76                            3231.28
# 50                           3878.46                            3231.79
# 51                           3879.28                            3132.46
# 52                           3861.97                            3133.44
#
#     construction  domestic_household_service_workers  education_and_training  \
# 0       13980.20                                8.37                 4400.41
# 1       13975.21                                8.37                 4403.57
# 2       10680.90                                8.37                 4403.43
# 3       10683.43                               11.07                 4404.89
# 4       10684.18                               11.07                 4411.27
# 5       10675.08                               11.07                 4412.37
# 6       10675.07                               11.07                 4412.98
# 7       10680.17                               11.07                 4413.01
# 8       10681.80                               11.07                 4419.71
# 9       10685.21                               11.07                 4423.02
# 10      10733.72                               11.07                 4423.21
# 11      10733.10                               11.07                 4425.76
# 12      10750.59                               11.07                 4429.40
# 13      10710.81                               11.07                 4429.40
# 14      10710.70                               11.07                 4429.42
# 15      10915.69                               11.07                 4433.31
# 16      10917.06                               11.07                 4434.40
# 17      10828.48                               11.07                 4436.49
# 18      10834.19                               11.07                 4436.63
# 19      10936.54                               11.07                 4440.56
# 20      10951.29                               11.07                 4440.35
# 21      10933.05                               11.07                 4569.74
# 22      10934.23                               11.07                 4570.00
# 23      10885.58                               11.07                 4574.22
# 24      10881.37                               11.07                 4576.14
# 25      10883.83                               11.07                 4586.94
# 26      10885.83                               11.07                 4588.68
# 27      10895.02                               11.07                 4590.56
# 28      10899.62                               11.07                 4590.52
# 29      11024.71                               11.07                 4590.96
# 30      11051.93                               11.07                 4591.56
# 31      11086.24                               11.07                 4592.24
# 32      11095.21                               11.07                 4595.90
# 33      11097.69                               11.07                 4596.35
# 34      11100.71                               11.07                 4598.75
# 35      11226.65                               11.07                 4599.09
# 36      10882.92                               11.07                 4601.54
# 37      10996.75                               11.07                 4602.43
# 38      11005.46                               11.07                 4602.81
# 39      11005.92                               11.07                 4599.75
# 40      10909.30                               11.07                 4615.72
# 41      10862.47                               11.07                 4615.81
# 42      10863.68                               11.07                 4629.40
# 43      10924.64                               11.07                 4633.60
# 44      10932.29                               11.07                 4630.31
# 45      10932.23                               11.07                 4630.45
# 46      10964.92                               11.07                 4631.79
# 47      10976.40                               11.07                 4635.42
# 48      10983.17                               11.07                 4626.91
# 49      10990.54                               11.07                 4634.69
# 50      10991.14                               11.07                 4638.26
# 51      10940.51                               11.07                 4638.26
# 52      10943.32                               10.64                 4636.49
#
#     financial_banking_and_insurance_activities  ...  \
# 0                                       738.97  ...
# 1                                       753.36  ...
# 2                                       753.36  ...
# 3                                       753.36  ...
# 4                                       752.76  ...
# 5                                       752.76  ...
# 6                                       752.76  ...
# 7                                       784.19  ...
# 8                                       784.19  ...
# 9                                       784.19  ...
# 10                                      784.19  ...
# 11                                      784.19  ...
# 12                                      784.19  ...
# 13                                      784.19  ...
# 14                                      788.69  ...
# 15                                      788.69  ...
# 16                                      788.69  ...
# 17                                      810.73  ...
# 18                                      810.68  ...
# 19                                      810.68  ...
# 20                                      912.57  ...
# 21                                      912.57  ...
# 22                                      912.62  ...
# 23                                      913.12  ...
# 24                                      913.84  ...
# 25                                      913.84  ...
# 26                                      913.86  ...
# 27                                      913.86  ...
# 28                                      945.05  ...
# 29                                      945.05  ...
# 30                                      944.92  ...
# 31                                      945.54  ...
# 32                                      920.77  ...
# 33                                      920.77  ...
# 34                                      920.92  ...
# 35                                      920.92  ...
# 36                                      920.92  ...
# 37                                      927.22  ...
# 38                                      927.23  ...
# 39                                      927.23  ...
# 40                                      927.73  ...
# 41                                      929.01  ...
# 42                                      930.00  ...
# 43                                      931.00  ...
# 44                                      930.85  ...
# 45                                      930.85  ...
# 46                                      930.45  ...
# 47                                      930.45  ...
# 48                                      932.45  ...
# 49                                      932.51  ...
# 50                                      932.54  ...
# 51                                      932.54  ...
# 52                                      932.54  ...
#
#     information_and_communication  manufacturing_and_processing_industry  \
# 0                         3943.14                               222939.9
# 1                         3946.56                               222929.5
# 2                         3947.45                               223619.6
# 3                         3950.95                               225733.2
# 4                         3966.70                               226490.2
# 5                         3970.73                               228058.2
# 6                         3976.51                               229081.8
# 7                         3985.53                               229967.6
# 8                         4010.26                               231167.9
# 9                         4026.77                               232778.5
# 10                        4038.19                               233678.3
# 11                        4050.52                               234393.2
# 12                        4053.58                               235699.4
# 13                        4053.71                               238160.9
# 14                        4075.10                               239020.7
# 15                        4178.90                               240228.0
# 16                        4246.22                               241936.5
# 17                        4256.30                               245982.5
# 18                        4288.06                               247729.4
# 19                        4295.55                               250720.6
# 20                        4361.76                               251394.4
# 21                        4798.26                               252009.8
# 22                        4806.09                               253643.4
# 23                        4822.08                               254365.4
# 24                        4836.32                               255228.2
# 25                        4852.02                               256415.7
# 26                        4976.71                               257455.9
# 27                        4984.59                               259163.7
# 28                        4919.06                               260117.5
# 29                        4938.03                               262155.3
# 30                        4951.09                               262877.6
# 31                        4965.02                               264200.2
# 32                        5074.58                               265523.1
# 33                        5077.03                               266918.9
# 34                        5082.07                               268351.6
# 35                        5096.19                               271213.4
# 36                        5099.16                               272224.3
# 37                        5104.44                               273878.1
# 38                        5102.96                               278597.3
# 39                        5106.56                               280539.5
# 40                        5121.87                               283026.2
# 41                        5127.03                               284427.9
# 42                        5127.63                               285395.2
# 43                        5122.74                               287481.0
# 44                        5136.84                               289671.3
# 45                        5147.34                               290897.8
# 46                        5166.56                               294155.3
# 47                        5156.25                               296100.5
# 48                        5161.26                               299876.2
# 49                        5164.09                               298713.5
# 50                        5169.83                               299808.1
# 51                        5205.72                               303874.7
# 52                        5230.90                               308763.5
#
#     mining_and_quarrying  other_service_activities  \
# 0                4896.95                    807.85
# 1                4896.95                    809.35
# 2                4897.63                    809.55
# 3                4897.63                    844.55
# 4                4897.63                    847.65
# 5                4897.63                    847.65
# 6                4897.63                    847.65
# 7                4897.63                    847.65
# 8                4897.76                    847.65
# 9                4894.76                    847.65
# 10               4894.76                    847.65
# 11               4894.76                    847.80
# 12               4894.76                    847.80
# 13               4898.40                    848.80
# 14               4898.40                    848.80
# 15               4898.40                    728.80
# 16               4898.40                    729.00
# 17               4900.37                    729.00
# 18               4900.37                    729.00
# 19               4900.37                    729.10
# 20               4900.37                    721.35
# 21               4900.37                    721.47
# 22               4900.37                    720.92
# 23               4900.37                    720.92
# 24               4900.37                    723.92
# 25               4900.37                    724.12
# 26               4900.37                    724.12
# 27               4900.37                    724.12
# 28               4894.57                    724.12
# 29               4894.57                    724.15
# 30               4894.57                    724.15
# 31               4894.57                    724.15
# 32               4894.57                    723.55
# 33               4894.57                    723.68
# 34               4894.57                    723.68
# 35               4894.57                    723.68
# 36               4894.57                    724.40
# 37               4894.57                    766.48
# 38               4994.57                    766.48
# 39               4892.57                    767.38
# 40               4892.57                    767.51
# 41               4892.57                    767.51
# 42               4892.57                    767.51
# 43               4892.57                    769.51
# 44               4892.57                    927.33
# 45               4892.57                    927.29
# 46               4892.80                    927.57
# 47               4889.17                    927.79
# 48               4889.24                    930.79
# 49               4889.24                    933.19
# 50               4889.24                    934.01
# 51               4889.24                    934.24
# 52               4870.24                    934.72
#
#     production_and_distribution_of_electricity_gas_water_and_air_co  \
# 0                                            27574.58
# 1                                            27906.19
# 2                                            28367.76
# 3                                            28733.30
# 4                                            28921.82
# 5                                            28607.84
# 6                                            30017.27
# 7                                            33569.09
# 8                                            33561.52
# 9                                            33733.79
# 10                                           33648.16
# 11                                           33906.86
# 12                                           33908.91
# 13                                           33939.71
# 14                                           33723.50
# 15                                           33876.41
# 16                                           33876.67
# 17                                           36245.85
# 18                                           36246.13
# 19                                           36380.52
# 20                                           36462.38
# 21                                           36462.38
# 22                                           36469.11
# 23                                           36473.79
# 24                                           36380.57
# 25                                           36381.64
# 26                                           38374.99
# 27                                           38315.70
# 28                                           38317.62
# 29                                           38317.62
# 30                                           38313.32
# 31                                           38320.66
# 32                                           38320.66
# 33                                           38320.66
# 34                                           38411.52
# 35                                           38411.52
# 36                                           38411.52
# 37                                           38411.52
# 38                                           38392.05
# 39                                           38570.79
# 40                                           40671.39
# 41                                           40671.39
# 42                                           40653.40
# 43                                           40653.40
# 44                                           40653.40
# 45                                           40771.40
# 46                                           40783.91
# 47                                           40783.91
# 48                                           40776.41
# 49                                           41674.21
# 50                                           41674.42
# 51                                           41674.41
# 52                                           41927.58
#
#     professional_scientific_and_technological_activities  \
# 0                                             3531.98
# 1                                             3577.34
# 2                                             3626.33
# 3                                             3643.84
# 4                                             3691.22
# 5                                             3686.19
# 6                                             3783.81
# 7                                             3774.90
# 8                                             3835.02
# 9                                             3845.10
# 10                                            3904.37
# 11                                            3925.22
# 12                                            3961.75
# 13                                            3963.83
# 14                                            4050.04
# 15                                            4081.50
# 16                                            4103.73
# 17                                            4121.68
# 18                                            4128.69
# 19                                            4128.03
# 20                                            4233.53
# 21                                            4240.77
# 22                                            4256.34
# 23                                            4474.60
# 24                                            4455.72
# 25                                            4577.19
# 26                                            4651.87
# 27                                            4723.48
# 28                                            4799.01
# 29                                            4966.02
# 30                                            4982.11
# 31                                            4998.24
# 32                                            5164.47
# 33                                            5284.69
# 34                                            5345.80
# 35                                            5437.98
# 36                                            5384.47
# 37                                            5389.53
# 38                                            5403.59
# 39                                            5441.97
# 40                                            5450.13
# 41                                            5446.37
# 42                                            5450.65
# 43                                            5472.58
# 44                                            5491.11
# 45                                            5483.96
# 46                                            5547.19
# 47                                            5555.38
# 48                                            5589.96
# 49                                            5587.71
# 50                                            5621.10
# 51                                            5651.74
# 52                                            5891.16
#
#     real_estate_business_activities  transportation_and_warehousing  \
# 0                          59680.52                         5162.01
# 1                          59600.97                         5217.30
# 2                          59878.27                         5218.74
# 3                          60112.78                         5235.86
# 4                          60057.32                         5341.13
# 5                          60498.70                         5501.77
# 6                          60748.06                         5501.67
# 7                          60769.75                         5501.96
# 8                          60925.45                         5498.99
# 9                          61018.88                         5500.45
# 10                         61045.46                         5692.96
# 11                         61062.95                         5697.30
# 12                         61234.81                         5727.10
# 13                         61290.93                         5760.54
# 14                         61339.47                         5767.80
# 15                         61561.85                         5806.01
# 16                         61773.58                         5797.58
# 17                         62917.39                         5752.70
# 18                         64358.18                         5752.62
# 19                         64963.03                         5876.20
# 20                         65142.86                         5879.67
# 21                         65319.10                         5949.04
# 22                         65356.84                         5984.62
# 23                         65352.17                         5989.43
# 24                         65457.89                         6147.96
# 25                         65509.69                         6170.60
# 26                         65763.00                         6129.33
# 27                         66192.93                         6166.21
# 28                         66267.55                         6170.57
# 29                         66347.88                         6254.35
# 30                         66460.95                         6301.99
# 31                         66749.05                         6307.73
# 32                         67002.19                         6242.93
# 33                         67128.50                         6261.66
# 34                         67111.96                         6267.63
# 35                         67177.18                         6274.79
# 36                         67204.55                         6294.56
# 37                         67380.51                         6061.35
# 38                         67436.31                         6081.34
# 39                         67572.78                         6123.81
# 40                         68045.86                         6127.79
# 41                         69472.23                         6173.98
# 42                         69607.35                         6184.38
# 43                         70062.98                         6168.67
# 44                         70164.95                         6278.19
# 45                         70573.99                         6314.27
# 46                         70545.18                         6365.35
# 47                         70590.82                         6464.29
# 48                         71082.12                         6467.60
# 49                         71521.51                         6528.46
# 50                         72352.93                         6530.76
# 51                         72547.35                         6601.10
# 52                         73175.11                         6606.91
#
#     water_supply_and_waste_treatment  \
# 0                            2859.30
# 1                            2859.30
# 2                            2865.42
# 3                            2923.42
# 4                            2923.42
# 5                            2926.02
# 6                            2926.02
# 7                            2926.02
# 8                            2897.03
# 9                            2897.03
# 10                           2895.03
# 11                           2895.03
# 12                           2895.03
# 13                           2895.03
# 14                           2899.75
# 15                           2899.75
# 16                           2905.94
# 17                           2908.25
# 18                           2908.70
# 19                           2908.70
# 20                           2908.70
# 21                           2908.70
# 22                           2909.10
# 23                           2991.41
# 24                           2990.17
# 25                           2991.17
# 26                           2991.17
# 27                           3035.78
# 28                           3035.78
# 29                           3042.93
# 30                           3042.47
# 31                           3042.47
# 32                           3042.47
# 33                           3042.47
# 34                           3042.47
# 35                           3042.47
# 36                           3102.47
# 37                           3102.47
# 38                           3158.22
# 39                           3158.22
# 40                           3158.22
# 41                           3158.22
# 42                           3158.22
# 43                           3159.48
# 44                           3159.48
# 45                           3049.18
# 46                           3049.18
# 47                           3049.18
# 48                           3049.18
# 49                           3049.18
# 50                           3049.18
# 51                           3049.18
# 52                           3157.01
#
#     wholesale_and_retail_repair_of_motor_vehicles_and_motorcycles
# 0                                             8331.80
# 1                                             8326.36
# 2                                             8392.81
# 3                                             8434.23
# 4                                             8484.48
# 5                                             8519.57
# 6                                             8528.54
# 7                                             8531.22
# 8                                             8805.32
# 9                                             8835.50
# 10                                            8687.51
# 11                                            8757.96
# 12                                            8817.32
# 13                                            8827.53
# 14                                            8801.86
# 15                                            9101.05
# 16                                            9091.10
# 17                                            9119.70
# 18                                            9106.54
# 19                                            9133.27
# 20                                            9648.52
# 21                                            9679.26
# 22                                            9731.82
# 23                                            9793.33
# 24                                            9834.74
# 25                                            9952.65
# 26                                           10135.46
# 27                                           10199.74
# 28                                           10260.41
# 29                                           10347.82
# 30                                           10403.47
# 31                                           10474.84
# 32                                           10504.43
# 33                                           10584.63
# 34                                           10634.82
# 35                                           10674.93
# 36                                           10742.72
# 37                                           10787.62
# 38                                           10877.47
# 39                                           10967.38
# 40                                           10988.45
# 41                                           11091.81
# 42                                           11127.10
# 43                                           11204.44
# 44                                           11346.35
# 45                                           11393.77
# 46                                           11469.29
# 47                                           11595.66
# 48                                           11623.45
# 49                                           11672.18
# 50                                           11729.48
# 51                                           12016.82
# 52                                           12022.83
#
# [53 rows x 21 columns]

# %%
std_silver_fdi_sector = my_visualizer.make_date_time_index_for_dataframe(
    silver_fdi_sector
)
std_silver_fdi_sector
# Out:
#           date  accommodation_and_food_services  \
# 0   2000-01-31                              NaN
# 1   2000-02-29                              NaN
# 2   2000-03-31                              NaN
# 3   2000-04-30                              NaN
# 4   2000-05-31                              NaN
# ..         ...                              ...
# 301 2025-02-28                              NaN
# 302 2025-03-31                              NaN
# 303 2025-04-30                              NaN
# 304 2025-05-31                              NaN
# 305 2025-06-30                              NaN
#
#      administrative_and_support_service_activities  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 301                                            NaN
# 302                                            NaN
# 303                                            NaN
# 304                                            NaN
# 305                                            NaN
#
#      agriculture_forestry_and_fishery  arts_entertainment_and_recreation  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
# 2                                 NaN                                NaN
# 3                                 NaN                                NaN
# 4                                 NaN                                NaN
# ..                                ...                                ...
# 301                               NaN                                NaN
# 302                               NaN                                NaN
# 303                               NaN                                NaN
# 304                               NaN                                NaN
# 305                               NaN                                NaN
#
#      construction  domestic_household_service_workers  education_and_training  \
# 0             NaN                                 NaN                     NaN
# 1             NaN                                 NaN                     NaN
# 2             NaN                                 NaN                     NaN
# 3             NaN                                 NaN                     NaN
# 4             NaN                                 NaN                     NaN
# ..            ...                                 ...                     ...
# 301           NaN                                 NaN                     NaN
# 302           NaN                                 NaN                     NaN
# 303           NaN                                 NaN                     NaN
# 304           NaN                                 NaN                     NaN
# 305           NaN                                 NaN                     NaN
#
#      financial_banking_and_insurance_activities  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 301                                         NaN
# 302                                         NaN
# 303                                         NaN
# 304                                         NaN
# 305                                         NaN
#
#      healthcare_and_social_assistance_activities  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 301                                          NaN
# 302                                          NaN
# 303                                          NaN
# 304                                          NaN
# 305                                          NaN
#
#      information_and_communication  manufacturing_and_processing_industry  \
# 0                              NaN                                    NaN
# 1                              NaN                                    NaN
# 2                              NaN                                    NaN
# 3                              NaN                                    NaN
# 4                              NaN                                    NaN
# ..                             ...                                    ...
# 301                            NaN                                    NaN
# 302                            NaN                                    NaN
# 303                            NaN                                    NaN
# 304                            NaN                                    NaN
# 305                            NaN                                    NaN
#
#      mining_and_quarrying  other_service_activities  \
# 0                     NaN                       NaN
# 1                     NaN                       NaN
# 2                     NaN                       NaN
# 3                     NaN                       NaN
# 4                     NaN                       NaN
# ..                    ...                       ...
# 301                   NaN                       NaN
# 302                   NaN                       NaN
# 303                   NaN                       NaN
# 304                   NaN                       NaN
# 305                   NaN                       NaN
#
#      production_and_distribution_of_electricity_gas_water_and_air_co  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 301                                                NaN
# 302                                                NaN
# 303                                                NaN
# 304                                                NaN
# 305                                                NaN
#
#      professional_scientific_and_technological_activities  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 301                                                NaN
# 302                                                NaN
# 303                                                NaN
# 304                                                NaN
# 305                                                NaN
#
#      real_estate_business_activities  transportation_and_warehousing  \
# 0                                NaN                             NaN
# 1                                NaN                             NaN
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                                NaN                             NaN
# ..                               ...                             ...
# 301                              NaN                             NaN
# 302                              NaN                             NaN
# 303                              NaN                             NaN
# 304                              NaN                             NaN
# 305                              NaN                             NaN
#
#      water_supply_and_waste_treatment  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 301                               NaN
# 302                               NaN
# 303                               NaN
# 304                               NaN
# 305                               NaN
#
#      wholesale_and_retail_repair_of_motor_vehicles_and_motorcycles
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 301                                                NaN
# 302                                                NaN
# 303                                                NaN
# 304                                                NaN
# 305                                                NaN
#
# [306 rows x 20 columns]

# %%
std_silver_fdi_sector_fig = my_visualizer.plot_lines_chart(
    std_silver_fdi_sector,
    x_column="date",
    y_columns=[
        "administrative_and_support_service_activities",
        "agriculture_forestry_and_fishery",
        "construction",
        "education_and_training",
        "healthcare_and_social_assistance_activities",
        "information_and_communication",
        "mining_and_quarrying",
    ],
    title="Foreign Direct Investment by Sector 1",
    y_axis_title="Value",
    y_unit="Million US Dollars",
    prefix_figure_name="fdi_sector",
    marker=None,
)
std_silver_fdi_sector_fig

# %%
std_silver_fdi_sector_fig = my_visualizer.plot_lines_chart(
    std_silver_fdi_sector,
    x_column="date",
    y_columns=[
        "manufacturing_and_processing_industry",
        "real_estate_business_activities",
        "production_and_distribution_of_electricity_gas_water_and_air_co",
    ],
    title="Foreign Direct Investment by Sector 2",
    y_axis_title="Value",
    y_unit="Million US Dollars",
    prefix_figure_name="fdi_sector",
    marker=None,
)
std_silver_fdi_sector_fig

# %% [markdown]
# ### silver_fdi_rd

# %%
silver_fdi_rd = my_visualizer.select(schema_name="macroeconomics", table_name="fdi_rd")
silver_fdi_rd
# Out:
#      year  month  fdi_disbursement  register
# 0    2009      1              0.31      2.30
# 1    2009      2              0.69      3.00
# 2    2009      3              1.16      0.70
# 3    2009      4              0.04      0.40
# 4    2009      5              0.60      0.30
# ..    ...    ...               ...       ...
# 193  2025      3              2.01      4.08
# 194  2025      4              1.78      2.84
# 195  2025      5              2.16      4.57
# 196  2025      6              2.82      3.13
# 197  2025      7              1.88      2.57
#
# [198 rows x 4 columns]

# %%
std_silver_fdi_rd = my_visualizer.make_date_time_index_for_dataframe(silver_fdi_rd)
std_silver_fdi_rd
# Out:
#           date  fdi_disbursement  register
# 0   2000-01-31               NaN       NaN
# 1   2000-02-29               NaN       NaN
# 2   2000-03-31               NaN       NaN
# 3   2000-04-30               NaN       NaN
# 4   2000-05-31               NaN       NaN
# ..         ...               ...       ...
# 301 2025-02-28              1.44      2.57
# 302 2025-03-31              2.01      4.08
# 303 2025-04-30              1.78      2.84
# 304 2025-05-31              2.16      4.57
# 305 2025-06-30              2.82      3.13
#
# [306 rows x 3 columns]

# %%
std_silver_fdi_rd_fig = my_visualizer.plot_lines_chart(
    std_silver_fdi_rd,
    x_column="date",
    y_columns=[
        "fdi_disbursement",
        "register",
    ],
    title="Foreign Direct Investment Registration Disbursement",
    y_axis_title="Value",
    y_unit="Billion US Dollars",
    prefix_figure_name="fdi_rd",
    marker=None,
)
std_silver_fdi_rd_fig

# %% [markdown]
# ### silver_export

# %%
silver_export = my_visualizer.select(schema_name="macroeconomics", table_name="export")
silver_export
# Out:
#      year  month  argentina    asean  poland  belarus  brazil  bulgaria  \
# 0    2016      1      33.59  1384.46   49.11      0.0  107.10      3.39
# 1    2016      2      39.84  1113.07   36.13      0.0  101.47      2.87
# 2    2016      3      35.74  1513.20   51.70      0.0   92.09      4.91
# 3    2016      4      27.46  1327.78   54.12      0.0   81.72      4.28
# 4    2016      5      29.35  1384.43   47.50      0.0  118.08      2.93
# ..    ...    ...        ...      ...     ...      ...     ...       ...
# 108  2025      1      85.51  2751.24  244.17      0.0  204.69      4.24
# 109  2025      2      87.46  2972.71  262.43      0.0  183.86      6.97
# 110  2025      3      88.13  3492.56  331.46      0.0  276.56     25.62
# 111  2025      4      95.83  3369.24  321.16      0.0  209.22     27.66
# 112  2025      5      86.68  3182.88  283.92      0.0  242.01      7.89
#
#      belgium  portugal  ...  ukraine  united_kingdom  austria  australia  \
# 0     176.51     23.69  ...    17.06          366.43   185.33     229.09
# 1     121.08     16.58  ...    10.38          333.19   140.26     158.38
# 2     140.42     23.45  ...    14.78          461.11   209.73     247.80
# 3     173.20     23.51  ...    15.96          428.50   236.85     227.88
# 4     184.04     23.96  ...    12.31          391.72   205.68     226.77
# ..       ...       ...  ...      ...             ...      ...        ...
# 108   244.38     53.59  ...     3.83          713.57   328.09     570.27
# 109   228.14     42.43  ...     6.21          540.56   225.77     421.23
# 110   331.45     46.90  ...     7.73          675.06   245.10     576.57
# 111   337.81     54.41  ...     9.53          610.91   161.10     486.71
# 112   365.15     48.95  ...    12.49          685.97   150.82     537.62
#
#       italy  denmark  taiwan  germany  saudi_arabia   india
# 0    256.41    24.27  161.48   526.33         25.24  196.39
# 1    207.27    14.69  114.69   401.96         32.29  147.31
# 2    298.73    24.31  195.10   499.12         52.36  218.77
# 3    256.14    21.54  161.21   500.93         32.55  211.59
# 4    320.35    24.59  175.60   502.35         32.23  217.96
# ..      ...      ...     ...      ...           ...     ...
# 108  422.89    40.42  437.55   862.27        141.64  836.88
# 109  425.69    28.74  475.14   708.05        127.26  664.35
# 110  453.44    36.05  645.16   876.43        140.64  872.89
# 111  461.76    34.95  582.41   842.54        187.09  922.26
# 112  479.10    30.28  596.50   793.19        193.13  849.56
#
# [113 rows x 73 columns]

# %%
std_silver_export = my_visualizer.make_date_time_index_for_dataframe(silver_export)
std_silver_export
# Out:
#           date  argentina    asean  poland  belarus  brazil  bulgaria  \
# 0   2000-01-31        NaN      NaN     NaN      NaN     NaN       NaN
# 1   2000-02-29        NaN      NaN     NaN      NaN     NaN       NaN
# 2   2000-03-31        NaN      NaN     NaN      NaN     NaN       NaN
# 3   2000-04-30        NaN      NaN     NaN      NaN     NaN       NaN
# 4   2000-05-31        NaN      NaN     NaN      NaN     NaN       NaN
# ..         ...        ...      ...     ...      ...     ...       ...
# 301 2025-02-28      87.46  2972.71  262.43      0.0  183.86      6.97
# 302 2025-03-31      88.13  3492.56  331.46      0.0  276.56     25.62
# 303 2025-04-30      95.83  3369.24  321.16      0.0  209.22     27.66
# 304 2025-05-31      86.68  3182.88  283.92      0.0  242.01      7.89
# 305 2025-06-30        NaN      NaN     NaN      NaN     NaN       NaN
#
#      belgium  portugal  ivory_coast  ...  ukraine  united_kingdom  austria  \
# 0        NaN       NaN          NaN  ...      NaN             NaN      NaN
# 1        NaN       NaN          NaN  ...      NaN             NaN      NaN
# 2        NaN       NaN          NaN  ...      NaN             NaN      NaN
# 3        NaN       NaN          NaN  ...      NaN             NaN      NaN
# 4        NaN       NaN          NaN  ...      NaN             NaN      NaN
# ..       ...       ...          ...  ...      ...             ...      ...
# 301   228.14     42.43        65.58  ...     6.21          540.56   225.77
# 302   331.45     46.90        58.48  ...     7.73          675.06   245.10
# 303   337.81     54.41        88.79  ...     9.53          610.91   161.10
# 304   365.15     48.95        37.00  ...    12.49          685.97   150.82
# 305      NaN       NaN          NaN  ...      NaN             NaN      NaN
#
#      australia   italy  denmark  taiwan  germany  saudi_arabia   india
# 0          NaN     NaN      NaN     NaN      NaN           NaN     NaN
# 1          NaN     NaN      NaN     NaN      NaN           NaN     NaN
# 2          NaN     NaN      NaN     NaN      NaN           NaN     NaN
# 3          NaN     NaN      NaN     NaN      NaN           NaN     NaN
# 4          NaN     NaN      NaN     NaN      NaN           NaN     NaN
# ..         ...     ...      ...     ...      ...           ...     ...
# 301     421.23  425.69    28.74  475.14   708.05        127.26  664.35
# 302     576.57  453.44    36.05  645.16   876.43        140.64  872.89
# 303     486.71  461.76    34.95  582.41   842.54        187.09  922.26
# 304     537.62  479.10    30.28  596.50   793.19        193.13  849.56
# 305        NaN     NaN      NaN     NaN      NaN           NaN     NaN
#
# [306 rows x 72 columns]

# %%
std_silver_export_fig = my_visualizer.plot_lines_chart(
    std_silver_export,
    x_column="date",
    y_columns=[
        "asean",
        "united_arab_emirates",
        "eu",
        "netherlands",
        "south_korea",
        "hong_kong",
        "usa",
        "japan",
        "china",
    ],
    title="Export statistics by countries",
    y_axis_title="Value",
    y_unit="Million US Dollars",
    prefix_figure_name="export",
    marker=None,
)
std_silver_export_fig

# %% [markdown]
# ### silver_import

# %%
silver_import = my_visualizer.select(schema_name="macroeconomics", table_name="import")
silver_import
# Out:
#      year  month  argentina    asean  poland  belarus  brazil  bulgaria  \
# 0    2016      1      88.05  1784.08   15.53    20.33  240.19      3.76
# 1    2016      2     145.36  1489.88   15.26     0.72  152.15      3.98
# 2    2016      3     164.51  2110.18   14.26     1.51  193.22      3.25
# 3    2016      4     220.01  1965.41   13.46     9.46  129.63      4.21
# 4    2016      5     224.70  2033.21   13.46     4.97   95.24      2.95
# ..    ...    ...        ...      ...     ...      ...     ...       ...
# 108  2025      1     231.56  3455.27   33.77     9.14  467.65      3.08
# 109  2025      2     328.61  4395.25   30.05     4.56  582.27      2.79
# 110  2025      3     253.13  5163.54   31.87     1.67  469.15      2.92
# 111  2025      4     310.94  4877.79   40.39     1.02  365.46      4.16
# 112  2025      5     386.03  4396.54   33.29     1.89  334.15      3.68
#
#      belgium  portugal  ...  ukraine  united_kingdom  austria  australia  \
# 0      33.22      5.07  ...     6.13           48.64    29.22     224.32
# 1      32.69      2.02  ...     2.59           46.73    29.14     176.12
# 2      35.71      5.23  ...     3.34           59.85    24.59     160.17
# 3      43.09      2.60  ...    11.66           52.18    19.52     178.91
# 4      49.23      2.55  ...    15.06           61.59    22.43     174.76
# ..       ...       ...  ...      ...             ...      ...        ...
# 108    37.97     11.37  ...     4.67           66.52    32.11     569.00
# 109    75.18      9.03  ...    20.89           65.82    37.34     515.22
# 110    76.85      8.43  ...     8.89           83.14    28.45     664.79
# 111    50.49     11.18  ...    56.13           80.56    33.42     688.69
# 112    58.05     11.50  ...     4.09           95.32    32.72     615.42
#
#       italy  denmark   taiwan  germany  saudi_arabia   india
# 0    107.29    19.31   835.31   195.42         75.57  261.25
# 1    105.43    17.00   682.03   176.47         44.54  182.43
# 2    122.97    33.57  1061.24   201.67        109.47  216.18
# 3    120.32    20.62   901.61   215.81         81.50  200.05
# 4    142.08    44.76   913.72   264.46        101.57  207.01
# ..      ...      ...      ...      ...           ...     ...
# 108  128.07    14.34  2195.36   224.65         92.27  469.28
# 109  170.43    20.43  2192.10   321.36        104.33  452.66
# 110  141.89    21.26  2439.01   330.74        104.15  485.62
# 111  168.31    21.31  2478.68   329.50         94.94  470.02
# 112  164.93    25.84  2895.37   363.30        105.98  497.59
#
# [113 rows x 73 columns]

# %%
std_silver_import = my_visualizer.make_date_time_index_for_dataframe(silver_import)
std_silver_import
# Out:
#           date  argentina    asean  poland  belarus  brazil  bulgaria  \
# 0   2000-01-31        NaN      NaN     NaN      NaN     NaN       NaN
# 1   2000-02-29        NaN      NaN     NaN      NaN     NaN       NaN
# 2   2000-03-31        NaN      NaN     NaN      NaN     NaN       NaN
# 3   2000-04-30        NaN      NaN     NaN      NaN     NaN       NaN
# 4   2000-05-31        NaN      NaN     NaN      NaN     NaN       NaN
# ..         ...        ...      ...     ...      ...     ...       ...
# 301 2025-02-28     328.61  4395.25   30.05     4.56  582.27      2.79
# 302 2025-03-31     253.13  5163.54   31.87     1.67  469.15      2.92
# 303 2025-04-30     310.94  4877.79   40.39     1.02  365.46      4.16
# 304 2025-05-31     386.03  4396.54   33.29     1.89  334.15      3.68
# 305 2025-06-30        NaN      NaN     NaN      NaN     NaN       NaN
#
#      belgium  portugal  ivory_coast  ...  ukraine  united_kingdom  austria  \
# 0        NaN       NaN          NaN  ...      NaN             NaN      NaN
# 1        NaN       NaN          NaN  ...      NaN             NaN      NaN
# 2        NaN       NaN          NaN  ...      NaN             NaN      NaN
# 3        NaN       NaN          NaN  ...      NaN             NaN      NaN
# 4        NaN       NaN          NaN  ...      NaN             NaN      NaN
# ..       ...       ...          ...  ...      ...             ...      ...
# 301    75.18      9.03        20.61  ...    20.89           65.82    37.34
# 302    76.85      8.43        13.58  ...     8.89           83.14    28.45
# 303    50.49     11.18        21.24  ...    56.13           80.56    33.42
# 304    58.05     11.50        84.45  ...     4.09           95.32    32.72
# 305      NaN       NaN          NaN  ...      NaN             NaN      NaN
#
#      australia   italy  denmark   taiwan  germany  saudi_arabia   india
# 0          NaN     NaN      NaN      NaN      NaN           NaN     NaN
# 1          NaN     NaN      NaN      NaN      NaN           NaN     NaN
# 2          NaN     NaN      NaN      NaN      NaN           NaN     NaN
# 3          NaN     NaN      NaN      NaN      NaN           NaN     NaN
# 4          NaN     NaN      NaN      NaN      NaN           NaN     NaN
# ..         ...     ...      ...      ...      ...           ...     ...
# 301     515.22  170.43    20.43  2192.10   321.36        104.33  452.66
# 302     664.79  141.89    21.26  2439.01   330.74        104.15  485.62
# 303     688.69  168.31    21.31  2478.68   329.50         94.94  470.02
# 304     615.42  164.93    25.84  2895.37   363.30        105.98  497.59
# 305        NaN     NaN      NaN      NaN      NaN           NaN     NaN
#
# [306 rows x 72 columns]

# %%
std_silver_import_fig = my_visualizer.plot_lines_chart(
    std_silver_import,
    x_column="date",
    y_columns=[
        "asean",
        "united_arab_emirates",
        "eu",
        "netherlands",
        "south_korea",
        "hong_kong",
        "usa",
        "japan",
        "china",
    ],
    title="Import statistics by countries",
    y_axis_title="Value",
    y_unit="Million US Dollars",
    prefix_figure_name="import",
    marker=None,
)
std_silver_import_fig

# %% [markdown]
# ### silver_gold_price

# %%
silver_gold_price = my_visualizer.select(
    schema_name="macroeconomics", table_name="gold_price"
)
silver_gold_price = silver_gold_price.astype(
    {
        **{col: "float" for col in silver_gold_price.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
silver_gold_price
# Out:
#            date   close    open    high     low    volume  change
# 0    2000-01-05   282.1   283.7   285.0   281.0   25450.0   -0.56
# 1    2000-01-06   282.4   281.6   282.8   280.2   19060.0    0.11
# 2    2000-01-07   282.9   282.5   284.5   282.0   11270.0    0.18
# 3    2000-01-10   282.7   282.4   283.9   281.8   30600.0   -0.07
# 4    2000-01-11   284.4   282.4   285.3   281.9   13500.0    0.60
# ...         ...     ...     ...     ...     ...       ...     ...
# 6487 2025-04-14  3226.3  3246.0  3261.6  3208.7  189620.0   -0.56
# 6488 2025-05-12  3228.0  3281.0  3295.5  3211.2  308530.0   -3.47
# 6489 2025-06-05  3375.1  3398.0  3427.7  3362.3  224860.0   -0.71
# 6490 2025-07-03  3342.9  3369.0  3376.9  3321.4  153230.0   -0.50
# 6491 2025-07-29  3368.3  3366.1  3368.8  3362.4     110.0    0.43
#
# [6492 rows x 7 columns]

# %%
std_silver_gold_price_fig = my_visualizer.plot_lines_bars_chart(
    silver_gold_price,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["volume"],
    title="Gold Price close",
    y_line_axis_title="USD",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="z_gold_price",
    marker=None,
)
std_silver_gold_price_fig

# %% [markdown]
# ### silver_oil_price

# %%
silver_oil_price = my_visualizer.select(
    schema_name="macroeconomics", table_name="oil_price"
)
silver_oil_price = silver_oil_price.astype(
    {
        **{col: "float" for col in silver_oil_price.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
silver_oil_price
# Out:
#            date     close      open      high       low       volume  change
# 0    2000-01-01  11497.12  11497.12  11497.12  11497.12          NaN    0.00
# 1    2000-01-02  11497.12  11497.12  11497.12  11497.12          NaN    0.00
# 2    2000-01-03   3790.55   3755.74   3836.86   3643.25          NaN    2.23
# 3    2000-01-04   3546.20   3766.57   3766.57   3542.73          NaN   -6.45
# 4    2000-01-05   3507.31   3543.13   3576.17   3371.75          NaN   -1.10
# ...         ...       ...       ...       ...       ...          ...     ...
# 7949 2025-08-06  23315.04  23070.95  23330.49  23042.27  357840000.0    1.29
# 7950 2025-08-07  23389.53  23483.42  23560.73  23225.72  375750000.0    0.32
# 7951 2025-08-08  23611.27  23458.13  23619.24  23437.61  348490000.0    0.95
# 7952 2025-08-11  23526.63  23629.02  23698.00  23484.25  353400000.0   -0.36
# 7953 2025-08-12  23815.88  23651.61  23828.95  23525.40  156130000.0    1.23
#
# [7954 rows x 7 columns]

# %%
std_silver_oil_price_fig = my_visualizer.plot_lines_bars_chart(
    silver_oil_price,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["volume"],
    title="Oil Price close",
    y_line_axis_title="USD",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="z_oil_price",
    marker=None,
)
std_silver_oil_price_fig

# %% [markdown]
# ### silver_dow_jones

# %%
silver_dow_jones = my_visualizer.select(
    schema_name="macroeconomics", table_name="dow_jones"
)
silver_dow_jones = silver_dow_jones.astype(
    {
        **{col: "float" for col in silver_dow_jones.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
silver_dow_jones
# Out:
#            date     close      open      high       low       volume  change
# 0    2000-01-01  11497.12  11497.12  11497.12  11497.12          NaN    0.00
# 1    2000-01-02  11497.12  11497.12  11497.12  11497.12          NaN    0.00
# 2    2000-01-03  11357.51  11501.85  11522.01  11305.69  169750000.0   -1.21
# 3    2000-01-04  10997.94  11349.75  11350.06  10986.45  178420000.0   -3.17
# 4    2000-01-05  11122.66  10989.37  11215.10  10938.67  203190000.0    1.13
# ...         ...       ...       ...       ...       ...          ...     ...
# 7860 2025-08-06  44193.12  44196.61  44290.09  44017.71  518970000.0    0.18
# 7861 2025-08-07  43968.64  44430.09  44498.43  43799.20  492480000.0   -0.51
# 7862 2025-08-08  44175.61  44044.95  44272.75  44028.94  452510000.0    0.47
# 7863 2025-08-11  43975.09  44184.36  44273.03  43911.31  431520000.0   -0.45
# 7864 2025-08-12  44489.13  44050.53  44489.69  44119.88  271350000.0    1.17
#
# [7865 rows x 7 columns]

# %%
std_silver_dow_jones_fig = my_visualizer.plot_lines_bars_chart(
    silver_dow_jones,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["volume"],
    title="Dow Jones close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="z_dow_jones",
    marker=None,
)
std_silver_dow_jones_fig

# %% [markdown]
# ### silver_nyse_composite

# %%
silver_nyse_composite = my_visualizer.select(
    schema_name="macroeconomics", table_name="nyse_composite"
)
silver_nyse_composite = silver_nyse_composite.astype(
    {
        **{col: "float" for col in silver_nyse_composite.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
silver_nyse_composite
# Out:
#            date    close     open     high      low  volume  change
# 0    2000-01-03   6762.1   6762.1   6762.1   6762.1     NaN   -1.66
# 1    2000-01-04   6543.8   6543.8   6543.8   6543.8     NaN   -3.23
# 2    2000-01-05   6567.0   6567.0   6567.0   6567.0     NaN    0.35
# 3    2000-01-06   6635.4   6635.4   6635.4   6635.4     NaN    1.04
# 4    2000-01-07   6792.7   6792.7   6792.7   6792.7     NaN    2.37
# ...         ...      ...      ...      ...      ...     ...     ...
# 6435 2025-08-05  20457.1  20488.9  20527.6  20364.8     NaN   -0.16
# 6436 2025-08-06  20489.1  20457.1  20538.2  20445.5     NaN    0.16
# 6437 2025-08-07  20465.8  20489.1  20643.0  20402.9     NaN   -0.11
# 6438 2025-08-08  20524.2  20465.8  20575.7  20465.8     NaN    0.29
# 6439 2025-08-11  20483.2  20524.2  20580.8  20462.5     NaN   -0.20
#
# [6440 rows x 7 columns]

# %%
std_silver_nyse_composite_fig = my_visualizer.plot_lines_bars_chart(
    silver_nyse_composite,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["volume"],
    title="Nyse Composite close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="z_nyse_composite",
    marker=None,
)
std_silver_nyse_composite_fig

# %% [markdown]
# ### silver_snp_500

# %%
silver_snp_500 = my_visualizer.select(
    schema_name="macroeconomics", table_name="snp_500"
)
silver_snp_500 = silver_snp_500.astype(
    {
        **{col: "float" for col in silver_snp_500.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
silver_snp_500
# Out:
#            date    close     open     high      low  volume  change
# 0    2000-01-03  1455.20  1469.20  1478.00  1438.40     NaN   -0.95
# 1    2000-01-04  1399.40  1455.20  1455.20  1397.40     NaN   -3.83
# 2    2000-01-05  1402.10  1399.40  1413.30  1377.70     NaN    0.19
# 3    2000-01-06  1403.50  1402.10  1411.90  1392.00     NaN    0.10
# 4    2000-01-07  1441.50  1403.50  1441.50  1400.50     NaN    2.71
# ...         ...      ...      ...      ...      ...     ...     ...
# 6436 2025-08-06  6345.06  6309.30  6352.83  6301.11     NaN    0.73
# 6437 2025-08-07  6340.00  6374.32  6389.71  6310.32     NaN   -0.08
# 6438 2025-08-08  6389.45  6355.22  6395.16  6355.22     NaN    0.78
# 6439 2025-08-11  6373.45  6389.67  6407.25  6364.06     NaN   -0.25
# 6440 2025-08-12  6441.76  6400.88  6442.16  6385.98     NaN    1.07
#
# [6441 rows x 7 columns]

# %%
std_silver_snp_500_fig = my_visualizer.plot_lines_bars_chart(
    silver_snp_500,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["volume"],
    title="SNP 500 close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="z_snp_500",
    marker=None,
)
std_silver_snp_500_fig

# %% [markdown]
# ### silver_nasdaq_composite

# %%
silver_nasdaq_composite = my_visualizer.select(
    schema_name="macroeconomics", table_name="nasdaq_composite"
)
silver_nasdaq_composite = silver_nasdaq_composite.astype(
    {
        **{col: "float" for col in silver_nasdaq_composite.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
silver_nasdaq_composite
# Out:
#            date     close      open      high       low        volume  change
# 0    2000-01-03   4131.15   4186.19   4192.19   3989.71           NaN    1.52
# 1    2000-01-04   3901.69   4020.00   4073.25   3898.23           NaN   -5.55
# 2    2000-01-05   3877.54   3854.35   3924.21   3734.87           NaN   -0.62
# 3    2000-01-06   3727.13   3834.44   3868.76   3715.62           NaN   -3.88
# 4    2000-01-07   3882.62   3711.09   3882.67   3711.09           NaN    4.17
# ...         ...       ...       ...       ...       ...           ...     ...
# 6436 2025-08-06  21169.42  20955.22  21183.88  20937.49  1.480000e+09    1.21
# 6437 2025-08-07  21242.70  21325.01  21408.15  21090.05  1.510000e+09    0.35
# 6438 2025-08-08  21450.02  21316.37  21464.53  21284.97  1.430000e+09    0.98
# 6439 2025-08-11  21385.40  21459.65  21549.73  21346.62  1.530000e+09   -0.30
# 6440 2025-08-12  21659.52  21507.44  21670.49  21386.25  7.531500e+08    1.28
#
# [6441 rows x 7 columns]

# %%
std_silver_nasdaq_composite_fig = my_visualizer.plot_lines_bars_chart(
    silver_nasdaq_composite,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["volume"],
    title="Nasdaq Composite close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="z_nasdaq_composite",
    marker=None,
)
std_silver_nasdaq_composite_fig

# %% [markdown]
# ### silver_nasdaq_100

# %%
silver_nasdaq_100 = my_visualizer.select(
    schema_name="macroeconomics", table_name="nasdaq_100"
)
silver_nasdaq_100 = silver_nasdaq_100.astype(
    {
        **{col: "float" for col in silver_nasdaq_100.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
silver_nasdaq_100
# Out:
#            date     close      open      high       low       volume  change
# 0    2000-01-03   3790.55   3755.74   3836.86   3643.25          NaN    2.23
# 1    2000-01-04   3546.20   3766.57   3766.57   3542.73          NaN   -6.45
# 2    2000-01-05   3507.31   3543.13   3576.17   3371.75          NaN   -1.10
# 3    2000-01-06   3340.81   3488.31   3513.55   3334.02          NaN   -4.75
# 4    2000-01-07   3529.60   3337.26   3529.75   3314.75          NaN    5.65
# ...         ...       ...       ...       ...       ...          ...     ...
# 6436 2025-08-06  23315.04  23070.95  23330.49  23042.27  357840000.0    1.29
# 6437 2025-08-07  23389.53  23483.42  23560.73  23225.72  375750000.0    0.32
# 6438 2025-08-08  23611.27  23458.13  23619.24  23437.61  348490000.0    0.95
# 6439 2025-08-11  23526.63  23629.02  23698.00  23484.25  353400000.0   -0.36
# 6440 2025-08-12  23815.88  23651.61  23828.95  23525.40  156130000.0    1.23
#
# [6441 rows x 7 columns]

# %%
std_silver_nasdaq_100_fig = my_visualizer.plot_lines_bars_chart(
    silver_nasdaq_100,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["volume"],
    title="Nasdaq 100 close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="z_nasdaq_100",
    marker=None,
)
std_silver_nasdaq_100_fig

# %% [markdown]
# ## STOCK MARKET

# %%
my_visualizer.connect_to_database(database_name=os.getenv("SILVER_POSTGRES_DATABASE"))
my_visualizer.set_chart_dir(CHARTS_DIR_STOCK_MARKET)

# %% [markdown]
# ### silver_vn_index

# %%
silver_vn_index = my_visualizer.select(
    schema_name="stock_market", table_name="vn_index"
)
silver_vn_index = silver_vn_index.astype(
    {
        **{col: "float" for col in silver_vn_index.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
silver_vn_index
# Out:
#            date     open     high      low    close        volume
# 0    2000-07-28   100.00   100.00   100.00   100.00  4.200000e+03
# 1    2000-07-31   101.55   101.55   101.55   101.55  1.030000e+04
# 2    2000-08-02   103.38   103.38   103.38   103.38  3.000000e+02
# 3    2000-08-04   105.20   105.20   105.20   105.20  3.700000e+03
# 4    2000-08-07   106.92   106.92   106.92   106.92  1.310000e+04
# ...         ...      ...      ...      ...      ...           ...
# 6082 2025-08-05  1547.19  1584.98  1519.08  1547.15  2.695362e+09
# 6083 2025-08-06  1558.56  1573.71  1551.60  1573.71  1.324819e+09
# 6084 2025-08-07  1587.84  1587.84  1567.72  1581.81  1.604082e+09
# 6085 2025-08-08  1589.58  1589.58  1565.45  1584.95  1.816206e+09
# 6086 2025-08-11  1590.98  1601.79  1586.21  1600.41  1.588653e+09
#
# [6087 rows x 6 columns]

# %%
std_silver_vn_index_fig = my_visualizer.plot_lines_bars_chart(
    silver_vn_index,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["volume"],
    title="VN Index close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="vn_index",
    marker=None,
)
std_silver_vn_index_fig

# %% [markdown]
# ### silver_hnx_index

# %%
silver_hnx_index = my_visualizer.select(
    schema_name="stock_market", table_name="hnx_index"
)
silver_hnx_index = silver_hnx_index.astype(
    {
        **{col: "float" for col in silver_hnx_index.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
silver_hnx_index

# %%
std_silver_hnx_index_fig = my_visualizer.plot_lines_bars_chart(
    silver_hnx_index,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["volume"],
    title="HNX Index close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="hnx_index",
    marker=None,
)
std_silver_hnx_index_fig

# %% [markdown]
# ### silver_vn_30_index

# %%
silver_vn_30_index = my_visualizer.select(
    schema_name="stock_market", table_name="vn_30_index"
)
silver_vn_30_index = silver_vn_30_index.astype(
    {
        **{col: "float" for col in silver_vn_30_index.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
silver_vn_30_index

# %%
std_silver_vn_30_index_fig = my_visualizer.plot_lines_bars_chart(
    silver_vn_30_index,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["matched_volume"],
    title="VN 30 Index close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="vn_30_index",
    marker=None,
)
std_silver_vn_30_index_fig

# %% [markdown]
# ### silver_vn_100_index

# %%
silver_vn_100_index = my_visualizer.select(
    schema_name="stock_market", table_name="vn_100_index"
)
silver_vn_100_index = silver_vn_100_index.astype(
    {
        **{col: "float" for col in silver_vn_100_index.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
silver_vn_100_index

# %%
std_silver_vn_100_index_fig = my_visualizer.plot_lines_bars_chart(
    silver_vn_100_index,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["matched_volume"],
    title="VN 100 Index close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="vn_100_index",
    marker=None,
)
std_silver_vn_100_index_fig

# %% [markdown]
# ### silver_hnx_30_index

# %%
silver_hnx_30_index = my_visualizer.select(
    schema_name="stock_market", table_name="hnx_30_index"
)
silver_hnx_30_index = silver_hnx_30_index.astype(
    {
        **{col: "float" for col in silver_hnx_30_index.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
silver_hnx_30_index

# %%
std_silver_hnx_30_index_fig = my_visualizer.plot_lines_bars_chart(
    silver_hnx_30_index,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["matched_volume"],
    title="HNX 30 Index close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="hnx_30_index",
    marker=None,
)
std_silver_hnx_30_index_fig

# %% [markdown]
# ### silver_upcom_index

# %%
silver_upcom_index = my_visualizer.select(
    schema_name="stock_market", table_name="upcom_index"
)
silver_upcom_index = silver_upcom_index.astype(
    {
        **{col: "float" for col in silver_upcom_index.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
silver_upcom_index

# %%
std_silver_upcom_index_fig = my_visualizer.plot_lines_bars_chart(
    silver_upcom_index,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["matched_volume"],
    title="UPCOM Index close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="upcom_index",
    marker=None,
)
std_silver_upcom_index_fig

# %% [markdown]
# ## ENTERPRISE

# %%
my_visualizer.connect_to_database(database_name=os.getenv("BRONZE_POSTGRES_DATABASE"))
my_visualizer.set_chart_dir(CHARTS_DIR_ENTERPRISE)

# %%
def get_code_table_and_plot(code: str):
    code = code.upper()

    if not code:
        print("Need to specify enterprise code before plotting.")
    else:
        silver_enterprise = my_visualizer.select(
            schema_name="enterprise",
            table_name="daily_price",
            conditions=[
                Condition(
                    column=Table.DAILY_PRICE.Column.CODE.value,
                    operator=SqlOperator.EQUAL_TO,
                    value=code,
                    data_type=DataType.VARCHAR,
                )
            ],
        )

        if len(silver_enterprise) == 0:
            print(f"No data found for code: {code}.")
            return

        silver_enterprise = silver_enterprise.astype(
            {
                Table.DAILY_PRICE.Column.DATE.value: "datetime64[ns]",
                Table.DAILY_PRICE.Column.CODE.value: "string",
                Table.DAILY_PRICE.Column.MARKET_ID.value: "int",
                **{
                    col: "float"
                    for col in silver_enterprise.columns
                    if col
                    not in [
                        Table.DAILY_PRICE.Column.DATE.value,
                        Table.DAILY_PRICE.Column.CODE.value,
                        Table.DAILY_PRICE.Column.MARKET_ID.value,
                    ]
                },
            }
        )

        display(silver_enterprise)

        silver_enterprise_fig = my_visualizer.plot_lines_bars_chart(
            silver_enterprise,
            x_column="date",
            y_line_columns=["close"],
            y_bar_columns=["volume"],
            title=f"{code} close",
            y_line_axis_title="Point",
            y_bar_axis_title="",
            y_unit="",
            prefix_figure_name=f"{code.lower()}",
            marker=None,
        )
        
        display(silver_enterprise_fig)

# %% [markdown]
# ### ACB

# %%
code = "ACB"
get_code_table_and_plot(code)

# %% [markdown]
# ### BCM

# %%
code = "BCM"
get_code_table_and_plot(code)

# %% [markdown]
# ### BID

# %%
code = "BID"
get_code_table_and_plot(code)

# %% [markdown]
# ### CTG

# %%
code = "CTG"
get_code_table_and_plot(code)

# %% [markdown]
# ### DGC

# %%
code = "DGC"
get_code_table_and_plot(code)

# %% [markdown]
# ### FPT

# %%
code = "FPT"
get_code_table_and_plot(code)

# %% [markdown]
# ### GAS

# %%
code = "GAS"
get_code_table_and_plot(code)

# %% [markdown]
# ### GVR

# %%
code = "GVR"
get_code_table_and_plot(code)

# %% [markdown]
# ### HDB

# %%
code = "HDB"
get_code_table_and_plot(code)

# %% [markdown]
# ### HPG

# %%
code = "HPG"
get_code_table_and_plot(code)

# %% [markdown]
# ### LPB

# %%
code = "LPB"
get_code_table_and_plot(code)

# %% [markdown]
# ### MBB

# %%
code = "MBB"
get_code_table_and_plot(code)

# %% [markdown]
# ### MSN

# %%
code = "MSN"
get_code_table_and_plot(code)

# %% [markdown]
# ### PLX

# %%
code = "PLX"
get_code_table_and_plot(code)

# %% [markdown]
# ### SAB

# %%
code = "SAB"
get_code_table_and_plot(code)

# %% [markdown]
# ### SHB

# %%
code = "SHB"
get_code_table_and_plot(code)

# %% [markdown]
# ### SSB

# %%
code = "SSB"
get_code_table_and_plot(code)

# %% [markdown]
# ### SSI

# %%
code = "SSI"
get_code_table_and_plot(code)

# %% [markdown]
# ### STB

# %%
code = "STB"
get_code_table_and_plot(code)

# %% [markdown]
# ### TCB

# %%
code = "TCB"
get_code_table_and_plot(code)

# %% [markdown]
# ### TPB

# %%
code = "TPB"
get_code_table_and_plot(code)

# %% [markdown]
# ### VCB

# %%
code = "VCB"
get_code_table_and_plot(code)

# %% [markdown]
# ### VHM

# %%
code = "VHM"
get_code_table_and_plot(code)

# %% [markdown]
# ### VIB

# %%
code = "VIB"
get_code_table_and_plot(code)

# %% [markdown]
# ### VIC

# %%
code = "VIC"
get_code_table_and_plot(code)

# %% [markdown]
# ### VJC

# %%
code = "VJC"
get_code_table_and_plot(code)

# %% [markdown]
# ### VNM

# %%
code = "VNM"
get_code_table_and_plot(code)

# %% [markdown]
# ### VPB

# %%
code = "VPB"
get_code_table_and_plot(code)

# %% [markdown]
# ### VRE

# %%
code = "VRE"
get_code_table_and_plot(code)
