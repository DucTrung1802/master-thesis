# %% [markdown]
# # Gold Visualization

# %% [markdown]
# ## Import libraries

# %%
import os
import sys
import pandas as pd

# go one level up from where the notebook is running
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

from logger.logger import Logger
from visualizer.visualizer import Visualizer
from utils.constants import *
from utils.enums import *
from dtos.tabular_database_driver_dtos.tabular_database_driver_dtos import *

# %% [markdown]
# ## Initialize the Logger

# %%
my_logger = Logger(file_name=GOLD_VISUALIZATION_LOG_FILE_BASE)

# %% [markdown]
# ## Initialize the Visualizer

# %%
my_visualizer = Visualizer(logger=my_logger)

# %% [markdown]
# ## MACROECONOMICS

# %%
my_visualizer.connect_to_database(database_name=os.getenv("GOLD_POSTGRES_DATABASE"))
my_visualizer.set_chart_dir(CHARTS_DIR_MACROECONOMICS)

# %% [markdown]
# ### gold_gdp

# %%
gold_gdp = my_visualizer.select(schema_name="macroeconomics", table_name="gdp")
gold_gdp
# Out:
#             date  gdp_growth
# 0     2000-01-02         NaN
# 1     2000-01-03         NaN
# 2     2000-01-04         NaN
# 3     2000-01-05         NaN
# 4     2000-01-06         NaN
# ...          ...         ...
# 9308  2025-06-13    7.767582
# 9309  2025-06-17    7.812857
# 9310  2025-06-20    7.846813
# 9311  2025-06-24    7.892088
# 9312  2025-06-28    7.937363
#
# [9313 rows x 2 columns]

# %%
std_gold_gdp = my_visualizer.make_date_time_index_for_dataframe(gold_gdp)
std_gold_gdp
# Out:
#            date  gdp_growth
# 0    2000-01-01         NaN
# 1    2000-01-02         NaN
# 2    2000-01-03         NaN
# 3    2000-01-04         NaN
# 4    2000-01-05         NaN
# ...         ...         ...
# 9308 2025-06-26    7.914725
# 9309 2025-06-27    7.926044
# 9310 2025-06-28    7.937363
# 9311 2025-06-29    7.948681
# 9312 2025-06-30    7.960000
#
# [9313 rows x 2 columns]

# %%
std_gold_gdp_fig = my_visualizer.plot_lines_chart(
    std_gold_gdp,
    x_column="date",
    y_columns=["gdp_growth"],
    title="GDP Growth",
    y_axis_title="Rate",
    y_unit="%",
    prefix_figure_name="gdp",
    marker=None,
)
std_gold_gdp_fig

# %% [markdown]
# ### gold_cpi

# %%
gold_cpi = my_visualizer.select(schema_name="macroeconomics", table_name="cpi")
gold_cpi
# Out:
#             date  beverage_and_cigarette  consumer_price_index  \
# 0     2000-01-01                     NaN                   NaN
# 1     2000-01-02                     NaN                   NaN
# 2     2000-01-03                     NaN                   NaN
# 3     2000-01-04                     NaN                   NaN
# 4     2000-01-05                     NaN                   NaN
# ...          ...                     ...                   ...
# 9308  2025-06-26                 100.192            100.437333
# 9309  2025-06-27                 100.194            100.448000
# 9310  2025-06-28                 100.196            100.458667
# 9311  2025-06-29                 100.198            100.469333
# 9312  2025-06-30                 100.200            100.480000
#
#       culture_entertainment_and_tourism  eating_outside  education       food  \
# 0                                   NaN             NaN        NaN        NaN
# 1                                   NaN             NaN        NaN        NaN
# 2                                   NaN             NaN        NaN        NaN
# 3                                   NaN             NaN        NaN        NaN
# 4                                   NaN             NaN        NaN        NaN
# ...                                 ...             ...        ...        ...
# 9308                         100.271333      100.297333     100.01  99.707333
# 9309                         100.271000      100.298000     100.01  99.703000
# 9310                         100.270667      100.298667     100.01  99.698667
# 9311                         100.270333      100.299333     100.01  99.694333
# 9312                         100.270000      100.300000     100.01  99.690000
#
#       food_and_foodstuff  foodstuff  garment_footwear_hat  \
# 0                    NaN        NaN                   NaN
# 1                    NaN        NaN                   NaN
# 2                    NaN        NaN                   NaN
# 3                    NaN        NaN                   NaN
# 4                    NaN        NaN                   NaN
# ...                  ...        ...                   ...
# 9308             100.056    100.012            100.093333
# 9309             100.057    100.014            100.095000
# 9310             100.058    100.016            100.096667
# 9311             100.059    100.018            100.098333
# 9312             100.060    100.020            100.100000
#
#       household_appliances_and_goods  housing_and_construction_materials  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
# ...                              ...                                 ...
# 9308                         100.138                             101.328
# 9309                         100.136                             101.351
# 9310                         100.134                             101.374
# 9311                         100.132                             101.397
# 9312                         100.130                             101.420
#
#       medicine_and_health_care  other_goods_and_services  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ...                        ...                       ...
# 9308                    100.02                100.135333
# 9309                    100.02                100.124000
# 9310                    100.02                100.112667
# 9311                    100.02                100.101333
# 9312                    100.02                100.090000
#
#       postal_services_and_telecommunication     traffic
# 0                                       NaN         NaN
# 1                                       NaN         NaN
# 2                                       NaN         NaN
# 3                                       NaN         NaN
# 4                                       NaN         NaN
# ...                                     ...         ...
# 9308                             100.010667  101.382667
# 9309                             100.003000  101.452000
# 9310                              99.995333  101.521333
# 9311                              99.987667  101.590667
# 9312                              99.980000  101.660000
#
# [9313 rows x 16 columns]

# %%
std_gold_cpi = my_visualizer.make_date_time_index_for_dataframe(gold_cpi)
std_gold_cpi
# Out:
#            date  beverage_and_cigarette  consumer_price_index  \
# 0    2000-01-01                     NaN                   NaN
# 1    2000-01-02                     NaN                   NaN
# 2    2000-01-03                     NaN                   NaN
# 3    2000-01-04                     NaN                   NaN
# 4    2000-01-05                     NaN                   NaN
# ...         ...                     ...                   ...
# 9308 2025-06-26                 100.192            100.437333
# 9309 2025-06-27                 100.194            100.448000
# 9310 2025-06-28                 100.196            100.458667
# 9311 2025-06-29                 100.198            100.469333
# 9312 2025-06-30                 100.200            100.480000
#
#       culture_entertainment_and_tourism  eating_outside  education       food  \
# 0                                   NaN             NaN        NaN        NaN
# 1                                   NaN             NaN        NaN        NaN
# 2                                   NaN             NaN        NaN        NaN
# 3                                   NaN             NaN        NaN        NaN
# 4                                   NaN             NaN        NaN        NaN
# ...                                 ...             ...        ...        ...
# 9308                         100.271333      100.297333     100.01  99.707333
# 9309                         100.271000      100.298000     100.01  99.703000
# 9310                         100.270667      100.298667     100.01  99.698667
# 9311                         100.270333      100.299333     100.01  99.694333
# 9312                         100.270000      100.300000     100.01  99.690000
#
#       food_and_foodstuff  foodstuff  garment_footwear_hat  \
# 0                    NaN        NaN                   NaN
# 1                    NaN        NaN                   NaN
# 2                    NaN        NaN                   NaN
# 3                    NaN        NaN                   NaN
# 4                    NaN        NaN                   NaN
# ...                  ...        ...                   ...
# 9308             100.056    100.012            100.093333
# 9309             100.057    100.014            100.095000
# 9310             100.058    100.016            100.096667
# 9311             100.059    100.018            100.098333
# 9312             100.060    100.020            100.100000
#
#       household_appliances_and_goods  housing_and_construction_materials  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
# ...                              ...                                 ...
# 9308                         100.138                             101.328
# 9309                         100.136                             101.351
# 9310                         100.134                             101.374
# 9311                         100.132                             101.397
# 9312                         100.130                             101.420
#
#       medicine_and_health_care  other_goods_and_services  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ...                        ...                       ...
# 9308                    100.02                100.135333
# 9309                    100.02                100.124000
# 9310                    100.02                100.112667
# 9311                    100.02                100.101333
# 9312                    100.02                100.090000
#
#       postal_services_and_telecommunication     traffic
# 0                                       NaN         NaN
# 1                                       NaN         NaN
# 2                                       NaN         NaN
# 3                                       NaN         NaN
# 4                                       NaN         NaN
# ...                                     ...         ...
# 9308                             100.010667  101.382667
# 9309                             100.003000  101.452000
# 9310                              99.995333  101.521333
# 9311                              99.987667  101.590667
# 9312                              99.980000  101.660000
#
# [9313 rows x 16 columns]

# %%
std_gold_cpi_fig = my_visualizer.plot_lines_chart(
    std_gold_cpi,
    x_column="date",
    y_columns=["consumer_price_index"],
    title="Consumer Price Index",
    y_axis_title="Rate",
    y_unit="%",
    prefix_figure_name="cpi",
    marker=None,
)
std_gold_cpi_fig

# %% [markdown]
# ### gold_ppi

# %%
gold_ppi = my_visualizer.select(schema_name="macroeconomics", table_name="ppi")
gold_ppi
# Out:
#             date general_index forestry_services agricultural_services  \
# 0     2000-01-01          None              None                  None
# 1     2000-01-02          None              None                  None
# 2     2000-01-03          None              None                  None
# 3     2000-01-04          None              None                  None
# 4     2000-01-05          None              None                  None
# ...          ...           ...               ...                   ...
# 9308  2025-06-26        103.14            100.76                103.83
# 9309  2025-06-27        103.14            100.76                103.83
# 9310  2025-06-28        103.14            100.76                103.83
# 9311  2025-06-29        103.14            100.76                103.83
# 9312  2025-06-30        103.14            100.76                103.83
#
#      forestry_and_related_services exploited_forest_products  \
# 0                             None                      None
# 1                             None                      None
# 2                             None                      None
# 3                             None                      None
# 4                             None                      None
# ...                            ...                       ...
# 9308                        101.35                    101.31
# 9309                        101.35                    101.31
# 9310                        101.35                    101.31
# 9311                        101.35                    101.31
# 9312                        101.35                    101.31
#
#      collected_forest_products agriculture_and_related_services  \
# 0                         None                             None
# 1                         None                             None
# 2                         None                             None
# 3                         None                             None
# 4                         None                             None
# ...                        ...                              ...
# 9308                    101.28                            103.5
# 9309                    101.28                            103.5
# 9310                    101.28                            103.5
# 9311                    101.28                            103.5
# 9312                    101.28                            103.5
#
#      livestock_products annual_crop_products perennial_crop_products  \
# 0                  None                 None                    None
# 1                  None                 None                    None
# 2                  None                 None                    None
# 3                  None                 None                    None
# 4                  None                 None                    None
# ...                 ...                  ...                     ...
# 9308              98.64               105.74                   106.7
# 9309              98.64               105.74                   106.7
# 9310              98.64               105.74                   106.7
# 9311              98.64               105.74                   106.7
# 9312              98.64               105.74                   106.7
#
#      exploited_aquatic_products aquatic_products_exploitation_and_farming  \
# 0                          None                                      None
# 1                          None                                      None
# 2                          None                                      None
# 3                          None                                      None
# 4                          None                                      None
# ...                         ...                                       ...
# 9308                     105.25                                    102.19
# 9309                     105.25                                    102.19
# 9310                     105.25                                    102.19
# 9311                     105.25                                    102.19
# 9312                     105.25                                    102.19
#
#      aquatic_farming_products forest_planting_and_care
# 0                        None                     None
# 1                        None                     None
# 2                        None                     None
# 3                        None                     None
# 4                        None                     None
# ...                       ...                      ...
# 9308                   100.04                   101.76
# 9309                   100.04                   101.76
# 9310                   100.04                   101.76
# 9311                   100.04                   101.76
# 9312                   100.04                   101.76
#
# [9313 rows x 15 columns]

# %%
std_gold_ppi = my_visualizer.make_date_time_index_for_dataframe(gold_ppi)
std_gold_ppi
# Out:
#            date general_index forestry_services agricultural_services  \
# 0    2000-01-01          None              None                  None
# 1    2000-01-02          None              None                  None
# 2    2000-01-03          None              None                  None
# 3    2000-01-04          None              None                  None
# 4    2000-01-05          None              None                  None
# ...         ...           ...               ...                   ...
# 9308 2025-06-26        103.14            100.76                103.83
# 9309 2025-06-27        103.14            100.76                103.83
# 9310 2025-06-28        103.14            100.76                103.83
# 9311 2025-06-29        103.14            100.76                103.83
# 9312 2025-06-30        103.14            100.76                103.83
#
#      forestry_and_related_services exploited_forest_products  \
# 0                             None                      None
# 1                             None                      None
# 2                             None                      None
# 3                             None                      None
# 4                             None                      None
# ...                            ...                       ...
# 9308                        101.35                    101.31
# 9309                        101.35                    101.31
# 9310                        101.35                    101.31
# 9311                        101.35                    101.31
# 9312                        101.35                    101.31
#
#      collected_forest_products agriculture_and_related_services  \
# 0                         None                             None
# 1                         None                             None
# 2                         None                             None
# 3                         None                             None
# 4                         None                             None
# ...                        ...                              ...
# 9308                    101.28                            103.5
# 9309                    101.28                            103.5
# 9310                    101.28                            103.5
# 9311                    101.28                            103.5
# 9312                    101.28                            103.5
#
#      livestock_products annual_crop_products perennial_crop_products  \
# 0                  None                 None                    None
# 1                  None                 None                    None
# 2                  None                 None                    None
# 3                  None                 None                    None
# 4                  None                 None                    None
# ...                 ...                  ...                     ...
# 9308              98.64               105.74                   106.7
# 9309              98.64               105.74                   106.7
# 9310              98.64               105.74                   106.7
# 9311              98.64               105.74                   106.7
# 9312              98.64               105.74                   106.7
#
#      exploited_aquatic_products aquatic_products_exploitation_and_farming  \
# 0                          None                                      None
# 1                          None                                      None
# 2                          None                                      None
# 3                          None                                      None
# 4                          None                                      None
# ...                         ...                                       ...
# 9308                     105.25                                    102.19
# 9309                     105.25                                    102.19
# 9310                     105.25                                    102.19
# 9311                     105.25                                    102.19
# 9312                     105.25                                    102.19
#
#      aquatic_farming_products forest_planting_and_care
# 0                        None                     None
# 1                        None                     None
# 2                        None                     None
# 3                        None                     None
# 4                        None                     None
# ...                       ...                      ...
# 9308                   100.04                   101.76
# 9309                   100.04                   101.76
# 9310                   100.04                   101.76
# 9311                   100.04                   101.76
# 9312                   100.04                   101.76
#
# [9313 rows x 15 columns]

# %%
std_gold_ppi_fig = my_visualizer.plot_lines_chart(
    std_gold_ppi,
    x_column="date",
    y_columns=["general_index"],
    title="Producer Price Index",
    y_axis_title="Rate",
    y_unit="%",
    prefix_figure_name="ppi",
    marker=None,
)
std_gold_ppi_fig

# %% [markdown]
# ### gold_ipi

# %%
gold_ipi = my_visualizer.select(schema_name="macroeconomics", table_name="ipi")
gold_ipi
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
std_gold_ipi = my_visualizer.make_date_time_index_for_dataframe(gold_ipi)
std_gold_ipi
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 std_gold_ipi = my_visualizer.make_date_time_index_for_dataframe(gold_ipi)
#       2 std_gold_ipi
#
# File d:\GIT\master-thesis\src\visualizer\visualizer.py:75, in Visualizer.make_date_time_index_for_dataframe(self, df, start_date, end_date)
#      69 def make_date_time_index_for_dataframe(
#      70     self,
#      71     df: pd.DataFrame,
#      72     start_date: datetime = SCRAPER_START_DATE,
#      73     end_date: datetime = SCRAPER_END_DATE,
#      74 ) -> pd.DataFrame:
# ---> 75     return make_date_time_index_for_dataframe(df, start_date, end_date)
#
# File d:\GIT\master-thesis\src\utils\utils.py:349, in make_date_time_index_for_dataframe(df, start_date, end_date)
#     347     generate_date_time_type = GenerateDateTimeType.DATE
#     348 else:
# --> 349     raise ValueError("DataFrame does not contain recognizable time columns")
#     351 # Build "date" column from existing fields
#     352 match generate_date_time_type:
#
# ValueError: DataFrame does not contain recognizable time columns

# %%
std_gold_ipi_fig = my_visualizer.plot_lines_chart(
    std_gold_ipi,
    x_column="date",
    y_columns=["general_index"],
    title="Industrial Production Index",
    y_axis_title="Rate",
    y_unit="%",
    prefix_figure_name="ipi",
)
std_gold_ipi_fig

# %% [markdown]
# ### gold_xpi

# %%
gold_xpi = my_visualizer.select(schema_name="macroeconomics", table_name="xpi")
gold_xpi
# Out:
#             date  animal_feed_and_raw_materials  aquatic_products  \
# 0     2000-01-01                            NaN               NaN
# 1     2000-01-02                            NaN               NaN
# 2     2000-01-03                            NaN               NaN
# 3     2000-01-04                            NaN               NaN
# 4     2000-01-05                            NaN               NaN
# ...          ...                            ...               ...
# 9308  2025-06-26                     106.386667        918.357333
# 9309  2025-06-27                     106.290000        915.328000
# 9310  2025-06-28                     106.193333        912.298667
# 9311  2025-06-29                     106.096667        909.269333
# 9312  2025-06-30                     106.000000        906.240000
#
#       cameras_camcorders_and_components  cashew_nuts  \
# 0                                   NaN          NaN
# 1                                   NaN          NaN
# 2                                   NaN          NaN
# 3                                   NaN          NaN
# 4                                   NaN          NaN
# ...                                 ...          ...
# 9308                            593.508    70.101333
# 9309                            595.866    69.641000
# 9310                            598.224    69.180667
# 9311                            600.582    68.720333
# 9312                            602.940    68.260000
#
#       cassava_and_cassava_products  chemical_products   chemicals  \
# 0                              NaN                NaN         NaN
# 1                              NaN                NaN         NaN
# 2                              NaN                NaN         NaN
# 3                              NaN                NaN         NaN
# 4                              NaN                NaN         NaN
# ...                            ...                ...         ...
# 9308                       289.834         221.745333  229.554667
# 9309                       285.543         221.559000  230.326000
# 9310                       281.252         221.372667  231.097333
# 9311                       276.961         221.186333  231.868667
# 9312                       272.670         221.000000  232.640000
#
#       clinker_and_cement      coffee  ...  rubber_products        tea  \
# 0                    NaN         NaN  ...              NaN        NaN
# 1                    NaN         NaN  ...              NaN        NaN
# 2                    NaN         NaN  ...              NaN        NaN
# 3                    NaN         NaN  ...              NaN        NaN
# 4                    NaN         NaN  ...              NaN        NaN
# ...                  ...         ...  ...              ...        ...
# 9308         2707.044667  122.727333  ...       126.334667  11.097333
# 9309         2696.421000  121.773000  ...       126.421000  11.123000
# 9310         2685.797333  120.818667  ...       126.507333  11.148667
# 9311         2675.173667  119.864333  ...       126.593667  11.174333
# 9312         2664.550000  118.910000  ...       126.680000  11.200000
#
#       textile_fibers_yarns_of_all_kinds  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 9308                            155.422
# 9309                            155.269
# 9310                            155.116
# 9311                            154.963
# 9312                            154.810
#
#       textile_garment_leather_footwear_raw_materials  textiles_garments  \
# 0                                                NaN                NaN
# 1                                                NaN                NaN
# 2                                                NaN                NaN
# 3                                                NaN                NaN
# 4                                                NaN                NaN
# ...                                              ...                ...
# 9308                                      194.995333           3555.660
# 9309                                      194.619000           3566.015
# 9310                                      194.242667           3576.370
# 9311                                      193.866333           3586.725
# 9312                                      193.490000           3597.080
#
#        total_value  toys_sports_equipment_and_parts  \
# 0              NaN                              NaN
# 1              NaN                              NaN
# 2              NaN                              NaN
# 3              NaN                              NaN
# 4              NaN                              NaN
# ...            ...                              ...
# 9308  39503.245333                       833.749333
# 9309  39499.699000                       839.847000
# 9310  39496.152667                       845.944667
# 9311  39492.606333                       852.042333
# 9312  39489.060000                       858.140000
#
#       transportation_vehicles_and_spare_parts  vegetables  \
# 0                                         NaN         NaN
# 1                                         NaN         NaN
# 2                                         NaN         NaN
# 3                                         NaN         NaN
# 4                                         NaN         NaN
# ...                                       ...         ...
# 9308                                 1451.090  781.501333
# 9309                                 1452.445  787.846000
# 9310                                 1453.800  794.190667
# 9311                                 1455.155  800.535333
# 9312                                 1456.510  806.880000
#
#       wood_and_wood_products
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 9308                1357.380
# 9309                1355.325
# 9310                1353.270
# 9311                1351.215
# 9312                1349.160
#
# [9313 rows x 45 columns]

# %%
std_gold_xpi = my_visualizer.make_date_time_index_for_dataframe(gold_xpi)
std_gold_xpi
# Out:
#            date  animal_feed_and_raw_materials  aquatic_products  \
# 0    2000-01-01                            NaN               NaN
# 1    2000-01-02                            NaN               NaN
# 2    2000-01-03                            NaN               NaN
# 3    2000-01-04                            NaN               NaN
# 4    2000-01-05                            NaN               NaN
# ...         ...                            ...               ...
# 9308 2025-06-26                     106.386667        918.357333
# 9309 2025-06-27                     106.290000        915.328000
# 9310 2025-06-28                     106.193333        912.298667
# 9311 2025-06-29                     106.096667        909.269333
# 9312 2025-06-30                     106.000000        906.240000
#
#       cameras_camcorders_and_components  cashew_nuts  \
# 0                                   NaN          NaN
# 1                                   NaN          NaN
# 2                                   NaN          NaN
# 3                                   NaN          NaN
# 4                                   NaN          NaN
# ...                                 ...          ...
# 9308                            593.508    70.101333
# 9309                            595.866    69.641000
# 9310                            598.224    69.180667
# 9311                            600.582    68.720333
# 9312                            602.940    68.260000
#
#       cassava_and_cassava_products  chemical_products   chemicals  \
# 0                              NaN                NaN         NaN
# 1                              NaN                NaN         NaN
# 2                              NaN                NaN         NaN
# 3                              NaN                NaN         NaN
# 4                              NaN                NaN         NaN
# ...                            ...                ...         ...
# 9308                       289.834         221.745333  229.554667
# 9309                       285.543         221.559000  230.326000
# 9310                       281.252         221.372667  231.097333
# 9311                       276.961         221.186333  231.868667
# 9312                       272.670         221.000000  232.640000
#
#       clinker_and_cement      coffee  ...  rubber_products        tea  \
# 0                    NaN         NaN  ...              NaN        NaN
# 1                    NaN         NaN  ...              NaN        NaN
# 2                    NaN         NaN  ...              NaN        NaN
# 3                    NaN         NaN  ...              NaN        NaN
# 4                    NaN         NaN  ...              NaN        NaN
# ...                  ...         ...  ...              ...        ...
# 9308         2707.044667  122.727333  ...       126.334667  11.097333
# 9309         2696.421000  121.773000  ...       126.421000  11.123000
# 9310         2685.797333  120.818667  ...       126.507333  11.148667
# 9311         2675.173667  119.864333  ...       126.593667  11.174333
# 9312         2664.550000  118.910000  ...       126.680000  11.200000
#
#       textile_fibers_yarns_of_all_kinds  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 9308                            155.422
# 9309                            155.269
# 9310                            155.116
# 9311                            154.963
# 9312                            154.810
#
#       textile_garment_leather_footwear_raw_materials  textiles_garments  \
# 0                                                NaN                NaN
# 1                                                NaN                NaN
# 2                                                NaN                NaN
# 3                                                NaN                NaN
# 4                                                NaN                NaN
# ...                                              ...                ...
# 9308                                      194.995333           3555.660
# 9309                                      194.619000           3566.015
# 9310                                      194.242667           3576.370
# 9311                                      193.866333           3586.725
# 9312                                      193.490000           3597.080
#
#        total_value  toys_sports_equipment_and_parts  \
# 0              NaN                              NaN
# 1              NaN                              NaN
# 2              NaN                              NaN
# 3              NaN                              NaN
# 4              NaN                              NaN
# ...            ...                              ...
# 9308  39503.245333                       833.749333
# 9309  39499.699000                       839.847000
# 9310  39496.152667                       845.944667
# 9311  39492.606333                       852.042333
# 9312  39489.060000                       858.140000
#
#       transportation_vehicles_and_spare_parts  vegetables  \
# 0                                         NaN         NaN
# 1                                         NaN         NaN
# 2                                         NaN         NaN
# 3                                         NaN         NaN
# 4                                         NaN         NaN
# ...                                       ...         ...
# 9308                                 1451.090  781.501333
# 9309                                 1452.445  787.846000
# 9310                                 1453.800  794.190667
# 9311                                 1455.155  800.535333
# 9312                                 1456.510  806.880000
#
#       wood_and_wood_products
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 9308                1357.380
# 9309                1355.325
# 9310                1353.270
# 9311                1351.215
# 9312                1349.160
#
# [9313 rows x 45 columns]

# %%
std_gold_xpi_fig = my_visualizer.plot_lines_chart(
    std_gold_xpi,
    x_column="date",
    y_columns=["total_value"],
    title="Export Price Index",
    y_axis_title="Value",
    y_unit="thousand tons",
    prefix_figure_name="xpi",
    marker=None,
)
std_gold_xpi_fig

# %% [markdown]
# ### gold_mpi

# %%
gold_mpi = my_visualizer.select(schema_name="macroeconomics", table_name="mpi")
gold_mpi

# %%
std_gold_mpi = my_visualizer.make_date_time_index_for_dataframe(gold_mpi)
std_gold_mpi

# %%
std_gold_mpi_fig = my_visualizer.plot_lines_chart(
    std_gold_mpi,
    x_column="date",
    y_columns=["total_value"],
    title="Import Price Index",
    y_axis_title="Value",
    y_unit="thousand tons",
    prefix_figure_name="mpi",
)
std_gold_mpi_fig

# %% [markdown]
# ### gold_population

# %%
gold_population = my_visualizer.select(
    schema_name="macroeconomics", table_name="population"
)
gold_population
# Out:
#             date  population  population_area_urban_rate  population_density  \
# 0     2000-01-01         NaN                         NaN                 NaN
# 1     2000-01-02         NaN                         NaN                 NaN
# 2     2000-01-03         NaN                         NaN                 NaN
# 3     2000-01-04         NaN                         NaN                 NaN
# 4     2000-01-05         NaN                         NaN                 NaN
# ...          ...         ...                         ...                 ...
# 9308  2025-06-26       101.3                        38.5               306.0
# 9309  2025-06-27       101.3                        38.5               306.0
# 9310  2025-06-28       101.3                        38.5               306.0
# 9311  2025-06-29       101.3                        38.5               306.0
# 9312  2025-06-30       101.3                        38.5               306.0
#
#       population_growth_rate
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 9308                    1.03
# 9309                    1.03
# 9310                    1.03
# 9311                    1.03
# 9312                    1.03
#
# [9313 rows x 5 columns]

# %%
std_gold_population = my_visualizer.make_date_time_index_for_dataframe(gold_population)
std_gold_population
# Out:
#            date  population  population_area_urban_rate  population_density  \
# 0    2000-01-01         NaN                         NaN                 NaN
# 1    2000-01-02         NaN                         NaN                 NaN
# 2    2000-01-03         NaN                         NaN                 NaN
# 3    2000-01-04         NaN                         NaN                 NaN
# 4    2000-01-05         NaN                         NaN                 NaN
# ...         ...         ...                         ...                 ...
# 9308 2025-06-26       101.3                        38.5               306.0
# 9309 2025-06-27       101.3                        38.5               306.0
# 9310 2025-06-28       101.3                        38.5               306.0
# 9311 2025-06-29       101.3                        38.5               306.0
# 9312 2025-06-30       101.3                        38.5               306.0
#
#       population_growth_rate
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 9308                    1.03
# 9309                    1.03
# 9310                    1.03
# 9311                    1.03
# 9312                    1.03
#
# [9313 rows x 5 columns]

# %%
std_gold_population_fig = my_visualizer.plot_lines_chart(
    std_gold_population,
    x_column="date",
    y_columns=["population"],
    title="Population",
    y_axis_title="Value",
    y_unit="millions people",
    prefix_figure_name="population",
    marker=None,
)
std_gold_population_fig

# %% [markdown]
# ### gold_labor

# %%
gold_labor = my_visualizer.select(schema_name="macroeconomics", table_name="labor")
gold_labor
# Out:
#             date  agriculture_forestry_and_fishery  employed_amount  female  \
# 0     2000-01-01                               NaN              NaN     NaN
# 1     2000-01-02                               NaN              NaN     NaN
# 2     2000-01-03                               NaN              NaN     NaN
# 3     2000-01-04                               NaN              NaN     NaN
# 4     2000-01-05                               NaN              NaN     NaN
# ...          ...                               ...              ...     ...
# 9308  2025-06-26                             13.67             52.9    46.6
# 9309  2025-06-27                             13.67             52.9    46.6
# 9310  2025-06-28                             13.67             52.9    46.6
# 9311  2025-06-29                             13.67             52.9    46.6
# 9312  2025-06-30                             13.67             52.9    46.6
#
#       industry_construction  labor_force_annual_change_percent  \
# 0                       NaN                                NaN
# 1                       NaN                                NaN
# 2                       NaN                                NaN
# 3                       NaN                                NaN
# 4                       NaN                                NaN
# ...                     ...                                ...
# 9308                  16.86                               0.95
# 9309                  16.86                               0.95
# 9310                  16.86                               0.95
# 9311                  16.86                               0.95
# 9312                  16.86                               0.95
#
#       labor_force_participation_rate_percent  male  services  unemployed  \
# 0                                        NaN   NaN       NaN         NaN
# 1                                        NaN   NaN       NaN         NaN
# 2                                        NaN   NaN       NaN         NaN
# 3                                        NaN   NaN       NaN         NaN
# 4                                        NaN   NaN       NaN         NaN
# ...                                      ...   ...       ...         ...
# 9308                                   51.23  53.4      20.8        0.52
# 9309                                   51.23  53.4      20.8        0.52
# 9310                                   51.23  53.4      20.8        0.52
# 9311                                   51.23  53.4      20.8        0.52
# 9312                                   51.23  53.4      20.8        0.52
#
#       urban_unemployment_rate
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 9308                     2.53
# 9309                     2.53
# 9310                     2.53
# 9311                     2.53
# 9312                     2.53
#
# [9313 rows x 11 columns]

# %%
std_gold_labor = my_visualizer.make_date_time_index_for_dataframe(gold_labor)
std_gold_labor
# Out:
#            date  agriculture_forestry_and_fishery  employed_amount  female  \
# 0    2000-01-01                               NaN              NaN     NaN
# 1    2000-01-02                               NaN              NaN     NaN
# 2    2000-01-03                               NaN              NaN     NaN
# 3    2000-01-04                               NaN              NaN     NaN
# 4    2000-01-05                               NaN              NaN     NaN
# ...         ...                               ...              ...     ...
# 9308 2025-06-26                             13.67             52.9    46.6
# 9309 2025-06-27                             13.67             52.9    46.6
# 9310 2025-06-28                             13.67             52.9    46.6
# 9311 2025-06-29                             13.67             52.9    46.6
# 9312 2025-06-30                             13.67             52.9    46.6
#
#       industry_construction  labor_force_annual_change_percent  \
# 0                       NaN                                NaN
# 1                       NaN                                NaN
# 2                       NaN                                NaN
# 3                       NaN                                NaN
# 4                       NaN                                NaN
# ...                     ...                                ...
# 9308                  16.86                               0.95
# 9309                  16.86                               0.95
# 9310                  16.86                               0.95
# 9311                  16.86                               0.95
# 9312                  16.86                               0.95
#
#       labor_force_participation_rate_percent  male  services  unemployed  \
# 0                                        NaN   NaN       NaN         NaN
# 1                                        NaN   NaN       NaN         NaN
# 2                                        NaN   NaN       NaN         NaN
# 3                                        NaN   NaN       NaN         NaN
# 4                                        NaN   NaN       NaN         NaN
# ...                                      ...   ...       ...         ...
# 9308                                   51.23  53.4      20.8        0.52
# 9309                                   51.23  53.4      20.8        0.52
# 9310                                   51.23  53.4      20.8        0.52
# 9311                                   51.23  53.4      20.8        0.52
# 9312                                   51.23  53.4      20.8        0.52
#
#       urban_unemployment_rate
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 9308                     2.53
# 9309                     2.53
# 9310                     2.53
# 9311                     2.53
# 9312                     2.53
#
# [9313 rows x 11 columns]

# %%
std_gold_labor_fig = my_visualizer.plot_lines_chart(
    std_gold_labor,
    x_column="date",
    y_columns=["employed_amount"],
    title="Employed Amount",
    y_axis_title="Value",
    y_unit="millions people",
    prefix_figure_name="labor",
    marker=None,
)
std_gold_labor_fig

# %% [markdown]
# ### gold_pmi

# %%
gold_pmi = my_visualizer.select(schema_name="macroeconomics", table_name="pmi")
gold_pmi

# %%
std_gold_pmi = my_visualizer.make_date_time_index_for_dataframe(gold_pmi)
std_gold_pmi

# %%
std_gold_pmi_fig = my_visualizer.plot_lines_chart(
    std_gold_pmi,
    x_column="date",
    y_columns=["pmi"],
    title="Purchasing Managers Index",
    y_axis_title="Value",
    y_unit="point",
    prefix_figure_name="pmi",
)
std_gold_pmi_fig

# %% [markdown]
# ### gold_iip

# %%
gold_iip = my_visualizer.select(schema_name="macroeconomics", table_name="iip")
gold_iip

# %%
std_gold_iip = my_visualizer.make_date_time_index_for_dataframe(gold_iip)
std_gold_iip

# %%
std_gold_iip_fig = my_visualizer.plot_lines_chart(
    std_gold_iip,
    x_column="date",
    y_columns=["entire_industrial_sector"],
    title="Index of Industrial Production",
    y_axis_title="Rate",
    y_unit="%",
    prefix_figure_name="iip",
)
std_gold_iip_fig

# %% [markdown]
# ### gold_ipv

# %%
gold_ipv = my_visualizer.select(schema_name="macroeconomics", table_name="ipv")
gold_ipv
# Out:
#             date   aluminium  animal_feed  aquatic_feed     beer       cars  \
# 0     2000-01-01         NaN          NaN           NaN      NaN        NaN
# 1     2000-01-02         NaN          NaN           NaN      NaN        NaN
# 2     2000-01-03         NaN          NaN           NaN      NaN        NaN
# 3     2000-01-04         NaN          NaN           NaN      NaN        NaN
# 4     2000-01-05         NaN          NaN           NaN      NaN        NaN
# ...          ...         ...          ...           ...      ...        ...
# 9308  2025-06-26  131.201333  1279.076667    878.437333  412.502  42.457333
# 9309  2025-06-27  131.276000  1279.695000    878.018000  413.439  42.643000
# 9310  2025-06-28  131.350667  1280.313333    877.598667  414.376  42.828667
# 9311  2025-06-29  131.425333  1280.931667    877.179333  415.313  43.014333
# 9312  2025-06-30  131.500000  1281.550000    876.760000  416.250  43.200000
#
#       casual_clothes     cement  chemical_paints  cigarettes  ...  \
# 0                NaN        NaN              NaN         NaN  ...
# 1                NaN        NaN              NaN         NaN  ...
# 2                NaN        NaN              NaN         NaN  ...
# 3                NaN        NaN              NaN         NaN  ...
# 4                NaN        NaN              NaN         NaN  ...
# ...              ...        ...              ...         ...  ...
# 9308      524.304667  17.061333          121.968  675.489333  ...
# 9309      524.436000  17.071000          121.916  675.222000  ...
# 9310      524.567333  17.080667          121.864  674.954667  ...
# 9311      524.698667  17.090333          121.812  674.687333  ...
# 9312      524.830000  17.100000          121.760  674.420000  ...
#
#       natural_fabrics  natural_gas_in_the_form_of_air  phone_accessories  \
# 0                 NaN                             NaN                NaN
# 1                 NaN                             NaN                NaN
# 2                 NaN                             NaN                NaN
# 3                 NaN                             NaN                NaN
# 4                 NaN                             NaN                NaN
# ...               ...                             ...                ...
# 9308           89.628                      505.209333             61.722
# 9309           89.621                      503.607000             62.249
# 9310           89.614                      502.004667             62.776
# 9311           89.607                      500.402333             63.303
# 9312           89.600                      498.800000             63.830
#
#       powdered_milk  processed_seafood  rolled_steel  steel_bars_angle_steel  \
# 0               NaN                NaN           NaN                     NaN
# 1               NaN                NaN           NaN                     NaN
# 2               NaN                NaN           NaN                     NaN
# 3               NaN                NaN           NaN                     NaN
# 4               NaN                NaN           NaN                     NaN
# ...             ...                ...           ...                     ...
# 9308         14.144         636.667333   1523.289333             1488.255333
# 9309         14.168         637.438000   1522.212000             1490.079000
# 9310         14.192         638.208667   1521.134667             1491.902667
# 9311         14.216         638.979333   1520.057333             1493.726333
# 9312         14.240         639.750000   1518.980000             1495.550000
#
#       synthetic_or_artificial_fabrics  television  urea_fertilizer
# 0                                 NaN         NaN              NaN
# 1                                 NaN         NaN              NaN
# 2                                 NaN         NaN              NaN
# 3                                 NaN         NaN              NaN
# 4                                 NaN         NaN              NaN
# ...                               ...         ...              ...
# 9308                       104.728667    1939.658       232.980667
# 9309                       104.959000    1939.776       232.293000
# 9310                       105.189333    1939.894       231.605333
# 9311                       105.419667    1940.012       230.917667
# 9312                       105.650000    1940.130       230.230000
#
# [9313 rows x 34 columns]

# %%
std_gold_ipv = my_visualizer.make_date_time_index_for_dataframe(gold_ipv)
std_gold_ipv
# Out:
#            date   aluminium  animal_feed  aquatic_feed     beer       cars  \
# 0    2000-01-01         NaN          NaN           NaN      NaN        NaN
# 1    2000-01-02         NaN          NaN           NaN      NaN        NaN
# 2    2000-01-03         NaN          NaN           NaN      NaN        NaN
# 3    2000-01-04         NaN          NaN           NaN      NaN        NaN
# 4    2000-01-05         NaN          NaN           NaN      NaN        NaN
# ...         ...         ...          ...           ...      ...        ...
# 9308 2025-06-26  131.201333  1279.076667    878.437333  412.502  42.457333
# 9309 2025-06-27  131.276000  1279.695000    878.018000  413.439  42.643000
# 9310 2025-06-28  131.350667  1280.313333    877.598667  414.376  42.828667
# 9311 2025-06-29  131.425333  1280.931667    877.179333  415.313  43.014333
# 9312 2025-06-30  131.500000  1281.550000    876.760000  416.250  43.200000
#
#       casual_clothes     cement  chemical_paints  cigarettes  ...  \
# 0                NaN        NaN              NaN         NaN  ...
# 1                NaN        NaN              NaN         NaN  ...
# 2                NaN        NaN              NaN         NaN  ...
# 3                NaN        NaN              NaN         NaN  ...
# 4                NaN        NaN              NaN         NaN  ...
# ...              ...        ...              ...         ...  ...
# 9308      524.304667  17.061333          121.968  675.489333  ...
# 9309      524.436000  17.071000          121.916  675.222000  ...
# 9310      524.567333  17.080667          121.864  674.954667  ...
# 9311      524.698667  17.090333          121.812  674.687333  ...
# 9312      524.830000  17.100000          121.760  674.420000  ...
#
#       natural_fabrics  natural_gas_in_the_form_of_air  phone_accessories  \
# 0                 NaN                             NaN                NaN
# 1                 NaN                             NaN                NaN
# 2                 NaN                             NaN                NaN
# 3                 NaN                             NaN                NaN
# 4                 NaN                             NaN                NaN
# ...               ...                             ...                ...
# 9308           89.628                      505.209333             61.722
# 9309           89.621                      503.607000             62.249
# 9310           89.614                      502.004667             62.776
# 9311           89.607                      500.402333             63.303
# 9312           89.600                      498.800000             63.830
#
#       powdered_milk  processed_seafood  rolled_steel  steel_bars_angle_steel  \
# 0               NaN                NaN           NaN                     NaN
# 1               NaN                NaN           NaN                     NaN
# 2               NaN                NaN           NaN                     NaN
# 3               NaN                NaN           NaN                     NaN
# 4               NaN                NaN           NaN                     NaN
# ...             ...                ...           ...                     ...
# 9308         14.144         636.667333   1523.289333             1488.255333
# 9309         14.168         637.438000   1522.212000             1490.079000
# 9310         14.192         638.208667   1521.134667             1491.902667
# 9311         14.216         638.979333   1520.057333             1493.726333
# 9312         14.240         639.750000   1518.980000             1495.550000
#
#       synthetic_or_artificial_fabrics  television  urea_fertilizer
# 0                                 NaN         NaN              NaN
# 1                                 NaN         NaN              NaN
# 2                                 NaN         NaN              NaN
# 3                                 NaN         NaN              NaN
# 4                                 NaN         NaN              NaN
# ...                               ...         ...              ...
# 9308                       104.728667    1939.658       232.980667
# 9309                       104.959000    1939.776       232.293000
# 9310                       105.189333    1939.894       231.605333
# 9311                       105.419667    1940.012       230.917667
# 9312                       105.650000    1940.130       230.230000
#
# [9313 rows x 34 columns]

# %%
std_gold_ipv_fig = my_visualizer.plot_lines_chart(
    std_gold_ipv,
    x_column="date",
    y_columns=["extracted_crude_oil"],
    title="Industrial Production Volume",
    y_axis_title="Value",
    y_unit="thousand tons",
    prefix_figure_name="ipv",
    marker=None,
)
std_gold_ipv_fig

# %% [markdown]
# ### gold_mip

# %%
gold_mip = my_visualizer.select(schema_name="macroeconomics", table_name="mip")
gold_mip
# Out:
#             date  air_conditioners  animal_and_poultry_feed  \
# 0     2000-01-01               NaN                      NaN
# 1     2000-01-02               NaN                      NaN
# 2     2000-01-03               NaN                      NaN
# 3     2000-01-04               NaN                      NaN
# 4     2000-01-05               NaN                      NaN
# ...          ...               ...                      ...
# 9308  2025-06-26             965.0                 19922.18
# 9309  2025-06-27             965.0                 19922.18
# 9310  2025-06-28             965.0                 19922.18
# 9311  2025-06-29             965.0                 19922.18
# 9312  2025-06-30             965.0                 19922.18
#
#       antimony_ore_and_antimony_concentrate  apatite_ore  aquaculture_feed  \
# 0                                       NaN          NaN               NaN
# 1                                       NaN          NaN               NaN
# 2                                       NaN          NaN               NaN
# 3                                       NaN          NaN               NaN
# 4                                       NaN          NaN               NaN
# ...                                     ...          ...               ...
# 9308                                 985.84      2983.35           5050.68
# 9309                                 985.84      2983.35           5050.68
# 9310                                 985.84      2983.35           5050.68
# 9311                                 985.84      2983.35           5050.68
# 9312                                 985.84      2983.35           5050.68
#
#       assembled_cars  assembled_motorcycles_and_mopeds  assembled_tvs  \
# 0                NaN                               NaN            NaN
# 1                NaN                               NaN            NaN
# 2                NaN                               NaN            NaN
# 3                NaN                               NaN            NaN
# 4                NaN                               NaN            NaN
# ...              ...                               ...            ...
# 9308          316.16                           3011.89        14708.4
# 9309          316.16                           3011.89        14708.4
# 9310          316.16                           3011.89        14708.4
# 9311          316.16                           3011.89        14708.4
# 9312          316.16                           3011.89        14708.4
#
#       bath_milk_and_facial_cleanser  ...  threshing_machines  \
# 0                               NaN  ...                 NaN
# 1                               NaN  ...                 NaN
# 2                               NaN  ...                 NaN
# 3                               NaN  ...                 NaN
# 4                               NaN  ...                 NaN
# ...                             ...  ...                 ...
# 9308                       59268.04  ...                3.29
# 9309                       59268.04  ...                3.29
# 9310                       59268.04  ...                3.29
# 9311                       59268.04  ...                3.29
# 9312                       59268.04  ...                3.29
#
#       titanium_ore_and_titanium_concentrate  tobacco  toothpaste  \
# 0                                       NaN      NaN         NaN
# 1                                       NaN      NaN         NaN
# 2                                       NaN      NaN         NaN
# 3                                       NaN      NaN         NaN
# 4                                       NaN      NaN         NaN
# ...                                     ...      ...         ...
# 9308                                 220.17  7532.99    42259.98
# 9309                                 220.17  7532.99    42259.98
# 9310                                 220.17  7532.99    42259.98
# 9311                                 220.17  7532.99    42259.98
# 9312                                 220.17  7532.99    42259.98
#
#       tubes_for_bicycles_and_motorcycles  tubes_for_cars_and_aircraft  \
# 0                                    NaN                          NaN
# 1                                    NaN                          NaN
# 2                                    NaN                          NaN
# 3                                    NaN                          NaN
# 4                                    NaN                          NaN
# ...                                  ...                          ...
# 9308                              150.24                      5991.78
# 9309                              150.24                      5991.78
# 9310                              150.24                      5991.78
# 9311                              150.24                      5991.78
# 9312                              150.24                      5991.78
#
#       various_types_of_batteries  various_types_of_bicycles  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
# ...                          ...                        ...
# 9308                   394468.57                    1035.72
# 9309                   394468.57                    1035.72
# 9310                   394468.57                    1035.72
# 9311                   394468.57                    1035.72
# 9312                   394468.57                    1035.72
#
#       various_types_of_sand  yellow_phosphorus
# 0                       NaN                NaN
# 1                       NaN                NaN
# 2                       NaN                NaN
# 3                       NaN                NaN
# 4                       NaN                NaN
# ...                     ...                ...
# 9308               27778.41             139.93
# 9309               27778.41             139.93
# 9310               27778.41             139.93
# 9311               27778.41             139.93
# 9312               27778.41             139.93
#
# [9313 rows x 84 columns]

# %%
std_gold_mip = my_visualizer.make_date_time_index_for_dataframe(gold_mip)
std_gold_mip
# Out:
#            date  air_conditioners  animal_and_poultry_feed  \
# 0    2000-01-01               NaN                      NaN
# 1    2000-01-02               NaN                      NaN
# 2    2000-01-03               NaN                      NaN
# 3    2000-01-04               NaN                      NaN
# 4    2000-01-05               NaN                      NaN
# ...         ...               ...                      ...
# 9308 2025-06-26             965.0                 19922.18
# 9309 2025-06-27             965.0                 19922.18
# 9310 2025-06-28             965.0                 19922.18
# 9311 2025-06-29             965.0                 19922.18
# 9312 2025-06-30             965.0                 19922.18
#
#       antimony_ore_and_antimony_concentrate  apatite_ore  aquaculture_feed  \
# 0                                       NaN          NaN               NaN
# 1                                       NaN          NaN               NaN
# 2                                       NaN          NaN               NaN
# 3                                       NaN          NaN               NaN
# 4                                       NaN          NaN               NaN
# ...                                     ...          ...               ...
# 9308                                 985.84      2983.35           5050.68
# 9309                                 985.84      2983.35           5050.68
# 9310                                 985.84      2983.35           5050.68
# 9311                                 985.84      2983.35           5050.68
# 9312                                 985.84      2983.35           5050.68
#
#       assembled_cars  assembled_motorcycles_and_mopeds  assembled_tvs  \
# 0                NaN                               NaN            NaN
# 1                NaN                               NaN            NaN
# 2                NaN                               NaN            NaN
# 3                NaN                               NaN            NaN
# 4                NaN                               NaN            NaN
# ...              ...                               ...            ...
# 9308          316.16                           3011.89        14708.4
# 9309          316.16                           3011.89        14708.4
# 9310          316.16                           3011.89        14708.4
# 9311          316.16                           3011.89        14708.4
# 9312          316.16                           3011.89        14708.4
#
#       bath_milk_and_facial_cleanser  ...  threshing_machines  \
# 0                               NaN  ...                 NaN
# 1                               NaN  ...                 NaN
# 2                               NaN  ...                 NaN
# 3                               NaN  ...                 NaN
# 4                               NaN  ...                 NaN
# ...                             ...  ...                 ...
# 9308                       59268.04  ...                3.29
# 9309                       59268.04  ...                3.29
# 9310                       59268.04  ...                3.29
# 9311                       59268.04  ...                3.29
# 9312                       59268.04  ...                3.29
#
#       titanium_ore_and_titanium_concentrate  tobacco  toothpaste  \
# 0                                       NaN      NaN         NaN
# 1                                       NaN      NaN         NaN
# 2                                       NaN      NaN         NaN
# 3                                       NaN      NaN         NaN
# 4                                       NaN      NaN         NaN
# ...                                     ...      ...         ...
# 9308                                 220.17  7532.99    42259.98
# 9309                                 220.17  7532.99    42259.98
# 9310                                 220.17  7532.99    42259.98
# 9311                                 220.17  7532.99    42259.98
# 9312                                 220.17  7532.99    42259.98
#
#       tubes_for_bicycles_and_motorcycles  tubes_for_cars_and_aircraft  \
# 0                                    NaN                          NaN
# 1                                    NaN                          NaN
# 2                                    NaN                          NaN
# 3                                    NaN                          NaN
# 4                                    NaN                          NaN
# ...                                  ...                          ...
# 9308                              150.24                      5991.78
# 9309                              150.24                      5991.78
# 9310                              150.24                      5991.78
# 9311                              150.24                      5991.78
# 9312                              150.24                      5991.78
#
#       various_types_of_batteries  various_types_of_bicycles  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
# ...                          ...                        ...
# 9308                   394468.57                    1035.72
# 9309                   394468.57                    1035.72
# 9310                   394468.57                    1035.72
# 9311                   394468.57                    1035.72
# 9312                   394468.57                    1035.72
#
#       various_types_of_sand  yellow_phosphorus
# 0                       NaN                NaN
# 1                       NaN                NaN
# 2                       NaN                NaN
# 3                       NaN                NaN
# 4                       NaN                NaN
# ...                     ...                ...
# 9308               27778.41             139.93
# 9309               27778.41             139.93
# 9310               27778.41             139.93
# 9311               27778.41             139.93
# 9312               27778.41             139.93
#
# [9313 rows x 84 columns]

# %%
std_gold_mip_fig = my_visualizer.plot_lines_chart(
    std_gold_mip,
    x_column="date",
    y_columns=[
        "clean_coal",
        "crude_oil_extraction",
        "milled_rice",
        "cement",
        "generated_electricity",
    ],
    title="Some Major Industrial Products",
    y_axis_title="Value",
    y_unit="thousand tons / million KWh",
    prefix_figure_name="mip",
    marker=None,
)
std_gold_mip_fig

# %% [markdown]
# ### gold_fa_by_house_types

# %%
gold_fa_by_house_types = my_visualizer.select(
    schema_name="macroeconomics", table_name="fa_by_house_types"
)
gold_fa_by_house_types
# Out:
#             date  _16_20_floors  _21_25_floors  _26_floors_and_above  \
# 0     2000-01-01            NaN            NaN                   NaN
# 1     2000-01-02            NaN            NaN                   NaN
# 2     2000-01-03            NaN            NaN                   NaN
# 3     2000-01-04            NaN            NaN                   NaN
# 4     2000-01-05            NaN            NaN                   NaN
# ...          ...            ...            ...                   ...
# 9308  2025-06-26           71.0          223.0                 652.0
# 9309  2025-06-27           71.0          223.0                 652.0
# 9310  2025-06-28           71.0          223.0                 652.0
# 9311  2025-06-29           71.0          223.0                 652.0
# 9312  2025-06-30           71.0          223.0                 652.0
#
#       _5_floors_and_below  _6_8_floors  _9_15_floors  apartment_buildings  \
# 0                     NaN          NaN           NaN                  NaN
# 1                     NaN          NaN           NaN                  NaN
# 2                     NaN          NaN           NaN                  NaN
# 3                     NaN          NaN           NaN                  NaN
# 4                     NaN          NaN           NaN                  NaN
# ...                   ...          ...           ...                  ...
# 9308                 42.0         17.0         127.0               1132.0
# 9309                 42.0         17.0         127.0               1132.0
# 9310                 42.0         17.0         127.0               1132.0
# 9311                 42.0         17.0         127.0               1132.0
# 9312                 42.0         17.0         127.0               1132.0
#
#       single_family_homes  single_family_homes_4_floors_and_above  \
# 0                     NaN                                     NaN
# 1                     NaN                                     NaN
# 2                     NaN                                     NaN
# 3                     NaN                                     NaN
# 4                     NaN                                     NaN
# ...                   ...                                     ...
# 9308             104058.0                                  2091.0
# 9309             104058.0                                  2091.0
# 9310             104058.0                                  2091.0
# 9311             104058.0                                  2091.0
# 9312             104058.0                                  2091.0
#
#       single_family_homes_below_4_floors     total  villas
# 0                                    NaN       NaN     NaN
# 1                                    NaN       NaN     NaN
# 2                                    NaN       NaN     NaN
# 3                                    NaN       NaN     NaN
# 4                                    NaN       NaN     NaN
# ...                                  ...       ...     ...
# 9308                            100742.0  105190.0  1225.0
# 9309                            100742.0  105190.0  1225.0
# 9310                            100742.0  105190.0  1225.0
# 9311                            100742.0  105190.0  1225.0
# 9312                            100742.0  105190.0  1225.0
#
# [9313 rows x 13 columns]

# %%
std_gold_fa_by_house_types = my_visualizer.make_date_time_index_for_dataframe(
    gold_fa_by_house_types
)
std_gold_fa_by_house_types
# Out:
#            date  _16_20_floors  _21_25_floors  _26_floors_and_above  \
# 0    2000-01-01            NaN            NaN                   NaN
# 1    2000-01-02            NaN            NaN                   NaN
# 2    2000-01-03            NaN            NaN                   NaN
# 3    2000-01-04            NaN            NaN                   NaN
# 4    2000-01-05            NaN            NaN                   NaN
# ...         ...            ...            ...                   ...
# 9308 2025-06-26           71.0          223.0                 652.0
# 9309 2025-06-27           71.0          223.0                 652.0
# 9310 2025-06-28           71.0          223.0                 652.0
# 9311 2025-06-29           71.0          223.0                 652.0
# 9312 2025-06-30           71.0          223.0                 652.0
#
#       _5_floors_and_below  _6_8_floors  _9_15_floors  apartment_buildings  \
# 0                     NaN          NaN           NaN                  NaN
# 1                     NaN          NaN           NaN                  NaN
# 2                     NaN          NaN           NaN                  NaN
# 3                     NaN          NaN           NaN                  NaN
# 4                     NaN          NaN           NaN                  NaN
# ...                   ...          ...           ...                  ...
# 9308                 42.0         17.0         127.0               1132.0
# 9309                 42.0         17.0         127.0               1132.0
# 9310                 42.0         17.0         127.0               1132.0
# 9311                 42.0         17.0         127.0               1132.0
# 9312                 42.0         17.0         127.0               1132.0
#
#       single_family_homes  single_family_homes_4_floors_and_above  \
# 0                     NaN                                     NaN
# 1                     NaN                                     NaN
# 2                     NaN                                     NaN
# 3                     NaN                                     NaN
# 4                     NaN                                     NaN
# ...                   ...                                     ...
# 9308             104058.0                                  2091.0
# 9309             104058.0                                  2091.0
# 9310             104058.0                                  2091.0
# 9311             104058.0                                  2091.0
# 9312             104058.0                                  2091.0
#
#       single_family_homes_below_4_floors     total  villas
# 0                                    NaN       NaN     NaN
# 1                                    NaN       NaN     NaN
# 2                                    NaN       NaN     NaN
# 3                                    NaN       NaN     NaN
# 4                                    NaN       NaN     NaN
# ...                                  ...       ...     ...
# 9308                            100742.0  105190.0  1225.0
# 9309                            100742.0  105190.0  1225.0
# 9310                            100742.0  105190.0  1225.0
# 9311                            100742.0  105190.0  1225.0
# 9312                            100742.0  105190.0  1225.0
#
# [9313 rows x 13 columns]

# %%
std_gold_fa_by_house_types_fig = my_visualizer.plot_lines_chart(
    std_gold_fa_by_house_types,
    x_column="date",
    y_columns=std_gold_fa_by_house_types.columns.difference(['date']),
    title="Floor Area",
    y_axis_title="Value",
    y_unit="thousand m2",
    prefix_figure_name="fa_by_house_types",
    marker=None,
)
std_gold_fa_by_house_types_fig

# %% [markdown]
# ### gold_it_bop

# %%
gold_it_bop = my_visualizer.select(schema_name="macroeconomics", table_name="it_bop")
gold_it_bop

# %%
std_gold_it_bop = my_visualizer.make_date_time_index_for_dataframe(gold_it_bop)
std_gold_it_bop

# %%
std_gold_it_bop_fig = my_visualizer.plot_lines_chart(
    std_gold_it_bop,
    x_column="date",
    y_columns=[
        "a_current_account",
        "c_financial_account",
        "d_errors_and_omissions",
        "e_overall_balance",
    ],
    title="International Trade and Balance of Payments",
    y_axis_title="Value",
    y_unit="million US dollars",
    prefix_figure_name="it_bop",
)
std_gold_it_bop_fig

# %% [markdown]
# ### gold_tsbr

# %%
gold_tsbr = my_visualizer.select(schema_name="macroeconomics", table_name="tsbr")
gold_tsbr

# %%
std_gold_tsbr = my_visualizer.make_date_time_index_for_dataframe(gold_tsbr)
std_gold_tsbr

# %%
std_gold_tsbr_fig = my_visualizer.plot_lines_chart(
    std_gold_tsbr,
    x_column="date",
    y_columns=["total_state_budget_revenue"],
    title="Total State Budget Revenue",
    y_axis_title="Value",
    y_unit="billion Dong",
    prefix_figure_name="tsbr",
)
std_gold_tsbr_fig

# %% [markdown]
# ### gold_tsbe

# %%
gold_tsbe = my_visualizer.select(schema_name="macroeconomics", table_name="tsbe")
gold_tsbe

# %%
std_gold_tsbe = my_visualizer.make_date_time_index_for_dataframe(gold_tsbe)
std_gold_tsbe

# %%
std_gold_tsbe_fig = my_visualizer.plot_lines_chart(
    std_gold_tsbe,
    x_column="date",
    y_columns=["total_state_budget_expenditure"],
    title="Total State Budget Expenditure",
    y_axis_title="Value",
    y_unit="billion Dong",
    prefix_figure_name="tsbe",
)
std_gold_tsbe_fig

# %% [markdown]
# ### gold_gd

# %%
gold_gd = my_visualizer.select(schema_name="macroeconomics", table_name="gd")
gold_gd

# %%
std_gold_gd = my_visualizer.make_date_time_index_for_dataframe(gold_gd)
std_gold_gd

# %%
std_gold_gd_fig = my_visualizer.plot_lines_chart(
    std_gold_gd,
    x_column="date",
    y_columns=["debt_balance", "domestic_debt", "foreign_debt"],
    title="Gorvernment Debt",
    y_axis_title="Value",
    y_unit="billion Dong",
    prefix_figure_name="gd",
)
std_gold_gd_fig

# %% [markdown]
# ### gold_brd

# %%
gold_brd = my_visualizer.select(schema_name="macroeconomics", table_name="brd")
gold_brd

# %%
std_gold_brd = my_visualizer.make_date_time_index_for_dataframe(gold_brd)
std_gold_brd

# %%
std_gold_brd_fig = my_visualizer.plot_lines_chart(
    std_gold_brd,
    x_column="date",
    y_columns=[
        "newly_established_enterprises",
        "enterprises_temporarily_suspended_awaiting_dissolution",
        "enterprises_resuming_operations",
        "enterprises_completing_dissolution",
    ],
    title="Business Registered Dissolved",
    y_axis_title="Value",
    y_unit="enterprises",
    prefix_figure_name="brd",
)
std_gold_brd_fig

# %% [markdown]
# ### gold_iisd

# %%
gold_iisd = my_visualizer.select(schema_name="macroeconomics", table_name="iisd")
gold_iisd

# %%
std_gold_iisd = my_visualizer.make_date_time_index_for_dataframe(gold_iisd)
std_gold_iisd

# %%
std_gold_iisd_fig = my_visualizer.plot_lines_chart(
    std_gold_iisd,
    x_column="date",
    y_columns=[
        "total",
        "investment_capital_from_the_state_budget",
        "investment_capital_from_residents_and_private_individuals",
        "foreign_direct_investment_capital",
    ],
    title="Investing In Social Development",
    y_axis_title="Value",
    y_unit="thousand billion Dong",
    prefix_figure_name="iisd",
)
std_gold_iisd_fig

# %% [markdown]
# ### gold_treg

# %%
gold_treg = my_visualizer.select(schema_name="macroeconomics", table_name="treg")
gold_treg
# Out:
#             date  \
# 0     2000-01-01
# 1     2000-01-02
# 2     2000-01-03
# 3     2000-01-04
# 4     2000-01-05
# ...          ...
# 9308  2025-06-26
# 9309  2025-06-27
# 9310  2025-06-28
# 9311  2025-06-29
# 9312  2025-06-30
#
#       international_liquidity_total_reserves_excluding_gold_foreign_e  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9308                                           79751.05
# 9309                                           79751.05
# 9310                                           79751.05
# 9311                                           79751.05
# 9312                                           79751.05
#
#       international_liquidity_total_reserves_excluding_gold_us_dollar
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9308                                           81694.07
# 9309                                           81694.07
# 9310                                           81694.07
# 9311                                           81694.07
# 9312                                           81694.07
#
# [9313 rows x 3 columns]

# %%
std_gold_treg = my_visualizer.make_date_time_index_for_dataframe(gold_treg)
std_gold_treg
# Out:
#            date  \
# 0    2000-01-01
# 1    2000-01-02
# 2    2000-01-03
# 3    2000-01-04
# 4    2000-01-05
# ...         ...
# 9308 2025-06-26
# 9309 2025-06-27
# 9310 2025-06-28
# 9311 2025-06-29
# 9312 2025-06-30
#
#       international_liquidity_total_reserves_excluding_gold_foreign_e  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9308                                           79751.05
# 9309                                           79751.05
# 9310                                           79751.05
# 9311                                           79751.05
# 9312                                           79751.05
#
#       international_liquidity_total_reserves_excluding_gold_us_dollar
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9308                                           81694.07
# 9309                                           81694.07
# 9310                                           81694.07
# 9311                                           81694.07
# 9312                                           81694.07
#
# [9313 rows x 3 columns]

# %%
std_gold_treg_fig = my_visualizer.plot_lines_chart(
    std_gold_treg,
    x_column="date",
    y_columns=[
        "international_liquidity_total_reserves_excluding_gold_us_dollar",
    ],
    title="Total Reserves excluding gold (USD)",
    y_axis_title="Value",
    y_unit="million USD",
    prefix_figure_name="treg",
    marker=None,
)
std_gold_treg_fig

# %% [markdown]
# ### gold_credit

# %%
gold_credit = my_visualizer.select(schema_name="macroeconomics", table_name="credit")
gold_credit

# %%
std_gold_credit = my_visualizer.make_date_time_index_for_dataframe(gold_credit)
std_gold_credit

# %%
std_gold_credit_fig = my_visualizer.plot_lines_chart(
    std_gold_credit,
    x_column="date",
    y_columns=["credit", "money_supply_m2"],
    title="Credit statistics",
    y_axis_title="Value",
    y_unit="billion Dong",
    prefix_figure_name="credit",
    marker=None,
)
std_gold_credit_fig

# %%
std_gold_credit_fig = my_visualizer.plot_lines_chart(
    std_gold_credit,
    x_column="date",
    y_columns=["credit_growth_ytd", "money_supply_growth_m2_ytd"],
    title="Credit growth statistics",
    y_axis_title="Value",
    y_unit="billion Dong",
    prefix_figure_name="credit",
    marker=None,
)
std_gold_credit_fig

# %% [markdown]
# ### gold_mobilization

# %%
gold_mobilization = my_visualizer.select(
    schema_name="macroeconomics", table_name="mobilization"
)
gold_mobilization

# %%
std_gold_mobilization = my_visualizer.make_date_time_index_for_dataframe(
    gold_mobilization
)
std_gold_mobilization

# %%
std_gold_mobilization_fig = my_visualizer.plot_lines_chart(
    std_gold_mobilization,
    x_column="date",
    y_columns=[
        "deposits_from_economic_organizations",
        "deposits_from_residents",
        "total_payment_instruments",
    ],
    title="mobilization statistics",
    y_axis_title="Value",
    y_unit="billion Dong",
    prefix_figure_name="mobilization",
    marker=None,
)
std_gold_mobilization_fig

# %% [markdown]
# ### gold_exchange_rate

# %%
gold_exchange_rate = my_visualizer.select(
    schema_name="macroeconomics", table_name="exchange_rate"
)
gold_exchange_rate

# %%
std_gold_exchange_rate = my_visualizer.make_date_time_index_for_dataframe(
    gold_exchange_rate
)
std_gold_exchange_rate

# %%
std_gold_exchange_rate_fig = my_visualizer.plot_lines_chart(
    std_gold_exchange_rate,
    x_column="date",
    y_columns=["central_rate"],
    title="Exchange rate statistics",
    y_axis_title="Value",
    y_unit="VND/USD",
    prefix_figure_name="exchange_rate",
    marker=None,
)
std_gold_exchange_rate_fig

# %% [markdown]
# ### gold_iir

# %%
gold_iir = my_visualizer.select(schema_name="macroeconomics", table_name="iir")
gold_iir

# %%
std_gold_iir = my_visualizer.make_date_time_index_for_dataframe(gold_iir)
std_gold_iir

# %%
rename_dict = {
    "_3_months": "three_months",
    "_6_months": "six_months",
    "_9_months": "nine_months",
}

# Apply renaming
std_gold_iir = std_gold_iir.rename(columns=rename_dict)
std_gold_iir

# %%
std_gold_iir_fig = my_visualizer.plot_lines_chart(
    std_gold_iir,
    x_column="date",
    y_columns=["overnight", "three_months", "six_months", "nine_months"],
    title="Interbank interest rates",
    y_axis_title="Value",
    y_unit="%",
    prefix_figure_name="iir",
    marker=None,
)
std_gold_iir_fig

# %% [markdown]
# ### gold_rrrr

# %%
std_gold_rrrr = my_visualizer.select(schema_name="macroeconomics", table_name="rrrr")
std_gold_rrrr
# Out:
#             date  discount_rate  refinancing_rate
# 0     2000-01-02            NaN               NaN
# 1     2000-01-03            NaN               NaN
# 2     2000-01-04            NaN               NaN
# 3     2000-01-05            NaN               NaN
# 4     2000-01-06            NaN               NaN
# ...          ...            ...               ...
# 9308  2025-06-20            3.0               4.5
# 9309  2025-06-23            3.0               4.5
# 9310  2025-06-25            3.0               4.5
# 9311  2025-06-28            3.0               4.5
# 9312  2025-06-30            3.0               4.5
#
# [9313 rows x 3 columns]

# %%
std_gold_rrrr_fig = my_visualizer.plot_lines_chart(
    std_gold_rrrr,
    x_column="date",
    y_columns=["discount_rate", "refinancing_rate"],
    title="Rediscount rate, Refinancing rate",
    y_axis_title="Rate",
    y_unit="%",
    prefix_figure_name="rrrr",
    marker=None,
)
std_gold_rrrr_fig

# %% [markdown]
# ### gold_fdi_sector

# %%
gold_fdi_sector = my_visualizer.select(
    schema_name="macroeconomics", table_name="fdi_sector"
)
gold_fdi_sector

# %%
std_gold_fdi_sector = my_visualizer.make_date_time_index_for_dataframe(gold_fdi_sector)
std_gold_fdi_sector

# %%
std_gold_fdi_sector_fig = my_visualizer.plot_lines_chart(
    std_gold_fdi_sector,
    x_column="date",
    y_columns=[
        "administrative_and_support_service_activities",
        "agriculture_forestry_and_fishery",
        "construction",
        "education_and_training",
        "healthcare_and_social_assistance_activities",
        "information_and_communication",
        "mining_and_quarrying",
    ],
    title="Foreign Direct Investment by Sector 1",
    y_axis_title="Value",
    y_unit="Million US Dollars",
    prefix_figure_name="fdi_sector",
    marker=None,
)
std_gold_fdi_sector_fig

# %%
std_gold_fdi_sector_fig = my_visualizer.plot_lines_chart(
    std_gold_fdi_sector,
    x_column="date",
    y_columns=[
        "manufacturing_and_processing_industry",
        "real_estate_business_activities",
        "production_and_distribution_of_electricity_gas_water_and_air_co",
    ],
    title="Foreign Direct Investment by Sector 2",
    y_axis_title="Value",
    y_unit="Million US Dollars",
    prefix_figure_name="fdi_sector",
    marker=None,
)
std_gold_fdi_sector_fig

# %% [markdown]
# ### gold_fdi_rd

# %%
gold_fdi_rd = my_visualizer.select(schema_name="macroeconomics", table_name="fdi_rd")
gold_fdi_rd

# %%
std_gold_fdi_rd = my_visualizer.make_date_time_index_for_dataframe(gold_fdi_rd)
std_gold_fdi_rd

# %%
std_gold_fdi_rd_fig = my_visualizer.plot_lines_chart(
    std_gold_fdi_rd,
    x_column="date",
    y_columns=[
        "fdi_disbursement",
        "register",
    ],
    title="Foreign Direct Investment Registration Disbursement",
    y_axis_title="Value",
    y_unit="Billion US Dollars",
    prefix_figure_name="fdi_rd",
    marker=None,
)
std_gold_fdi_rd_fig

# %% [markdown]
# ### gold_export

# %%
gold_export = my_visualizer.select(schema_name="macroeconomics", table_name="export")
gold_export

# %%
std_gold_export = my_visualizer.make_date_time_index_for_dataframe(gold_export)
std_gold_export

# %%
std_gold_export_fig = my_visualizer.plot_lines_chart(
    std_gold_export,
    x_column="date",
    y_columns=[
        "asean",
        "united_arab_emirates",
        "eu",
        "netherlands",
        "south_korea",
        "hong_kong",
        "usa",
        "japan",
        "china",
    ],
    title="Export statistics by countries",
    y_axis_title="Value",
    y_unit="Million US Dollars",
    prefix_figure_name="export",
    marker=None,
)
std_gold_export_fig

# %% [markdown]
# ### gold_import

# %%
gold_import = my_visualizer.select(schema_name="macroeconomics", table_name="import")
gold_import

# %%
std_gold_import = my_visualizer.make_date_time_index_for_dataframe(gold_import)
std_gold_import

# %%
std_gold_import_fig = my_visualizer.plot_lines_chart(
    std_gold_import,
    x_column="date",
    y_columns=[
        "asean",
        "united_arab_emirates",
        "eu",
        "netherlands",
        "south_korea",
        "hong_kong",
        "usa",
        "japan",
        "china",
    ],
    title="Import statistics by countries",
    y_axis_title="Value",
    y_unit="Million US Dollars",
    prefix_figure_name="import",
    marker=None,
)
std_gold_import_fig

# %% [markdown]
# ### gold_gold_price

# %%
gold_gold_price = my_visualizer.select(
    schema_name="macroeconomics", table_name="gold_price"
)
gold_gold_price
# Out:
#             date               close                open                high  \
# 0     2000-01-01                None                None                None
# 1     2000-01-02                None                None                None
# 2     2000-01-03                None                None                None
# 3     2000-01-05               282.1               283.7               285.0
# 4     2000-01-06               282.4               281.6               282.8
# ...          ...                 ...                 ...                 ...
# 9308  2025-03-22  3046.9333333333334   3071.633333333333  3076.9333333333334
# 9309  2025-04-20  3401.0750000000003            3349.625  3424.7000000000003
# 9310  2025-05-17  3211.9333333333334  3244.3333333333335   3263.866666666667
# 9311  2025-05-31  3342.6666666666665  3336.4666666666667   3367.366666666667
# 9312  2025-06-22  3382.2999999999997  3387.0333333333333  3398.8666666666663
#
#                      low              volume                 change
# 0                   None                None                   None
# 1                   None                None                   None
# 2                   None                None                   None
# 3                  281.0             25450.0                  -0.56
# 4                  280.2             19060.0                   0.11
# ...                  ...                 ...                    ...
# 9308  3032.7999999999997   63426.66666666667    -0.5466666666666666
# 9309              3332.1            243112.5     2.0475000000000003
# 9310              3183.0   170676.6666666667  -0.036666666666666625
# 9311              3303.0  183513.33333333334     0.2566666666666667
# 9312  3350.9333333333334   95803.33333333334   -0.09333333333333332
#
# [9313 rows x 7 columns]

# %%
std_gold_gold_price_fig = my_visualizer.plot_lines_bars_chart(
    gold_gold_price,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["volume"],
    title="Gold Price close",
    y_line_axis_title="USD",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="z_gold_price",
    marker=None,
)
std_gold_gold_price_fig

# %% [markdown]
# ### gold_oil_price

# %%
gold_oil_price = my_visualizer.select(
    schema_name="macroeconomics", table_name="oil_price"
)
gold_oil_price = gold_oil_price.astype(
    {
        **{col: "float" for col in gold_oil_price.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
gold_oil_price
# Out:
#            date     close      open          high           low       volume  \
# 0    2000-01-01  11497.12  11497.12  11497.120000  11497.120000          NaN
# 1    2000-01-02  11497.12  11497.12  11497.120000  11497.120000          NaN
# 2    2000-01-03   3790.55   3755.74   3836.860000   3643.250000          NaN
# 3    2000-01-04   3546.20   3766.57   3766.570000   3542.730000          NaN
# 4    2000-01-05   3507.31   3543.13   3576.170000   3371.750000          NaN
# ...         ...       ...       ...           ...           ...          ...
# 9308 2025-06-26  22447.29  22328.24  22466.990000  22255.270000  343210000.0
# 9309 2025-06-27  22534.20  22484.87  22603.220000  22382.790000  643790000.0
# 9310 2025-06-28  22582.47  22534.22  22642.646667  22443.563333  565950000.0
# 9311 2025-06-29  22630.74  22583.57  22682.073333  22504.336667  488110000.0
# 9312 2025-06-30  22679.01  22632.92  22721.500000  22565.110000  410270000.0
#
#         change
# 0     0.000000
# 1     0.000000
# 2     2.230000
# 3    -6.450000
# 4    -1.100000
# ...        ...
# 9308  0.940000
# 9309  0.390000
# 9310  0.473333
# 9311  0.556667
# 9312  0.640000
#
# [9313 rows x 7 columns]

# %%
std_gold_oil_price_fig = my_visualizer.plot_lines_bars_chart(
    gold_oil_price,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["volume"],
    title="Oil Price close",
    y_line_axis_title="USD",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="z_oil_price",
    marker=None,
)
std_gold_oil_price_fig

# %% [markdown]
# ### gold_dow_jones

# %%
gold_dow_jones = my_visualizer.select(
    schema_name="macroeconomics", table_name="dow_jones"
)
gold_dow_jones = gold_dow_jones.astype(
    {
        **{col: "float" for col in gold_dow_jones.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
gold_dow_jones

# %%
std_gold_dow_jones_fig = my_visualizer.plot_lines_bars_chart(
    gold_dow_jones,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["volume"],
    title="Dow Jones close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="z_dow_jones",
    marker=None,
)
std_gold_dow_jones_fig

# %% [markdown]
# ### gold_nyse_composite

# %%
gold_nyse_composite = my_visualizer.select(
    schema_name="macroeconomics", table_name="nyse_composite"
)
gold_nyse_composite = gold_nyse_composite.astype(
    {
        **{col: "float" for col in gold_nyse_composite.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
gold_nyse_composite

# %%
std_gold_nyse_composite_fig = my_visualizer.plot_lines_bars_chart(
    gold_nyse_composite,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["volume"],
    title="Nyse Composite close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="z_nyse_composite",
    marker=None,
)
std_gold_nyse_composite_fig

# %% [markdown]
# ### gold_snp_500

# %%
gold_snp_500 = my_visualizer.select(schema_name="macroeconomics", table_name="snp_500")
gold_snp_500 = gold_snp_500.astype(
    {
        **{col: "float" for col in gold_snp_500.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
gold_snp_500

# %%
std_gold_snp_500_fig = my_visualizer.plot_lines_bars_chart(
    gold_snp_500,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["volume"],
    title="SNP 500 close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="z_snp_500",
    marker=None,
)
std_gold_snp_500_fig

# %% [markdown]
# ### gold_nasdaq_composite

# %%
gold_nasdaq_composite = my_visualizer.select(
    schema_name="macroeconomics", table_name="nasdaq_composite"
)
gold_nasdaq_composite = gold_nasdaq_composite.astype(
    {
        **{col: "float" for col in gold_nasdaq_composite.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
gold_nasdaq_composite

# %%
std_gold_nasdaq_composite_fig = my_visualizer.plot_lines_bars_chart(
    gold_nasdaq_composite,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["volume"],
    title="Nasdaq Composite close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="z_nasdaq_composite",
    marker=None,
)
std_gold_nasdaq_composite_fig

# %% [markdown]
# ### gold_nasdaq_100

# %%
gold_nasdaq_100 = my_visualizer.select(
    schema_name="macroeconomics", table_name="nasdaq_100"
)
gold_nasdaq_100 = gold_nasdaq_100.astype(
    {
        **{col: "float" for col in gold_nasdaq_100.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
gold_nasdaq_100

# %%
std_gold_nasdaq_100_fig = my_visualizer.plot_lines_bars_chart(
    gold_nasdaq_100,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["volume"],
    title="Nasdaq 100 close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="z_nasdaq_100",
    marker=None,
)
std_gold_nasdaq_100_fig

# %% [markdown]
# ## STOCK MARKET

# %%
my_visualizer.connect_to_database(database_name=os.getenv("GOLD_POSTGRES_DATABASE"))
my_visualizer.set_chart_dir(CHARTS_DIR_STOCK_MARKET)

# %% [markdown]
# ### gold_vn_index

# %%
gold_vn_index = my_visualizer.select(schema_name="stock_market", table_name="vn_index")
gold_vn_index = gold_vn_index.astype(
    {
        **{col: "float" for col in gold_vn_index.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
gold_vn_index

# %%
std_gold_vn_index_fig = my_visualizer.plot_lines_bars_chart(
    gold_vn_index,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["volume"],
    title="VN Index close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="vn_index",
    marker=None,
)
std_gold_vn_index_fig

# %% [markdown]
# ### gold_hnx_index

# %%
gold_hnx_index = my_visualizer.select(
    schema_name="stock_market", table_name="hnx_index"
)
gold_hnx_index = gold_hnx_index.astype(
    {
        **{col: "float" for col in gold_hnx_index.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
gold_hnx_index

# %%
std_gold_hnx_index_fig = my_visualizer.plot_lines_bars_chart(
    gold_hnx_index,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["volume"],
    title="HNX Index close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="hnx_index",
    marker=None,
)
std_gold_hnx_index_fig

# %% [markdown]
# ### gold_vn_30_index

# %%
gold_vn_30_index = my_visualizer.select(
    schema_name="stock_market", table_name="vn_30_index"
)
gold_vn_30_index = gold_vn_30_index.astype(
    {
        **{col: "float" for col in gold_vn_30_index.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
gold_vn_30_index

# %%
std_gold_vn_30_index_fig = my_visualizer.plot_lines_bars_chart(
    gold_vn_30_index,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["matched_volume"],
    title="VN 30 Index close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="vn_30_index",
    marker=None,
)
std_gold_vn_30_index_fig

# %% [markdown]
# ### gold_vn_100_index

# %%
gold_vn_100_index = my_visualizer.select(
    schema_name="stock_market", table_name="vn_100_index"
)
gold_vn_100_index = gold_vn_100_index.astype(
    {
        **{col: "float" for col in gold_vn_100_index.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
gold_vn_100_index

# %%
std_gold_vn_100_index_fig = my_visualizer.plot_lines_bars_chart(
    gold_vn_100_index,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["matched_volume"],
    title="VN 100 Index close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="vn_100_index",
    marker=None,
)
std_gold_vn_100_index_fig

# %% [markdown]
# ### gold_hnx_30_index

# %%
gold_hnx_30_index = my_visualizer.select(
    schema_name="stock_market", table_name="hnx_30_index"
)
gold_hnx_30_index = gold_hnx_30_index.astype(
    {
        **{col: "float" for col in gold_hnx_30_index.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
gold_hnx_30_index

# %%
std_gold_hnx_30_index_fig = my_visualizer.plot_lines_bars_chart(
    gold_hnx_30_index,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["matched_volume"],
    title="HNX 30 Index close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="hnx_30_index",
    marker=None,
)
std_gold_hnx_30_index_fig

# %% [markdown]
# ### gold_upcom_index

# %%
gold_upcom_index = my_visualizer.select(
    schema_name="stock_market", table_name="upcom_index"
)
gold_upcom_index = gold_upcom_index.astype(
    {
        **{col: "float" for col in gold_upcom_index.columns if col != "date"},
        "date": "datetime64[ns]",
    }
)
gold_upcom_index

# %%
std_gold_upcom_index_fig = my_visualizer.plot_lines_bars_chart(
    gold_upcom_index,
    x_column="date",
    y_line_columns=["close"],
    y_bar_columns=["matched_volume"],
    title="UPCOM Index close",
    y_line_axis_title="Point",
    y_bar_axis_title="",
    y_unit="",
    prefix_figure_name="upcom_index",
    marker=None,
)
std_gold_upcom_index_fig

# %% [markdown]
# ## ENTERPRISE

# %%
my_visualizer.connect_to_database(database_name=os.getenv("BRONZE_POSTGRES_DATABASE"))
my_visualizer.set_chart_dir(CHARTS_DIR_ENTERPRISE)

# %%
def get_code_table_and_plot(code: str):
    code = code.upper()

    if not code:
        print("Need to specify enterprise code before plotting.")
    else:
        gold_enterprise = my_visualizer.select(
            schema_name="enterprise",
            table_name="daily_price",
            conditions=[
                Condition(
                    column=Table.DAILY_PRICE.Column.CODE.value,
                    operator=SqlOperator.EQUAL_TO,
                    value=code,
                    data_type=DataType.VARCHAR,
                )
            ],
        )

        if len(gold_enterprise) == 0:
            print(f"No data found for code: {code}.")
            return

        gold_enterprise = gold_enterprise.astype(
            {
                Table.DAILY_PRICE.Column.DATE.value: "datetime64[ns]",
                Table.DAILY_PRICE.Column.CODE.value: "string",
                Table.DAILY_PRICE.Column.MARKET_ID.value: "int",
                **{
                    col: "float"
                    for col in gold_enterprise.columns
                    if col
                    not in [
                        Table.DAILY_PRICE.Column.DATE.value,
                        Table.DAILY_PRICE.Column.CODE.value,
                        Table.DAILY_PRICE.Column.MARKET_ID.value,
                    ]
                },
            }
        )

        display(gold_enterprise)

        gold_enterprise_fig = my_visualizer.plot_lines_bars_chart(
            gold_enterprise,
            x_column="date",
            y_line_columns=["close"],
            y_bar_columns=["volume"],
            title=f"{code} close",
            y_line_axis_title="Point",
            y_bar_axis_title="",
            y_unit="",
            prefix_figure_name=f"{code.lower()}",
            marker=None,
        )

        display(gold_enterprise_fig)

# %% [markdown]
# ### ACB

# %%
code = "ACB"
get_code_table_and_plot(code)

# %% [markdown]
# ### BCM

# %%
code = "BCM"
get_code_table_and_plot(code)

# %% [markdown]
# ### BID

# %%
code = "BID"
get_code_table_and_plot(code)

# %% [markdown]
# ### CTG

# %%
code = "CTG"
get_code_table_and_plot(code)

# %% [markdown]
# ### DGC

# %%
code = "DGC"
get_code_table_and_plot(code)

# %% [markdown]
# ### FPT

# %%
code = "FPT"
get_code_table_and_plot(code)

# %% [markdown]
# ### GAS

# %%
code = "GAS"
get_code_table_and_plot(code)

# %% [markdown]
# ### GVR

# %%
code = "GVR"
get_code_table_and_plot(code)

# %% [markdown]
# ### HDB

# %%
code = "HDB"
get_code_table_and_plot(code)

# %% [markdown]
# ### HPG

# %%
code = "HPG"
get_code_table_and_plot(code)

# %% [markdown]
# ### LPB

# %%
code = "LPB"
get_code_table_and_plot(code)

# %% [markdown]
# ### MBB

# %%
code = "MBB"
get_code_table_and_plot(code)

# %% [markdown]
# ### MSN

# %%
code = "MSN"
get_code_table_and_plot(code)

# %% [markdown]
# ### PLX

# %%
code = "PLX"
get_code_table_and_plot(code)

# %% [markdown]
# ### SAB

# %%
code = "SAB"
get_code_table_and_plot(code)

# %% [markdown]
# ### SHB

# %%
code = "SHB"
get_code_table_and_plot(code)

# %% [markdown]
# ### SSB

# %%
code = "SSB"
get_code_table_and_plot(code)

# %% [markdown]
# ### SSI

# %%
code = "SSI"
get_code_table_and_plot(code)

# %% [markdown]
# ### STB

# %%
code = "STB"
get_code_table_and_plot(code)

# %% [markdown]
# ### TCB

# %%
code = "TCB"
get_code_table_and_plot(code)

# %% [markdown]
# ### TPB

# %%
code = "TPB"
get_code_table_and_plot(code)

# %% [markdown]
# ### VCB

# %%
code = "VCB"
get_code_table_and_plot(code)

# %% [markdown]
# ### VHM

# %%
code = "VHM"
get_code_table_and_plot(code)

# %% [markdown]
# ### VIB

# %%
code = "VIB"
get_code_table_and_plot(code)

# %% [markdown]
# ### VIC

# %%
code = "VIC"
get_code_table_and_plot(code)

# %% [markdown]
# ### VJC

# %%
code = "VJC"
get_code_table_and_plot(code)

# %% [markdown]
# ### VNM

# %%
code = "VNM"
get_code_table_and_plot(code)

# %% [markdown]
# ### VPB

# %%
code = "VPB"
get_code_table_and_plot(code)

# %% [markdown]
# ### VRE

# %%
code = "VRE"
get_code_table_and_plot(code)
