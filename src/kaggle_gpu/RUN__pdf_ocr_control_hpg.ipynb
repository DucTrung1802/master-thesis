# %% [markdown]
# # OCR a ticker's filings

# %% [markdown]
# ## 1 · Parameters — the only cell you edit

# %%
# ══════════════════════════════════════════════════════════════════════════════════
#  HOSE_HPG — what is true of THIS ticker, MEASURED from disk 2026-09-07
# ══════════════════════════════════════════════════════════════════════════════════
#  template `corp` (CafeF fingerprint, over the network)  ·  65 quarter(s) filed
#  **0 `pdf` cells of 195**  ·  65 quarter(s) open  ·  0 settled  ·  0 span operands
#
#      balance_sheet      0 / 65 `pdf`      no CSV on disk
#      income_statement   0 / 65 `pdf`      no CSV on disk
#      cash_flow          0 / 65 `pdf`      no CSV on disk
#
#  ⚠️ **THIS IS A BOOTSTRAP — NOT ONE OF THE THREE STATEMENT CSVs EXISTS.**
#     `raw_data/cafef/financials/statements/corp/{balance_sheet,income_statement,cash_flow}/`
#     carries BSR, FPT, GAS, GVR, MSN and VIC, and no `*_HOSE_HPG.csv`.
#     `FinancialsBuilder._write` creates the directory and the file, so a missing CSV costs
#     nothing by itself; what it IMPLIES is the two warnings below.
#
#  ⛔ **AND IT IS A `corp`, WHICH IS THE THING TO READ BEFORE ANY OF IT IS QUOTED.**
#     `TPL-1` / `CRP-1` gate this template, and HDB's bootstrap header is where the contrast
#     was written down: `bank` is the chart the seven reconcile anchors were built against,
#     and HPG is not on it. Two consequences, both measured, not inferred:
#       · `C_LIABILITIES` maps to nothing on `corp` (the row is there, but its account text is
#         9 characters, below `MIN_CONTAINS = 10`), so `reconcile`'s `A = L + E` never runs
#         and the balance sheet falls back to the TRIVIAL `assets == resources` — two grand
#         totals any page reading both gets right together (`SEC-1`).
#       · ✅ **`SEC-1` SHIPPED THE MISSING ARITHMETIC ON 2026-09-04** and it is the one thing
#         that makes this bootstrap better gated than FPT's, GAS's or VIC's were: the VAS
#         form's own section sums (`A + B = TỔNG CỘNG TÀI SẢN`, `C + D = TỔNG CỘNG NGUỒN VỐN`)
#         are now part of `reconcile`. Measured on the population the gate sees — 209 answer,
#         14 fail, 7 abstain — so a `corp` balance sheet is no longer ungated.
#     ⚠️ **THE INCOME STATEMENT AND THE CASH FLOW GAINED NOTHING FROM THAT**, and `CRP-1`(3)
#     is still open: over 27 VIC quarters the balance sheet split on ASSURANCE, 12/13 on
#     audited or reviewed filings against 1/14 on unaudited ones, because the parser was
#     taking the **prior year-end comparative column**. `reconcile` cannot see that column —
#     it is internally consistent — so **`sane`'s equality gate is the only thing between
#     this and a wrong balance sheet written as `pdf`.** Which is the next warning.
#     ⛔ **Nothing this run produces may be quoted as a fundamental until it has been screened
#        by hand.** That is `TPL-1`/`CRP-1`, not a doubt about this ticker's scans.
#
#  ⚠️ **195 OF 195 CELLS HAVE NO `sane` BAND, MEASURED PER CELL AND PER ENTITY, NOT INFERRED.**
#     `seed_history(before=<that quarter>)` was asked for every (quarter, report) pair the way
#     the run asks it — indexed by the task's own `consolidated` flag, since `SAN-1` splits the
#     band per entity — and every one came back empty for want of a `pdf` row to build a band
#     from. That is `BND-1`'s loop in full: no `pdf` row -> no band -> refusal 2 -> still no
#     `pdf` row.
#     ⚠️ **AND THE RAW RETURN LOOKS LIKE THE OPPOSITE OF THAT, WHICH IS WORTH ONE LINE HERE.**
#     `seed_history` returns `{report: {entity: [probe]}}`, so `hist['balance_sheet']` is
#     `{'True': [], 'False': []}` — a TRUTHY dict whose every band is empty. Counting the
#     reports rather than the entities says "195 of 195 cells HAVE a band", which is the exact
#     inverse of the truth. Index to the entity before you believe a band count.
#     ✅ **THE LOOP NO LONGER CLOSES, SINCE 2026-09-06**: a quarter whose filing produced ALL
#     THREE statements is written band or no band, by both writers. So `FORCE_EMPTY_BAND`
#     stays False below — a bootstrap no longer needs it — and what it would still decide here
#     is a filing that produced TWO statements of three.
#  ⚠️ **EVERY ROW THIS RUN WRITES THEREFORE PASSED NO MAGNITUDE GUARD**, on a template whose
#     one working guard against the comparative column IS that band. `sane` is what catches an
#     OCR misread by three orders of magnitude (BSR Q3-2019 read 361,884,738 where another
#     layer reads 361,884,738,267). Screen these by arithmetic before quoting any of them —
#     `web_scraper/statement_screens.py`, and PDF_OCR.md §6's free cross-checks: the cash
#     flow's closing balance IS the balance sheet's cash line, and a balance sheet's two grand
#     totals are one number.
#
#  ✅ **ONE ENTITY, ALL BUT ONE QUARTER — the simplest entity picture of any bootstrap here.**
#     64 of the 65 documents are `hop_nhat` (`consolidated=True`) and **exactly one is
#     STANDALONE**: 2010-Q2. ✅ And it is not a wrong choice — the index carries no consolidated
#     filing of that quarter at all, so `allow_parent` is reaching the only statement that
#     exists rather than preferring a lesser one. ⚠️ **THE COST IS THE BAND, NOT THE CHOICE**,
#     and here it is sharper than HDB's ten-against-forty-five: `SAN-1` builds the `False`
#     entity's band from **one quarter**, so 2010-Q2 is the one cell in this run that can never
#     acquire a band of its own however many quarters succeed around it.
#
#  ⚠️ **THE FILING CHAIN HAS A RAGGED HEAD AND A CLEAN TAIL, AND THE HOLES ARE NOT PARSE
#     FAILURES.** 182 PDFs on disk and 183 index rows (one file listed twice) resolve to 65
#     openable quarters:
#         2008-Q4 · 2009-Q2 · 2009-Q4 · 2010-Q2
#         then 2011-Q1 -> 2026-Q1, contiguous (61 quarters)
#     Everything else in that span — **2008-Q1..Q3 · 2009-Q1 · 2009-Q3 · 2010-Q1 · 2010-Q3 ·
#     2010-Q4** — has NO filing on disk. `missing` is the CORRECT answer for those eight and no
#     run can change it (§5 rule 24).
#     ⚠️ **ONE MORE INDEX PERIOD IS DROPPED BY POLICY**: `Q3-2007` is the 64th Q* period and is
#     cut by `FINANCIALS_PERIOD_MIN = "Q1-2008"`, as is the `FY-2006` annual. That is the floor
#     doing its job, not a document the run failed to reach.
#     ⚠️ **AND TWO QUARTERS ARE OPENED THROUGH AN `FY-` ROW**: 2008-Q4 and 2009-Q4 have no
#     `Q4-*` quarterly at all, so `documents()` normalises the audited annual onto the Q4
#     slot. 63 Q* periods + those 2 = the 65 tasks.
#
#  ⚠️ **17 OF THE 65 TASKS ARE AUDITED ANNUALS, AND 15 OF THOSE 17 HAVE A `Q4-<year>_*`
#     QUARTERLY ON DISK THAT LOST THE SORT** (every Q4 from 2011 to 2025). That matters twice:
#     an annual is the dearer document (9.1 min/MB against 2.5 on a quarterly,
#     §6-2-noviesdecies), and the loser is what `_alternate_retry` (`ALT-1`) reaches for when
#     the chosen filing comes back `absent`.
#     ✅ **`ALT-1` HAS A LOT TO WORK WITH HERE**: **58 of the 65** chosen quarters carry at
#     least one alternate filing, 84 alternates in all. §8 prints which filing each recovered
#     statement came from — read it rather than assuming the chosen one won.
#
#  ✅ **31 OF THE 65 TASKS ARE CUMULATIVE — AND 29 OF THE 31 ARE FULLY DE-CUMULABLE INSIDE
#     THIS ONE RUN.** Every Q4 annual (17) and every Q2 half-year from 2011 on (14). A
#     cumulative income statement is written only when the merge can subtract priors whose
#     span is a KNOWN three months, and on a gap-fill that is `SPN-1`'s recurring refusal —
#     CTG carried seven parsed-but-unwritable Q4s on 2026-09-02, blocked by a blank `months`
#     in ANOTHER row. ✅ **A whole-ticker bootstrap does not have that problem**: this run
#     writes `months` on every quarter it parses, `MERGE_EACH` upserts oldest first, and the
#     Q1..Q3 a Q4 needs are therefore on disk before the Q4 is planned. Measured, per quarter:
#     **29 of 31 have every prior in this run's own task list.**
#     ⚠️ **THE OTHER TWO ARE THE RAGGED HEAD, AND THEY ARE NOT A DEFECT**: 2008-Q4 (2008-Q1,
#     Q2, Q3 never filed) and 2009-Q4 (2009-Q1 and Q3 never filed). The merge writes those
#     with `months` saying how long a span they cover, because no run can ever split them.
#     ⛔ **A 12-MONTH ROW IS NOT A QUARTER. Read `months` before using either of them.**
#     ⚠️ **AND THAT 29 IS THE ARGUMENT FOR RUNNING THIS TICKER IN ONE PASS, OLDEST FIRST.**
#     Chopping it into batches by hand re-creates `SPN-1` for free.
#
#  ⚠️ **SIZE: 416.0 MB over the 65 chosen filings** (min 0.4 MB at 2008-Q4, median 6.8 MB, max
#     19.2 MB at 2011-Q2), of which the 17 annuals are 100.9 MB. Three filings exceed 10 MB —
#     2011-Q2 (19.2), 2015-Q1 (12.2), 2016-Q2 (10.6). ⚠️ **Do not turn that into an ETA here.**
#     Four runs of ONE identical easy document on this machine came in at 100.6, 113.3, 50.8
#     and 50.3 s — a 2.25× swing — so a per-MB rate quoted to a decimal would be inventing
#     precision. What is safe to say is the SHAPE: 65 filings on the LOCAL card, one process
#     each, is hours and not minutes, and HOSE_FPT's 71 filings took 185 min on a T4.
#
#  ⚠️ **NO PAST RUN HAS WITHDRAWN A CONCLUSION ABOUT THIS TICKER, BECAUSE THERE IS NO PAST
#     RUN.** `reports/pdf_ocr/` holds no HOSE_HPG folder and `settled_absences` is empty — so
#     every `absent` this run reports will be a FIRST reading, with no `SET-2` history behind
#     it. Write what you settle into this header before spending the cascade a second time.
#
# ══════════════════════════════════════════════════════════════════════════════════

# ── PARAMETERS — the only cell you edit ───────────────────────────────
ENVIRONMENT = "LOCAL"        # "LOCAL" = parse here | "KAGGLE" = ship it to a T4
EXCHANGE    = "HOSE"         # HOSE | HNX | UPCOM
SYMBOL      = "HPG"          # ticker, as CafeF files it

# ⚠️ WHICH KAGGLE ACCOUNT PAYS FOR THIS RUN — read ONLY when ENVIRONMENT = "KAGGLE".
#   "auto"     -> §4 surveys every `KAGGLE_API_TOKEN*` in `.env` and chooses on REMAINING
#                 WEEKLY GPU HOURS: the SMALLEST balance that still covers this run's
#                 estimate. Tightest fit and not most-remaining, because the quota does NOT
#                 POOL — two accounts holding 15 h each cannot run the ~70-filing ticker that
#                 one account holding 30 h can, so packing one and leaving the other whole is
#                 the only state in which the longest run is still startable.
#   "<user>"   -> a named account. ⚠️ ONE TOKEN PER ACCOUNT IN `.env`, THE VARIABLE NAMED
#                 AFTER IT IN UPPER CASE — `KAGGLE_API_TOKEN_LYDUCTRUNG`,
#                 `KAGGLE_API_TOKEN_DUCTRUNG180200` — and the label is that suffix,
#                 lower-cased, i.e. the username. `python -m kgpu accounts` lists every
#                 account this machine holds with its hours, and spends nothing.
# ⚠️ **A TICKER THIS MACHINE HAS ALREADY PUSHED KEEPS ITS ACCOUNT, WHATEVER THE QUOTA SAYS.**
#    The kernel AND the payload dataset live under that username; switching mid-ticker leaves
#    the running kernel unpullable on the other account and re-uploads the whole filings
#    payload. `kgpu/.accounts.json` is the ledger, written at PUSH, keyed by the job name.
# ⚠️ **THE ESTIMATE IS NOMINAL AND SIZES A QUOTA QUESTION — IT DOES NOT PREDICT A RUNTIME.**
#    documents x 2.6 min (HOSE_FPT: 71 filings, 185 min on a T4) + 0.5 h of payload, queue and
#    the worker's pip install, x1.25 safety. The spread behind that average is a filing
#    accepted at layer 1 in ~1 min against one that defeated the cascade in 33.
# ⚠️ **AND IT IS A REAL GUARD, NOT A TIDINESS ONE — measured 2026-09-08.** `ductrung180200`
#    held **3.59 h of 30**, under a whole-ticker run, while `lyductrung` held 30.00 h — and
#    until the tokens were renamed after their accounts, the first was the one every code
#    path took. A run started on the wrong one is killed by the quota with its filings parsed
#    inside a kernel nothing will pull (`ACC-1`).
KAGGLE_ACCOUNT = "auto"


# WHICH QUARTERS — A LIST, AND NOTHING ELSE. Each entry is YYYY-QQ; "2026-Q4" and the
# zero-padded "2026-04" are the same quarter, folded once at the edge.
#   []                     ->  EVERY quarter this ticker files  (⚠️ ~70 documents, hours).
#                              ⚠️ Safe on this 4 GiB card ONLY because `ISOLATE_DOCUMENTS`
#                              is on; the same list in one process died at document 4
#                              (`GPU-1`). `ONLY_MISSING` below narrows it to the gap.
#   ["2014-Q4", "2015-03"] ->  exactly these quarters, and nothing else.
# ⚠️ The repo-native "Q3-2014" is REFUSED rather than quietly accepted: a typo has to report
#    itself as a typo, not as a quarter CafeF does not file. A STRING is refused for the same
#    reason — a bare "2014-Q4" with the brackets forgotten included; §2 has the measurement.
QUARTERS = []   # ⚠️ THE DEFAULT CHANGED 2026-09-03 AND IT IS THE EXPENSIVE DIRECTION. This
                # read "OUTSTANDING", which resolved to the GAP and raised when there was none;
                # `[]` is every quarter the ticker files — ~70 documents and hours — on a
                # notebook somebody just pressed run on. §2 and §3 both print which it is and
                # how many documents, before anything is spent.
                #   the old default back:  ONLY_MISSING = True
                #   one quarter:           QUARTERS = ["2014-Q4"]

# ⚠️ NARROW AN EMPTY `QUARTERS` TO WHAT IS STILL MISSING — read ONLY when the list is empty,
#    and it is what the retired "OUTSTANDING" sentinel became.
#   False -> every quarter the ticker files, which is what `[]` says above.
#   True  -> exactly the quarters §3 finds still `missing` AND still winnable, plus the span
#            operands they need. Resolved from the three statement CSVs and the PDF index,
#            printed before anything is spent, and it RAISES rather than falling through to
#            "every quarter" when there is nothing left to do.
ONLY_MISSING = False

# ⚠️ **`open` IS NOT `WINNABLE`, AND §3 CANNOT TELL YOU WHICH — so read this before setting
#    ONLY_MISSING = True on a ticker you have already run.** `settled_absences` records one
#    reason and one only: `no such statement on any page of this filing`, which is a verdict
#    on the DOCUMENT and therefore permanent. Every OTHER refusal — a total that will not
#    balance, an identity that does not close, a magnitude the guard rejected — is reported
#    as `open — a re-run could still win it`, because a later layer or a fixed anchor could
#    in principle overturn it. Re-running one costs the FULL cascade to return the same word.
#
# ⚠️ **AND WHEN ONE COMES BACK `absent` TWICE, THE FIRST THING TO CHECK IS THE PDF INDEX,
#    NOT THE LAYERS.** `documents()` returns ONE filing per period and a quarter can have
#    several. Measured 2026-09-04 on TCB's Q2-2019: its closing cash balance is printed under
#    the company's round stamp in the AUDITED consolidated filing, so the recogniser returns
#    a different wrong figure at 200, 300, 400+pad6, 500 and 600 dpi and never the printed
#    one — and the REVIEWED consolidated filing of the same quarter is a different scan that
#    reads the whole tail cleanly at layer 1. *No OCR configuration can read this figure* was
#    measured, true, and written up as *this quarter cannot be parsed*, which is a claim about
#    a different thing. `_alternate_retry` (`ALT-1`) now tries the others automatically; §8
#    prints which filing each recovered statement came from.
#    So: read §8's `absent_reasons`, check the index for a second filing, and write whatever
#    you settle down where a reader meets it BEFORE spending the cascade again — this comment
#    or the per-ticker notebook. §6-2-septquadragies is the same lesson for the settled kind:
#    *a measurement that exists only as prose is one the next session cannot act on.*
#
# ⚠️ **AND A `SETTLED` CELL IS NOT PROOF EITHER — `SET-2`, measured 2026-09-04.** The one
#    reason `settled_absences` treats as PERMANENT, `no such statement on any page of this
#    filing`, is a verdict on the PAGE CLASSIFIER and reads as one on the document. TCB's
#    Q1-2017 and Q3-2017 print the notes title AND the notes form code on the cash flow's
#    FIRST page, so no cash-flow page is found and both were recorded as filings containing
#    no cash flow — page 8 of Q1-2017 prints "LƯU CHUYỂN TIỀN THUẦN TỪ HOẠT ĐỘNG KINH
#    DOANH" over 67 figures. §3 DROPS such a cell before any OCR, so re-trying one means
#    naming its quarter in QUARTERS explicitly.

# ⚠️ What to do about a quarter ALREADY on disk:
#   False -> FILL THE GAPS. One reading `pdf` in all three statements is dropped before any OCR
#            (and before it is uploaded); a figure that DIFFERS is never written over it.
#   True  -> re-parse every selected quarter and let the result replace what disk holds.
#   ⚠️ To replace ONE wrong row use REPAIR below, never this — see the note there.
# ⚠️ TRUE IS REQUIRED BY `SPAN_OPERANDS`, and that is the only reason it is the default here:
#    a span operand is BY DEFINITION a quarter already reading `pdf`, so with False it is
#    dropped before any OCR and the Q4 it unblocks stays unwritable. It is safe in this
#    combination ONLY because MERGE_INTO_CSV is off — `force_differs` follows OVERWRITE into
#    the automatic per-quarter merge, and never into §9's.
# ⚠️ **False HERE, AND IT IS THE PAIR `SPAN_OPERANDS` BELOW DECIDES** (PDF_OCR.md §1a).
#    The generic notebook ships True only because a span operand REQUIRES it — and
#    `plan_batch` reports **0 span operands** for HPG, necessarily: an operand is by
#    definition a quarter already reading `pdf`, and this ticker has none. With no
#    operand to enable, True would buy nothing and lift the DIFFERS refusal on every
#    statement of all 65 quarters. False is the safer half of the safer pair.
OVERWRITE = False

# UPSERT the accepted statements into raw_data/.../statements/*.csv, through `pdf_ocr_merge`:
# it BACKS THE THREE CSVs UP FIRST, prints every changed cell, and refuses four things it
# cannot judge — a statement whose `sane` band was empty, a figure that DIFFERS from a good
# `pdf` row, a cumulative income statement whose priors it cannot subtract, and ⚠️ a document
# any of whose layers RAISED (`VCR-1`: an exception measures the MACHINE, not the filing, so
# whatever won the cascade won by default).
# ⚠️ **KAGGLE NO LONGER READS THIS FLAG AT ALL — THE PULL UPSERTS, ALWAYS** (2026-09-08).
#    It used to be handed to `pdf_ocr.job(merge_statements=...)`, and OFF was the advice here,
#    for two reasons that were both about the OLD merge and are both gone: the pull forced
#    DIFFERS from `OVERWRITE`, and `merge_run` planned a WHOLE FOLDER against one disk state,
#    so a Q4 was decided while the Q3 span it depends on was still whatever disk held when the
#    call started. `runner.merge_statements` is `pdf_ocr_batch.merge_batch` now — one period
#    at a time, oldest first, `force_differs` never passed — i.e. it IS §9. With the two
#    paths identical there was nothing left for a flag to choose between, and what it was
#    choosing in practice was whether hours of T4 ever reached the CSVs at all.
# ⚠️ **THE MEASUREMENT THAT CLOSED IT: HOSE_MBB, 2026-09-08.** A 158-minute round trip
#    accepted **176 of 186 cells** and wrote **0**, because this was False and the process
#    holding the notebook died after the pull — so §9 never ran. `BND-1`'s third face: the
#    parse is durable in the run folder, the CSV was never opened, and a green run says
#    nothing about which.
# ⚠️ WHAT IT STILL DECIDES: the LOCAL one-process path only (`ISOLATE_DOCUMENTS = False`),
#    where it reaches `JobSpec.merge_into_csv` and DOES carry `force_differs = OVERWRITE`.
#    Leave it off there; §9 below is the safer writer. On the LOCAL batch path the writer is
#    `MERGE_EACH`, and `run_batch` now runs the §9 sweep itself before it returns.
#    A deliberate dry run of the pull's merge is `python -m kgpu merge <job> --dry-run`.
MERGE_INTO_CSV = False

# ⚠️ WRITE A STATEMENT WHOSE `sane` BAND WAS EMPTY — it lifts a real guard (`BND-1`).
#   True  -> write it anyway.
#   False -> keep the guard.
# ⚠️ **IT NO LONGER DECIDES WHETHER A NEW TICKER CAN START, AND THAT CHANGED 2026-09-06.** A
#    quarter whose filing produced ALL THREE statements is written band or no band, by both
#    writers, because refusing it was `BND-1`'s loop rather than a guard — see MERGE_EACH.
#    What this flag still governs is everything that gate does NOT cover: a filing that
#    produced two statements of three, which is a judgement about THAT filing and stays the
#    operator's. False is right for a ticker with history on disk, and now also for a
#    bootstrap — the bootstrap no longer needs it.
FORCE_EMPTY_BAND = False

# ⚠️ THE ONNX-ONLY CASCADE — 53 layers of 55, and it is about REPRODUCING, not about speed.
#   True  -> drop `tesseract@200` and `tesseract@400+relax`.
#   False -> the full cascade as shipped.
# ⚠️ `tesseract@200` IS LAYER 4 OF 55 HERE AND DOES NOT EXIST ON A KAGGLE WORKER (`TSS-1`,
#    CLAUDE.md §6-2-quinquagies). So it can win a statement twenty onnx layers would have read
#    better, and every ticker bootstrapped on a T4 carries rows produced by the 53-layer
#    cascade — a local re-parse under the full 55 is a DIFFERENT PROCEDURE and reports the
#    difference as DIFFERS. Measured on BSR Q3-2019: `tesseract@200` read
#    361,884,738 where the Kaggle `onnx@300+tail` row reads 361,884,738,267.
ONNX_ONLY = True

# ⚠️ PULL IN THE QUARTERS A CUMULATIVE Q4 NEEDS AS OPERANDS (`QUARTERS = []` with
#    ONLY_MISSING = True only — the other two modes already name every quarter they are going
#    to open, so there is nothing left for this to add).
#   A Q4 income statement is the YEAR, and the standalone quarter is FY − (Q1+Q2+Q3). The
#   merge will only subtract a prior whose span is a KNOWN three months, and most of the
#   corpus predates the `months` column — so the priors read `unrecorded`, a blank is NOT 3
#   (§5 rule 2), and the Q4 is refused however well it parsed.
# ⚠️ MEASURED: CTG carried SEVEN such Q4 income statements on 2026-09-02, every one of them
#    parsed and none of them writable, blocked by a blank column in ANOTHER ROW. Re-parsing a
#    prior moves no figure — an unchanged reading goes through the merge's `fills_span`
#    branch, which writes the span and nothing else.
# ⚠️ **False — MEASURED, NOT PREFERRED: `plan_batch` returns 0 span operands.** It is
#    read only when `QUARTERS = []` AND `ONLY_MISSING = True`, which is not this run's
#    mode either, and §2 REFUSES it without `OVERWRITE`. All three reasons point one way.
#    ⚠️ **THAT IS NOT THE SAME AS "NO CUMULATIVE PROBLEM"** — 31 of the 65 tasks ARE
#    cumulative. What makes them writable here is `MERGE_EACH` merging oldest first so
#    each Q4 finds its own run's Q1..Q3 already on disk, not this flag. See the header.
SPAN_OPERANDS = False

# ⚠️ ONE PROCESS PER DOCUMENT — what makes a WHOLE-TICKER run possible on a 4 GiB card.
#   True  -> `pdf_ocr_batch.run_batch`: a fresh process per filing, and it waits for the card
#            to have VRAM_FLOOR_MB free before each one.
#   False -> `pdf_ocr_job.run` parses every filing in THIS process. Right for one quarter.
# ⚠️ MEASURED 2026-09-02: 18 documents in one process cleared three filings and then every
#    `onnx@*` layer raised `CUDA failure 2: out of memory` — 294 of them — and the cascade
#    went on and reported `pdf` for statements it had been unable to read. The same 25
#    documents, one process each, ran with **0 engine errors**. It changes no semantics:
#    `seed_history` re-seeds `sane` from DISK per document and the page cache is per filing.
# ⚠️ The cost is model load, ~10-20 s per document.
ISOLATE_DOCUMENTS = True
VRAM_FLOOR_MB = 2600     # free VRAM one document wants before it starts; a filing peaked at 2.9-3.2 GiB
SHOW_ABSENT_ROWS = True  # §8 prints the rows behind a REFUSED statement — the cause, not the symptom

TEMPLATE     = None      # None = RESOLVE it (templates.csv, then CafeF's fingerprint). ⚠️ Never defaulted to "bank".
ALLOW_PARENT = True      # fall back to the STANDALONE filing where no consolidated one exists
PERIODS      = None      # the repo-native form, e.g. ["Q3-2014"]. Optional, and INTERSECTS with QUARTERS.
LAYERS       = None      # None = the cascade ONNX_ONLY selects, in cascade order
COMPARE      = True      # score every parsed cell against the statement CSV already on disk
NOTES        = ""        # free text into the run folder; blank writes a sensible default

# ── THE MERGE — as the run goes (§6), then the sweep (§9) ────────────────────────────
# ⚠️ Merging period by period is not a style choice: `merge_run` plans against disk and writes
#    afterwards, so a span recorded for one quarter reaches the NEXT quarter's planner only in
#    the following call. That is the dependency a span operand needs.

# ⚠️ WRITE EACH QUARTER THE MOMENT ITS FILING HAS PRODUCED ALL THREE STATEMENTS, instead of
#    waiting for §9. ⚠️ **LOCAL + ISOLATE_DOCUMENTS ONLY** — on KAGGLE the worker's data root
#    is a payload that dies with the kernel (`pdf_ocr_job.run` refuses to merge there at all),
#    so the write is the pull's; on the one-process path it is `MERGE_INTO_CSV` above.
#   True  -> `run_batch` upserts a finished quarter BETWEEN DOCUMENTS, through the same
#            `merge_run` §9 calls, and `force_differs` is NEVER passed.
#   False -> nothing reaches the CSVs until §9.
# ⚠️ **THE CSV IS CREATED IF THE TICKER HAS NONE, AND NO KNOB IS NEEDED FOR IT** (2026-09-06,
#    by request). `FinancialsBuilder._write` makes the directory and the file; what used to
#    stop a brand-new ticker was not the missing file but refusal 2 — an EMPTY magnitude band,
#    meaning `sane` failed open and the figure passed no guard — and refusing on that is a
#    LOOP, not a guard: no `pdf` row -> no band -> every statement refused -> still no `pdf`
#    row (`BND-1`). So a quarter that clears the gate is written whether or not `sane` had a
#    band, on this path and in §9 alike, and each such row is PRINTED and RECORDED as
#    unguarded — in the run folder's `merge` block, and again in §10.
# ⚠️ **THOSE ROWS PASSED NO MAGNITUDE GUARD. SCREEN THEM BY ARITHMETIC BEFORE QUOTING ANY OF
#    THEM** — two statements agreeing on one figure, a printed subtotal closing. `sane` is what
#    catches an OCR misread by three orders of magnitude (BSR Q3-2019 was read as
#    361,884,738 where another layer reads 361,884,738,267), and on a bootstrap it is not there.
# ⚠️ THE OTHER THREE REFUSALS ARE UNTOUCHED: a figure that DIFFERS from a `pdf` row on disk, a
#    cumulative income statement whose priors cannot be subtracted, and a document any of whose
#    layers RAISED are all still refused.
# ⚠️ **THE REASON IT IS ON: A RUN THAT STOPS HALFWAY KEEPS WHAT IT HAS ALREADY READ.** ⚠️ The
#    measurement is HOSE_FPT, 2026-09-04, and its CAUSE was a knob and not an interrupt — a
#    185-minute round trip over 71 filings accepted 128 of 213 statements, §9 planned 96 WRITEs
#    and 0 of them reached disk because MERGE_APPLY was off. What it measures for THIS flag is
#    the shape the two share: the parse is durable in the run folder and the CSVs are not
#    touched until a later step that may never run (`BND-1` — the work is on disk, the CSV is
#    not, and a green run says nothing about which). `_write` renders to a `.tmp` and
#    `os.replace`s it, so an interrupt can lose the quarter in flight and never one on disk.
# ⚠️ **THE GATE IS THE FILING, NOT THE STATEMENT.** A document that accepted two of three is
#    HELD — and named in the log as it happens — for §9, where you are reading the refusals.
#    The three CSVs of a quarter move together or they do not move.
# ⚠️ **AND IT IS ALSO `SPN-1`'s ORDER, FOR FREE**: the quarters are parsed oldest first, so a
#    span operand is written before the Q4 it exists to unblock is even planned. §9 has to
#    reproduce that order deliberately; here it falls out of the loop.
# ⚠️ IT DOES NOT MAKE §9 REDUNDANT — what it wrote comes back `identical to the row already on
#    disk`, which is a check, and what it held is what §9 picks up.
MERGE_EACH = True

MERGE_TWO_PASS = True
MERGE_REPORTS = None     # ⚠️ WHICH STATEMENTS §9 MAY WRITE. None = all three.
                         # ⚠️ SCOPE IT WHEN YOU ARE REPAIRING ONE CELL. A quarter whose
                         # other two statements are already `pdf` FROM THE SAME filing
                         # has nothing to gain from leaving them writable, and something
                         # to lose: a DIFFERS decided by recency rather than by the
                         # filing. CTG Q4-2014 was written that way on 2026-09-03.
MERGE_APPLY   = True     # ⚠️ THE DEFAULT SINCE 2026-09-04, AND IT IS WHAT MAKES THIS
                         # NOTEBOOK WRITE. It was False, so a run that parsed perfectly
                         # ended in a PLAN and the three statement CSVs were never opened.
                         # ⚠️ IT GOVERNS BOTH WRITERS SINCE 2026-09-06: §6's per-quarter
                         # upsert (`MERGE_EACH`) and §9's sweep. False makes §6 print
                         # each finished quarter's PLAN as it goes and write nothing —
                         # which is the honest reading of "apply", not a second knob.
                         # ⚠️ MEASURED ON HOSE_FPT, 2026-09-04: a 185-minute T4 round trip
                         #    over 71 filings accepted 128 of 213 statements, §9 planned
                         #    **96 WRITEs**, and **0** of them reached disk. Two knobs had
                         #    to be flipped by hand afterwards to finish a job the machine
                         #    had already done — which is `BND-1`'s loop wearing a second
                         #    face: the work is on disk, the CSV is not, and a green run
                         #    says nothing about which.
                         #   False -> PLAN ONLY. Right when you are about to REPAIR a row,
                         #            or want to read the refusals before spending disk.
                         # ⚠️ WHAT MAKES AN AUTOMATIC WRITE DEFENSIBLE IS THE REFUSALS, NOT
                         # THE EXTRA COMMAND (CLAUDE.md §6-2-quinquadragies, which made the
                         # LOCAL per-quarter merge automatic on the same argument). §9 passes
                         # `force_differs=False`, so a figure that DIFFERS from a good `pdf`
                         # row on disk is STILL refused however `OVERWRITE` is set — and the
                         # other three refusals stand untouched: an empty `sane` band, a
                         # cumulative income statement whose priors it cannot subtract, and
                         # a document any of whose layers RAISED. A backup of the three CSVs
                         # is taken by the first call that writes anything, and every changed
                         # cell is printed. `REPAIR` in §11 is still the only way past
                         # DIFFERS, and it is still opt-in and scoped.
                         # ⚠️ AND A DRY RUN UNDERSTATES A TWO-PASS WRITE, BY CONSTRUCTION:
                         # with nothing written, a later period is planned against the span
                         # the earlier one has not recorded yet, and reports the refusal it
                         # always would. That is a property of the dry run, not a result —
                         # which is the other reason False was the worse default: it could
                         # not even tell you what True would do.

# ⚠️ REPAIR — REPLACE A `pdf` ROW THAT IS ALREADY ON DISK AND WRONG. Name the exact
#    (quarter, statement) pairs; anything not named keeps the DIFFERS refusal. The quarter is
#    the REPO-NATIVE form here:   REPAIR = [("Q3-2019", "income_statement")]
# ⚠️ `OVERWRITE = True` IS THE WRONG TOOL FOR THIS, AND THE REASON IS MEASURED. It lifts DIFFERS
#    for every statement of every quarter in the run — and a `pdf_ocr_job` run is NOT the run
#    that wrote those rows: its `sane` band is rebuilt from disk where a full `build()`
#    accumulates one as it goes, so the two escalate DIFFERENTLY and the seeded run can win on
#    an EARLIER, POORER layer. On ACB 2026-08-30 it would have replaced a 33-item balance sheet
#    with a 19-item one while repairing another statement, reporting only "DIFFERS in N columns".
# ⚠️ Read the DIFFERS report in section 7 first, and decide against the FILING (a printed
#    subtotal, the next quarter's comparative column) — never by preferring the newer run.
REPAIR = []
REPAIR_APPLY = False     # False = print the plan and change nothing. True once you agree.

EXECUTE  = True          # False = resolve and print the plan, spend nothing
REHEARSE = True          # KAGGLE only: the worker side, locally, no quota (~60 s)

# %% [markdown]
# ## 2 · Setup — validate the parameters, find the repo

# %%
# ── SETUP — validate the parameters and find the repo ─────────────────────────
# ⚠️ Checked HERE, before a payload is built or a page is rendered: every one of these is a
# mistake that would otherwise surface hours later, or as a spent Kaggle round trip.
import os
import sys
from pathlib import Path

ENVIRONMENT = str(ENVIRONMENT).upper()
EXCHANGE = str(EXCHANGE).upper()
SYMBOL = str(SYMBOL).upper()
if ENVIRONMENT not in ("LOCAL", "KAGGLE"):
    raise ValueError(f"ENVIRONMENT must be 'LOCAL' or 'KAGGLE', not {ENVIRONMENT!r}")
if EXCHANGE not in ("HOSE", "HNX", "UPCOM"):
    raise ValueError(f"EXCHANGE must be HOSE, HNX or UPCOM, not {EXCHANGE!r}")
# ⚠️ FOLDED HERE so "AUTO", "Auto" and "auto" are one value: it becomes a label lookup in §4
# and a label that differs by case is an account that does not exist.
KAGGLE_ACCOUNT = str(KAGGLE_ACCOUNT).strip().lower() or "auto"

REPO = next((p for p in [Path.cwd(), *Path.cwd().parents]
             if (p / "src" / "kaggle_gpu").is_dir()), None)
if REPO is None:
    raise RuntimeError(f"no src/kaggle_gpu at or above {Path.cwd()} — open this notebook "
                       f"from inside the repo.")
# ⚠️ `kgpu` stages the payload and talks to the Kaggle client relative to the CWD, so the
# notebook anchors itself the way a shell would. LOCAL does not need it and gets it anyway:
# one behaviour, printed, beats two that differ by a mode.
os.chdir(REPO / "src" / "kaggle_gpu")
for _p in (REPO / "src", REPO / "src" / "kaggle_gpu"):
    if str(_p) not in sys.path:
        sys.path.insert(0, str(_p))

# ⚠️ A LONG-LIVED KERNEL PINS THE REPO TO THE COMMIT IT FIRST IMPORTED — `import` is a no-op
# once a module is in `sys.modules`, so re-running this notebook after the repo moves underneath
# it runs the OLD code. The loud form is an AttributeError; ⚠️ the silent form is an OCR run
# executing a previous commit's parser while `metadata.json` records HEAD's hash — a run folder
# that names code it did not run. So the repo's OWN packages are dropped here and re-imported
# from disk on every pass; third-party ones (torch, onnxruntime) are left alone, they do not
# move. ⚠️ It re-imports, so run this notebook TOP TO BOTTOM.
_OURS = ("kgpu", "utils", "web_scraper")
_RELOADED = [_n for _n in list(sys.modules) if _n.split(".")[0] in _OURS]
for _n in _RELOADED:
    del sys.modules[_n]

from utils import progress                          # noqa: E402
from web_scraper import pdf_ocr_job as job          # noqa: E402

# ⚠️ FOLDED ONCE, HERE. "2026-04" and "2026-Q4" are one quarter, and the job name, the payload
# directory and the Kaggle kernel slug are all derived from this list — two spellings that
# reached those would be two runs racing for one slug. An EMPTY list folds to `None`, which is
# `plan()`'s own contract for "every quarter this ticker files".
# ⚠️ A LIST, AND NOTHING ELSE (2026-09-03). QUARTERS used to take the strings "ALL" and
# "OUTSTANDING" beside the list, and TWO TYPES IN ONE PARAMETER COST THREE MEASURED READINGS,
# every one of which reported the wrong mistake:
#   QUARTERS = ""          an empty string is FALSY, so it fell past the sentinel test into
#                          `canonical_quarters`, which reads empty as `None` — it opened EVERY
#                          quarter this ticker files, silently, and printed "ALL".
#   QUARTERS = "  "        strips to "" and falls the same way, except `canonical_quarters`
#                          then iterates the string CHARACTER BY CHARACTER: `' ' is not a
#                          quarter`, an error about the QUARTER FORM for a mistake in the MODE.
#   QUARTERS = "2014-Q4"   the brackets forgotten — refused with `must be "ALL" or
#                          "OUTSTANDING"`, an error about the MODE for a mistake in the LIST.
# The narrowing sentinel is `ONLY_MISSING` now, the list is only ever a list, and ONE message
# covers a string, a `None` and anything else that is not one.
if not isinstance(QUARTERS, (list, tuple)):
    raise TypeError(f'QUARTERS is a LIST of quarters — [] or ["2014-Q4"] — not {QUARTERS!r}. '
                    f"{job.QUARTER_FORM}. An EMPTY list is every quarter the ticker files, "
                    f"and ONLY_MISSING = True narrows it to the ones still `missing`.")
QUARTERS = job.canonical_quarters(QUARTERS)
# ⚠️ AN EMPTY LIST IS RESOLVED IN §3, NOT HERE, and it is the only thing that is: §3 is where
# the statement CSVs and the PDF index are read, and neither has been opened yet.
RESOLVE_FROM_DISK = QUARTERS is None
OUTSTANDING_ONLY = RESOLVE_FROM_DISK and ONLY_MISSING

# ⚠️ THE CASCADE IS PART OF A RUN'S PROVENANCE, NOT ONLY OF ITS COST (`TSS-1`). `tesseract@200`
# is layer 4 of 55 HERE and does not exist on a Kaggle worker, so the two machines run
# DIFFERENT cascades and a local re-parse of a T4-parsed ticker can win on a layer the row on
# disk never saw. `ONNX_ONLY` makes the two the same 53. It never overrides an explicit
# `LAYERS`, and the resolved list is recorded in the run folder either way.
from web_scraper.cafef_financials import FinancialsBuilder as _FB   # noqa: E402

if ONNX_ONLY and LAYERS is None:

    LAYERS = [_l.name for _l in _FB.LAYERS if _l.name.startswith("onnx")]

# ⚠️ TWO COMBINATIONS ARE REFUSED HERE RATHER THAN DISCOVERED AFTERWARDS, and both were
# measured on real runs:
#   (a) SPAN_OPERANDS needs OVERWRITE. A span operand is by definition a quarter already
#       reading `pdf`, so at OVERWRITE=False it is dropped before any OCR and the Q4 it
#       exists to unblock stays unwritable — the run would look complete and change nothing.
#   (b) OVERWRITE + MERGE_INTO_CSV passes `force_differs=True` into the automatic per-quarter
#       merge, i.e. it lifts DIFFERS for EVERY statement of every quarter in the run. On ACB
#       (2026-08-30) that would have replaced a 33-item balance sheet with a 19-item one while
#       repairing a different statement. §9's merge is unforced; REPAIR is the scoped escape.
if SPAN_OPERANDS and not OVERWRITE:
    raise ValueError("SPAN_OPERANDS needs OVERWRITE = True — a span operand is a quarter "
                     "already reading `pdf`, and OVERWRITE=False drops it before any OCR.")
if OVERWRITE and MERGE_INTO_CSV:
    raise ValueError("OVERWRITE = True passes force_differs into the automatic merge, which "
                     "lifts DIFFERS for every statement of the run. Leave MERGE_INTO_CSV off "
                     "and use §9 (unforced, one period at a time), or REPAIR for one row.")

# The task label EVERY progress line in this notebook carries, so it is kept SHORT: it is
# repeated on every row of every table below, and a 40-character label pushes a verdict table
# off the screen to say something §4 already printed. Two quarters or fewer are named; more
# are a count.
# ⚠️ Rebuilt in §3 when the sentinel resolves: a label reading "all quarters" over a
# three-quarter run is a progress line lying about its own denominator.
LABEL = f"{EXCHANGE}_{SYMBOL}" + (
    " " + " ".join(QUARTERS) if QUARTERS and len(QUARTERS) <= 2
    else f" {len(QUARTERS)}q" if QUARTERS else "")

# ⚠️ **ONE PLAN FOR THE WHOLE NOTEBOOK, AND THEREFORE ONE PERCENTAGE.** Every line printed
# from here down leads with `xx.x%` of THE WHOLE SESSION — not of the cell you are in — in the
# one shape `utils.progress` formats and nothing else writes:
#     ` 33.7% - step 5/15 HOSE_CTG 70q - wait kernel - [ 1.5 min] RUNNING`
# Before 2026-09-04 only §5 and §6 reported at all, each with a plan of its own, so a reader
# got `33.7%` from the run cell and bare prose from the nine cells around it and had no way to
# tell a session 3 % in from one 96 % in. The three honest denominators are still named, in
# the segments (`step 5/15`, `doc 2/3`, `page 40/96`).
# ⚠️ THE OCR STEPS ARE THE ROUND TRIP'S OWN (`kgpu.runner.RUN_STAGES`) ON KAGGLE, EMBEDDED
#    HERE RATHER THAN RUN AS A SECOND PLAN — `runner.run` looks its stages up BY KEY, so
#    handing it this plan makes its six steps six steps of this notebook and keeps ONE number
#    on the line. `final=False` is what stops its closing `done()` reading as "the notebook is
#    finished" and parking every cell after it at 100 %.
if ENVIRONMENT == "KAGGLE":
    from kgpu import runner as _runner              # noqa: E402

    _OCR_STAGES = list(_runner.RUN_STAGES)          # export upload push wait download merge
else:
    # ⚠️ Weighted 100 to match `RUN_STAGES`' own total, so the OCR is the same share of the
    # notebook on both machines and the two runs' percentages mean the same thing.
    _OCR_STAGES = [("parse", "OCR the filings", 100.0)]
OCR_KEYS = [_s[0] for _s in _OCR_STAGES]
NOTEBOOK_PLAN = [
    ("setup",    "setup",                1.0),
    ("gap",      "what is left",         1.0),
    ("job",      "resolve the job",      2.0),
    ("rehearse", "rehearse worker",      3.0),
    *_OCR_STAGES,
    ("results",  "read the run folders", 1.0),
    ("refused",  "refused vs written",   1.0),
    ("upsert",   "merge into the CSVs",  5.0),
    ("landed",   "did it land",          1.0),
    ("repair",   "repair one row",       1.0),
]
# ⚠️ THE WEIGHTS ARE NOMINAL AND SAY SO. They put the OCR where it belongs — ~86 % of the
# plan — and they measure no run: a filing accepted at layer 1 is ~1 min and one that defeats
# the cascade was 33 (§6-2-noviesdecies). A weight pretending to be measured would be §5
# rule 2 wearing a progress bar.
# ⚠️ RE-RUN §2 AFTER EDITING §1: the plan's SHAPE depends on ENVIRONMENT. The number is
#    monotone by construction, so re-running a cell out of order re-prints its step at the
#    percentage already reached rather than winding the bar back.
NB = progress.Stages(NOTEBOOK_PLAN, label=LABEL, final=False)
NB.begin("setup", f"{ENVIRONMENT} — parameters validated, repo found")
with NB.capture(nested=True):
    print(f"environment : {ENVIRONMENT}")
    print(f"ticker      : {EXCHANGE}_{SYMBOL}")
    print("quarters    : " + ("OUTSTANDING — resolved in §3 from what is on disk"
                              if OUTSTANDING_ONLY else
                              f"{QUARTERS or 'ALL — every quarter this ticker files'}"))
    # ⚠️ A KNOB THAT IS NOT READ HAS TO SAY SO WHERE IT WOULD BE READ. Silence is what lets
    # a reader believe a flag they set had an effect, and this one is inert the moment the
    # list names its own quarters.
    if QUARTERS and ONLY_MISSING:
        print("            : ⚠️ ONLY_MISSING is IGNORED — it is read only when QUARTERS is "
              "empty, and this run names its quarters.")
    print(f"overwrite   : {OVERWRITE}"
          + ("" if OVERWRITE else "   (quarters already `pdf` in all three are skipped)"))
    print(f"upsert csv  : {MERGE_INTO_CSV}"
          + ("   per quarter, as each finishes" if MERGE_INTO_CSV and ENVIRONMENT == "LOCAL"
             else "   after the pull" if MERGE_INTO_CSV else ""))
    # ⚠️ A KNOB THAT IS NOT READ HAS TO SAY SO WHERE IT WOULD BE READ — the same rule
    # `ONLY_MISSING` obeys two lines up. `MERGE_EACH` is `run_batch`'s argument and nothing
    # else's, so on KAGGLE (the worker cannot reach this disk) and on the one-process path
    # (that is `MERGE_INTO_CSV`) it is inert, and silence is what would let a reader believe
    # the CSVs were being written as the run went.
    print(f"merge each  : {MERGE_EACH}"
          + ("   each quarter is upserted the moment all three of its statements are in"
             if MERGE_EACH and ENVIRONMENT == "LOCAL" and ISOLATE_DOCUMENTS else
             "   ⚠️ IGNORED — read only on LOCAL + ISOLATE_DOCUMENTS; "
             + ("KAGGLE writes on the pull" if ENVIRONMENT == "KAGGLE"
                else "the one-process path is MERGE_INTO_CSV") if MERGE_EACH else
             "   nothing reaches the CSVs until §9"))
    print(f"bootstrap   : {FORCE_EMPTY_BAND}"
          + ("   an EMPTY `sane` band is written anyway — the only way a new ticker "
             "starts" if FORCE_EMPTY_BAND else "   an EMPTY `sane` band is REFUSED"))
    print(f"isolation   : "
          + ("one process per document, VRAM floor "
             f"{VRAM_FLOOR_MB} MiB   (`GPU-1`)" if ISOLATE_DOCUMENTS and ENVIRONMENT == "LOCAL"
             else "one process for the whole run" if ENVIRONMENT == "LOCAL" else "n/a — KAGGLE"))
    print(f"cascade     : "
          + (f"{len(LAYERS)} layer(s)" if LAYERS else "the full cascade")
          + ("   onnx only — the cascade a Kaggle worker runs (`TSS-1`)"
             if ONNX_ONLY and LAYERS else ""))
    # ⚠️ **WHAT THIS CASCADE CAN RECOVER, DERIVED FROM THE LAYERS THEMSELVES.** The methods are
    # SHARED CODE — `FinancialsBuilder.LAYERS` and the `ParseLayer` flags — not notebook
    # settings, so every ticker driven from here gets all of them and there is nothing to "turn
    # on". What the readout is for is the log: a line ending `[onnx@200+noteshead]` means a
    # widening rule won that statement, and this says which rules were even reachable.
    # ⚠️ Listed from `dataclasses.fields`, never from a hand-written list — a gloss typed here
    # would be a second copy of the cascade and would be wrong the first time a flag is added.
    # `ParseLayer`'s docstring is where each one is explained and measured.
    # ⚠️ **`is_strict` IS THE LINE THAT MATTERS**: a layer reading the page AS PRINTED must
    # never run after one that widens what may be believed, so the strict reads come first and
    # a widening layer only ever judges a statement all of them refused.
    import dataclasses                                    # noqa: E402
    import textwrap                                       # noqa: E402

    from web_scraper.cafef_financials import ParseLayer   # noqa: E402

    _CASCADE = [l for l in _FB.LAYERS if LAYERS is None or l.name in set(LAYERS)]
    _WIDE = sorted(f.name for f in dataclasses.fields(ParseLayer)
                   if any(getattr(l, f.name) is True for l in _CASCADE))
    _STRICT = sum(1 for l in _CASCADE if l.is_strict)
    print(f"recoveries  : {_STRICT} strict read(s), then {len(_CASCADE) - _STRICT} widening "
          f"layer(s) carrying {len(_WIDE)} flag(s)")
    print(textwrap.fill(" ".join(_WIDE), 92, initial_indent="              ",
                        subsequent_indent="              "))
    # ⚠️ A KNOB THAT IS NOT READ HAS TO SAY SO WHERE IT WOULD BE READ — the same rule
    # `ONLY_MISSING` and `MERGE_EACH` obey above. The account is resolved in §4 and only on
    # KAGGLE; printing it unqualified on a LOCAL run would let a reader believe a hosted
    # account had been picked for a parse that never left this laptop.
    print(f"kaggle acct : {KAGGLE_ACCOUNT}"
          + ("   resolved in §4, against every account's remaining GPU hours"
             if ENVIRONMENT == "KAGGLE" and KAGGLE_ACCOUNT == "auto" else
             "   forced — §4 takes this label and does not rank"
             if ENVIRONMENT == "KAGGLE" else
             "   ⚠️ IGNORED — LOCAL parses here and authenticates nothing"))
    print(f"repo        : {REPO}")
    print(f"cwd         : {Path.cwd()}")
    print(f"code        : {REPO / 'src'}"
          + (f"   ({len(_RELOADED)} cached module(s) dropped, re-imported from disk)"
             if _RELOADED else "   (first import in this kernel)"))
    # ⚠️ The percentage is a POSITION IN THE PLAN and not a fraction of the time left — a filing
    # accepted at layer 1 of 47 costs ~1 min and one that defeats the cascade cost 33. Said here,
    # once, because it is on every line below it.
    print(f"log shape   : {progress.format_line(0.337, 'task', 'sub-task', 'detail')}")
    print(f"              overall % of THIS NOTEBOOK — {len(NOTEBOOK_PLAN)} steps, the OCR worth "
          f"{100 * sum(_s[2] for _s in _OCR_STAGES) / sum(_s[2] for _s in NOTEBOOK_PLAN):.0f}%.")
    print("              A position in the plan, never a fraction of the time — a LOWER bound, "
          "so a run finishes early rather than stalling at 99 %.")
NB.end()
# Out:
#   0.0% - step 1/10 HOSE_HPG - setup - LOCAL — parameters validated, repo found
#   0.0% - step 1/10 HOSE_HPG - setup - environment : LOCAL
#   0.0% - step 1/10 HOSE_HPG - setup - ticker      : HOSE_HPG
#   0.0% - step 1/10 HOSE_HPG - setup - quarters    : ALL — every quarter this ticker files
#   0.0% - step 1/10 HOSE_HPG - setup - overwrite   : False   (quarters already `pdf` in all three are skipped)
#   0.0% - step 1/10 HOSE_HPG - setup - upsert csv  : False
#   0.0% - step 1/10 HOSE_HPG - setup - merge each  : True   each quarter is upserted the moment all three of its statements are in
#   0.0% - step 1/10 HOSE_HPG - setup - bootstrap   : False   an EMPTY `sane` band is REFUSED
#   0.0% - step 1/10 HOSE_HPG - setup - isolation   : one process per document, VRAM floor 2600 MiB   (`GPU-1`)
#   0.0% - step 1/10 HOSE_HPG - setup - cascade     : 115 layer(s)   onnx only — the cascade a Kaggle worker runs (`TSS-1`)
#   0.0% - step 1/10 HOSE_HPG - setup - recoveries  : 21 strict read(s), then 94 widening layer(s) carrying 32 flag(s)
#   0.0% - step 1/10 HOSE_HPG - setup - annual_tail cash_close_from_bs cash_extra_terms cash_wording
#   0.0% - step 1/10 HOSE_HPG - setup - code_column_by_value column_header_blind condensed_form condensed_income
#   0.0% - step 1/10 HOSE_HPG - setup - deskew_rows duplicate_period equity_wording income_by_columns join_digits
#   0.0% - step 1/10 HOSE_HPG - setup - join_lost_separator label_wrap loose_form_code merged_tail notes_boundary
#   0.0% - step 1/10 HOSE_HPG - setup - notes_head notes_tail realign_rows red_channel relax_components
#   0.0% - step 1/10 HOSE_HPG - setup - relax_merged_seam relax_split_tail relax_totals reseat_words tail_continuation
#   0.0% - step 1/10 HOSE_HPG - setup - title_over_form total_from_section truncated_total unit_from_document
#   0.0% - step 1/10 HOSE_HPG - setup - repo        : D:\GIT\master-thesis
#   0.0% - step 1/10 HOSE_HPG - setup - cwd         : D:\GIT\master-thesis\src\kaggle_gpu
#   0.0% - step 1/10 HOSE_HPG - setup - code        : D:\GIT\master-thesis\src   (first import in this kernel)
#   0.0% - step 1/10 HOSE_HPG - setup - log shape   :  33.7% - task - sub-task - detail
#   0.0% - step 1/10 HOSE_HPG - setup - overall % of THIS NOTEBOOK — 10 steps, the OCR worth 86%.
#   0.0% - step 1/10 HOSE_HPG - setup - A position in the plan, never a fraction of the time — a LOWER bound, so a run finishes early rather than stalling at 99 %.

# %% [markdown]
# ## 3 · What is left — the gap on disk, and what a re-run cannot change

# %%
# ── WHAT IS LEFT — the gap on disk, and what a re-run cannot change ───────────
# ⚠️ THE QUESTION THIS ANSWERS IS THE ONE THAT DECIDES `QUARTERS`, and until 2026-09-02 the
# notebook could not answer it: you had to know which (quarter, statement) cells of this ticker
# still read `missing`, and the only way to find out was an ad-hoc script over the three CSVs.
#
# ⚠️ IT IS NOT A SECOND RULE. The quarters come from `documents()` through `job.plan()` — the
# same call the run makes — "already done" is `job.parsed_reports()`, which is `pdf` and nothing
# else, and a cell a past run PROVED unproducible is dropped by `settled_absences`.
#
# ⚠️ `use_data_root()` FIRST, AND IT IS LOAD-BEARING (`CWD-1`). `fin.STATEMENTS_DIR` is a
# RELATIVE default read at call time, and §2 has just `os.chdir`-ed into `src/kaggle_gpu` — so
# without this every quarter reads `absent`, which is a legitimate state for a ticker being
# bootstrapped and therefore looks like nothing is wrong.
NB.begin("gap", "the three statement CSVs and the PDF index — no OCR")
with NB.capture(nested=True):
    from web_scraper import cafef_financials as fin      # noqa: E402
    from web_scraper import pdf_ocr_batch                # noqa: E402

    job.use_data_root(REPO / "raw_data" / "cafef")
    _builder = fin.FinancialsBuilder(logger=None)

    # ⚠️ RESOLVED, NEVER DEFAULTED — and how it resolved is printed, because "read off
    # templates.csv" and "fingerprinted over the network" are not the same claim (`TPX-1`).
    [PLAN] = pdf_ocr_batch.plan_batch(
        [SYMBOL], exchange=EXCHANGE, reports_root=REPO / "reports" / "pdf_ocr",
        allow_parent=ALLOW_PARENT, span_operands=SPAN_OPERANDS, template=TEMPLATE,
        builder=_builder)
    TEMPLATE, TEMPLATE_HOW = PLAN.template, PLAN.template_how

    print(f"{PLAN.key}   template {TEMPLATE} ({TEMPLATE_HOW})   "
          f"{PLAN.filed} quarter(s) filed, {PLAN.complete} complete")
    print("")
    # ⚠️ NO FILINGS AND NOTHING OUTSTANDING PRINT THE SAME LINE OTHERWISE, and they are opposite
    # answers: one says the ticker is done, the other that nothing was ever measured (§5 rule 2).
    if not PLAN.filed:
        print("  ⚠️ this ticker files NO document `documents()` will open — an absent PDF "
              "index, or")
        print("     everything before FINANCIALS_PERIOD_MIN. Nothing here says the ticker "
              "is done.")
    elif not PLAN.quarters and not PLAN.settled:
        print("  every filed quarter reads `pdf` in all three statements. Nothing is outstanding.")
    else:
        for _q in PLAN.quarters:
            _tag = "SPAN OPERAND — re-parsed only to record `months`" if _q in PLAN.operands else \
                   "open — a re-run could still win it"
            print(f"  {_q:9} {_tag}")
        for _q, _reports in sorted(PLAN.settled.items()):
            for _r in _reports:
                print(f"  {_q:9} {_r:18} SETTLED — the filing contains no such statement")
        print("")
        print(f"  {len(PLAN.quarters)} quarter(s) with an OPEN cell "
              f"(of which {len(PLAN.operands)} are span operands), "
              f"{sum(len(v) for v in PLAN.settled.values())} SETTLED cell(s)")

    # ⚠️ A SETTLED CELL IS `missing` FOREVER, and re-running it costs the full cascade to
    # return the same word. ACB's Q2-2009 and Q3-2009 cash flows were put through all 50
    # layers FOUR times on
    # 2026-08-30 before anything recorded why: both filings are three-page `BÁO CÁO TÀI CHÍNH TÓM
    # TẮT` forms (Mẫu CBTT-03) with no cash flow statement in them at all.
    # ⚠️ AND AN EMPTY SETTLED SET IS SILENCE, NOT A CLEAN BILL: a run older than artefact schema v4
    # recorded no reason, so a cell reading "open" here may still be unwinnable and merely
    # unmeasured (§5 rule 2).
    if PLAN.settled:
        print("")
        print("  `missing` is the correct and PERMANENT answer for the SETTLED rows (§5 rule 24).")

    # ⚠️ WHICH QUARTERS THE RUN ACTUALLY TAKES — three modes, and an EMPTY `QUARTERS` is resolved
    # HERE and nowhere else. An ONLY_MISSING that resolves to nothing RAISES rather than falling
    # through: `plan()` reads an empty `quarters` as "every quarter this ticker files", so the one
    # thing a "nothing left to do" answer must not do is silently open 70 filings.
    if OUTSTANDING_ONLY:
        if not PLAN.quarters:
            raise RuntimeError(
                f"ONLY_MISSING resolved to nothing for {PLAN.key}: every filed quarter either "
                f"reads `pdf` in all three statements or is SETTLED. Name the quarters "
                f"explicitly, or set ONLY_MISSING = False, if you meant to re-parse "
                f"something anyway.")
        QUARTERS = PLAN.quarters
    elif RESOLVE_FROM_DISK:
        # ⚠️ EVERY QUARTER THE TICKER FILES — including the ones already `pdf`, which is the point:
        # this is the mode that gets a ticker to FULL coverage rather than filling its gaps. It
        # needs OVERWRITE (validated in §2) and, on this card, ISOLATE_DOCUMENTS.
        QUARTERS = [job.as_quarter(t.period) for t in
                    job.plan(_builder, EXCHANGE, SYMBOL, allow_parent=ALLOW_PARENT,
                             template=TEMPLATE)]
        PLAN.quarters = QUARTERS
    else:
        # ⚠️ `else`, not `elif QUARTERS`: an empty list is the two branches above, so everything
        # reaching here NAMES its quarters. A truthiness test would leave a fourth, silent
        # path that ran with `PLAN.quarters` still holding §3's outstanding set — a run
        # taking quarters nobody asked for, with nothing printing a difference.
        PLAN.quarters = list(QUARTERS)

    # ⚠️ The label reaches EVERY line below, so it is a count once past two quarters — §4 prints
    # the list, and repeating it on each row of a 70-quarter verdict table buys nothing.
    LABEL = f"{EXCHANGE}_{SYMBOL}" + (" " + " ".join(PLAN.quarters)
                                      if 1 <= len(PLAN.quarters) <= 2
                                      else f" {len(PLAN.quarters)}q")
    NB.task = LABEL          # the sentinel has resolved; the denominator on the line is now true
    print("")
    _MODE = "OUTSTANDING" if OUTSTANDING_ONLY else "ALL" if RESOLVE_FROM_DISK else "explicit"
    print(f'  QUARTERS = {_MODE} -> {len(PLAN.quarters)} document(s)'
          + (f": {' '.join(PLAN.quarters)}" if len(PLAN.quarters) <= 12 else
             f": {' '.join(PLAN.quarters[:6])} … {' '.join(PLAN.quarters[-3:])}"))

    # ⚠️ **THE THREE CSVs THEMSELVES, BECAUSE `MERGE_EACH` WRITES INTO THEM AS THE RUN GOES —
    # and because a MISSING file is not the obstacle a reader expects it to be.**
    # `FinancialsBuilder._write` creates the directory and the file, so "there is no CSV yet"
    # costs nothing by itself. What costs is what a missing CSV IMPLIES: no `pdf` row on disk,
    # so `seed_history` reconstructs no magnitude band, so `sane` fails open, so every
    # statement is refused, so there is still no CSV — `BND-1`, and it is a loop that only
    # FORCE_EMPTY_BAND breaks. Printed HERE, where nothing has been spent, because the
    # alternative is learning it after a whole-ticker parse (HOSE_FPT, 2026-09-04).
    # ⚠️ `_builder._existing` is `plan_merge`'s own reader, not a second one — a count taken
    # by a different reader here could disagree with the merge that follows it.
    print("")
    CSV_ON_DISK = {}
    for _report in fin.REPORTS:
        _rows = _builder._existing(EXCHANGE, SYMBOL, TEMPLATE, _report)
        CSV_ON_DISK[_report] = sum(1 for _r in _rows.values() if _r.get("source") == "pdf")
        _path = Path(fin.statement_path(TEMPLATE, _report, EXCHANGE, SYMBOL))
        print(f"  {_report:18} "
              + (f"{len(_rows):>3} row(s), {CSV_ON_DISK[_report]:>3} `pdf`   {_path.name}"
                 if _path.is_file() else
                 f"⚠️ NO FILE — {_path.name} is created by the first write that clears the "
                 f"refusals"))
    # ⚠️ **NO `pdf` ROW ANYWHERE IS THE BOOTSTRAP CASE, AND IT IS NOT THE SAME TEST AS "NO
    # FILE".** A CSV that exists holding only `missing`/`cafef` rows seeds no band either
    # (`seed_history` reads `pdf` and nothing else, §5 rule 24), so a file-existence test would
    # call such a ticker ready and every write would still be refused.
    NEEDS_BOOTSTRAP = not any(CSV_ON_DISK.values())
    if NEEDS_BOOTSTRAP:
        print("")
        print(f"  ⚠️ {PLAN.key} HAS NO `pdf` ROW ON DISK — this run BOOTSTRAPS the ticker, and")
        print("     `seed_history` has nothing to rebuild a magnitude band from, so `sane` "
              "FAILS OPEN")
        print("     on every statement of it. A quarter whose filing produces all three is "
              "written")
        print("     anyway (`BND-1` is a loop, not a guard — MERGE_EACH says why), and the "
              "three CSVs")
        print("     are CREATED by the first such write.")
        print("     ⚠️ THOSE ROWS PASS NO MAGNITUDE GUARD. Screen them by arithmetic — two "
              "statements")
        print("        agreeing on one figure, a printed subtotal closing — before quoting "
              "any of them.")
        print("        Each is printed as it is written, recorded in the run folder's `merge` "
              "block,")
        print("        and counted again in §10.")
NB.end()
# Out:
#   0.9% - step 2/10 HOSE_HPG - what is left - the three statement CSVs and the PDF index — no OCR
#   0.9% - step 2/10 HOSE_HPG - what is left - HOSE_HPG   template corp (detect_template (CafeF fingerprint, over the network))   65 quarter(s) filed, 0 complete
#   0.9% - step 2/10 HOSE_HPG - what is left - 2008-Q4   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2009-Q2   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2009-Q4   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2010-Q2   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2011-Q1   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2011-Q2   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2011-Q3   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2011-Q4   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2012-Q1   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2012-Q2   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2012-Q3   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2012-Q4   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2013-Q1   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2013-Q2   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2013-Q3   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2013-Q4   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2014-Q1   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2014-Q2   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2014-Q3   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2014-Q4   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2015-Q1   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2015-Q2   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2015-Q3   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2015-Q4   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2016-Q1   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2016-Q2   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2016-Q3   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2016-Q4   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2017-Q1   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2017-Q2   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2017-Q3   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2017-Q4   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2018-Q1   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2018-Q2   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2018-Q3   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2018-Q4   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2019-Q1   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2019-Q2   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2019-Q3   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2019-Q4   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2020-Q1   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2020-Q2   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2020-Q3   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2020-Q4   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2021-Q1   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2021-Q2   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2021-Q3   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2021-Q4   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2022-Q1   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2022-Q2   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2022-Q3   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2022-Q4   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2023-Q1   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2023-Q2   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2023-Q3   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2023-Q4   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2024-Q1   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2024-Q2   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2024-Q3   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2024-Q4   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2025-Q1   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2025-Q2   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2025-Q3   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2025-Q4   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 2026-Q1   open — a re-run could still win it
#   0.9% - step 2/10 HOSE_HPG - what is left - 65 quarter(s) with an OPEN cell (of which 0 are span operands), 0 SETTLED cell(s)
#   0.9% - step 2/10 HOSE_HPG 65q - what is left - QUARTERS = ALL -> 65 document(s): 2008-Q4 2009-Q2 2009-Q4 2010-Q2 2011-Q1 2011-Q2 … 2025-Q3 2025-Q4 2026-Q1
#   0.9% - step 2/10 HOSE_HPG 65q - what is left - balance_sheet      ⚠️ NO FILE — bs_HOSE_HPG.csv is created by the first write that clears the refusals
#   0.9% - step 2/10 HOSE_HPG 65q - what is left - income_statement   ⚠️ NO FILE — is_HOSE_HPG.csv is created by the first write that clears the refusals
#   0.9% - step 2/10 HOSE_HPG 65q - what is left - cash_flow          ⚠️ NO FILE — cf_HOSE_HPG.csv is created by the first write that clears the refusals
#   0.9% - step 2/10 HOSE_HPG 65q - what is left - ⚠️ HOSE_HPG HAS NO `pdf` ROW ON DISK — this run BOOTSTRAPS the ticker, and
#   0.9% - step 2/10 HOSE_HPG 65q - what is left - `seed_history` has nothing to rebuild a magnitude band from, so `sane` FAILS OPEN
#   0.9% - step 2/10 HOSE_HPG 65q - what is left - on every statement of it. A quarter whose filing produces all three is written
#   0.9% - step 2/10 HOSE_HPG 65q - what is left - anyway (`BND-1` is a loop, not a guard — MERGE_EACH says why), and the three CSVs
#   0.9% - step 2/10 HOSE_HPG 65q - what is left - are CREATED by the first such write.
#   0.9% - step 2/10 HOSE_HPG 65q - what is left - ⚠️ THOSE ROWS PASS NO MAGNITUDE GUARD. Screen them by arithmetic — two statements
#   0.9% - step 2/10 HOSE_HPG 65q - what is left - agreeing on one figure, a printed subtotal closing — before quoting any of them.
#   0.9% - step 2/10 HOSE_HPG 65q - what is left - Each is printed as it is written, recorded in the run folder's `merge` block,
#   0.9% - step 2/10 HOSE_HPG 65q - what is left - and counted again in §10.

# %% [markdown]
# ## 4 · The plan — what would run, before anything is spent

# %%
# ── THE JOB — resolved and printed, before anything is spent ──────────────────
# ⚠️ Both branches end at the SAME object. `pdf_ocr.job()` writes a `JobSpec`'s fields into the
# worker notebook's parameter cell, and the worker builds the JobSpec from them — so a LOCAL run
# and a KAGGLE run of the same parameters are one procedure on two machines, not two. What
# differs is the stack, and every run records its `stack_fingerprint`.
NB.begin("job", "resolve the spec, count the ceiling — nothing is spent")
with NB.capture(nested=True):
    SPEC = CFG = PREPARED = None

    if ENVIRONMENT == "LOCAL":
        SPEC = job.JobSpec(
            exchange=EXCHANGE, symbol=SYMBOL, periods=PERIODS, quarters=PLAN.quarters,
            allow_parent=ALLOW_PARENT, overwrite=OVERWRITE, template=TEMPLATE, layers=LAYERS,
            compare_with_disk=COMPARE, merge_into_csv=MERGE_INTO_CSV,
            force_empty_band=FORCE_EMPTY_BAND,
            notes=NOTES or f"ENVIRONMENT=LOCAL overwrite={OVERWRITE}",
        )
        # ⚠️ `prepare()` resolves the data root, the models, the TEMPLATE and the document list and
        # RAISES on any of them — no OCR, no PDF. It also raises, in as many words, when every
        # quarter you asked for is already parsed and OVERWRITE is False.
        PREPARED = SPEC.prepare()
        print("\n".join(PREPARED.describe()))
        print()
        for _t in PREPARED.tasks:
            print(f"  {_t.period:<8} {_t.file[:56]:<56} "
                  f"{os.path.getsize(_t.path) / 1024 ** 2:>6.1f} MB"
                  + ("  CUMULATIVE" if _t.cumulative else ""))
        # ⚠️ THE CEILING, BEFORE ANY OF IT IS SPENT. The bill is `pages x OCR passes`, and the 49
        # layers are only 7 passes — a layer that changes only the mapping or a gate re-maps
        # a parse the page cache already holds. Both numbers are free: `page_count` opens
        # the PDF without
        # rendering a pixel, and the pass count is a property of the cascade.
        # ⚠️ It is a CEILING, loose in the honest direction: `scan` stops as soon as all three
        # statements are behind it (BID Q3-2011 reads 7 pages of 32) and the cascade stops at the
        # first layer that accepts. What it tells you is which filing would be dear IF something in
        # it cannot be read — that is the only case that pays it.
        import fitz                                       # noqa: E402
        from web_scraper.cafef_financials import ocr_key  # noqa: E402

        PASSES = len({ocr_key(_l) for _l in PREPARED.layers})
        PAGES = 0
        for _t in PREPARED.tasks:
            try:
                with fitz.open(_t.path) as _d:
                    PAGES += _d.page_count
            except Exception as _e:                       # a damaged page tree is `scan`'s problem
                print(f"  ⚠️ could not count pages of {_t.file}: {_e}")
        print("")
        print(f"  ceiling      : {PAGES} page(s) x {PASSES} OCR pass(es) = "
              f"{PAGES * PASSES:,} page-reads at most")
        print(f"                 ~{PAGES * PASSES * 0.65 / 60:.0f} min at 0.65 s/page "
              f"(onnx@200 on this laptop; the 300/400 dpi passes cost more).")
        print("                 A filing accepted at layer 1 pays ONE pass over the pages "
              "up to its last")
        print("                 statement, which is the usual case — see the run log.")

        if PREPARED.template != "bank":
            print(f"\n⚠️ CRP-1: this is a `{PREPARED.template}` filing. `C_LIABILITIES` still "
                  f"misses on corp,\n   so the balance sheet reconciles on the TRIVIAL "
                  f"`assets == resources` — true by\n   construction on any page that reads both. "
                  f"Nothing from a non-bank run may be\n   quoted as a fundamental yet.")
    else:
        from kgpu import accounts, pdf_ocr, runner       # noqa: E402

        # ⚠️ **THE ACCOUNT IS CHOSEN BEFORE THE JOB IS BUILT, AND THE ORDER IS LOAD-BEARING.**
        # `pdf_ocr.job` derives BOTH slugs — the kernel and the payload dataset — from whoever
        # is authenticated at build time (`kaggle_user()`), so selecting afterwards would leave
        # a config naming one account while the credentials are another's. Kaggle answers that
        # with a 403 AFTER the payload is uploaded, which is the expensive half of the trip.
        # ⚠️ The survey is read-only and spends NO quota — 2-3 s per account, measured
        # 2026-09-08. It is `quota_view`, the same call `python -m kgpu accounts` makes.
        ACCOUNT_STATUS = accounts.survey()
        print("\n".join(accounts.report(ACCOUNT_STATUS)))
        # ⚠️ The job NAME is derived from the filter alone and needs no credentials — which is
        # exactly why it can be computed here, one line before the account that will own it.
        # It is the ledger's key, so a ticker resumed next week finds the account that owns
        # its kernel rather than starting a second one beside it.
        JOB_NAME = pdf_ocr.job_name(SYMBOL, periods=PERIODS, quarters=PLAN.quarters)
        NEED_HOURS = accounts.estimate_hours(len(PLAN.quarters))
        print(f"\nestimate    : {len(PLAN.quarters)} document(s) x "
              f"{accounts.HOURS_PER_DOCUMENT * 60:.1f} min + "
              f"{accounts.FIXED_OVERHEAD_HOURS:.2f}h overhead = ~{NEED_HOURS:.2f}h GPU")
        print("              ⚠️ NOMINAL — it sizes the quota question and predicts no "
              "runtime (`accounts.estimate_hours`).")
        ACCOUNT = accounts.select_for_name(
            JOB_NAME, need_hours=NEED_HOURS, statuses=ACCOUNT_STATUS,
            force_label=None if KAGGLE_ACCOUNT == "auto" else KAGGLE_ACCOUNT)
        print("\n".join(ACCOUNT.lines()))
        print()

        CFG = pdf_ocr.job(
            SYMBOL, exchange=EXCHANGE, periods=PERIODS, quarters=PLAN.quarters,
            allow_parent=ALLOW_PARENT, overwrite=OVERWRITE, template=TEMPLATE, layers=LAYERS,
            compare=COMPARE, notes=NOTES,
            # ⚠️ NOT a worker parameter. The worker cannot upsert — it writes /kaggle/working and
            # exits — so this is the PULL's knob, read by `runner.merge_statements` on this
            # machine.
            force_empty_band=FORCE_EMPTY_BAND,
        )
        print("\n".join(pdf_ocr.describe(CFG)))
        print()
        # The filings this selects are the filings the WORKER will open: `plan()` runs HERE, so the
        # payload cannot diverge from the worker's own choice.
        runner.plan(CFG)
NB.end()
# Out:
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - resolve the spec, count the ceiling — nothing is spent
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - symbol       : HOSE_HPG
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - template     : corp   (override)
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - documents    : 65  (Q4-2008, Q2-2009, Q4-2009, Q2-2010, Q1-2011, Q2-2011, Q3-2011, Q4-2011 …)
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - quarters     : ['2008-Q4', '2009-Q2', '2009-Q4', '2010-Q2', '2011-Q1', '2011-Q2', '2011-Q3', '2011-Q4', '2012-Q1', '2012-Q2', '2012-Q3', '2012-Q4', '2013-Q1', '2013-Q2', '2013-Q3', '2013-Q4', '2014-Q1', '2014-Q2', '2014-Q3', '2014-Q4', '2015-Q1', '2015-Q2', '2015-Q3', '2015-Q4', '2016-Q1', '2016-Q2', '2016-Q3', '2016-Q4', '2017-Q1', '2017-Q2', '2017-Q3', '2017-Q4', '2018-Q1', '2018-Q2', '2018-Q3', '2018-Q4', '2019-Q1', '2019-Q2', '2019-Q3', '2019-Q4', '2020-Q1', '2020-Q2', '2020-Q3', '2020-Q4', '2021-Q1', '2021-Q2', '2021-Q3', '2021-Q4', '2022-Q1', '2022-Q2', '2022-Q3', '2022-Q4', '2023-Q1', '2023-Q2', '2023-Q3', '2023-Q4', '2024-Q1', '2024-Q2', '2024-Q3', '2024-Q4', '2025-Q1', '2025-Q2', '2025-Q3', '2025-Q4', '2026-Q1']   selected ['2008-Q4', '2009-Q2', '2009-Q4', '2010-Q2', '2011-Q1', '2011-Q2', '2011-Q3', '2011-Q4', '2012-Q1', '2012-Q2', '2012-Q3', '2012-Q4', '2013-Q1', '2013-Q2', '2013-Q3', '2013-Q4', '2014-Q1', '2014-Q2', '2014-Q3', '2014-Q4', '2015-Q1', '2015-Q2', '2015-Q3', '2015-Q4', '2016-Q1', '2016-Q2', '2016-Q3', '2016-Q4', '2017-Q1', '2017-Q2', '2017-Q3', '2017-Q4', '2018-Q1', '2018-Q2', '2018-Q3', '2018-Q4', '2019-Q1', '2019-Q2', '2019-Q3', '2019-Q4', '2020-Q1', '2020-Q2', '2020-Q3', '2020-Q4', '2021-Q1', '2021-Q2', '2021-Q3', '2021-Q4', '2022-Q1', '2022-Q2', '2022-Q3', '2022-Q4', '2023-Q1', '2023-Q2', '2023-Q3', '2023-Q4', '2024-Q1', '2024-Q2', '2024-Q3', '2024-Q4', '2025-Q1', '2025-Q2', '2025-Q3', '2025-Q4', '2026-Q1']
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - skipped      : 0 quarter(s) already `pdf` in all three statements
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - cascade      : 115 of 117 layers
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - data root    : D:\GIT\master-thesis\raw_data\cafef
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - models       : det=deepdoc_det.onnx vietocr=vgg_seq2seq.pth
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - vietocr cfg  : D:\GIT\master-thesis\src\web_scraper\models\vietocr_vgg_seq2seq.yml
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q4-2008  FY-2008_bao_cao_tai_chinh_hop_nhat_nam_2008_da_kiem_toan    0.4 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q2-2009  Q2-2009_bao_cao_tai_chinh_hop_nhat_quy_2_nam_2009.pdf       3.7 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q4-2009  FY-2009_bao_cao_tai_chinh_hop_nhat_nam_2009_da_kiem_toan    1.9 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q2-2010  Q2-2010_bao_cao_tai_chinh_quy_2_nam_2010_da_kiem_toan.pd    4.9 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q1-2011  Q1-2011_bao_cao_tai_chinh_hop_nhat_quy_1_nam_2011.pdf       7.3 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q2-2011  Q2-2011_bao_cao_tai_chinh_hop_nhat_quy_2_nam_2011_da_soa   18.3 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q3-2011  Q3-2011_bao_cao_tai_chinh_hop_nhat_quy_3_nam_2011.pdf       4.3 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q4-2011  FY-2011_bao_cao_tai_chinh_hop_nhat_nam_2011_da_kiem_toan    3.3 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q1-2012  Q1-2012_bao_cao_tai_chinh_hop_nhat_quy_1_nam_2012.pdf       4.1 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q2-2012  Q2-2012_bao_cao_tai_chinh_hop_nhat_quy_2_nam_2012_da_soa    5.1 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q3-2012  Q3-2012_bao_cao_tai_chinh_hop_nhat_quy_3_nam_2012.pdf       2.9 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q4-2012  FY-2012_bao_cao_tai_chinh_hop_nhat_nam_2012_da_kiem_toan    6.1 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q1-2013  Q1-2013_bao_cao_tai_chinh_hop_nhat_quy_1_nam_2013.pdf       4.1 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q2-2013  Q2-2013_bao_cao_tai_chinh_hop_nhat_quy_2_nam_2013_da_soa    2.3 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q3-2013  Q3-2013_bao_cao_tai_chinh_hop_nhat_quy_3_nam_2013.pdf       4.3 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q4-2013  FY-2013_bao_cao_tai_chinh_hop_nhat_nam_2013_da_kiem_toan    2.6 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q1-2014  Q1-2014_bao_cao_tai_chinh_hop_nhat_quy_1_nam_2014.pdf       3.5 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q2-2014  Q2-2014_bao_cao_tai_chinh_hop_nhat_quy_2_nam_2014_da_soa    3.3 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q3-2014  Q3-2014_bao_cao_tai_chinh_hop_nhat_quy_3_nam_2014.pdf       4.2 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q4-2014  FY-2014_bao_cao_tai_chinh_hop_nhat_nam_2014_da_kiem_toan    1.6 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q1-2015  Q1-2015_bao_cao_tai_chinh_hop_nhat_quy_1_nam_2015.pdf      11.6 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q2-2015  Q2-2015_bao_cao_tai_chinh_hop_nhat_quy_2_nam_2015_da_soa    8.4 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q3-2015  Q3-2015_bao_cao_tai_chinh_hop_nhat_quy_3_nam_2015.pdf       3.9 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q4-2015  FY-2015_bao_cao_tai_chinh_hop_nhat_nam_2015_da_kiem_toan    8.1 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q1-2016  Q1-2016_bao_cao_tai_chinh_hop_nhat_quy_1_nam_2016.pdf       9.3 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q2-2016  Q2-2016_bao_cao_tai_chinh_hop_nhat_quy_2_nam_2016_da_soa   10.1 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q3-2016  Q3-2016_bao_cao_tai_chinh_hop_nhat_quy_3_nam_2016.pdf       5.6 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q4-2016  FY-2016_bao_cao_tai_chinh_hop_nhat_nam_2016_da_kiem_toan    6.3 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q1-2017  Q1-2017_bao_cao_tai_chinh_hop_nhat_quy_1_nam_2017.pdf       6.1 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q2-2017  Q2-2017_bao_cao_tai_chinh_hop_nhat_quy_2_nam_2017_da_soa    2.5 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q3-2017  Q3-2017_bao_cao_tai_chinh_hop_nhat_quy_3_nam_2017.pdf       3.7 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q4-2017  FY-2017_bao_cao_tai_chinh_hop_nhat_nam_2017_da_kiem_toan    9.5 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q1-2018  Q1-2018_bao_cao_tai_chinh_hop_nhat_quy_1_nam_2018.pdf       3.4 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q2-2018  Q2-2018_bao_cao_tai_chinh_hop_nhat_quy_2_nam_2018_da_soa    6.6 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q3-2018  Q3-2018_bao_cao_tai_chinh_hop_nhat_quy_3_nam_2018.pdf       6.9 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q4-2018  FY-2018_bao_cao_tai_chinh_hop_nhat_nam_2018_da_kiem_toan    5.4 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q1-2019  Q1-2019_bao_cao_tai_chinh_hop_nhat_quy_1_nam_2019.pdf       6.7 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q2-2019  Q2-2019_bao_cao_tai_chinh_hop_nhat_quy_2_nam_2019_da_soa    9.4 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q3-2019  Q3-2019_bao_cao_tai_chinh_hop_nhat_quy_3_nam_2019.pdf       6.6 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q4-2019  FY-2019_bao_cao_tai_chinh_hop_nhat_nam_2019_da_kiem_toan    4.3 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q1-2020  Q1-2020_bao_cao_tai_chinh_hop_nhat_quy_1_nam_2020.pdf       6.5 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q2-2020  Q2-2020_bao_cao_tai_chinh_hop_nhat_quy_2_nam_2020_da_soa    5.6 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q3-2020  Q3-2020_bao_cao_tai_chinh_hop_nhat_quy_3_nam_2020.pdf       6.5 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q4-2020  FY-2020_bao_cao_tai_chinh_hop_nhat_nam_2020_da_kiem_toan    6.3 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q1-2021  Q1-2021_bao_cao_tai_chinh_hop_nhat_quy_1_nam_2021.pdf       6.5 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q2-2021  Q2-2021_bao_cao_tai_chinh_hop_nhat_quy_2_nam_2021_da_soa    6.0 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q3-2021  Q3-2021_bao_cao_tai_chinh_hop_nhat_quy_3_nam_2021.pdf       4.1 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q4-2021  FY-2021_bao_cao_tai_chinh_hop_nhat_nam_2021_da_kiem_toan    7.3 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q1-2022  Q1-2022_bao_cao_tai_chinh_hop_nhat_quy_1_nam_2022.pdf       6.8 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q2-2022  Q2-2022_bao_cao_tai_chinh_hop_nhat_quy_2_nam_2022.pdf       8.0 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q3-2022  Q3-2022_bao_cao_tai_chinh_hop_nhat_quy_3_nam_2022.pdf       6.8 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q4-2022  FY-2022_bao_cao_tai_chinh_hop_nhat_nam_2022_da_kiem_toan    8.3 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q1-2023  Q1-2023_bao_cao_tai_chinh_hop_nhat_quy_1_nam_2023.pdf       6.9 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q2-2023  Q2-2023_bao_cao_tai_chinh_hop_nhat_quy_2_nam_2023_da_soa    7.7 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q3-2023  Q3-2023_bao_cao_tai_chinh_hop_nhat_quy_3_nam_2023.pdf       7.2 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q4-2023  FY-2023_bao_cao_tai_chinh_hop_nhat_nam_2023_da_kiem_toan    8.7 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q1-2024  Q1-2024_bao_cao_tai_chinh_hop_nhat_quy_1_nam_2024.pdf       6.2 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q2-2024  Q2-2024_bao_cao_tai_chinh_hop_nhat_quy_2_nam_2024_da_soa    7.9 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q3-2024  Q3-2024_bao_cao_tai_chinh_hop_nhat_quy_3_nam_2024.pdf       7.1 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q4-2024  FY-2024_bao_cao_tai_chinh_hop_nhat_nam_2024_da_kiem_toan    8.2 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q1-2025  Q1-2025_bao_cao_tai_chinh_hop_nhat_quy_1_nam_2025.pdf       6.8 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q2-2025  Q2-2025_bao_cao_tai_chinh_hop_nhat_quy_2_nam_2025_da_soa    7.1 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q3-2025  Q3-2025_bao_cao_tai_chinh_hop_nhat_quy_3_nam_2025.pdf       6.9 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q4-2025  FY-2025_bao_cao_tai_chinh_hop_nhat_nam_2025_da_kiem_toan    7.9 MB  CUMULATIVE
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - Q1-2026  Q1-2026_bao_cao_tai_chinh_hop_nhat_quy_1_nam_2026.pdf       6.9 MB
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - ceiling      : 3214 page(s) x 7 OCR pass(es) = 22,498 page-reads at most
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - ~244 min at 0.65 s/page (onnx@200 on this laptop; the 300/400 dpi passes cost more).
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - A filing accepted at layer 1 pays ONE pass over the pages up to its last
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - statement, which is the usual case — see the run log.
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - ⚠️ CRP-1: this is a `corp` filing. `C_LIABILITIES` still misses on corp,
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - so the balance sheet reconciles on the TRIVIAL `assets == resources` — true by
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - construction on any page that reads both. Nothing from a non-bank run may be
#   1.7% - step 3/10 HOSE_HPG 65q - resolve the job - quoted as a fundamental yet.

# %% [markdown]
# ## 5 · Rehearse — KAGGLE only: the worker side, locally, no quota

# %%
# ── STAGE + REHEARSE — KAGGLE only: the worker side, locally, no quota ────────
# ⚠️ THE PAYLOAD IS STAGED HERE, AND IT HAS TO BE: a rehearsal runs the worker against
# `.payload/<job>/`, so there is nothing to rehearse until that exists. `export` is local and
# free — it writes the zip, it does not upload; the RUN cell below re-exports and uploads, so
# nothing here commits you to anything.
# ⚠️ The rehearsal runs no OCR pass. What it proves is that the payload holds every input the
# parse reads, under BOTH of Kaggle's mount layouts, and it prints the magnitude band `sane`
# will get. AN EMPTY BAND IS THE WARNING TO STOP FOR: `sane` fails open without one, and that
# is the documented way a run writes a wrong figure (CLAUDE.md §6-2-octodecies).
# ⚠️ ONE STEP OF THE NOTEBOOK'S OWN PLAN, NOT A SECOND PLAN. This cell used to build a
# `Stages` of its own and print `50.0% - step 1/2 …` beside a run cell printing its own
# percentage of a different denominator — two bars, neither answering "how far through the
# whole thing am I?". `inside()` moves through THIS step instead, and `capture()` re-emits
# `export`'s and `rehearse`'s own output as the DETAIL of it.
if ENVIRONMENT == "KAGGLE" and REHEARSE:
    from kgpu import export, runner               # noqa: E402

    NB.begin("rehearse", "stage the payload — local, no upload, no quota")
    with NB.capture(nested=True):
        export.export(CFG)                        # -> .payload/<job>/  (no upload)
    NB.inside(0.5, "rehearse the worker — both Kaggle mount layouts")
    with NB.capture(nested=True):
        runner.rehearse(CFG)
    NB.end("rehearsed — nothing was spent")
else:
    # ⚠️ A SKIPPED STEP CLAIMS ITS WEIGHT rather than redistributing it: the plan is the plan,
    # and "we did not have to do that" is progress through it.
    NB.skip("rehearse", "REHEARSE = False" if ENVIRONMENT == "KAGGLE"
            else "LOCAL — nothing to rehearse")
# Out:
#   6.0% - step 4/10 HOSE_HPG 65q - rehearse worker - LOCAL — nothing to rehearse

# %% [markdown]
# ## 6 · Run

# %%
# ── RUN ───────────────────────────────────────────────────────────────────────
# ⚠️ One line shape on both machines — ` 33.7% - <task> - <sub-task> - <detail>`, one formatter
# (`utils.progress`), so the two cannot drift. LOCAL the task is the DOCUMENT and the sub-task
# its position in the cascade; KAGGLE the task is the STEP of the round trip.
# ⚠️ THE OVERALL % IS A POSITION IN THE PLAN, NOT A FRACTION OF THE TIME. A filing accepted at
# its FIRST OCR pass is ~1 min and one that defeats all 24 of them was 33, so the number is a
# LOWER BOUND — a run finishes early, it does not stall at 99 %.
#
# ⚠️ **`ISOLATE_DOCUMENTS` IS WHAT MAKES A WHOLE-TICKER RUN POSSIBLE ON THIS CARD.** Measured
# 2026-09-02: an 18-document run inside ONE process cleared three filings and then every
# `onnx@*` layer raised `CUDA failure 2: out of memory` — 294 of them — and the cascade went on
# and reported `pdf` for statements it had been unable to read. `pdf_ocr_batch.run_batch` spawns
# one process per document and waits for the card to have `VRAM_FLOOR_MB` free before each; the
# same 25 documents then ran with **0 engine errors**. It changes no semantics, because
# `seed_history` re-seeds `sane` from DISK per document and `PdfParser._ocr_cache` is scoped to
# one filing — see the module docstring.
FOLDERS: list = []
LATEST = EXIT = None

if not EXECUTE:
    # ⚠️ SKIPPED BY NAME, one line each, rather than one jump to the last OCR step. `skip`
    # advances to a stage's CEILING, so skipping the last would claim all six on a line
    # reading "merge into repo" — a step nobody asked about, credited for work nobody did.
    for _k in OCR_KEYS:
        NB.skip(_k, "EXECUTE = False — the plan above is resolved and nothing was spent")
elif ENVIRONMENT == "LOCAL" and ISOLATE_DOCUMENTS:
    from web_scraper import pdf_ocr_batch                # noqa: E402

    # ⚠️ **A BOOTSTRAP IS SAID BEFORE IT HAPPENS, NOT REFUSED.** Until 2026-09-06 this
    # raised here — a ticker with no `pdf` row has no magnitude band, so every write was
    # refused, and the run would have parsed every filing and landed none of them. The write
    # now happens for any quarter whose filing produced all three statements, so what is left
    # to do is name what that costs, once, where the hours are about to be spent.
    NB.begin("parse", f"{len(PLAN.quarters)} document(s), one process each, "
                      f"VRAM floor {VRAM_FLOOR_MB} MiB"
                      + ("   upserting each quarter as its three statements land"
                         if MERGE_EACH else ""))
    # ⚠️ AFTER `begin`, so the line carries the PARSE stage's label and its percentage — a
    # warning printed at the previous stage's position reads as being about that stage.
    if NEEDS_BOOTSTRAP and MERGE_EACH:
        NB.note(f"{PLAN.key} has no `pdf` row on disk — the three CSVs are CREATED by the "
                f"first quarter that produces all three statements, and every row this run "
                f"writes passes NO magnitude guard (`sane` fails open with no band, `BND-1`). "
                f"Screen them by arithmetic before quoting any of them.")
    # ⚠️ `progress=NB` is what stops the bar standing still through the longest thing the
    # notebook does: `run_batch` moves it ONE DOCUMENT AT A TIME through this step, and its own
    # lines come out as its detail. ⚠️ Each document is a SUBPROCESS that inherits stdout, so
    # its per-page lines go to the kernel log rather than into this cell — they are in that
    # document's own `run.log`, in the same shape.
    # ⚠️ **`merge_each` IS THE ONLY THING HERE THAT REACHES `raw_data/`.** `force_differs` is
    # not in `run_batch`'s signature and cannot be passed from it, so THREE of the four
    # refusals stand exactly as they do in §9 — a cumulative income statement whose priors it
    # cannot subtract, a figure that DIFFERS from a good `pdf` row, and a document any of
    # whose layers RAISED. What changes is WHEN: a quarter is written between documents, so an
    # interrupted run keeps what it has read.
    # ⚠️ **THE FOURTH — AN EMPTY `sane` BAND — IS LIFTED, AND THERE IS NO `force_empty_band`
    # ARGUMENT LEFT TO DECIDE OTHERWISE.** This path only ever merges a quarter whose filing
    # produced all three statements, and such a quarter is written band or no band: refusing
    # it is `BND-1`'s loop rather than a guard (§1's MERGE_EACH has the reasoning). Every such
    # row is printed as it is written, recorded in the run folder as `band: 0`, and counted
    # again in §10 — and it passed NO magnitude guard. FORCE_EMPTY_BAND still reaches §9,
    # which is what sees the quarters this path HELD.
    FOLDERS = pdf_ocr_batch.run_batch(
        [PLAN], layers=LAYERS, allow_parent=ALLOW_PARENT, overwrite=OVERWRITE,
        compare=COMPARE, notes=NOTES or f"{EXCHANGE}_{SYMBOL} — one process per document",
        vram_floor_mb=VRAM_FLOOR_MB, merge_each=MERGE_EACH, merge_apply=MERGE_APPLY,
        merge_reports=MERGE_REPORTS, progress=NB)
    NB.end(f"{len(FOLDERS)} run folder(s)")
elif ENVIRONMENT == "LOCAL":
    # ⚠️ THE OLD PATH, AND IT IS KEPT FOR ONE DOCUMENT AT A TIME. `job.run` parses every planned
    # filing in THIS process, which is right for a repair of one quarter and is what died at
    # document 4 of 18. It prints the progress line itself and writes the SAME line into the run
    # folder's `run.log`, so what you read here is what a later reader gets.
    # ⚠️ `nested=True` because those lines ALREADY lead with a percentage — of that run's own
    # documents, not of this notebook. Printed verbatim they would put two numbers on one line
    # and the second would appear to walk backwards; split, the inner percentage is dropped and
    # its `layer 12/47 …` / `page 40/96 …` segments are kept.
    NB.begin("parse", "one process for the whole run — right for ONE document")
    with NB.capture(nested=True):
        LATEST = job.run(SPEC)
    FOLDERS = [LATEST]
    NB.end(LATEST.name)
else:
    from kgpu import runner                              # noqa: E402

    # ⚠️ **NOT A FLAG ANY MORE, AND SAYING SO IS THE POINT** (2026-09-08). The pull
    # upserts every pulled run folder, through the same ordered unforced `merge_batch` §9
    # calls — `MERGE_INTO_CSV` no longer reaches this branch and is read only by the LOCAL
    # one-process path. What it used to decide, in practice, was whether hours of T4 ever
    # reached the CSVs: HOSE_MBB accepted 176 of 186 cells and wrote 0 with it off.
    NB.note("the pull upserts the accepted statements into raw_data/.../statements/, "
            "one period at a time and oldest first, with a backup taken first and every "
            "changed cell printed. `force_differs` is never passed.")
    # `refresh_data=True` re-exports and re-uploads the payload every time — correct, because
    # the filter above may have changed since the last run of this job.
    # ⚠️ THE NOTEBOOK'S OWN PLAN IS HANDED STRAIGHT TO `runner.run`, because six of its stages
    # ARE the round trip's (§2 embedded `RUN_STAGES` by key). So the round trip reports as
    # steps 5..10 of 15 and the reader keeps ONE number. `final=False` (§2) is why its closing
    # `done()` ends the round trip rather than the notebook.
    EXIT = runner.run(CFG, refresh_data=True, progress=NB)
    NB.note(f"exit {EXIT}   (0 = COMPLETE and pulled)")
# Out:
#   6.0% - step 5/10 HOSE_HPG 65q - OCR the filings - 65 document(s), one process each, VRAM floor 2600 MiB   upserting each quarter as its three statements land
#   6.0% - step 5/10 HOSE_HPG 65q - OCR the filings - HOSE_HPG has no `pdf` row on disk — the three CSVs are CREATED by the first quarter that produces all three statements, and every row this run writes passes NO magnitude guard (`sane` fails open with no band, `BND-1`). Screen them by arithmetic before quoting any of them.
#   6.0% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 1/65  HOSE_HPG 2008-Q4 ──────────────────────────────
#   6.0% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   0.2 min   20260907-233112__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 1 quarters (Q4-2008..Q4-2008), 1 parsed, 0 missing, 54 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 1 quarters (Q4-2008..Q4-2008), 1 parsed, 0 missing, 18 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 1 quarters (Q4-2008..Q4-2008), 1 parsed, 0 missing, 24 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#   7.4% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q4-2008   balance_sheet      [onnx@200] 54 items              recovers a quarter disk records as `absent`
#   7.4% - step 5/10 HOSE_HPG 65q - OCR the filings - ⚠️  ⚠️ WRITTEN UNGUARDED — the magnitude band was EMPTY, so `sane` failed open and this figure passed no magnitude guard. Screen it by arithmetic (two statements agreeing, a printed subtotal closing) before quoting it
#   7.4% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q4-2008   cash_flow          [onnx@200+relax] 24 items        recovers a quarter disk records as `absent`
#   7.4% - step 5/10 HOSE_HPG 65q - OCR the filings - ⚠️  ⚠️ WRITTEN UNGUARDED — the magnitude band was EMPTY, so `sane` failed open and this figure passed no magnitude guard. Screen it by arithmetic (two statements agreeing, a printed subtotal closing) before quoting it
#   7.4% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q4-2008   income_statement   [onnx@200] 18 items              recovers a quarter disk records as `absent`
#   7.4% - step 5/10 HOSE_HPG 65q - OCR the filings - ⚠️  12-month figure — Q1-2008, Q2-2008, Q3-2008 were never filed, so no run can ever split it. Written with `months=12`; ⚠️ WRITTEN UNGUARDED — the magnitude band was EMPTY, so `sane` failed open and this figure passed no magnitude guard. Screen it by arithmetic (two statements agreeing, a printed subtotal closing) before quoting it
#   7.4% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: D:\GIT\master-thesis\raw_data\_backup\statements\20260907-233124__HOSE_HPG
#   7.4% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 1, 'income_statement': 1, 'cash_flow': 1}
#   7.4% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 2/65  HOSE_HPG 2009-Q2 ──────────────────────────────
#   7.4% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   0.6 min   20260907-233124__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 2 quarters (Q4-2008..Q2-2009), 2 parsed, 0 missing, 55 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 2 quarters (Q4-2008..Q2-2009), 2 parsed, 0 missing, 18 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 2 quarters (Q4-2008..Q2-2009), 2 parsed, 0 missing, 30 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#   8.7% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2009   balance_sheet      [onnx@200] 55 items              recovers a quarter disk records as `absent`
#   8.7% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2009   cash_flow          [onnx@200+title] 30 items        recovers a quarter disk records as `absent`
#   8.7% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2009   income_statement   [onnx@200] 18 items              recovers a quarter disk records as `absent`
#   8.7% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#   8.7% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 2, 'income_statement': 2, 'cash_flow': 2}
#   8.7% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 3/65  HOSE_HPG 2009-Q4 ──────────────────────────────
#   8.7% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   0.7 min   20260907-233202__hose_hpg__pdf_ocr
#  10.0% - step 5/10 HOSE_HPG 65q - OCR the filings - Q4-2009 HELD — 2 of 3 statement(s) accepted — no income_statement
#  10.0% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 4/65  HOSE_HPG 2010-Q2 ──────────────────────────────
#  10.0% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   3.3 min   20260907-233242__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 3 quarters (Q4-2008..Q2-2010), 3 parsed, 0 missing, 51 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 3 quarters (Q4-2008..Q2-2010), 3 parsed, 0 missing, 16 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 3 quarters (Q4-2008..Q2-2010), 3 parsed, 0 missing, 17 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  11.3% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2010   balance_sheet      [onnx@200] 51 items              recovers a quarter disk records as `absent`
#  11.3% - step 5/10 HOSE_HPG 65q - OCR the filings - ⚠️  ⚠️ WRITTEN UNGUARDED — the magnitude band was EMPTY, so `sane` failed open and this figure passed no magnitude guard. Screen it by arithmetic (two statements agreeing, a printed subtotal closing) before quoting it
#  11.3% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2010   cash_flow          [onnx@200+relax] 17 items        recovers a quarter disk records as `absent`
#  11.3% - step 5/10 HOSE_HPG 65q - OCR the filings - ⚠️  ⚠️ WRITTEN UNGUARDED — the magnitude band was EMPTY, so `sane` failed open and this figure passed no magnitude guard. Screen it by arithmetic (two statements agreeing, a printed subtotal closing) before quoting it
#  11.3% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2010   income_statement   [onnx@200] 16 items              recovers a quarter disk records as `absent`
#  11.3% - step 5/10 HOSE_HPG 65q - OCR the filings - ⚠️  ⚠️ WRITTEN UNGUARDED — the magnitude band was EMPTY, so `sane` failed open and this figure passed no magnitude guard. Screen it by arithmetic (two statements agreeing, a printed subtotal closing) before quoting it
#  11.3% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  11.3% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 3, 'income_statement': 3, 'cash_flow': 3}
#  11.3% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 5/65  HOSE_HPG 2011-Q1 ──────────────────────────────
#  11.3% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   6.1 min   20260907-233601__hose_hpg__pdf_ocr
#  12.7% - step 5/10 HOSE_HPG 65q - OCR the filings - Q1-2011 HELD — 2 of 3 statement(s) accepted — no cash_flow
#  12.7% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 6/65  HOSE_HPG 2011-Q2 ──────────────────────────────
#  12.7% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   1.9 min   20260907-234205__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 4 quarters (Q4-2008..Q2-2011), 4 parsed, 0 missing, 51 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 4 quarters (Q4-2008..Q2-2011), 3 parsed, 1 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 4 quarters (Q4-2008..Q2-2011), 4 parsed, 0 missing, 18 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  14.0% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2011   balance_sheet      [onnx@200] 51 items              recovers a quarter disk records as `absent`
#  14.0% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2011   cash_flow          [onnx@300] 18 items              recovers a quarter disk records as `absent`
#  14.0% - step 5/10 HOSE_HPG 65q - OCR the filings - skip   Q2-2011   income_statement   [onnx@200] 15 items              cumulative income statement — cannot de-cumulate here because Q1-2011 is `absent` on disk. Q1..Q1-2011 WERE filed, so a full `build()` can still subtract them
#  14.0% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  14.0% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 4, 'income_statement': 3, 'cash_flow': 4}
#  14.0% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 7/65  HOSE_HPG 2011-Q3 ──────────────────────────────
#  14.0% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   5.3 min   20260907-234358__hose_hpg__pdf_ocr
#  15.3% - step 5/10 HOSE_HPG 65q - OCR the filings - Q3-2011 HELD — 1 of 3 statement(s) accepted — no income_statement, cash_flow
#  15.3% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 8/65  HOSE_HPG 2011-Q4 ──────────────────────────────
#  15.3% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   7.9 min   20260907-234915__hose_hpg__pdf_ocr
#  16.6% - step 5/10 HOSE_HPG 65q - OCR the filings - Q4-2011 HELD — 2 of 3 statement(s) accepted — no income_statement
#  16.6% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 9/65  HOSE_HPG 2012-Q1 ──────────────────────────────
#  16.6% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   5.9 min   20260907-235707__hose_hpg__pdf_ocr
#  18.0% - step 5/10 HOSE_HPG 65q - OCR the filings - Q1-2012 HELD — 1 of 3 statement(s) accepted — no income_statement, cash_flow
#  18.0% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 10/65  HOSE_HPG 2012-Q2 ──────────────────────────────
#  18.0% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   1.5 min   20260908-000259__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 5 quarters (Q4-2008..Q2-2012), 5 parsed, 0 missing, 49 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 5 quarters (Q4-2008..Q2-2012), 3 parsed, 2 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 5 quarters (Q4-2008..Q2-2012), 5 parsed, 0 missing, 20 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  19.3% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2012   balance_sheet      [onnx@200] 49 items              recovers a quarter disk records as `absent`
#  19.3% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2012   cash_flow          [onnx@300+relax] 20 items        recovers a quarter disk records as `absent`
#  19.3% - step 5/10 HOSE_HPG 65q - OCR the filings - skip   Q2-2012   income_statement   [onnx@200] 13 items              cumulative income statement — cannot de-cumulate here because Q1-2012 is `absent` on disk. Q1..Q1-2012 WERE filed, so a full `build()` can still subtract them
#  19.3% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  19.3% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 5, 'income_statement': 3, 'cash_flow': 5}
#  19.3% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 11/65  HOSE_HPG 2012-Q3 ──────────────────────────────
#  19.3% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   6.0 min   20260908-000428__hose_hpg__pdf_ocr
#  20.6% - step 5/10 HOSE_HPG 65q - OCR the filings - Q3-2012 HELD — 2 of 3 statement(s) accepted — no cash_flow
#  20.6% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 12/65  HOSE_HPG 2012-Q4 ──────────────────────────────
#  20.6% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   8.6 min   20260908-001029__hose_hpg__pdf_ocr
#  21.9% - step 5/10 HOSE_HPG 65q - OCR the filings - Q4-2012 HELD — 2 of 3 statement(s) accepted — no cash_flow
#  21.9% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 13/65  HOSE_HPG 2013-Q1 ──────────────────────────────
#  21.9% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   5.1 min   20260908-001906__hose_hpg__pdf_ocr
#  23.3% - step 5/10 HOSE_HPG 65q - OCR the filings - Q1-2013 HELD — 1 of 3 statement(s) accepted — no income_statement, cash_flow
#  23.3% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 14/65  HOSE_HPG 2013-Q2 ──────────────────────────────
#  23.3% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   1.3 min   20260908-002415__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 6 quarters (Q4-2008..Q2-2013), 6 parsed, 0 missing, 47 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 6 quarters (Q4-2008..Q2-2013), 3 parsed, 3 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 6 quarters (Q4-2008..Q2-2013), 6 parsed, 0 missing, 20 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  24.6% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2013   balance_sheet      [onnx@200] 47 items              recovers a quarter disk records as `absent`
#  24.6% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2013   cash_flow          [onnx@200+relax] 20 items        recovers a quarter disk records as `absent`
#  24.6% - step 5/10 HOSE_HPG 65q - OCR the filings - skip   Q2-2013   income_statement   [onnx@200] 14 items              cumulative income statement — cannot de-cumulate here because Q1-2013 is `absent` on disk. Q1..Q1-2013 WERE filed, so a full `build()` can still subtract them
#  24.6% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  24.6% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 6, 'income_statement': 3, 'cash_flow': 6}
#  24.6% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 15/65  HOSE_HPG 2013-Q3 ──────────────────────────────
#  24.6% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   5.4 min   20260908-002535__hose_hpg__pdf_ocr
#  25.9% - step 5/10 HOSE_HPG 65q - OCR the filings - Q3-2013 HELD — 1 of 3 statement(s) accepted — no income_statement, cash_flow
#  25.9% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 16/65  HOSE_HPG 2013-Q4 ──────────────────────────────
#  25.9% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   0.6 min   20260908-003058__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 7 quarters (Q4-2008..Q4-2013), 7 parsed, 0 missing, 47 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 7 quarters (Q4-2008..Q4-2013), 3 parsed, 4 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 7 quarters (Q4-2008..Q4-2013), 7 parsed, 0 missing, 21 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  27.3% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q4-2013   balance_sheet      [onnx@200] 47 items              recovers a quarter disk records as `absent`
#  27.3% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q4-2013   cash_flow          [onnx@200+relax] 21 items        recovers a quarter disk records as `absent`
#  27.3% - step 5/10 HOSE_HPG 65q - OCR the filings - skip   Q4-2013   income_statement   [onnx@200] 16 items              cumulative income statement — cannot de-cumulate here because Q1-2013 is `absent` on disk. Q1..Q3-2013 WERE filed, so a full `build()` can still subtract them
#  27.3% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  27.3% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 7, 'income_statement': 3, 'cash_flow': 7}
#  27.3% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 17/65  HOSE_HPG 2014-Q1 ──────────────────────────────
#  27.3% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   5.5 min   20260908-003136__hose_hpg__pdf_ocr
#  28.6% - step 5/10 HOSE_HPG 65q - OCR the filings - Q1-2014 HELD — 1 of 3 statement(s) accepted — no income_statement, cash_flow
#  28.6% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 18/65  HOSE_HPG 2014-Q2 ──────────────────────────────
#  28.6% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   3.0 min   20260908-003706__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 8 quarters (Q4-2008..Q2-2014), 8 parsed, 0 missing, 46 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 8 quarters (Q4-2008..Q2-2014), 3 parsed, 5 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 8 quarters (Q4-2008..Q2-2014), 8 parsed, 0 missing, 20 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  29.9% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2014   balance_sheet      [onnx@200] 46 items              recovers a quarter disk records as `absent`
#  29.9% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2014   cash_flow          [onnx@200+total+relax] 20 items  recovers a quarter disk records as `absent`
#  29.9% - step 5/10 HOSE_HPG 65q - OCR the filings - skip   Q2-2014   income_statement   [onnx@200] 14 items              cumulative income statement — cannot de-cumulate here because Q1-2014 is `absent` on disk. Q1..Q1-2014 WERE filed, so a full `build()` can still subtract them
#  29.9% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  29.9% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 8, 'income_statement': 3, 'cash_flow': 8}
#  29.9% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 19/65  HOSE_HPG 2014-Q3 ──────────────────────────────
#  29.9% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   5.6 min   20260908-004006__hose_hpg__pdf_ocr
#  31.2% - step 5/10 HOSE_HPG 65q - OCR the filings - Q3-2014 HELD — 2 of 3 statement(s) accepted — no cash_flow
#  31.2% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 20/65  HOSE_HPG 2014-Q4 ──────────────────────────────
#  31.2% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   0.4 min   20260908-004543__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 9 quarters (Q4-2008..Q4-2014), 9 parsed, 0 missing, 46 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 9 quarters (Q4-2008..Q4-2014), 3 parsed, 6 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 9 quarters (Q4-2008..Q4-2014), 9 parsed, 0 missing, 18 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  32.6% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q4-2014   balance_sheet      [onnx@200] 46 items              recovers a quarter disk records as `absent`
#  32.6% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q4-2014   cash_flow          [onnx@200+relax] 18 items        recovers a quarter disk records as `absent`
#  32.6% - step 5/10 HOSE_HPG 65q - OCR the filings - skip   Q4-2014   income_statement   [onnx@200] 16 items              cumulative income statement — cannot de-cumulate here because Q1-2014 is `absent` on disk. Q1..Q3-2014 WERE filed, so a full `build()` can still subtract them
#  32.6% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  32.6% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 9, 'income_statement': 3, 'cash_flow': 9}
#  32.6% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 21/65  HOSE_HPG 2015-Q1 ──────────────────────────────
#  32.6% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   6.1 min   20260908-004605__hose_hpg__pdf_ocr
#  33.9% - step 5/10 HOSE_HPG 65q - OCR the filings - Q1-2015 HELD — 2 of 3 statement(s) accepted — no cash_flow
#  33.9% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 22/65  HOSE_HPG 2015-Q2 ──────────────────────────────
#  33.9% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   1.5 min   20260908-005209__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 10 quarters (Q4-2008..Q2-2015), 10 parsed, 0 missing, 64 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 10 quarters (Q4-2008..Q2-2015), 3 parsed, 7 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 10 quarters (Q4-2008..Q2-2015), 10 parsed, 0 missing, 20 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  35.2% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2015   balance_sheet      [onnx@200] 64 items              recovers a quarter disk records as `absent`
#  35.2% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2015   cash_flow          [onnx@300+relax] 20 items        recovers a quarter disk records as `absent`
#  35.2% - step 5/10 HOSE_HPG 65q - OCR the filings - skip   Q2-2015   income_statement   [onnx@200] 20 items              cumulative income statement — cannot de-cumulate here because Q1-2015 is `absent` on disk. Q1..Q1-2015 WERE filed, so a full `build()` can still subtract them
#  35.2% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  35.2% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 10, 'income_statement': 3, 'cash_flow': 10}
#  35.2% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 23/65  HOSE_HPG 2015-Q3 ──────────────────────────────
#  35.2% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   5.4 min   20260908-005342__hose_hpg__pdf_ocr
#  36.5% - step 5/10 HOSE_HPG 65q - OCR the filings - Q3-2015 HELD — 2 of 3 statement(s) accepted — no income_statement
#  36.5% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 24/65  HOSE_HPG 2015-Q4 ──────────────────────────────
#  36.5% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   2.0 min   20260908-005908__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 11 quarters (Q4-2008..Q4-2015), 11 parsed, 0 missing, 64 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 11 quarters (Q4-2008..Q4-2015), 3 parsed, 8 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 11 quarters (Q4-2008..Q4-2015), 11 parsed, 0 missing, 21 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  37.9% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q4-2015   balance_sheet      [onnx@200] 64 items              recovers a quarter disk records as `absent`
#  37.9% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q4-2015   cash_flow          [onnx@200+tail+relax] 21 items   recovers a quarter disk records as `absent`
#  37.9% - step 5/10 HOSE_HPG 65q - OCR the filings - skip   Q4-2015   income_statement   [onnx@200] 19 items              cumulative income statement — cannot de-cumulate here because Q1-2015 is `absent` on disk. Q1..Q3-2015 WERE filed, so a full `build()` can still subtract them
#  37.9% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  37.9% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 11, 'income_statement': 3, 'cash_flow': 11}
#  37.9% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 25/65  HOSE_HPG 2016-Q1 ──────────────────────────────
#  37.9% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   2.9 min   20260908-010110__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 12 quarters (Q4-2008..Q1-2016), 12 parsed, 0 missing, 66 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 12 quarters (Q4-2008..Q1-2016), 4 parsed, 8 missing, 18 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 12 quarters (Q4-2008..Q1-2016), 12 parsed, 0 missing, 23 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  39.2% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q1-2016   balance_sheet      [onnx@200+tail] 66 items         recovers a quarter disk records as `absent`
#  39.2% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q1-2016   cash_flow          [onnx@200+tail+relax] 23 items   recovers a quarter disk records as `absent`
#  39.2% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q1-2016   income_statement   [onnx@200] 18 items              recovers a quarter disk records as `absent`
#  39.2% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  39.2% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 12, 'income_statement': 4, 'cash_flow': 12}
#  39.2% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 26/65  HOSE_HPG 2016-Q2 ──────────────────────────────
#  39.2% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   1.9 min   20260908-010401__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 13 quarters (Q4-2008..Q2-2016), 13 parsed, 0 missing, 66 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 13 quarters (Q4-2008..Q2-2016), 5 parsed, 8 missing, 16 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 13 quarters (Q4-2008..Q2-2016), 13 parsed, 0 missing, 20 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  40.5% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2016   balance_sheet      [onnx@200] 66 items              recovers a quarter disk records as `absent`
#  40.5% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2016   cash_flow          [onnx@400+loose+relax] 20 items  recovers a quarter disk records as `absent`
#  40.5% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2016   income_statement   [onnx@200] 16 items              recovers a quarter disk records as `absent`
#  40.5% - step 5/10 HOSE_HPG 65q - OCR the filings - ⚠️  de-cumulated: 6-month figure minus Q1-2016 -> the standalone quarter, 16 of 19 columns
#  40.5% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  40.5% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 13, 'income_statement': 5, 'cash_flow': 13}
#  40.5% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 27/65  HOSE_HPG 2016-Q3 ──────────────────────────────
#  40.5% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   5.1 min   20260908-010555__hose_hpg__pdf_ocr
#  41.8% - step 5/10 HOSE_HPG 65q - OCR the filings - Q3-2016 HELD — 2 of 3 statement(s) accepted — no income_statement
#  41.8% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 28/65  HOSE_HPG 2016-Q4 ──────────────────────────────
#  41.8% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   2.1 min   20260908-011103__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 14 quarters (Q4-2008..Q4-2016), 14 parsed, 0 missing, 53 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 14 quarters (Q4-2008..Q4-2016), 5 parsed, 9 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 14 quarters (Q4-2008..Q4-2016), 14 parsed, 0 missing, 20 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  43.2% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q4-2016   balance_sheet      [onnx@200+tail] 53 items         recovers a quarter disk records as `absent`
#  43.2% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q4-2016   cash_flow          [onnx@400+loose+relax] 20 items  recovers a quarter disk records as `absent`
#  43.2% - step 5/10 HOSE_HPG 65q - OCR the filings - skip   Q4-2016   income_statement   [onnx@200] 19 items              cumulative income statement — cannot de-cumulate here because Q3-2016 is `absent` on disk. Q1..Q3-2016 WERE filed, so a full `build()` can still subtract them
#  43.2% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  43.2% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 14, 'income_statement': 5, 'cash_flow': 14}
#  43.2% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 29/65  HOSE_HPG 2017-Q1 ──────────────────────────────
#  43.2% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   1.3 min   20260908-011309__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 15 quarters (Q4-2008..Q1-2017), 15 parsed, 0 missing, 67 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 15 quarters (Q4-2008..Q1-2017), 6 parsed, 9 missing, 19 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 15 quarters (Q4-2008..Q1-2017), 15 parsed, 0 missing, 21 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  44.5% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q1-2017   balance_sheet      [onnx@200] 67 items              recovers a quarter disk records as `absent`
#  44.5% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q1-2017   cash_flow          [onnx@200+relax] 21 items        recovers a quarter disk records as `absent`
#  44.5% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q1-2017   income_statement   [onnx@200] 19 items              recovers a quarter disk records as `absent`
#  44.5% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  44.5% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 15, 'income_statement': 6, 'cash_flow': 15}
#  44.5% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 30/65  HOSE_HPG 2017-Q2 ──────────────────────────────
#  44.5% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   1.8 min   20260908-011425__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 16 quarters (Q4-2008..Q2-2017), 16 parsed, 0 missing, 65 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 16 quarters (Q4-2008..Q2-2017), 7 parsed, 9 missing, 18 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 16 quarters (Q4-2008..Q2-2017), 16 parsed, 0 missing, 22 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  45.8% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2017   balance_sheet      [onnx@200] 65 items              recovers a quarter disk records as `absent`
#  45.8% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2017   cash_flow          [onnx@200+relax] 22 items        recovers a quarter disk records as `absent`
#  45.8% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2017   income_statement   [onnx@200] 18 items              recovers a quarter disk records as `absent`
#  45.8% - step 5/10 HOSE_HPG 65q - OCR the filings - ⚠️  de-cumulated: 6-month figure minus Q1-2017 -> the standalone quarter, 18 of 20 columns
#  45.8% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  45.8% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 16, 'income_statement': 7, 'cash_flow': 16}
#  45.8% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 31/65  HOSE_HPG 2017-Q3 ──────────────────────────────
#  45.8% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   5.1 min   20260908-011611__hose_hpg__pdf_ocr
#  47.1% - step 5/10 HOSE_HPG 65q - OCR the filings - Q3-2017 HELD — 2 of 3 statement(s) accepted — no income_statement
#  47.1% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 32/65  HOSE_HPG 2017-Q4 ──────────────────────────────
#  47.1% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   2.0 min   20260908-012115__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 17 quarters (Q4-2008..Q4-2017), 17 parsed, 0 missing, 64 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 17 quarters (Q4-2008..Q4-2017), 7 parsed, 10 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 17 quarters (Q4-2008..Q4-2017), 17 parsed, 0 missing, 23 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  48.5% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q4-2017   balance_sheet      [onnx@200] 64 items              recovers a quarter disk records as `absent`
#  48.5% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q4-2017   cash_flow          [onnx@200+tail+relax] 23 items   recovers a quarter disk records as `absent`
#  48.5% - step 5/10 HOSE_HPG 65q - OCR the filings - skip   Q4-2017   income_statement   [onnx@200] 19 items              cumulative income statement — cannot de-cumulate here because Q3-2017 is `absent` on disk. Q1..Q3-2017 WERE filed, so a full `build()` can still subtract them
#  48.5% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  48.5% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 17, 'income_statement': 7, 'cash_flow': 17}
#  48.5% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 33/65  HOSE_HPG 2018-Q1 ──────────────────────────────
#  48.5% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   1.0 min   20260908-012318__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 18 quarters (Q4-2008..Q1-2018), 18 parsed, 0 missing, 66 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 18 quarters (Q4-2008..Q1-2018), 8 parsed, 10 missing, 18 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 18 quarters (Q4-2008..Q1-2018), 18 parsed, 0 missing, 18 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  49.8% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q1-2018   balance_sheet      [onnx@200] 66 items              recovers a quarter disk records as `absent`
#  49.8% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q1-2018   cash_flow          [onnx@200+relax] 18 items        recovers a quarter disk records as `absent`
#  49.8% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q1-2018   income_statement   [onnx@200] 18 items              recovers a quarter disk records as `absent`
#  49.8% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  49.8% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 18, 'income_statement': 8, 'cash_flow': 18}
#  49.8% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 34/65  HOSE_HPG 2018-Q2 ──────────────────────────────
#  49.8% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   2.1 min   20260908-012417__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 19 quarters (Q4-2008..Q2-2018), 19 parsed, 0 missing, 65 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 19 quarters (Q4-2008..Q2-2018), 9 parsed, 10 missing, 15 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 19 quarters (Q4-2008..Q2-2018), 19 parsed, 0 missing, 22 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  51.1% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2018   balance_sheet      [onnx@200] 65 items              recovers a quarter disk records as `absent`
#  51.1% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2018   cash_flow          [onnx@200+tail+relax] 22 items   recovers a quarter disk records as `absent`
#  51.1% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2018   income_statement   [onnx@200] 15 items              recovers a quarter disk records as `absent`
#  51.1% - step 5/10 HOSE_HPG 65q - OCR the filings - ⚠️  de-cumulated: 6-month figure minus Q1-2018 -> the standalone quarter, 15 of 17 columns
#  51.1% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  51.1% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 19, 'income_statement': 9, 'cash_flow': 19}
#  51.1% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 35/65  HOSE_HPG 2018-Q3 ──────────────────────────────
#  51.1% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   1.0 min   20260908-012625__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 20 quarters (Q4-2008..Q3-2018), 20 parsed, 0 missing, 67 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 20 quarters (Q4-2008..Q3-2018), 10 parsed, 10 missing, 18 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 20 quarters (Q4-2008..Q3-2018), 20 parsed, 0 missing, 19 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  52.5% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q3-2018   balance_sheet      [onnx@200] 67 items              recovers a quarter disk records as `absent`
#  52.5% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q3-2018   cash_flow          [onnx@200+relax] 19 items        recovers a quarter disk records as `absent`
#  52.5% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q3-2018   income_statement   [onnx@200] 18 items              recovers a quarter disk records as `absent`
#  52.5% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  52.5% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 20, 'income_statement': 10, 'cash_flow': 20}
#  52.5% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 36/65  HOSE_HPG 2018-Q4 ──────────────────────────────
#  52.5% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   2.2 min   20260908-012725__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 21 quarters (Q4-2008..Q4-2018), 21 parsed, 0 missing, 65 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 21 quarters (Q4-2008..Q4-2018), 11 parsed, 10 missing, 15 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 21 quarters (Q4-2008..Q4-2018), 21 parsed, 0 missing, 22 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  53.8% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q4-2018   balance_sheet      [onnx@200] 65 items              recovers a quarter disk records as `absent`
#  53.8% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q4-2018   cash_flow          [onnx@200+tail+relax] 22 items   recovers a quarter disk records as `absent`
#  53.8% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q4-2018   income_statement   [onnx@200] 15 items              recovers a quarter disk records as `absent`
#  53.8% - step 5/10 HOSE_HPG 65q - OCR the filings - ⚠️  de-cumulated: 12-month figure minus Q1-2018, Q2-2018, Q3-2018 -> the standalone quarter, 15 of 17 columns
#  53.8% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  53.8% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 21, 'income_statement': 11, 'cash_flow': 21}
#  53.8% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 37/65  HOSE_HPG 2019-Q1 ──────────────────────────────
#  53.8% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   1.1 min   20260908-012935__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 22 quarters (Q4-2008..Q1-2019), 22 parsed, 0 missing, 67 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 22 quarters (Q4-2008..Q1-2019), 12 parsed, 10 missing, 17 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 22 quarters (Q4-2008..Q1-2019), 22 parsed, 0 missing, 18 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  55.1% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q1-2019   balance_sheet      [onnx@200] 67 items              recovers a quarter disk records as `absent`
#  55.1% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q1-2019   cash_flow          [onnx@200+relax] 18 items        recovers a quarter disk records as `absent`
#  55.1% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q1-2019   income_statement   [onnx@200] 17 items              recovers a quarter disk records as `absent`
#  55.1% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  55.1% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 22, 'income_statement': 12, 'cash_flow': 22}
#  55.1% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 38/65  HOSE_HPG 2019-Q2 ──────────────────────────────
#  55.1% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   2.4 min   20260908-013043__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 23 quarters (Q4-2008..Q2-2019), 23 parsed, 0 missing, 66 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 23 quarters (Q4-2008..Q2-2019), 13 parsed, 10 missing, 14 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 23 quarters (Q4-2008..Q2-2019), 23 parsed, 0 missing, 21 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  56.4% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2019   balance_sheet      [onnx@200] 66 items              recovers a quarter disk records as `absent`
#  56.4% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2019   cash_flow          [onnx@200+tail+relax] 21 items   recovers a quarter disk records as `absent`
#  56.4% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2019   income_statement   [onnx@200] 14 items              recovers a quarter disk records as `absent`
#  56.4% - step 5/10 HOSE_HPG 65q - OCR the filings - ⚠️  de-cumulated: 6-month figure minus Q1-2019 -> the standalone quarter, 14 of 16 columns
#  56.4% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  56.4% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 23, 'income_statement': 13, 'cash_flow': 23}
#  56.4% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 39/65  HOSE_HPG 2019-Q3 ──────────────────────────────
#  56.4% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   4.4 min   20260908-013310__hose_hpg__pdf_ocr
#  57.8% - step 5/10 HOSE_HPG 65q - OCR the filings - Q3-2019 HELD — 2 of 3 statement(s) accepted — no income_statement
#  57.8% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 40/65  HOSE_HPG 2019-Q4 ──────────────────────────────
#  57.8% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   2.2 min   20260908-013732__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 24 quarters (Q4-2008..Q4-2019), 24 parsed, 0 missing, 66 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 24 quarters (Q4-2008..Q4-2019), 13 parsed, 11 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 24 quarters (Q4-2008..Q4-2019), 24 parsed, 0 missing, 21 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  59.1% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q4-2019   balance_sheet      [onnx@300] 66 items              recovers a quarter disk records as `absent`
#  59.1% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q4-2019   cash_flow          [onnx@200+tail+relax] 21 items   recovers a quarter disk records as `absent`
#  59.1% - step 5/10 HOSE_HPG 65q - OCR the filings - skip   Q4-2019   income_statement   [onnx@200] 18 items              cumulative income statement — cannot de-cumulate here because Q3-2019 is `absent` on disk. Q1..Q3-2019 WERE filed, so a full `build()` can still subtract them
#  59.1% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  59.1% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 24, 'income_statement': 13, 'cash_flow': 24}
#  59.1% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 41/65  HOSE_HPG 2020-Q1 ──────────────────────────────
#  59.1% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   1.8 min   20260908-013946__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 25 quarters (Q4-2008..Q1-2020), 25 parsed, 0 missing, 67 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 25 quarters (Q4-2008..Q1-2020), 14 parsed, 11 missing, 17 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 25 quarters (Q4-2008..Q1-2020), 25 parsed, 0 missing, 17 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  60.4% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q1-2020   balance_sheet      [onnx@200] 67 items              recovers a quarter disk records as `absent`
#  60.4% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q1-2020   cash_flow          [onnx@200+relax] 17 items        recovers a quarter disk records as `absent`
#  60.4% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q1-2020   income_statement   [onnx@200] 17 items              recovers a quarter disk records as `absent`
#  60.4% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  60.4% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 25, 'income_statement': 14, 'cash_flow': 25}
#  60.4% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 42/65  HOSE_HPG 2020-Q2 ──────────────────────────────
#  60.4% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   4.2 min   20260908-014131__hose_hpg__pdf_ocr
# ...
#  76.3% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   2.7 min   20260908-022332__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 33 quarters (Q4-2008..Q2-2023), 33 parsed, 0 missing, 62 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 33 quarters (Q4-2008..Q2-2023), 19 parsed, 14 missing, 15 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 33 quarters (Q4-2008..Q2-2023), 33 parsed, 0 missing, 21 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  77.7% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2023   balance_sheet      [onnx@200] 62 items              recovers a quarter disk records as `absent`
#  77.7% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2023   cash_flow          [onnx@200+relax] 21 items        recovers a quarter disk records as `absent`
#  77.7% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2023   income_statement   [onnx@300] 15 items              recovers a quarter disk records as `absent`
#  77.7% - step 5/10 HOSE_HPG 65q - OCR the filings - ⚠️  de-cumulated: 6-month figure minus Q1-2023 -> the standalone quarter, 15 of 17 columns
#  77.7% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  77.7% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 33, 'income_statement': 19, 'cash_flow': 33}
#  77.7% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 55/65  HOSE_HPG 2023-Q3 ──────────────────────────────
#  77.7% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   4.6 min   20260908-022613__hose_hpg__pdf_ocr
#  79.0% - step 5/10 HOSE_HPG 65q - OCR the filings - Q3-2023 HELD — 2 of 3 statement(s) accepted — no income_statement
#  79.0% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 56/65  HOSE_HPG 2023-Q4 ──────────────────────────────
#  79.0% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   2.3 min   20260908-023049__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 34 quarters (Q4-2008..Q4-2023), 34 parsed, 0 missing, 63 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 34 quarters (Q4-2008..Q4-2023), 19 parsed, 15 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 34 quarters (Q4-2008..Q4-2023), 34 parsed, 0 missing, 21 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  80.3% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q4-2023   balance_sheet      [onnx@300] 63 items              recovers a quarter disk records as `absent`
#  80.3% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q4-2023   cash_flow          [onnx@400+loose+relax] 21 items  recovers a quarter disk records as `absent`
#  80.3% - step 5/10 HOSE_HPG 65q - OCR the filings - skip   Q4-2023   income_statement   [onnx@200] 17 items              cumulative income statement — cannot de-cumulate here because Q3-2023 is `absent` on disk. Q1..Q3-2023 WERE filed, so a full `build()` can still subtract them
#  80.3% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  80.3% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 34, 'income_statement': 19, 'cash_flow': 34}
#  80.3% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 57/65  HOSE_HPG 2024-Q1 ──────────────────────────────
#  80.3% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   1.2 min   20260908-023306__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 35 quarters (Q4-2008..Q1-2024), 35 parsed, 0 missing, 64 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 35 quarters (Q4-2008..Q1-2024), 20 parsed, 15 missing, 18 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 35 quarters (Q4-2008..Q1-2024), 35 parsed, 0 missing, 17 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  81.6% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q1-2024   balance_sheet      [onnx@200] 64 items              recovers a quarter disk records as `absent`
#  81.6% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q1-2024   cash_flow          [onnx@200+relax] 17 items        recovers a quarter disk records as `absent`
#  81.6% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q1-2024   income_statement   [onnx@200] 18 items              recovers a quarter disk records as `absent`
#  81.6% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  81.6% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 35, 'income_statement': 20, 'cash_flow': 35}
#  81.6% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 58/65  HOSE_HPG 2024-Q2 ──────────────────────────────
#  81.6% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   2.2 min   20260908-023418__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 36 quarters (Q4-2008..Q2-2024), 36 parsed, 0 missing, 63 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 36 quarters (Q4-2008..Q2-2024), 21 parsed, 15 missing, 14 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 36 quarters (Q4-2008..Q2-2024), 36 parsed, 0 missing, 21 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  83.0% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2024   balance_sheet      [onnx@200] 63 items              recovers a quarter disk records as `absent`
#  83.0% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2024   cash_flow          [onnx@200+relax] 21 items        recovers a quarter disk records as `absent`
#  83.0% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2024   income_statement   [onnx@200+tail] 14 items         recovers a quarter disk records as `absent`
#  83.0% - step 5/10 HOSE_HPG 65q - OCR the filings - ⚠️  de-cumulated: 6-month figure minus Q1-2024 -> the standalone quarter, 14 of 16 columns
#  83.0% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  83.0% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 36, 'income_statement': 21, 'cash_flow': 36}
#  83.0% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 59/65  HOSE_HPG 2024-Q3 ──────────────────────────────
#  83.0% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   4.5 min   20260908-023628__hose_hpg__pdf_ocr
#  84.3% - step 5/10 HOSE_HPG 65q - OCR the filings - Q3-2024 HELD — 2 of 3 statement(s) accepted — no income_statement
#  84.3% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 60/65  HOSE_HPG 2024-Q4 ──────────────────────────────
#  84.3% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   2.1 min   20260908-024058__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 37 quarters (Q4-2008..Q4-2024), 37 parsed, 0 missing, 64 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 37 quarters (Q4-2008..Q4-2024), 21 parsed, 16 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 37 quarters (Q4-2008..Q4-2024), 37 parsed, 0 missing, 22 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  85.6% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q4-2024   balance_sheet      [onnx@200] 64 items              recovers a quarter disk records as `absent`
#  85.6% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q4-2024   cash_flow          [onnx@200+tail+relax] 22 items   recovers a quarter disk records as `absent`
#  85.6% - step 5/10 HOSE_HPG 65q - OCR the filings - skip   Q4-2024   income_statement   [onnx@200] 17 items              cumulative income statement — cannot de-cumulate here because Q3-2024 is `absent` on disk. Q1..Q3-2024 WERE filed, so a full `build()` can still subtract them
#  85.6% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  85.6% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 37, 'income_statement': 21, 'cash_flow': 37}
#  85.6% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 61/65  HOSE_HPG 2025-Q1 ──────────────────────────────
#  85.6% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   1.5 min   20260908-024303__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 38 quarters (Q4-2008..Q1-2025), 38 parsed, 0 missing, 63 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 38 quarters (Q4-2008..Q1-2025), 22 parsed, 16 missing, 19 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 38 quarters (Q4-2008..Q1-2025), 38 parsed, 0 missing, 18 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  86.9% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q1-2025   balance_sheet      [onnx@200] 63 items              recovers a quarter disk records as `absent`
#  86.9% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q1-2025   cash_flow          [onnx@200+relax] 18 items        recovers a quarter disk records as `absent`
#  86.9% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q1-2025   income_statement   [onnx@200] 19 items              recovers a quarter disk records as `absent`
#  86.9% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  86.9% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 38, 'income_statement': 22, 'cash_flow': 38}
#  86.9% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 62/65  HOSE_HPG 2025-Q2 ──────────────────────────────
#  86.9% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   1.0 min   20260908-024433__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 39 quarters (Q4-2008..Q2-2025), 39 parsed, 0 missing, 61 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 39 quarters (Q4-2008..Q2-2025), 23 parsed, 16 missing, 15 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 39 quarters (Q4-2008..Q2-2025), 39 parsed, 0 missing, 20 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  88.3% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2025   balance_sheet      [onnx@200] 61 items              recovers a quarter disk records as `absent`
#  88.3% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2025   cash_flow          [onnx@200] 20 items              recovers a quarter disk records as `absent`
#  88.3% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q2-2025   income_statement   [onnx@200] 15 items              recovers a quarter disk records as `absent`
#  88.3% - step 5/10 HOSE_HPG 65q - OCR the filings - ⚠️  de-cumulated: 6-month figure minus Q1-2025 -> the standalone quarter, 15 of 17 columns
#  88.3% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  88.3% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 39, 'income_statement': 23, 'cash_flow': 39}
#  88.3% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 63/65  HOSE_HPG 2025-Q3 ──────────────────────────────
#  88.3% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   5.2 min   20260908-024536__hose_hpg__pdf_ocr
#  89.6% - step 5/10 HOSE_HPG 65q - OCR the filings - Q3-2025 HELD — 2 of 3 statement(s) accepted — no income_statement
#  89.6% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 64/65  HOSE_HPG 2025-Q4 ──────────────────────────────
#  89.6% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   0.9 min   20260908-025050__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 40 quarters (Q4-2008..Q4-2025), 40 parsed, 0 missing, 65 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 40 quarters (Q4-2008..Q4-2025), 23 parsed, 17 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 40 quarters (Q4-2008..Q4-2025), 40 parsed, 0 missing, 22 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  90.9% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q4-2025   balance_sheet      [onnx@200] 65 items              recovers a quarter disk records as `absent`
#  90.9% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q4-2025   cash_flow          [onnx@200] 22 items              recovers a quarter disk records as `absent`
#  90.9% - step 5/10 HOSE_HPG 65q - OCR the filings - skip   Q4-2025   income_statement   [onnx@200] 17 items              cumulative income statement — cannot de-cumulate here because Q3-2025 is `absent` on disk. Q1..Q3-2025 WERE filed, so a full `build()` can still subtract them
#  90.9% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  90.9% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 40, 'income_statement': 23, 'cash_flow': 40}
#  90.9% - step 5/10 HOSE_HPG 65q - OCR the filings - ── 65/65  HOSE_HPG 2026-Q1 ──────────────────────────────
#  90.9% - step 5/10 HOSE_HPG 65q - OCR the filings - exit 0   1.2 min   20260908-025143__hose_hpg__pdf_ocr
# cafef financials: HPG balance_sheet: 41 quarters (Q4-2008..Q1-2026), 41 parsed, 0 missing, 69 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
# cafef financials: HPG income_statement: 41 quarters (Q4-2008..Q1-2026), 24 parsed, 17 missing, 17 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# cafef financials: HPG cash_flow: 41 quarters (Q4-2008..Q1-2026), 41 parsed, 0 missing, 21 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  92.2% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q1-2026   balance_sheet      [onnx@200] 69 items              recovers a quarter disk records as `absent`
#  92.2% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q1-2026   cash_flow          [onnx@200+relax] 21 items        recovers a quarter disk records as `absent`
#  92.2% - step 5/10 HOSE_HPG 65q - OCR the filings - WRITE  Q1-2026   income_statement   [onnx@200] 17 items              recovers a quarter disk records as `absent`
#  92.2% - step 5/10 HOSE_HPG 65q - OCR the filings - backup: — (taken earlier in this run)
#  92.2% - step 5/10 HOSE_HPG 65q - OCR the filings - written: {'balance_sheet': 41, 'income_statement': 24, 'cash_flow': 41}
#  92.2% - step 5/10 HOSE_HPG 65q - OCR the filings - -> 106 statement(s) reached the CSVs as the run proceeded
#  92.2% - step 5/10 HOSE_HPG 65q - OCR the filings - ⚠️ 6 of them passed NO MAGNITUDE GUARD — this ticker had no `pdf` history for `seed_history` to rebuild a band from, so `sane` failed open (`BND-1`).
#  92.2% - step 5/10 HOSE_HPG 65q - OCR the filings - Screen those figures by arithmetic — two statements agreeing on one figure, a printed subtotal closing — before quoting any of them.
#  92.2% - step 5/10 HOSE_HPG 65q - OCR the filings - 65 run folder(s)

# %% [markdown]
# ## 7 · The result — verdicts from the run folder

# %%
# ── READ THE RUN FOLDERS ────────────────────────────────────────────────
# ⚠️ Read back from disk rather than from anything in memory, so this measures what a later
# reader would actually get. `metadata.json` already carries the whole scorecard in `results`.
# ⚠️ **A BATCH IS MANY FOLDERS, ONE PER DOCUMENT.** `FOLDERS` comes from the run cell; when the
# kernel was restarted between the two, fall back to this ticker's folders newer than the
# newest CSV backup — never to "the newest folder" alone, which on a batch is the LAST document
# and would report a 70-quarter run as a one-quarter one.
NB.begin("results", "read back from disk, not from memory")
with NB.capture(nested=True):
    import json                                          # noqa: E402

    PATTERN = f"*__{EXCHANGE.lower()}_{SYMBOL.lower()}__pdf_ocr"
    if not FOLDERS:
        FOLDERS = sorted((REPO / "reports" / "pdf_ocr").glob(PATTERN), key=lambda p: p.name)[-1:]
    LATEST = FOLDERS[-1] if FOLDERS else None
    META = MERGE = None
    RESULTS: list = []

    if LATEST is None:
        print(f"no run folder matching {PATTERN}")
    else:
        META = json.loads((LATEST / "metadata.json").read_text(encoding="utf-8"))
        inputs, ocr = META.get("inputs", {}), META.get("environment", {}).get("ocr", {})
        SCHEMA = META.get("schema_version", 1)
        print(f"{len(FOLDERS)} run folder(s), {FOLDERS[0].name} … {LATEST.name}")
        print(f"  commit       : {META.get('git_commit')}")
        print(f"  template     : {inputs.get('template')}  ({inputs.get('template_how')})")
        # ⚠️ THE TWO OCR HALVES FAIL INDEPENDENTLY — detection is onnxruntime, recognition is torch
        # — so "the GPU was used" is two questions. `ORT-1` is a green run that was half on the CPU
        # because onnxruntime ADVERTISED a provider the session then could not create.
        print(f"  detection    : {(ocr.get('det_providers') or ['?'])[0]}"
              f"   (onnxruntime {ocr.get('onnxruntime')})")
        print(f"  recognition  : {ocr.get('recognizer_device')}")
        print(f"  stack        : {ocr.get('stack_fingerprint')}"
              + (f"   ⚠️ PIN VIOLATIONS: {ocr['pin_violations']}"
                 if ocr.get("pin_violations") else ""))

        # ⚠️ **A RUN WHOSE ONNX LAYERS RAISED REPORTS `pdf` WITH A REAL LAYER AND A REAL ITEM
        # COUNT.** The rows below look identical to a good run; what happened is that the layer
        # could not run, the cascade went on, and something later won BY DEFAULT — which on this
        # machine is `tesseract@200`, layer 4 of 55. Measured 2026-09-02 on HOSE_CTG: 85 layers
        # raised `CUDA failure 2: out of memory` and 30 of 33 statements were reported `pdf`.
        # ⚠️ `pdf_ocr_merge` refuses such a document whole (`VCR-1`), so nothing reaches disk — but
        # that is the LAST line of defence and it is silent about WHY until §8. This says it here,
        # where the verdict table is read.
        RAISED = {}
        for _folder in FOLDERS:
            for _doc in sorted((_folder / "documents").glob("*.json")):
                _d = json.loads(_doc.read_text(encoding="utf-8"))
                if _d.get("engine_errors"):
                    RAISED[_d.get("period", _doc.stem)] = _d["engine_errors"]
            _m = json.loads((_folder / "metadata.json").read_text(encoding="utf-8"))
            RESULTS += _m.get("results", [])
        if RAISED:
            print()
            print(f"  ⚠️ {len(RAISED)} document(s) had at least one layer RAISE rather than "
                  f"refuse.")
            print("     Whatever won them won BY DEFAULT, and the merge refuses them whole.")
            for _p in sorted(RAISED)[:8]:
                print(f"       {_p:10} {len(RAISED[_p])} layer(s): "
                      f"{', '.join(l for l, _ in RAISED[_p][:3])}")
            _kinds = sorted({str(w).split(";")[0].strip()[:70]
                             for e in RAISED.values() for _l, w in e})
            for _k in _kinds[:3]:
                print(f"       cause: {_k}")
            print("     ⚠️ `out of memory` means the card was short — raise VRAM_FLOOR_MB, close "
                  "other")
            print("        CUDA processes, and re-run those quarters. Nothing of theirs is "
                  "on disk.")


        # ⚠️ **WHICH FILING EACH STATEMENT ACTUALLY CAME FROM (`ALT-1`).** `documents()` returns
        # ONE document per period and a quarter can have several, so a statement every layer
        # refused on the chosen filing is retried on the others of the same period and ENTITY.
        # When that succeeds the row on disk names THAT filing, not the one the document block
        # above names — and if this cell did not print it, nothing a reader sees would.
        # ⚠️ Measured on TCB Q2-2019: its closing balance is printed under the company's round
        # stamp in the AUDITED filing and no engine, DPI or crop reads it, while the REVIEWED
        # filing of the same quarter reads the whole tail cleanly at layer 1.
        ALT = {}
        for _folder in FOLDERS:
            for _doc in sorted((_folder / "documents").glob("*.json")):
                _d = json.loads(_doc.read_text(encoding="utf-8"))
                for _rep, _got in (_d.get("accepted") or {}).items():
                    if _got.get("document"):
                        ALT[(_d["period"], _rep)] = (_got["document"],
                                                     _got.get("assurance", ""))
        if ALT:
            print()
            print(f"  ⚠️ {len(ALT)} statement(s) came from a DIFFERENT filing of the same "
                  f"period and entity:")
            for (_p, _rep), (_file, _ass) in sorted(ALT.items()):
                print(f"       {_p:10} {_rep:18} {_ass:10} {_file}")
            print("     ⚠️ The ENTITY is fixed by `alternates`, so none of these changed which "
                  "company the")
            print("     row describes; the ASSURANCE may be lower, and that is the trade.")
        print()
        print(f"  {'period':10} {'report':18} {'layer':30} {'items':>5}  {'status':8} verdict")
        for r in sorted(RESULTS, key=lambda r: (fin._period_key(r["period"]), r["report"])):
            print(f"  {r['period']:10} {r['report']:18} {(r['layer'] or '—'):30} "
                  f"{r['items']:>5}  {r['status']:8} {r['verdict']}")
        # ⚠️ `seconds` is the DOCUMENT's cost repeated on each of its three report rows, so it is
        # summed per PERIOD. A set would also collapse two documents that took the same time.
        PER_DOC = {r["period"]: r["seconds"] for r in RESULTS}
        _ok = sum(1 for r in RESULTS if r["status"] == "pdf")
        print(f"\n  parse: {sum(PER_DOC.values()) / 60:.1f} min over {len(PER_DOC)} document(s)"
              f"   {_ok} of {len(RESULTS)} statement(s) accepted")
NB.end()
# Out:
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - read back from disk, not from memory
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - 65 run folder(s), 20260907-233112__hose_hpg__pdf_ocr … 20260908-025143__hose_hpg__pdf_ocr
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - commit       : fd9faad9
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - template     : corp  (override)
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - detection    : CUDAExecutionProvider   (onnxruntime 1.22.0)
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - recognition  : cuda
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - stack        : e6b778e294b4
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - period     report             layer                          items  status   verdict
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2008    balance_sheet      onnx@200                          54  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2008    cash_flow          onnx@200+relax                    24  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2008    income_statement   onnx@200                          18  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2009    balance_sheet      onnx@200                          55  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2009    cash_flow          onnx@200+title                    30  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2009    income_statement   onnx@200                          18  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2009    balance_sheet      onnx@200                          56  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2009    cash_flow          onnx@200                          28  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2009    income_statement   —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2010    balance_sheet      onnx@200                          51  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2010    cash_flow          onnx@200+relax                    17  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2010    income_statement   onnx@200                          16  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2011    balance_sheet      onnx@200                          59  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2011    cash_flow          —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2011    income_statement   onnx@200+bycol                    16  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2011    balance_sheet      onnx@200                          51  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2011    cash_flow          onnx@300                          18  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2011    income_statement   onnx@200                          15  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2011    balance_sheet      onnx@300                          59  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2011    cash_flow          —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2011    income_statement   —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2011    balance_sheet      onnx@200                          52  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2011    cash_flow          onnx@200+relax                    23  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2011    income_statement   —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2012    balance_sheet      onnx@200+red                      60  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2012    cash_flow          —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2012    income_statement   —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2012    balance_sheet      onnx@200                          49  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2012    cash_flow          onnx@300+relax                    20  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2012    income_statement   onnx@200                          13  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2012    balance_sheet      onnx@200+red                      55  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2012    cash_flow          —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2012    income_statement   onnx@200+tail                      6  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2012    balance_sheet      onnx@300                          52  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2012    cash_flow          —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2012    income_statement   onnx@200                          13  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2013    balance_sheet      onnx@200                          58  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2013    cash_flow          —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2013    income_statement   —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2013    balance_sheet      onnx@200                          47  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2013    cash_flow          onnx@200+relax                    20  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2013    income_statement   onnx@200                          14  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2013    balance_sheet      onnx@200                          56  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2013    cash_flow          —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2013    income_statement   —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2013    balance_sheet      onnx@200                          47  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2013    cash_flow          onnx@200+relax                    21  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2013    income_statement   onnx@200                          16  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2014    balance_sheet      onnx@200                          59  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2014    cash_flow          —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2014    income_statement   —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2014    balance_sheet      onnx@200                          46  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2014    cash_flow          onnx@200+total+relax              20  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2014    income_statement   onnx@200                          14  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2014    balance_sheet      onnx@200+join+components          59  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2014    cash_flow          —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2014    income_statement   onnx@200+equity                    5  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2014    balance_sheet      onnx@200                          46  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2014    cash_flow          onnx@200+relax                    18  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2014    income_statement   onnx@200                          16  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2015    balance_sheet      onnx@200+join+components          77  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2015    cash_flow          —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2015    income_statement   onnx@200+pad6+components           9  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2015    balance_sheet      onnx@200                          64  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2015    cash_flow          onnx@300+relax                    20  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2015    income_statement   onnx@200                          20  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2015    balance_sheet      onnx@300                          61  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2015    cash_flow          onnx@200+relax                    24  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2015    income_statement   —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2015    balance_sheet      onnx@200                          64  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2015    cash_flow          onnx@200+tail+relax               21  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2015    income_statement   onnx@200                          19  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2016    balance_sheet      onnx@200+tail                     66  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2016    cash_flow          onnx@200+tail+relax               23  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2016    income_statement   onnx@200                          18  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2016    balance_sheet      onnx@200                          66  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2016    cash_flow          onnx@400+loose+relax              20  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2016    income_statement   onnx@200                          19  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2016    balance_sheet      onnx@200+tail                     66  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2016    cash_flow          onnx@200+relax                    19  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2016    income_statement   —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2016    balance_sheet      onnx@200+tail                     53  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2016    cash_flow          onnx@400+loose+relax              20  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2016    income_statement   onnx@200                          19  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2017    balance_sheet      onnx@200                          67  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2017    cash_flow          onnx@200+relax                    21  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2017    income_statement   onnx@200                          19  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2017    balance_sheet      onnx@200                          65  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2017    cash_flow          onnx@200+relax                    22  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2017    income_statement   onnx@200                          20  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2017    balance_sheet      onnx@200+tail                     63  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2017    cash_flow          onnx@200+relax                    19  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2017    income_statement   —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2017    balance_sheet      onnx@200                          64  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2017    cash_flow          onnx@200+tail+relax               23  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2017    income_statement   onnx@200                          19  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2018    balance_sheet      onnx@200                          66  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2018    cash_flow          onnx@200+relax                    18  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2018    income_statement   onnx@200                          18  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2018    balance_sheet      onnx@200                          65  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2018    cash_flow          onnx@200+tail+relax               22  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2018    income_statement   onnx@200                          17  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2018    balance_sheet      onnx@200                          67  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2018    cash_flow          onnx@200+relax                    19  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2018    income_statement   onnx@200                          18  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2018    balance_sheet      onnx@200                          65  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2018    cash_flow          onnx@200+tail+relax               22  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2018    income_statement   onnx@200                          17  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2019    balance_sheet      onnx@200                          67  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2019    cash_flow          onnx@200+relax                    18  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2019    income_statement   onnx@200                          17  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2019    balance_sheet      onnx@200                          66  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2019    cash_flow          onnx@200+tail+relax               21  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2019    income_statement   onnx@200                          16  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2019    balance_sheet      onnx@200                          67  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2019    cash_flow          onnx@200+relax                    18  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2019    income_statement   —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2019    balance_sheet      onnx@300                          66  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2019    cash_flow          onnx@200+tail+relax               21  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2019    income_statement   onnx@200                          18  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2020    balance_sheet      onnx@200                          67  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2020    cash_flow          onnx@200+relax                    17  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2020    income_statement   onnx@200                          17  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2020    balance_sheet      onnx@200+codecol                  66  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2020    cash_flow          onnx@300+pad6+annual+extra        21  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2020    income_statement   onnx@200                          18  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2020    balance_sheet      onnx@200                          69  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2020    cash_flow          onnx@200+relax                    17  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2020    income_statement   —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2020    balance_sheet      onnx@200                          66  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2020    cash_flow          onnx@200+pad6+annual+extra        19  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2020    income_statement   onnx@200                          17  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2021    balance_sheet      onnx@200                          68  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2021    cash_flow          onnx@200+tail+relax               24  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2021    income_statement   onnx@200                          17  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2021    balance_sheet      onnx@200                          66  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2021    cash_flow          onnx@200+relax                    22  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2021    income_statement   onnx@300                          16  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2021    balance_sheet      onnx@200                          68  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2021    cash_flow          onnx@200+relax                    18  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2021    income_statement   —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2021    balance_sheet      onnx@200                          63  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2021    cash_flow          onnx@200+tail+relax               22  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2021    income_statement   onnx@200                          18  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2022    balance_sheet      onnx@200                          67  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2022    cash_flow          onnx@200+relax                    18  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2022    income_statement   —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2022    balance_sheet      onnx@200                          67  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2022    cash_flow          onnx@200+relax                    19  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2022    income_statement   —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2022    balance_sheet      onnx@200+tail                     67  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2022    cash_flow          onnx@200+relax                    18  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2022    income_statement   —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2022    balance_sheet      onnx@200+tail                     63  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2022    cash_flow          onnx@200+relax                    22  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2022    income_statement   onnx@200                          16  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2023    balance_sheet      onnx@200                          66  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2023    cash_flow          onnx@200+relax                    18  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2023    income_statement   onnx@200                          18  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2023    balance_sheet      onnx@200                          62  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2023    cash_flow          onnx@200+relax                    21  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2023    income_statement   onnx@300                          17  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2023    balance_sheet      onnx@200                          66  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2023    cash_flow          onnx@200+relax                    18  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2023    income_statement   —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2023    balance_sheet      onnx@300                          63  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2023    cash_flow          onnx@400+loose+relax              21  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2023    income_statement   onnx@200                          17  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2024    balance_sheet      onnx@200                          64  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2024    cash_flow          onnx@200+relax                    17  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2024    income_statement   onnx@200                          18  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2024    balance_sheet      onnx@200                          63  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2024    cash_flow          onnx@200+relax                    21  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2024    income_statement   onnx@200+tail                     16  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2024    balance_sheet      onnx@200                          66  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2024    cash_flow          onnx@200+relax                    17  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2024    income_statement   —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2024    balance_sheet      onnx@200                          64  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2024    cash_flow          onnx@200+tail+relax               22  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2024    income_statement   onnx@200                          17  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2025    balance_sheet      onnx@200                          63  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2025    cash_flow          onnx@200+relax                    18  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2025    income_statement   onnx@200                          19  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2025    balance_sheet      onnx@200                          61  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2025    cash_flow          onnx@200                          20  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q2-2025    income_statement   onnx@200                          17  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2025    balance_sheet      onnx@200+reseat                   59  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2025    cash_flow          onnx@200+relax                    21  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q3-2025    income_statement   —                                  0  absent   absent in this run
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2025    balance_sheet      onnx@200                          65  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2025    cash_flow          onnx@200                          22  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q4-2025    income_statement   onnx@200                          17  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2026    balance_sheet      onnx@200                          69  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2026    cash_flow          onnx@200+relax                    21  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - Q1-2026    income_statement   onnx@200                          17  pdf      no pdf row on disk to compare against
#  92.2% - step 6/10 HOSE_HPG 65q - read the run folders - parse: 198.3 min over 65 document(s)   166 of 195 statement(s) accepted

# %% [markdown]
# ## 8 · Refused vs written — two questions, two places

# %%
# ── WHAT WAS REFUSED, AND WHAT WAS WRITTEN ───────────────────────────────
#   the PARSE refused a statement   -> the document JSON's `absent_reasons`, and `run.log`
#   the MERGE refused a statement   -> the `merge` block, written by whatever ran the UPSERT
# ⚠️ ON KAGGLE THOSE ARE TWO MACHINES. A cell that greps the worker's `run.log` for
# `WRITE `/`skip ` finds nothing on a Kaggle run and, finding nothing, used to print "no
# refusals — every statement was accepted". That false success was printed over a run that
# wrote 0 of 201 accepted cells (HOSE_CTG, 2026-08-30).
#
# ⚠️ **THE REASON IS DATA NOW, NOT PROSE** (`absent_reasons`, artefact schema v4) — and since
# 2026-09-02 so are the ROWS behind it (`absent_rows`). A reason names the SYMPTOM (`no total
# assets`); the rows say WHAT THE FILING PRINTS where the chart expects that anchor, which is
# the only thing a fix can be written from. Recovering that used to cost a second OCR run.
NB.begin("refused", "the PARSE refused, and what the MERGE decided")
with NB.capture(nested=True):
    if FOLDERS:
        print("── the PARSE refused ────────────────────────────────────────")
        ABSENT: dict = {}
        for _folder in FOLDERS:
            for _doc in sorted((_folder / "documents").glob("*.json")):
                _d = json.loads(_doc.read_text(encoding="utf-8"))
                for _rep, _tried in (_d.get("absent_reasons") or {}).items():
                    ABSENT[(_d["period"], _rep)] = (
                        _tried, (_d.get("absent_rows") or {}).get(_rep))
        if not ABSENT:
            print("  nothing — every statement the cascade opened was accepted")
        for (_period, _rep), (_tried, _rows) in sorted(
                ABSENT.items(), key=lambda kv: (fin._period_key(kv[0][0]), kv[0][1])):
            print(f"  {_period:9} {_rep:18}")
            for _layer, _why in _tried:
                print(f"      [{_layer:28}] {_why}")
            # ⚠️ THE ROWS ARE THE CAUSE AND THE REASON IS THE SYMPTOM. Printed only for the
            # statements this run could not accept, and only the EARLIEST reading of them — the
            # last layer is always the most relaxed one and its rows answer a question nobody
            # asked (§6-2-duovicies' trap for the reason applies to the rows too).
            if _rows and SHOW_ABSENT_ROWS:
                print(f"      rows read at [{_rows['layer']}], pages {_rows['pages']}, "
                      f"{len(_rows['rows'])} row(s) — the ones naming a TOTAL:")
                for _r in _rows["rows"]:
                    _lab = (_r["label"] or "").upper()
                    if any(w in _lab for w in ("TỔNG", "TONG", "CUỐI", "CUOI", "ĐẦU", "DAU")):
                        print(f"        {_r['key'][:54]:54} {_r['values'][:2]}")
                        print(f"          {_r['label'][:96]}")

        # ⚠️ NOT a refusal — a fact about the FILING. A page whose scan is turned reads as vertical
        # noise, and before 2026-08-30 that cost a whole statement in silence (BID Q3-2011).
        TURNED = [ln for _f in FOLDERS
                  for ln in (_f / "run.log").read_text(encoding="utf-8",
                                                       errors="replace").splitlines()
                  if "text lines are vertical" in ln]
        if TURNED:
            print("\n── pages the READ had to turn ──────────────────────────────")
            for ln in TURNED[:12]:
                print("  " + progress.detail_of(ln))

        print("\n── the MERGE decided ───────────────────────────────────────")
        EVENTS = []
        for _folder in FOLDERS:
            _m = json.loads((_folder / "metadata.json").read_text(encoding="utf-8"))
            for _ev in (_m.get("merge") or {}).get("events", []):
                EVENTS += [(d, _ev["applied"]) for d in _ev["decisions"]]
        if EVENTS:
            for _d, _applied in sorted(EVENTS, key=lambda e: (fin._period_key(e[0]["period"]),
                                                              e[0]["report"])):
                mark = "WRITE " if _d["action"] == "write" else "skip  "
                items = f"[{_d['layer']}] {_d['items']} items" if _d["layer"] else ""
                print(f"  {mark} {_d['period']:9} {_d['report']:18} {items:32} {_d['reason']}")
                # ⚠️ A CAVEAT ON A WRITE IS LOUDER THAN A REFUSAL, because a refusal stops and a
                # write does not. Printed only for a WRITE: refusal 1 sets the note before
                # refusals 2-4 have had their say, so beside `skip` it would contradict the line.
                if _d.get("note") and _d["action"] == "write":
                    print(f"           ⚠️  {_d['note']}")
            _w = sum(1 for d, a in EVENTS if d["action"] == "write" and a)
            print(f"\n  -> {_w} statement(s) written, {len(EVENTS) - _w} refused or planned only")
            if not _w:
                print("  ⚠️ NOTHING REACHED raw_data/. On a ticker with no CSV yet the commonest "
                      "reason is an")
                print("     EMPTY `sane` band — set FORCE_EMPTY_BAND = True. It lifts ONE guard "
                      "and no other,")
                print("     so screen the artefact before quoting anything (`BND-1`).")
        else:
            print("  ⚠️ NO MERGE RAN against these run folders — the statement CSVs were not "
                  "opened.")
            print("     §9 below does it: MERGE_TWO_PASS = True, then MERGE_APPLY = True.")
NB.end()
# Out:
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - the PARSE refused, and what the MERGE decided
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - ── the PARSE refused ────────────────────────────────────────
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q4-2009   income_statement
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] reconcile: operating profit does not close: components give 2.29703e+12 (or 1.65505e+12 with the deductions taken as expenses) against a printed 1.50568e+12
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - rows read at [onnx@200], pages [10], 24 row(s) — the ones naming a TOTAL:
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tong_loi_nhuan_ke_toan_truoc_thue                      [None, 1509979337847]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Tổng lợi nhuận kế toán trước thuế
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q1-2011   cash_flow
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] reconcile: 194 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300                    ] reconcile: 192 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@400                    ] reconcile: 184 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+pad6+components    ] reconcile: 129 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+join+components    ] reconcile: 56 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+red                ] reconcile: 190 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+red                ] reconcile: 198 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+pad6+annual+extra  ] reconcile: 141 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+joinlost           ] reconcile: 63 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+joinlost+red       ] reconcile: 59 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+joinlost+red       ] reconcile: 64 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@400+deskew             ] reconcile: 53 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - rows read at [onnx@200], pages [6], 35 row(s) — the ones naming a TOTAL:
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - lai_lo_tu_hoat_dong_dau_tu                             [139, 930]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Lãi, lỗ từ hoạt động đầu tư
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - luu_chuyen_tien_tu_hoat_dong_dau_tu_1_tien_chi_de_mua_ [0, 184]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - II. Lưu chuyến tiền từ hoạt động đầu tư 1.Tiền chi để mua sắm, xây dựng TSCĐ và các tài sản dài
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_chi_dau_tu_gop_von_vao_don_vi_khac                [2, 373]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - 5.Tiền chi đầu tư góp vốn vào đơn vị khác
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_thu_hoi_dau_tu_gop_von_vao_don_vi_khac_7_tien_thu [28, 33]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - 6.Tiền thu hồi đầu tư góp vốn vào đơn vị khác 7.Tiền thu lãi cho vay, cổ tức và lợi nhuận được c
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - luu_chuyen_tien_thuan_tu_hoat_dong_dau_tu              [0, 749]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Lưu chuyến tiền thuần từ hoạt động đầu tư
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_va_tuong_duong_tien_dau_ky                        [1047, 480]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Tiền và tương đương tiền đầu kỳ
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_va_tuong_duong_tien_cuoi_ky_70_50_60_61           [1, 795]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Tiền và tương đương tiền cuối kỳ (70 - 50?60-61)
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q3-2011   cash_flow
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] reconcile: 193 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@400                    ] reconcile: 200 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+pad6+components    ] reconcile: 114 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+join+components    ] reconcile: 35 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+red                ] reconcile: 199 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+red                ] reconcile: 196 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+pad6+annual+extra  ] reconcile: 128 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+joinlost           ] reconcile: 51 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+joinlost+red       ] reconcile: 31 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+joinlost+red       ] reconcile: 55 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@400+deskew             ] reconcile: 41 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - rows read at [onnx@200], pages [5], 36 row(s) — the ones naming a TOTAL:
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - lai_lo_tu_hoat_dong_dau_tu                             [145, 179]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Lãi, lỗ từ hoạt động đầu tư
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - luu_chuyen_tien_tu_hoat_dong_dau_tu_1_tien_chi_de_mua_ [449, 646]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - II. Lưu chuyễn tiền từ hoạt động đầu tư 1.Tiền chi để mua sắm, xây dựng TSCĐ và các tài sản dài
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_chi_dau_tu_gop_von_vao_don_vi_khac                [30, 0]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - 5.Tiền chi đầu tự góp vốn vào đơn vị khác
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_thu_hoi_dau_tu_gop_von_vao_don_vi_khac            [285, None]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - 6.Tiền thu hồi đầu tư góp vốn vào đơn vị khác
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - luu_chuyen_tien_thuan_tu_hoat_dong_dau_tu              [119, -1]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Lưu chuyển tiền thuần từ hoạt động đầu tư
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_va_tuong_duong_tien_dau_ky                        [1047, 1]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Tiền và tương đương tiền đầu kỳ
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_va_tuong_duong_tien_cuoi_ky_70_50_60_61           [845930, 435]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Tiền và tương đương tiền cuối kỳ (70 - 50?60-61)
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q3-2011   income_statement
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] reconcile: no profit before tax
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - rows read at [onnx@200], pages [23, 24], 36 row(s) — the ones naming a TOTAL:
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tong_doanh_thu_ban_hang_va_cung_cap_dich_vu_ma_so_01   [4118429778532, 3954265116798]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - 25- Tổng doanh thu bán hàng và cung cấp dịch vụ (mã số 01)
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - lo_tu_hoat_dong_dau_tu_tai_chinh                       [None, 66269198573]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - - Lỗ từ hoạt động đầu tư tài chính
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - dieu_chinh_chi_phi_thue_thu_nhap_doanh_nghiep_cua_cac_ [None, 32415286826]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Điều chỉnh chi phí thuế thu nhập doanh nghiệp của các năm trước vào chi phí thuế thu nhập hiện h
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q4-2011   income_statement
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] reconcile: no profit before tax
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - rows read at [onnx@200], pages [9, 10, 11], 29 row(s) — the ones naming a TOTAL:
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - phat_va_bao_cao_ket_qua_hoat_dong_kinh_doanh_ma_so_ton [26, None]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Phát và Báo cáo kết quả hoạt động kinh doanh Mã số Tổng doanh thu
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - cong_vnd_tong_phoi                                     [0, -2790000000]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - cộng VND Tổng phối
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - cong_vnd_tong_phoi                                     [-313613480000, 1539869803156]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - cộng VND Tổng phối
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q1-2012   cash_flow
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] reconcile: 171 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300                    ] reconcile: 168 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+pad6+components    ] reconcile: 96 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+join+components    ] reconcile: 28 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+red                ] reconcile: 169 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+red                ] reconcile: 165 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+pad6+annual+extra  ] reconcile: 88 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+joinlost           ] reconcile: 25 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+joinlost           ] reconcile: 35 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+joinlost+red       ] reconcile: 23 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+joinlost+red       ] reconcile: 32 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@400+deskew             ] reconcile: 30 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - rows read at [onnx@200], pages [5], 31 row(s) — the ones naming a TOTAL:
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - lai_lo_tu_hoat_dong_dau_u                              [9, 139]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Lài, lỗ từ hoạt động đầu u
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - luu_chuyen_tien_tu_hoat_dong_dau_tr_1_tien_chi_de_mua_ [353, 485]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - II. Lưu chuyến tiền từ hoạt động đầu tr 1.Tiện chi để mua sắm, xây dựng TSCĐ và các tài sản dài
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_thu_hoi_cho_vay_ban_lai_cac_cong_cu_no_cua_dn_vi_ [25, 2]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - 4.Tiền thu hồi cho vay, bán lại các công cụ nợ của đn vị khác 5.Tiền chi đầu tư góp vốn vào đơn
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_thu_hoi_dau_tr_gop_von_vao_don_vi_khac_7_tien_thu [20, 28]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - 6.Tiền thu hồi đầu tr góp vốn vào đơn vị khác 7.Tiền thu lài cho vay, cố tức và lợi nhuận được c
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - luu_chuyen_tien_thuan_tu_hoat_dong_dau_tr              [350, 744]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Lưu chuyển tiền thuần từ hoạt động đầu tr
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_va_tuong_duong_tien_dau_ky                        [64, 1047]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Tiền và tương đương tiền đầu kỳ
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - anh_huong_cua_thay_doi_ty_gia_hoi_doai_quy_doi_ngoai_t [None, 1]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Anh hưởng của thay đồi tý giá hối đoái quy đổi ngoại tệ Tiền và tương đương tiến cuối kỳ (70 - 5
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q1-2012   income_statement
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] reconcile: no profit before tax
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - rows read at [onnx@200], pages [23, 24], 32 row(s) — the ones naming a TOTAL:
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tong_doanh_thu_ban_hang_va_cung_cap_dich_vu_ma_so_01_d [None, 4732453721580]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - 25- Tổng doanh thu bán hàng và cung cấp dịch vụ (mã số 01) Doanh thu bán hàng
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q3-2012   cash_flow
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] reconcile: 206 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300                    ] reconcile: 196 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@400                    ] reconcile: 197 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+pad6+components    ] reconcile: 127 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+join+components    ] reconcile: 26 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+red                ] reconcile: 201 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+red                ] reconcile: 195 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+pad6+annual+extra  ] reconcile: 125 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+joinlost           ] reconcile: 23 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+joinlost           ] reconcile: 40 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+joinlost+red       ] reconcile: 30 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+joinlost+red       ] reconcile: 35 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@400+deskew             ] reconcile: 37 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - rows read at [onnx@200], pages [5], 36 row(s) — the ones naming a TOTAL:
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - lai_lo_tu_hoat_dong_dau_tr                             [101, 13]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Lãi, lỗ từ hoạt động đầu tr
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - luu_chuyen_tien_tu_hoat_dong_dau_tr_1_tien_chi_de_mua_ [682, 296]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - II. Lưu chuyển tiền từ hoạt động đầu tr 1.Tiền chi để mua sắm, xây dựng TSCĐ và các tài sán dài
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_chi_dau_tu_gop_von_vao_don_vi_khac                [344, 860]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - 5.Tiền chi đầu tự góp vốn vào đơn vị khác
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_thu_hoi_dau_tu_gop_von_vao_don_vi_khac            [300, 0]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - 6.Tiền thu hồi đầu tư góp vốn vào đơn vị khác
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - luu_chuyen_tien_thuan_tu_hoat_dong_dau_tr              [610, 71]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Lưu chuyển tiền thuần từ hoạt động đầu tr
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_va_tuong_duong_tien_dau_ky                        [64, 90]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Tiền và tương đương tiền đầu kỳ
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_va_tuong_duong_tien_cuoi_ky_70_50_60_61           [841, 686]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Tiền và tương đương tiền cuối kỷ (70 - 50?60?61)
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q4-2012   cash_flow
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] reconcile: no closing cash balance
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+relax              ] reconcile: closing cash balance 1,294,493,700,487 disagrees with the balance sheet's cash line 493,700,487 of the same filing
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - rows read at [onnx@200], pages [11, 12, 13], 38 row(s) — the ones naming a TOTAL:
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - lai_tu_hoat_dong_dau_tu                                [-127834058603, -168431397099]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Lai từ hoạt động đầu tu
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - ma_thuyet_so_minh_vnd_luu_chuyen_tien_tu_hoat_dong_dau [-1828105150975, -1723752583204]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Mã Thuyết số minh VND LƯU CHUYÊN TIỀN TỪ HOẠT ĐỘNG ĐẦU TƯ Tiền chỉ mua tải sản cố định và tài sá
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_chn_dau_tu_gop_von_vao_cac_don_vi_khac            [-1500000000, 908790]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Tiền chn đầu tư góp vôn vào các đơn vị khác
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_thu_hoi_dau_tu_gop_von_vao_cac_don_vi_khac        [356306160000, 314022199450]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Tiền thu hồi đầu tư góp vốn vào các đơn vị khác
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - dau_nam_anh_huong_cua_thay_doi_ty_gia_hoi_doai_doi_voi [-10998131, 238380867]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - đầu năm Ảnh hưởng của thay đối tỷ giá hối đoái đổi với tiền và các khoàn
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q1-2013   cash_flow
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] reconcile: 142 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300                    ] reconcile: 139 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@400                    ] reconcile: 134 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+pad6+components    ] reconcile: 88 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+join+components    ] reconcile: 23 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+red                ] reconcile: 147 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+red                ] reconcile: 128 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+pad6+annual+extra  ] reconcile: 87 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+joinlost           ] reconcile: 25 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+joinlost+red       ] reconcile: 17 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+joinlost+red       ] reconcile: 28 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@400+deskew             ] reconcile: 20 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - rows read at [onnx@200], pages [5], 35 row(s) — the ones naming a TOTAL:
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - lai_lo_tu_hoat_dong_dau_tr                             [132, 847850]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Lãi, lỗ từ hoạt động đầu tr
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - luu_chuyen_tien_tu_hoat_dong_dau_tr_1_tien_chi_de_mua_ [980, 115]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - II. Lưu chuyển tiền từ hoạt động đầu tr 1.Tiền chi để mua sắm, xây dựng TSCĐ ả các tài sản đài h
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_chi_dau_tu_gop_von_vao_don_vi_khac                [7, 599]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - 5.Tiền chi đầu tự góp vốn vào đơn vị khác
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_thu_hoi_dau_tu_gop_von_vao_don_vi_khac            [125, 383]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - 6.Tiền thu hồi đầu tư góp vốn vào đơn vị khác
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - luu_chuyen_tien_thuan_tu_hoat_dong_dau_tr              [822, 350]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Lưu chuyển tiền thuần từ hoạt động đầu tr
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_va_tuong_duong_tien_dau_ky                        [294, 700]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Tiền và tương đương tiền đầu kỳ
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_va_tuong_duong_tien_cuoi_ky_70_50_60_61           [996, 633]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Tiền và tương dương tiền cuối kỳ (70 - 50?60-61)
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q1-2013   income_statement
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] reconcile: no profit before tax
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - rows read at [onnx@200], pages [22, 23, 24], 42 row(s) — the ones naming a TOTAL:
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tong_doanh_thu_ban_hang_va_cung_cap_dich_vu_ma_so_01   [3797910680620, 3974000229829]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - 25- Tổng doanh thu bán hàng và cung cấp dịch vụ (mã số 01)
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - lai_tu_dau_tu_tai_chinh                                [105909577391, None]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Lãi từ đầu tư tài chính
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - lo_tu_hoat_dong_dau_tu_tai_chinh                       [None, 2303923839]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Lỗ từ hoạt động đầu tư tài chính
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - dieu_chinh_chi_phi_thue_thu_nhap_doanh_nghiep_cua_cac_ [93264621288, 44403993294]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Điều chỉnh chi phí thuế thu nhập đoanh nghiệp của các năm trước vào chi phí thuế thu nhập hiện h
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q3-2013   cash_flow
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] reconcile: 201 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300                    ] reconcile: 211 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@400                    ] reconcile: 206 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+pad6+components    ] reconcile: 111 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+join+components    ] reconcile: 36 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+red                ] reconcile: 209 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+red                ] reconcile: 205 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+pad6+annual+extra  ] reconcile: 106 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+joinlost           ] reconcile: 32 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+joinlost+red       ] reconcile: 40 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+joinlost+red       ] reconcile: 38 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@400+deskew             ] reconcile: 55 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - rows read at [onnx@200], pages [5], 34 row(s) — the ones naming a TOTAL:
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - lai_lo_tu_hoat_dong_dau_tu                             [176, 101]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Lãi, lỗ từ hoạt động đầu tư
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - luu_chuyen_tien_tu_hoat_dong_dau_tu_1_tien_chi_de_mua_ [-2, 682]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - II. Lưu chuyển tiền từ hoạt động đầu tư 1.Tiền chi để mua sắm, xây dựng TSCĐ và các tài sản dài
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_chi_dau_tu_gop_von_vao_don_vi_khac                [7, 344]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - 5.Tiền chi đầu tự góp vốn vào đơn vị khác
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_thu_hoi_dau_tu_gop_von_vao_don_vi_khac            [116, 300]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - 6.Tiền thu hồi đầu tư góp vốn vào đơn vị khác
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - luu_chuyen_tien_thuan_tu_hoat_dong_dau_tu              [-2, 610]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Lưu chuyến tiền thuần từ hoạt động đầu tư
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_va_tuong_duong_tien_cuoi_ky_70_50_60161           [2004, 841]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Tiền và tương đương tiến cuối kỳ (70 - 50-60161)
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q3-2013   income_statement
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] reconcile: no profit before tax
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - rows read at [onnx@200], pages [22, 23, 26], 51 row(s) — the ones naming a TOTAL:
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tong_doanh_thu_ban_hang_va_cung_cap_dich_vu_ma_so_01_d [4035381663555, 4037626064181]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - 25- Tổng doanh thu bán hàng và cung cấp dịch vụ (mã số 01) Doanh thu bán hàng
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - lo_tu_hoat_dong_dau_tu_tai_chinh_lo_do_chenh_lech_ty_g [13658368867, 8313304365]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - - Lỗ từ hoạt động đầu tư tài chính Lỗ do chênh lệch tỷ giá đã thực hiện
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - cho_cac_bo_phan_tong_doanh_thu_thuan                   [355545364456, 37547967987]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - cho các bộ phận Tổng doanh thu thuần
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tong_tai_san                                           [897930677424, 4052662270038]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Tổng tài sản
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tong_cong_no                                           [441528035366, None]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Tổng công nợ
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q1-2014   cash_flow
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] reconcile: 188 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300                    ] reconcile: 189 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+pad6+components    ] reconcile: 120 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+join+components    ] reconcile: 26 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+red                ] reconcile: 190 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+red                ] reconcile: 191 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+pad6+annual+extra  ] reconcile: 124 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+joinlost           ] reconcile: 28 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+joinlost+red       ] reconcile: 25 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+joinlost+red       ] reconcile: 33 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@400+deskew             ] reconcile: 34 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - rows read at [onnx@200], pages [5], 34 row(s) — the ones naming a TOTAL:
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - lai_lo_tu_hoat_dong_dau_tu                             [33, 296]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Lãi, lỗ từ hoạt động đầu tư
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - luu_chuyen_tien_tu_hoat_dong_dau_tu_1_tien_chi_de_mua_ [238, 892]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - II. Lưu chuyển tiền từ hoạt động đầu tư 1.Tiền chi để mua sắm, xây dựng TSCĐ và các tài sản dài
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_chi_dau_tu_gop_von_vao_don_vi_khac                [None, None]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - 5.Tiền chi đầu tự góp vốn vào đơn vị khác
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_thu_hoi_dau_tu_gop_von_vao_don_vi_khac            [None, None]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - 6.Tiền thu hồi đầu tư góp vốn vào đơn vị khác
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - luu_chuyen_tien_thuan_tu_hoat_dong_dau_tu              [227, 260]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Lưu chuyển tiền thuần từ hoạt động đầu tư
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_va_tuong_duong_tien_dau_ky                        [125, 390]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Tiền và tương đương tiền đầu kỳ
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_va_tuong_duong_tien_cuoi_ky_70_50_60_61           [195, 257]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Tiền và tương đương tiến cuối kỳ (70 - 50?60-61)
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q1-2014   income_statement
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] reconcile: no profit before tax
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - rows read at [onnx@200], pages [22, 23, 24], 39 row(s) — the ones naming a TOTAL:
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tong_doanh_thu_ban_hang_va_cung_cap_dich_vu_ma_so_01_d [4336279919870, 3797910680620]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - 25- Tổng doanh thu bán hàng và cung cấp dịch vụ (mã số 01) Doanh thu bán hàng
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - lai_tu_dau_tu_tai_chinh                                [None, 105909577391]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - - Lãi từ đầu tư tài chính
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - lo_tu_hoat_dong_dau_tu_tai_chinh_lo_do_chenh_lech_ty_g [6419460116, 10492075197]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - - Lỗ từ hoạt động đầu tư tài chính - Lỗ do chênh lệch tỷ giá đã thực hiện
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - dieu_chinh_chi_phi_thue_thu_nhap_doanh_nghiep_cua_cac_ [160243799955, 93264621288]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Điều chỉnh chi phí thuế thu nhập doanh nghiệp của các năm trước vào chi phí thuế thu nhập hiện h
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q3-2014   cash_flow
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] reconcile: 178 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300                    ] reconcile: 183 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@400                    ] reconcile: 197 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+pad6+components    ] reconcile: 129 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+join+components    ] reconcile: 41 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+red                ] reconcile: 198 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+red                ] reconcile: 195 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+pad6+annual+extra  ] reconcile: 122 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+joinlost           ] reconcile: 54 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+joinlost+red       ] reconcile: 46 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - rows read at [onnx@200], pages [6], 34 row(s) — the ones naming a TOTAL:
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - lai_lo_tu_hoat_dong_dau_tu                             [67, 883]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Lãi, lỗ từ hoạt động đầu tư
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - luu_chuyen_tien_tu_hoat_dong_dau_tu_1_tien_chi_de_mua_ [11, 12]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - II. Lưu chuyển tiền từ hoạt động đầu tư 1.Tiền chi để mua sảm, xây dựng TSCĐ và các tài sản dài
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_chi_dau_tu_gop_von_vao_don_vi_khac                [55, 935]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - 5.Tiền chi đầu tự góp vốn vào đơn vị khác
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_thu_hoi_dau_tu_gop_von_vao_don_vi_khac            [None, 266]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - 6.Tiền thu hồi đầu tư góp vốn vào đơn vị khác
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - luu_chuyen_tien_thuan_tu_hoat_dong_dau_tu              [436, 536]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Lưu chuyển tiền thuần từ hoạt động đầu tư
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_va_tuong_duong_tien_dau_ky                        [125, 493]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Tiền và tương đương tiền đầu kỳ
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_va_tuong_duong_tien_cuoi_ky_70_50_60_61           [1651561, 263]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Tiền và tương đương tiền cuối kỳ (70 - 50-60-61)
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q1-2015   cash_flow
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] reconcile: 168 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300                    ] reconcile: 171 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@400                    ] reconcile: 169 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+pad6+components    ] reconcile: 99 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+join+components    ] reconcile: 12 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+red                ] reconcile: 160 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+pad6+annual+extra  ] reconcile: 101 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+joinlost           ] reconcile: 20 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+joinlost+red       ] reconcile: 11 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+joinlost+red       ] reconcile: 15 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@400+deskew             ] reconcile: 14 figure(s) split across two boxes — this reading is fragmented
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - rows read at [onnx@200], pages [6], 35 row(s) — the ones naming a TOTAL:
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - lai_lo_tu_hoat_dong_dau_tu                             [359, 506]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Lãi, lỗ từ hoạt động đầu tư
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_chi_dau_tu_gop_von_vao_don_vi_khac_6_tien_thu_hoi [213, 148]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - 5.Tiền chi đầu tự góp vốn vào đơn vị khác 6.Tiền thu hồi đầu tư góp vốn vào đơn vị khác 7, Tiền
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - luu_chuyen_tien_thuan_tu_hoat_dong_dau_tu              [533, 135]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Lưu chuyển tiền thuần từ hoạt động đầu tư
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_va_tuong_duong_tien_dau_ky                        [91, 713]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Tiền và tương dương tiền đầu kỳ
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - tien_va_tuong_duong_tien_cuoi_ky_70_50460_61           [4973, 15]
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Tiền và tương dương tiến cuối kỳ (70 - 50460-61)
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q3-2015   income_statement
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] no such statement on any page of this filing
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q3-2016   income_statement
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] no such statement on any page of this filing
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q3-2017   income_statement
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] no such statement on any page of this filing
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+title+loose        ] reconcile: no profit before tax
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - rows read at [onnx@200+title+loose], pages [26], 17 row(s) — the ones naming a TOTAL:
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q3-2019   income_statement
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] no such statement on any page of this filing
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q3-2020   income_statement
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] no such statement on any page of this filing
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q3-2021   income_statement
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] no such statement on any page of this filing
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+title              ] reconcile: only 2 rows parsed
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+title+red          ] reconcile: only 4 rows parsed
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - rows read at [onnx@200+title], pages [13], 2 row(s) — the ones naming a TOTAL:
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q1-2022   income_statement
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] no such statement on any page of this filing
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q2-2022   income_statement
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] no such statement on any page of this filing
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200+title              ] reconcile: only 11 rows parsed
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - rows read at [onnx@200+title], pages [27], 11 row(s) — the ones naming a TOTAL:
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q3-2022   income_statement
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] no such statement on any page of this filing
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q3-2023   income_statement
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] no such statement on any page of this filing
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q3-2024   income_statement
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] no such statement on any page of this filing
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@300+title+red          ] reconcile: no profit before tax
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - rows read at [onnx@300+title+red], pages [27], 13 row(s) — the ones naming a TOTAL:
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - Q3-2025   income_statement
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - [onnx@200                    ] no such statement on any page of this filing
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - ── pages the READ had to turn ──────────────────────────────
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - page 11: text lines are vertical (29/29 boxes) — reading it at /Rotate 90
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - page 28: text lines are vertical (25/25 boxes) — reading it at /Rotate 90
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - page 29: text lines are vertical (33/33 boxes) — reading it at /Rotate 90
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - page 40: text lines are vertical (20/20 boxes) — reading it at /Rotate 90
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - page 4: text lines are vertical (27/34 boxes) — reading it at /Rotate 90
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - page 14: text lines are vertical (43/51 boxes) — reading it at /Rotate 90
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - page 15: text lines are vertical (18/24 boxes) — reading it at /Rotate 90
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - page 16: text lines are vertical (21/28 boxes) — reading it at /Rotate 90
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - page 28: text lines are vertical (79/86 boxes) — reading it at /Rotate 90
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - page 26: text lines are vertical (20/20 boxes) — reading it at /Rotate 90
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - page 17: text lines are vertical (21/21 boxes) — reading it at /Rotate 90
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - page 26: text lines are vertical (65/87 boxes) — reading it at /Rotate 90
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - ── the MERGE decided ───────────────────────────────────────
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q4-2008   balance_sheet      [onnx@200] 54 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - ⚠️  ⚠️ WRITTEN UNGUARDED — the magnitude band was EMPTY, so `sane` failed open and this figure passed no magnitude guard. Screen it by arithmetic (two statements agreeing, a printed subtotal closing) before quoting it
# ...
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q1-2017   cash_flow          [onnx@200+relax] 21 items        recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q1-2017   income_statement   [onnx@200] 19 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q2-2017   balance_sheet      [onnx@200] 65 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q2-2017   cash_flow          [onnx@200+relax] 22 items        recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q2-2017   income_statement   [onnx@200] 18 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - ⚠️  de-cumulated: 6-month figure minus Q1-2017 -> the standalone quarter, 18 of 20 columns
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q4-2017   balance_sheet      [onnx@200] 64 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q4-2017   cash_flow          [onnx@200+tail+relax] 23 items   recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - skip   Q4-2017   income_statement   [onnx@200] 19 items              cumulative income statement — cannot de-cumulate here because Q3-2017 is `absent` on disk. Q1..Q3-2017 WERE filed, so a full `build()` can still subtract them
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q1-2018   balance_sheet      [onnx@200] 66 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q1-2018   cash_flow          [onnx@200+relax] 18 items        recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q1-2018   income_statement   [onnx@200] 18 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q2-2018   balance_sheet      [onnx@200] 65 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q2-2018   cash_flow          [onnx@200+tail+relax] 22 items   recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q2-2018   income_statement   [onnx@200] 15 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - ⚠️  de-cumulated: 6-month figure minus Q1-2018 -> the standalone quarter, 15 of 17 columns
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q3-2018   balance_sheet      [onnx@200] 67 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q3-2018   cash_flow          [onnx@200+relax] 19 items        recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q3-2018   income_statement   [onnx@200] 18 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q4-2018   balance_sheet      [onnx@200] 65 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q4-2018   cash_flow          [onnx@200+tail+relax] 22 items   recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q4-2018   income_statement   [onnx@200] 15 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - ⚠️  de-cumulated: 12-month figure minus Q1-2018, Q2-2018, Q3-2018 -> the standalone quarter, 15 of 17 columns
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q1-2019   balance_sheet      [onnx@200] 67 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q1-2019   cash_flow          [onnx@200+relax] 18 items        recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q1-2019   income_statement   [onnx@200] 17 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q2-2019   balance_sheet      [onnx@200] 66 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q2-2019   cash_flow          [onnx@200+tail+relax] 21 items   recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q2-2019   income_statement   [onnx@200] 14 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - ⚠️  de-cumulated: 6-month figure minus Q1-2019 -> the standalone quarter, 14 of 16 columns
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q4-2019   balance_sheet      [onnx@300] 66 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q4-2019   cash_flow          [onnx@200+tail+relax] 21 items   recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - skip   Q4-2019   income_statement   [onnx@200] 18 items              cumulative income statement — cannot de-cumulate here because Q3-2019 is `absent` on disk. Q1..Q3-2019 WERE filed, so a full `build()` can still subtract them
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q1-2020   balance_sheet      [onnx@200] 67 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q1-2020   cash_flow          [onnx@200+relax] 17 items        recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q1-2020   income_statement   [onnx@200] 17 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q2-2020   balance_sheet      [onnx@200+codecol] 66 items      recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q2-2020   cash_flow          [onnx@300+pad6+annual+extra] 21 items recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q2-2020   income_statement   [onnx@200] 15 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - ⚠️  de-cumulated: 6-month figure minus Q1-2020 -> the standalone quarter, 15 of 18 columns
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q4-2020   balance_sheet      [onnx@200] 66 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q4-2020   cash_flow          [onnx@200+pad6+annual+extra] 19 items recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - skip   Q4-2020   income_statement   [onnx@200] 17 items              cumulative income statement — cannot de-cumulate here because Q3-2020 is `absent` on disk. Q1..Q3-2020 WERE filed, so a full `build()` can still subtract them
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q1-2021   balance_sheet      [onnx@200] 68 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q1-2021   cash_flow          [onnx@200+tail+relax] 24 items   recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q1-2021   income_statement   [onnx@200] 17 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q2-2021   balance_sheet      [onnx@200] 66 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q2-2021   cash_flow          [onnx@200+relax] 22 items        recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q2-2021   income_statement   [onnx@300] 11 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - ⚠️  de-cumulated: 6-month figure minus Q1-2021 -> the standalone quarter, 11 of 16 columns; ⚠️ 4 column(s) DROPPED — the year-to-date's own subtotals contradict it — one term of its identity is misread in the SOURCE
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q4-2021   balance_sheet      [onnx@200] 63 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q4-2021   cash_flow          [onnx@200+tail+relax] 22 items   recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - skip   Q4-2021   income_statement   [onnx@200] 18 items              cumulative income statement — cannot de-cumulate here because Q3-2021 is `absent` on disk. Q1..Q3-2021 WERE filed, so a full `build()` can still subtract them
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q4-2022   balance_sheet      [onnx@200+tail] 63 items         recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q4-2022   cash_flow          [onnx@200+relax] 22 items        recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - skip   Q4-2022   income_statement   [onnx@200] 16 items              cumulative income statement — cannot de-cumulate here because Q1-2022 is `absent` on disk. Q1..Q3-2022 WERE filed, so a full `build()` can still subtract them
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q1-2023   balance_sheet      [onnx@200] 66 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q1-2023   cash_flow          [onnx@200+relax] 18 items        recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q1-2023   income_statement   [onnx@200] 18 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q2-2023   balance_sheet      [onnx@200] 62 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q2-2023   cash_flow          [onnx@200+relax] 21 items        recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q2-2023   income_statement   [onnx@300] 15 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - ⚠️  de-cumulated: 6-month figure minus Q1-2023 -> the standalone quarter, 15 of 17 columns
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q4-2023   balance_sheet      [onnx@300] 63 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q4-2023   cash_flow          [onnx@400+loose+relax] 21 items  recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - skip   Q4-2023   income_statement   [onnx@200] 17 items              cumulative income statement — cannot de-cumulate here because Q3-2023 is `absent` on disk. Q1..Q3-2023 WERE filed, so a full `build()` can still subtract them
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q1-2024   balance_sheet      [onnx@200] 64 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q1-2024   cash_flow          [onnx@200+relax] 17 items        recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q1-2024   income_statement   [onnx@200] 18 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q2-2024   balance_sheet      [onnx@200] 63 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q2-2024   cash_flow          [onnx@200+relax] 21 items        recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q2-2024   income_statement   [onnx@200+tail] 14 items         recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - ⚠️  de-cumulated: 6-month figure minus Q1-2024 -> the standalone quarter, 14 of 16 columns
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q4-2024   balance_sheet      [onnx@200] 64 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q4-2024   cash_flow          [onnx@200+tail+relax] 22 items   recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - skip   Q4-2024   income_statement   [onnx@200] 17 items              cumulative income statement — cannot de-cumulate here because Q3-2024 is `absent` on disk. Q1..Q3-2024 WERE filed, so a full `build()` can still subtract them
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q1-2025   balance_sheet      [onnx@200] 63 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q1-2025   cash_flow          [onnx@200+relax] 18 items        recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q1-2025   income_statement   [onnx@200] 19 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q2-2025   balance_sheet      [onnx@200] 61 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q2-2025   cash_flow          [onnx@200] 20 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q2-2025   income_statement   [onnx@200] 15 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - ⚠️  de-cumulated: 6-month figure minus Q1-2025 -> the standalone quarter, 15 of 17 columns
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q4-2025   balance_sheet      [onnx@200] 65 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q4-2025   cash_flow          [onnx@200] 22 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - skip   Q4-2025   income_statement   [onnx@200] 17 items              cumulative income statement — cannot de-cumulate here because Q3-2025 is `absent` on disk. Q1..Q3-2025 WERE filed, so a full `build()` can still subtract them
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q1-2026   balance_sheet      [onnx@200] 69 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q1-2026   cash_flow          [onnx@200+relax] 21 items        recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - WRITE  Q1-2026   income_statement   [onnx@200] 17 items              recovers a quarter disk records as `absent`
#  93.1% - step 7/10 HOSE_HPG 65q - refused vs written - -> 106 statement(s) written, 17 refused or planned only

# %% [markdown]
# ## 9 · The merge — one period at a time, oldest first, and UNFORCED

# %%
# ── THE MERGE — one period at a time, oldest first, and UNFORCED ──────────
# ⚠️ WHY NOT ONE CALL OVER THE FOLDER: `merge_run` runs `plan_merge` against disk FIRST and
# `_write` afterwards, so every decision in one call is taken against the SAME disk state.
# `_quarter_priors` reads a prior's `months` from that state, so the span a Q3 records reaches
# Q4's planner only in the NEXT call. That is `SPN-1`'s dependency, and it is why a batch that
# re-parses a span operand AND the Q4 it unblocks must merge them separately, oldest first.
# ⚠️ AND NOTHING HERE LIFTS A REFUSAL. `force_differs` is not passed, so a reading that
# disagrees with disk is refused exactly as it would be by default — which is the honest
# outcome, not a failure of this cell. `REPAIR` in §11 is the scoped escape.
# ⚠️ ONE BACKUP PER TICKER, taken by the first call that actually writes.
NB.begin("upsert", f"apply={MERGE_APPLY}   one period at a time, oldest first")
with NB.capture(nested=True):
    from web_scraper import pdf_ocr_batch                  # noqa: E402

    if not MERGE_TWO_PASS:
        print("MERGE_TWO_PASS = False — nothing was merged.")
    elif not FOLDERS:
        print("no run folder to merge — run the cells above first.")
    else:
        # ⚠️ `force_empty_band` IS NOT THE WHOLE ANSWER ANY MORE, so printing it alone
        # would understate what this pass will write. `merge_batch` lifts the band refusal
        # for any quarter whose filing produced ALL THREE statements — the same rule §6's
        # per-quarter write applies, so the two writers cannot disagree about one quarter —
        # and this flag governs only what that gate does not cover.
        print(f"       force_differs=False   force_empty_band={FORCE_EMPTY_BAND}"
              "   (+ always, for a quarter with all three statements)")
        print(f"       reports={MERGE_REPORTS or 'all three'}")
        # ⚠️ WHAT THIS PASS IS FOR ONCE §6 HAS ALREADY WRITTEN. Not a second write: every
        # quarter §6 landed is re-planned against disk and comes back `identical to the row
        # already on disk`, which is a CHECK. What it picks up is what §6 HELD — a filing that
        # produced two statements of three, a document whose layers RAISED — and any quarter
        # whose span operand only landed later in the run.
        if MERGE_EACH and ENVIRONMENT == "LOCAL" and ISOLATE_DOCUMENTS:
            print("       ⚠️ MERGE_EACH already wrote every quarter whose filing produced all "
                  "three")
            print("          statements. This is the SWEEP: those come back `identical to the "
                  "row")
            print("          already on disk`, and what §6 HELD is what this writes.")
        print()
        TALLY = pdf_ocr_batch.merge_batch(
            FOLDERS, apply=MERGE_APPLY, reports=MERGE_REPORTS,
            force_empty_band=FORCE_EMPTY_BAND)
        print()
        if not MERGE_APPLY:
            print("nothing was written. Set MERGE_APPLY = True to apply the plan above.")
            print("⚠️ AND THE PLAN ABOVE UNDERSTATES IT, BY CONSTRUCTION: with nothing written, a")
            print("   later period is planned against a span the earlier one has not "
                  "recorded yet,")
            print("   and reports the refusal it always would. A dry run cannot show a "
                  "second pass")
            print("   that depends on the first.")
        elif TALLY["written"]:
            print(f"{TALLY['written']} statement(s) reached raw_data/.../statements/ — §10 reads")
            print("the CSVs themselves, which is the only place the two can be told apart.")
        elif TALLY.get("already"):
            # ⚠️ **"0 WRITTEN" IS THE NORMAL OUTCOME OF THIS PASS ONCE §6 HAS ALREADY WRITTEN,
            # AND IT MUST NOT READ AS THE ALARM BELOW.** The branch after this one is `BND-1`'s
            # siren — a run that parsed and landed nothing — and printing it over a ticker
            # whose every quarter is on disk would train a reader to ignore the one message
            # that matters. What tells them apart is `already`: a statement re-planned against
            # disk and found unchanged is a CHECK that passed, not a refusal.
            print(f"0 written, {TALLY['already']} statement(s) already on disk unchanged — "
                  f"this pass")
            print("re-planned what §6 wrote and agreed with it. That is the sweep doing its "
                  "job.")
            if TALLY["skipped"]:
                print(f"⚠️ {TALLY['skipped']} statement(s) WERE refused — §8 says which and "
                      f"why. Those are the")
                print("   quarters §6 held back: a filing that produced two statements of "
                      "three.")
        else:
            # ⚠️ "THE RUN FINISHED" AND "THE CSV CHANGED" ARE DIFFERENT FACTS, and only the
            # second was ever the point. Read back from each folder's own `merge` block — the
            # structured record `record_merge` has just written — rather than from the lines
            # above, so this reports what a later reader gets and not what this cell printed.
            import collections                                # noqa: E402

            print("⚠️ NOTHING REACHED raw_data/.../statements/. Every accepted statement was")
            print("   refused, and these are the refusals, most common first:")
            WHY = collections.Counter(
                (_d["reason"] or "").split(" — ")[0].split(" because ")[0][:64]
                for _f in FOLDERS
                for _ev in (json.loads((Path(_f) / "metadata.json").read_text(encoding="utf-8"))
                            .get("merge") or {}).get("events", []) if _ev["applied"]
                for _d in _ev["decisions"] if _d["action"] != "write")
            for _reason, _n in (WHY.most_common(6)
                                or [("(no merge block — nothing was planned)", 0)]):
                print(f"     {_n:>4}  {_reason}")
            # ⚠️ THE ONE REFUSAL THAT CLOSES ON ITSELF — and since 2026-09-06 a quarter
            # with all three statements is past it before this branch can be reached, so
            # anything left here is a filing that produced TWO of three (or none).
            if any("band" in _r for _r in WHY):
                print("   ⚠️ `sane` band EMPTY is `BND-1`, and it is a LOOP: this ticker has no")
                print("      `pdf` row on disk, so `seed_history` builds no magnitude band, so")
                print("      every statement is refused, so there is still no CSV.")
                print("      ⚠️ A QUARTER WHOSE FILING PRODUCED ALL THREE STATEMENTS IS ALREADY "
                      "PAST THIS")
                print("         — both writers lift the band for it. What is refused here "
                      "produced two")
                print("         of three, which is a judgement about THAT filing and stays "
                      "yours: §8 says")
                print("         which statement is missing and why, and FORCE_EMPTY_BAND = True "
                      "writes the")
                print("         other two anyway. It LIFTS A REAL GUARD, so screen the figures "
                      "by arithmetic")
                print("         first (two statements agreeing on one figure, a printed subtotal")
                print("         closing) before quoting any of them.")
NB.end()
# Out:
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - apply=True   one period at a time, oldest first
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - force_differs=False   force_empty_band=False   (+ always, for a quarter with all three statements)
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - reports=all three
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - ⚠️ MERGE_EACH already wrote every quarter whose filing produced all three
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - statements. This is the SWEEP: those come back `identical to the row
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - already on disk`, and what §6 HELD is what this writes.
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - APPLY — 65 (ticker, period) pass(es), oldest first
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2008   balance_sheet      [onnx@200] 54 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2008   cash_flow          [onnx@200+relax] 24 items        identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2008   income_statement   [onnx@200] 18 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2009   balance_sheet      [onnx@200] 55 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2009   cash_flow          [onnx@200+title] 30 items        identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2009   income_statement   [onnx@200] 18 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG balance_sheet: 42 quarters (Q4-2008..Q1-2026), 42 parsed, 0 missing, 56 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG income_statement: 42 quarters (Q4-2008..Q1-2026), 24 parsed, 18 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG cash_flow: 42 quarters (Q4-2008..Q1-2026), 42 parsed, 0 missing, 28 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q4-2009   balance_sheet      [onnx@200] 56 items              recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q4-2009   cash_flow          [onnx@200] 28 items              recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2009   income_statement                                    absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - backup: D:\GIT\master-thesis\raw_data\_backup\statements\20260908-025253__HOSE_HPG
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - written: {'balance_sheet': 42, 'income_statement': 24, 'cash_flow': 42}
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - backup: D:\GIT\master-thesis\raw_data\_backup\statements\20260908-025253__HOSE_HPG
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2010   balance_sheet      [onnx@200] 51 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2010   cash_flow          [onnx@200+relax] 17 items        identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2010   income_statement   [onnx@200] 16 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG balance_sheet: 43 quarters (Q4-2008..Q1-2026), 43 parsed, 0 missing, 59 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG income_statement: 43 quarters (Q4-2008..Q1-2026), 25 parsed, 18 missing, 16 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG cash_flow: 43 quarters (Q4-2008..Q1-2026), 42 parsed, 1 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q1-2011   balance_sheet      [onnx@200] 59 items              recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2011   cash_flow                                           absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q1-2011   income_statement   [onnx@200+bycol] 16 items        recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - backup: — (taken earlier in this run)
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - written: {'balance_sheet': 43, 'income_statement': 25, 'cash_flow': 42}
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG balance_sheet: 43 quarters (Q4-2008..Q1-2026), 43 parsed, 0 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG income_statement: 43 quarters (Q4-2008..Q1-2026), 26 parsed, 17 missing, 14 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG cash_flow: 43 quarters (Q4-2008..Q1-2026), 42 parsed, 1 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2011   balance_sheet      [onnx@200] 51 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2011   cash_flow          [onnx@300] 18 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q2-2011   income_statement   [onnx@200] 14 items              recovers a quarter disk records as `missing`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - ⚠️  de-cumulated: 6-month figure minus Q1-2011 -> the standalone quarter, 14 of 15 columns
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - backup: — (taken earlier in this run)
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - written: {'balance_sheet': 43, 'income_statement': 26, 'cash_flow': 42}
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG balance_sheet: 44 quarters (Q4-2008..Q1-2026), 44 parsed, 0 missing, 59 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG income_statement: 44 quarters (Q4-2008..Q1-2026), 26 parsed, 18 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG cash_flow: 44 quarters (Q4-2008..Q1-2026), 42 parsed, 2 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q3-2011   balance_sheet      [onnx@300] 59 items              recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q3-2011   cash_flow                                           absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q3-2011   income_statement                                    absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - backup: — (taken earlier in this run)
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - written: {'balance_sheet': 44, 'income_statement': 26, 'cash_flow': 42}
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG balance_sheet: 45 quarters (Q4-2008..Q1-2026), 45 parsed, 0 missing, 52 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG income_statement: 45 quarters (Q4-2008..Q1-2026), 26 parsed, 19 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG cash_flow: 45 quarters (Q4-2008..Q1-2026), 43 parsed, 2 missing, 23 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q4-2011   balance_sheet      [onnx@200] 52 items              recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q4-2011   cash_flow          [onnx@200+relax] 23 items        recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2011   income_statement                                    absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - backup: — (taken earlier in this run)
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - written: {'balance_sheet': 45, 'income_statement': 26, 'cash_flow': 43}
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG balance_sheet: 46 quarters (Q4-2008..Q1-2026), 46 parsed, 0 missing, 60 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG income_statement: 46 quarters (Q4-2008..Q1-2026), 26 parsed, 20 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG cash_flow: 46 quarters (Q4-2008..Q1-2026), 43 parsed, 3 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q1-2012   balance_sheet      [onnx@200+red] 60 items          recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2012   cash_flow                                           absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2012   income_statement                                    absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - backup: — (taken earlier in this run)
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - written: {'balance_sheet': 46, 'income_statement': 26, 'cash_flow': 43}
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2012   balance_sheet      [onnx@200] 49 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2012   cash_flow          [onnx@300+relax] 20 items        identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2012   income_statement   [onnx@200] 13 items              cumulative income statement — cannot de-cumulate here because Q1-2012 is `missing` on disk. Q1..Q1-2012 WERE filed, so a full `build()` can still subtract them
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG balance_sheet: 47 quarters (Q4-2008..Q1-2026), 47 parsed, 0 missing, 55 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG income_statement: 47 quarters (Q4-2008..Q1-2026), 27 parsed, 20 missing, 6 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG cash_flow: 47 quarters (Q4-2008..Q1-2026), 43 parsed, 4 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q3-2012   balance_sheet      [onnx@200+red] 55 items          recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q3-2012   cash_flow                                           absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q3-2012   income_statement   [onnx@200+tail] 6 items          recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - backup: — (taken earlier in this run)
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - written: {'balance_sheet': 47, 'income_statement': 27, 'cash_flow': 43}
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG balance_sheet: 48 quarters (Q4-2008..Q1-2026), 48 parsed, 0 missing, 52 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG income_statement: 48 quarters (Q4-2008..Q1-2026), 27 parsed, 21 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG cash_flow: 48 quarters (Q4-2008..Q1-2026), 43 parsed, 5 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q4-2012   balance_sheet      [onnx@300] 52 items              recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2012   cash_flow                                           absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2012   income_statement   [onnx@200] 13 items              cumulative income statement — cannot de-cumulate here because Q1-2012 is `missing` on disk. Q1..Q3-2012 WERE filed, so a full `build()` can still subtract them
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - backup: — (taken earlier in this run)
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - written: {'balance_sheet': 48, 'income_statement': 27, 'cash_flow': 43}
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG balance_sheet: 49 quarters (Q4-2008..Q1-2026), 49 parsed, 0 missing, 58 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG income_statement: 49 quarters (Q4-2008..Q1-2026), 27 parsed, 22 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG cash_flow: 49 quarters (Q4-2008..Q1-2026), 43 parsed, 6 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q1-2013   balance_sheet      [onnx@200] 58 items              recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2013   cash_flow                                           absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2013   income_statement                                    absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - backup: — (taken earlier in this run)
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - written: {'balance_sheet': 49, 'income_statement': 27, 'cash_flow': 43}
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2013   balance_sheet      [onnx@200] 47 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2013   cash_flow          [onnx@200+relax] 20 items        identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2013   income_statement   [onnx@200] 14 items              cumulative income statement — cannot de-cumulate here because Q1-2013 is `missing` on disk. Q1..Q1-2013 WERE filed, so a full `build()` can still subtract them
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG balance_sheet: 50 quarters (Q4-2008..Q1-2026), 50 parsed, 0 missing, 56 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG income_statement: 50 quarters (Q4-2008..Q1-2026), 27 parsed, 23 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG cash_flow: 50 quarters (Q4-2008..Q1-2026), 43 parsed, 7 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q3-2013   balance_sheet      [onnx@200] 56 items              recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q3-2013   cash_flow                                           absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q3-2013   income_statement                                    absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - backup: — (taken earlier in this run)
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - written: {'balance_sheet': 50, 'income_statement': 27, 'cash_flow': 43}
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2013   balance_sheet      [onnx@200] 47 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2013   cash_flow          [onnx@200+relax] 21 items        identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2013   income_statement   [onnx@200] 16 items              cumulative income statement — cannot de-cumulate here because Q1-2013 is `missing` on disk. Q1..Q3-2013 WERE filed, so a full `build()` can still subtract them
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG balance_sheet: 51 quarters (Q4-2008..Q1-2026), 51 parsed, 0 missing, 59 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG income_statement: 51 quarters (Q4-2008..Q1-2026), 27 parsed, 24 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG cash_flow: 51 quarters (Q4-2008..Q1-2026), 43 parsed, 8 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q1-2014   balance_sheet      [onnx@200] 59 items              recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2014   cash_flow                                           absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2014   income_statement                                    absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - backup: — (taken earlier in this run)
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - written: {'balance_sheet': 51, 'income_statement': 27, 'cash_flow': 43}
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2014   balance_sheet      [onnx@200] 46 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2014   cash_flow          [onnx@200+total+relax] 20 items  identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2014   income_statement   [onnx@200] 14 items              cumulative income statement — cannot de-cumulate here because Q1-2014 is `missing` on disk. Q1..Q1-2014 WERE filed, so a full `build()` can still subtract them
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG balance_sheet: 52 quarters (Q4-2008..Q1-2026), 52 parsed, 0 missing, 59 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG income_statement: 52 quarters (Q4-2008..Q1-2026), 28 parsed, 24 missing, 5 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG cash_flow: 52 quarters (Q4-2008..Q1-2026), 43 parsed, 9 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q3-2014   balance_sheet      [onnx@200+join+components] 59 items recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q3-2014   cash_flow                                           absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q3-2014   income_statement   [onnx@200+equity] 5 items        recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - backup: — (taken earlier in this run)
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - written: {'balance_sheet': 52, 'income_statement': 28, 'cash_flow': 43}
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2014   balance_sheet      [onnx@200] 46 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2014   cash_flow          [onnx@200+relax] 18 items        identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2014   income_statement   [onnx@200] 16 items              cumulative income statement — cannot de-cumulate here because Q1-2014 is `missing` on disk. Q1..Q3-2014 WERE filed, so a full `build()` can still subtract them
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG balance_sheet: 53 quarters (Q4-2008..Q1-2026), 53 parsed, 0 missing, 77 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG income_statement: 53 quarters (Q4-2008..Q1-2026), 29 parsed, 24 missing, 9 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG cash_flow: 53 quarters (Q4-2008..Q1-2026), 43 parsed, 10 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q1-2015   balance_sheet      [onnx@200+join+components] 77 items recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2015   cash_flow                                           absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q1-2015   income_statement   [onnx@200+pad6+components] 9 items recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - backup: — (taken earlier in this run)
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - written: {'balance_sheet': 53, 'income_statement': 29, 'cash_flow': 43}
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG balance_sheet: 53 quarters (Q4-2008..Q1-2026), 53 parsed, 0 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG income_statement: 53 quarters (Q4-2008..Q1-2026), 30 parsed, 23 missing, 3 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG cash_flow: 53 quarters (Q4-2008..Q1-2026), 43 parsed, 10 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2015   balance_sheet      [onnx@200] 64 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2015   cash_flow          [onnx@300+relax] 20 items        identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q2-2015   income_statement   [onnx@200] 3 items               recovers a quarter disk records as `missing`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - ⚠️  de-cumulated: 6-month figure minus Q1-2015 -> the standalone quarter, 3 of 20 columns; ⚠️ 6 column(s) DROPPED — an operand's sign convention could not be measured; repairing that prior restores this column
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - backup: — (taken earlier in this run)
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - written: {'balance_sheet': 53, 'income_statement': 30, 'cash_flow': 43}
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG balance_sheet: 54 quarters (Q4-2008..Q1-2026), 54 parsed, 0 missing, 61 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG income_statement: 54 quarters (Q4-2008..Q1-2026), 30 parsed, 24 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG cash_flow: 54 quarters (Q4-2008..Q1-2026), 44 parsed, 10 missing, 24 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q3-2015   balance_sheet      [onnx@300] 61 items              recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q3-2015   cash_flow          [onnx@200+relax] 24 items        recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q3-2015   income_statement                                    absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - backup: — (taken earlier in this run)
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - written: {'balance_sheet': 54, 'income_statement': 30, 'cash_flow': 44}
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2015   balance_sheet      [onnx@200] 64 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2015   cash_flow          [onnx@200+tail+relax] 21 items   identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2015   income_statement   [onnx@200] 19 items              cumulative income statement — cannot de-cumulate here because Q3-2015 is `missing` on disk. Q1..Q3-2015 WERE filed, so a full `build()` can still subtract them
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2016   balance_sheet      [onnx@200+tail] 66 items         identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2016   cash_flow          [onnx@200+tail+relax] 23 items   identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2016   income_statement   [onnx@200] 18 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2016   balance_sheet      [onnx@200] 66 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2016   cash_flow          [onnx@400+loose+relax] 20 items  identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2016   income_statement   [onnx@200] 16 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG balance_sheet: 55 quarters (Q4-2008..Q1-2026), 55 parsed, 0 missing, 66 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG income_statement: 55 quarters (Q4-2008..Q1-2026), 30 parsed, 25 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG cash_flow: 55 quarters (Q4-2008..Q1-2026), 45 parsed, 10 missing, 19 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q3-2016   balance_sheet      [onnx@200+tail] 66 items         recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q3-2016   cash_flow          [onnx@200+relax] 19 items        recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q3-2016   income_statement                                    absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - backup: — (taken earlier in this run)
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - written: {'balance_sheet': 55, 'income_statement': 30, 'cash_flow': 45}
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2016   balance_sheet      [onnx@200+tail] 53 items         identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2016   cash_flow          [onnx@400+loose+relax] 20 items  identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2016   income_statement   [onnx@200] 19 items              cumulative income statement — cannot de-cumulate here because Q3-2016 is `missing` on disk. Q1..Q3-2016 WERE filed, so a full `build()` can still subtract them
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2017   balance_sheet      [onnx@200] 67 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2017   cash_flow          [onnx@200+relax] 21 items        identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2017   income_statement   [onnx@200] 19 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2017   balance_sheet      [onnx@200] 65 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2017   cash_flow          [onnx@200+relax] 22 items        identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2017   income_statement   [onnx@200] 18 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG balance_sheet: 56 quarters (Q4-2008..Q1-2026), 56 parsed, 0 missing, 63 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG income_statement: 56 quarters (Q4-2008..Q1-2026), 30 parsed, 26 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG cash_flow: 56 quarters (Q4-2008..Q1-2026), 46 parsed, 10 missing, 19 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q3-2017   balance_sheet      [onnx@200+tail] 63 items         recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q3-2017   cash_flow          [onnx@200+relax] 19 items        recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q3-2017   income_statement                                    absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - backup: — (taken earlier in this run)
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - written: {'balance_sheet': 56, 'income_statement': 30, 'cash_flow': 46}
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2017   balance_sheet      [onnx@200] 64 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2017   cash_flow          [onnx@200+tail+relax] 23 items   identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2017   income_statement   [onnx@200] 19 items              cumulative income statement — cannot de-cumulate here because Q3-2017 is `missing` on disk. Q1..Q3-2017 WERE filed, so a full `build()` can still subtract them
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2018   balance_sheet      [onnx@200] 66 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2018   cash_flow          [onnx@200+relax] 18 items        identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2018   income_statement   [onnx@200] 18 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2018   balance_sheet      [onnx@200] 65 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2018   cash_flow          [onnx@200+tail+relax] 22 items   identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2018   income_statement   [onnx@200] 15 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q3-2018   balance_sheet      [onnx@200] 67 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q3-2018   cash_flow          [onnx@200+relax] 19 items        identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q3-2018   income_statement   [onnx@200] 18 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2018   balance_sheet      [onnx@200] 65 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2018   cash_flow          [onnx@200+tail+relax] 22 items   identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2018   income_statement   [onnx@200] 15 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2019   balance_sheet      [onnx@200] 67 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2019   cash_flow          [onnx@200+relax] 18 items        identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2019   income_statement   [onnx@200] 17 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2019   balance_sheet      [onnx@200] 66 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2019   cash_flow          [onnx@200+tail+relax] 21 items   identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2019   income_statement   [onnx@200] 14 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG balance_sheet: 57 quarters (Q4-2008..Q1-2026), 57 parsed, 0 missing, 67 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG income_statement: 57 quarters (Q4-2008..Q1-2026), 30 parsed, 27 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG cash_flow: 57 quarters (Q4-2008..Q1-2026), 47 parsed, 10 missing, 18 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q3-2019   balance_sheet      [onnx@200] 67 items              recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q3-2019   cash_flow          [onnx@200+relax] 18 items        recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q3-2019   income_statement                                    absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - backup: — (taken earlier in this run)
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - written: {'balance_sheet': 57, 'income_statement': 30, 'cash_flow': 47}
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2019   balance_sheet      [onnx@300] 66 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2019   cash_flow          [onnx@200+tail+relax] 21 items   identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2019   income_statement   [onnx@200] 18 items              cumulative income statement — cannot de-cumulate here because Q3-2019 is `missing` on disk. Q1..Q3-2019 WERE filed, so a full `build()` can still subtract them
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2020   balance_sheet      [onnx@200] 67 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2020   cash_flow          [onnx@200+relax] 17 items        identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2020   income_statement   [onnx@200] 17 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2020   balance_sheet      [onnx@200+codecol] 66 items      identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2020   cash_flow          [onnx@300+pad6+annual+extra] 21 items identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2020   income_statement   [onnx@200] 15 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG balance_sheet: 58 quarters (Q4-2008..Q1-2026), 58 parsed, 0 missing, 69 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG income_statement: 58 quarters (Q4-2008..Q1-2026), 30 parsed, 28 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG cash_flow: 58 quarters (Q4-2008..Q1-2026), 48 parsed, 10 missing, 17 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q3-2020   balance_sheet      [onnx@200] 69 items              recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q3-2020   cash_flow          [onnx@200+relax] 17 items        recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q3-2020   income_statement                                    absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - backup: — (taken earlier in this run)
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - written: {'balance_sheet': 58, 'income_statement': 30, 'cash_flow': 48}
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2020   balance_sheet      [onnx@200] 66 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2020   cash_flow          [onnx@200+pad6+annual+extra] 19 items identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2020   income_statement   [onnx@200] 17 items              cumulative income statement — cannot de-cumulate here because Q3-2020 is `missing` on disk. Q1..Q3-2020 WERE filed, so a full `build()` can still subtract them
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2021   balance_sheet      [onnx@200] 68 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2021   cash_flow          [onnx@200+tail+relax] 24 items   identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2021   income_statement   [onnx@200] 17 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2021   balance_sheet      [onnx@200] 66 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2021   cash_flow          [onnx@200+relax] 22 items        identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2021   income_statement   [onnx@300] 11 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG balance_sheet: 59 quarters (Q4-2008..Q1-2026), 59 parsed, 0 missing, 68 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG income_statement: 59 quarters (Q4-2008..Q1-2026), 30 parsed, 29 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
# ...
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q1-2022   balance_sheet      [onnx@200] 67 items              recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q1-2022   cash_flow          [onnx@200+relax] 18 items        recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2022   income_statement                                    absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - backup: — (taken earlier in this run)
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - written: {'balance_sheet': 60, 'income_statement': 30, 'cash_flow': 50}
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG balance_sheet: 61 quarters (Q4-2008..Q1-2026), 61 parsed, 0 missing, 67 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG income_statement: 61 quarters (Q4-2008..Q1-2026), 30 parsed, 31 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG cash_flow: 61 quarters (Q4-2008..Q1-2026), 51 parsed, 10 missing, 19 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q2-2022   balance_sheet      [onnx@200] 67 items              recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q2-2022   cash_flow          [onnx@200+relax] 19 items        recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2022   income_statement                                    absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - backup: — (taken earlier in this run)
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - written: {'balance_sheet': 61, 'income_statement': 30, 'cash_flow': 51}
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG balance_sheet: 62 quarters (Q4-2008..Q1-2026), 62 parsed, 0 missing, 67 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG income_statement: 62 quarters (Q4-2008..Q1-2026), 30 parsed, 32 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG cash_flow: 62 quarters (Q4-2008..Q1-2026), 52 parsed, 10 missing, 18 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q3-2022   balance_sheet      [onnx@200+tail] 67 items         recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q3-2022   cash_flow          [onnx@200+relax] 18 items        recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q3-2022   income_statement                                    absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - backup: — (taken earlier in this run)
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - written: {'balance_sheet': 62, 'income_statement': 30, 'cash_flow': 52}
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2022   balance_sheet      [onnx@200+tail] 63 items         identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2022   cash_flow          [onnx@200+relax] 22 items        identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2022   income_statement   [onnx@200] 16 items              cumulative income statement — cannot de-cumulate here because Q1-2022 is `missing` on disk. Q1..Q3-2022 WERE filed, so a full `build()` can still subtract them
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2023   balance_sheet      [onnx@200] 66 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2023   cash_flow          [onnx@200+relax] 18 items        identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2023   income_statement   [onnx@200] 18 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2023   balance_sheet      [onnx@200] 62 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2023   cash_flow          [onnx@200+relax] 21 items        identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2023   income_statement   [onnx@300] 15 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG balance_sheet: 63 quarters (Q4-2008..Q1-2026), 63 parsed, 0 missing, 66 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG income_statement: 63 quarters (Q4-2008..Q1-2026), 30 parsed, 33 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG cash_flow: 63 quarters (Q4-2008..Q1-2026), 53 parsed, 10 missing, 18 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q3-2023   balance_sheet      [onnx@200] 66 items              recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q3-2023   cash_flow          [onnx@200+relax] 18 items        recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q3-2023   income_statement                                    absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - backup: — (taken earlier in this run)
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - written: {'balance_sheet': 63, 'income_statement': 30, 'cash_flow': 53}
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2023   balance_sheet      [onnx@300] 63 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2023   cash_flow          [onnx@400+loose+relax] 21 items  identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2023   income_statement   [onnx@200] 17 items              cumulative income statement — cannot de-cumulate here because Q3-2023 is `missing` on disk. Q1..Q3-2023 WERE filed, so a full `build()` can still subtract them
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2024   balance_sheet      [onnx@200] 64 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2024   cash_flow          [onnx@200+relax] 17 items        identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2024   income_statement   [onnx@200] 18 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2024   balance_sheet      [onnx@200] 63 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2024   cash_flow          [onnx@200+relax] 21 items        identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2024   income_statement   [onnx@200+tail] 14 items         identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG balance_sheet: 64 quarters (Q4-2008..Q1-2026), 64 parsed, 0 missing, 66 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG income_statement: 64 quarters (Q4-2008..Q1-2026), 30 parsed, 34 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG cash_flow: 64 quarters (Q4-2008..Q1-2026), 54 parsed, 10 missing, 17 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q3-2024   balance_sheet      [onnx@200] 66 items              recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q3-2024   cash_flow          [onnx@200+relax] 17 items        recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q3-2024   income_statement                                    absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - backup: — (taken earlier in this run)
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - written: {'balance_sheet': 64, 'income_statement': 30, 'cash_flow': 54}
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2024   balance_sheet      [onnx@200] 64 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2024   cash_flow          [onnx@200+tail+relax] 22 items   identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2024   income_statement   [onnx@200] 17 items              cumulative income statement — cannot de-cumulate here because Q3-2024 is `missing` on disk. Q1..Q3-2024 WERE filed, so a full `build()` can still subtract them
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2025   balance_sheet      [onnx@200] 63 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2025   cash_flow          [onnx@200+relax] 18 items        identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2025   income_statement   [onnx@200] 19 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2025   balance_sheet      [onnx@200] 61 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2025   cash_flow          [onnx@200] 20 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q2-2025   income_statement   [onnx@200] 15 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG balance_sheet: 65 quarters (Q4-2008..Q1-2026), 65 parsed, 0 missing, 59 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\balance_sheet\bs_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG income_statement: 65 quarters (Q4-2008..Q1-2026), 30 parsed, 35 missing, 0 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\income_statement\is_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - cafef financials: HPG cash_flow: 65 quarters (Q4-2008..Q1-2026), 55 parsed, 10 missing, 21 line items -> D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp\cash_flow\cf_HOSE_HPG.csv
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q3-2025   balance_sheet      [onnx@200+reseat] 59 items       recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - WRITE  Q3-2025   cash_flow          [onnx@200+relax] 21 items        recovers a quarter disk records as `absent`
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q3-2025   income_statement                                    absent in this run
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - backup: — (taken earlier in this run)
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - written: {'balance_sheet': 65, 'income_statement': 30, 'cash_flow': 55}
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2025   balance_sheet      [onnx@200] 65 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2025   cash_flow          [onnx@200] 22 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q4-2025   income_statement   [onnx@200] 17 items              cumulative income statement — cannot de-cumulate here because Q3-2025 is `missing` on disk. Q1..Q3-2025 WERE filed, so a full `build()` can still subtract them
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2026   balance_sheet      [onnx@200] 69 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2026   cash_flow          [onnx@200+relax] 21 items        identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - skip   Q1-2026   income_statement   [onnx@200] 17 items              identical to the row already on disk
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - nothing to write — every statement was refused, or is already on disk unchanged
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - -> 44 statement(s) written, 106 already on disk unchanged, 45 refused
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - 44 statement(s) reached raw_data/.../statements/ — §10 reads
#  94.0% - step 8/10 HOSE_HPG 65q - merge into the CSVs - the CSVs themselves, which is the only place the two can be told apart.

# %% [markdown]
# ## 10 · Did it land? — the statement CSVs themselves

# %%
# ── DID IT LAND? — the statement CSVs themselves ───────────────────────────
# ⚠️ Everything above reports what some process DECIDED; this reads what is on disk. The two
# came apart on a Kaggle round trip that finished green, wrote a complete run folder and created
# no CSV at all (`BND-1`, HOSE_BSR and again HOSE_CTG) — and no amount of log reading would have
# said so, because the merge that refused everything ran on the other machine.
NB.begin("landed", "the statement CSVs themselves — not what a process decided")
with NB.capture(nested=True):
    import csv                                            # noqa: E402

    from web_scraper import cafef_financials as fin       # noqa: E402

    # ⚠️ `CWD-1`, AND THIS CELL WALKED STRAIGHT INTO IT. `statement_path()` reads
    # `fin.STATEMENTS_DIR` at call time and its module default is RELATIVE — while the SETUP cell
    # `os.chdir`s to `src/kaggle_gpu`, where `kgpu` stages its payload. So the first version
    # of this cell reported `NO FILE` for a ticker whose three CSVs were on disk. The path
    # is PRINTED,
    # because a directory nobody names is a directory nobody checks.
    ROOT = job.use_data_root(job.DEFAULT_DATA_ROOT)

    TPL = (META or {}).get("inputs", {}).get("template") or TEMPLATE
    # ⚠️ KEYED BY (period, REPORT), not by period. A merge writes one statement of a quarter and
    # skips another — VCB Q1-2026 wrote its income statement and cash flow while its balance sheet
    # was `identical to the row already on disk` — so a period-only set credits this run with a row
    # it deliberately left alone.
    # ⚠️ **EVERY RUN FOLDER, NOT ONE — AND THIS COLUMN NEVER APPEARED ON A BATCH UNTIL
    # 2026-09-06.** It read `MERGE`, which only the one-process path ever assigns; a batch is
    # ONE FOLDER PER DOCUMENT and both writers record into their own through
    # `pdf_ocr_merge.record_merge` (§6's per-quarter upsert and §9's sweep alike), so there
    # was nothing to read and `<- N from this run` was silently never printed. A folder
    # without `metadata.json` is an interrupted child and is skipped, exactly as §9 skips it.
    import json                                          # noqa: E402

    DECIDED = [d
               for _f in (Path(_x) for _x in FOLDERS)
               if (_f / "metadata.json").is_file()
               for ev in (json.loads((_f / "metadata.json").read_text(encoding="utf-8"))
                          .get("merge") or {}).get("events", [])
               for d in ev["decisions"] if d["action"] == "write" and ev["applied"]]
    MINE = {(d["period"], d["report"]) for d in DECIDED}
    # ⚠️ **WHICH OF THIS RUN'S ROWS `sane` NEVER JUDGED — `band == 0` and nothing else.**
    # A quarter whose filing produced all three statements is written band or no band
    # (`BND-1` is a loop, not a guard — §1's MERGE_EACH), so this is the price of that
    # decision and it has to be READABLE rather than merely taken. ⚠️ `0` is "the band was
    # empty"; a MISSING `band` key is a run folder written before 2026-09-06, which is
    # "nobody recorded it" and NOT the same claim (§5 rule 2) — so the test is `== 0`, and an
    # older artefact reports nothing here rather than reporting everything.
    UNGUARDED = sorted({(d["period"], d["report"]) for d in DECIDED if d.get("band") == 0})
    if UNGUARDED:
        print(f"⚠️ {len(UNGUARDED)} of the {len(MINE)} statement(s) this run wrote PASSED NO "
              f"MAGNITUDE GUARD:")
        print("   `seed_history` had no `pdf` row on disk to rebuild a band from, so `sane` "
              "failed open.")
        for _p, _r in UNGUARDED[:12]:
            print(f"     {_p:10} {_r}")
        if len(UNGUARDED) > 12:
            print(f"     … and {len(UNGUARDED) - 12} more")
        print("   ⚠️ SCREEN THESE BY ARITHMETIC BEFORE QUOTING ANY OF THEM — two statements "
              "agreeing on")
        print("      one figure, a printed subtotal closing. This is what `sane` would have "
              "caught:")
        print("      an OCR misread by three orders of magnitude reads like a figure "
              "(`TSS-1`'s BSR")
        print("      Q3-2019 was 361,884,738 against another layer's 361,884,738,267).")
        print("   The same list is in each run folder's `merge` block, per decision, as "
              "`band: 0`.")
        print("")
    if TPL is None:
        print("no template resolved — run the cells above first")
    else:
        print(f"{ROOT / 'financials' / 'statements' / TPL}   {EXCHANGE}_{SYMBOL}")
        print()
        ANY = False
        for _report in fin.REPORTS:
            _path = Path(fin.statement_path(TPL, _report, EXCHANGE, SYMBOL))
            if not _path.is_file():
                print(f"  {_report:18} ⚠️ NO FILE — {_path.name} does not exist")
                continue
            ANY = True
            with open(_path, encoding="utf-8-sig") as _f:
                _rows = list(csv.DictReader(_f))
            _src = {}
            for _r in _rows:
                _src[_r.get("source", "")] = _src.get(_r.get("source", ""), 0) + 1
            _mine = [_r for _r in _rows if _r.get("source") == "pdf"
                     and (_r["period"], _report) in MINE]
            print(f"  {_report:18} {len(_rows):>3} quarters   "
                  + "  ".join(f"{k}={v}" for k, v in sorted(_src.items()))
                  + (f"   <- {len(_mine)} from this run" if _mine else ""))
            # ⚠️ Rule 24: a financial statement comes from the filing PDF and from nothing else.
            # A `cafef` row is an HTML transcription and must not be in this file.
            if _src.get("cafef"):
                print(f"       ⚠️ {_src['cafef']} row(s) read `source=cafef` — an HTML "
                      f"transcription. §5 rule 24 forbids it.")
        if not ANY:
            print()
            print("  ⚠️ THIS TICKER HAS NO STATEMENT CSV AT ALL. The parse is in the run folder "
                  "and")
            print("     nothing was upserted — the MERGE section above says which refusal "
                  "stopped it.")
NB.end()
# Out:
#  98.3% - step 9/10 HOSE_HPG 65q - did it land - the statement CSVs themselves — not what a process decided
#  98.3% - step 9/10 HOSE_HPG 65q - did it land - ⚠️ 6 of the 150 statement(s) this run wrote PASSED NO MAGNITUDE GUARD:
#  98.3% - step 9/10 HOSE_HPG 65q - did it land - `seed_history` had no `pdf` row on disk to rebuild a band from, so `sane` failed open.
#  98.3% - step 9/10 HOSE_HPG 65q - did it land - Q2-2010    balance_sheet
#  98.3% - step 9/10 HOSE_HPG 65q - did it land - Q2-2010    cash_flow
#  98.3% - step 9/10 HOSE_HPG 65q - did it land - Q2-2010    income_statement
#  98.3% - step 9/10 HOSE_HPG 65q - did it land - Q4-2008    balance_sheet
#  98.3% - step 9/10 HOSE_HPG 65q - did it land - Q4-2008    cash_flow
#  98.3% - step 9/10 HOSE_HPG 65q - did it land - Q4-2008    income_statement
#  98.3% - step 9/10 HOSE_HPG 65q - did it land - ⚠️ SCREEN THESE BY ARITHMETIC BEFORE QUOTING ANY OF THEM — two statements agreeing on
#  98.3% - step 9/10 HOSE_HPG 65q - did it land - one figure, a printed subtotal closing. This is what `sane` would have caught:
#  98.3% - step 9/10 HOSE_HPG 65q - did it land - an OCR misread by three orders of magnitude reads like a figure (`TSS-1`'s BSR
#  98.3% - step 9/10 HOSE_HPG 65q - did it land - Q3-2019 was 361,884,738 against another layer's 361,884,738,267).
#  98.3% - step 9/10 HOSE_HPG 65q - did it land - The same list is in each run folder's `merge` block, per decision, as `band: 0`.
#  98.3% - step 9/10 HOSE_HPG 65q - did it land - D:\GIT\master-thesis\raw_data\cafef\financials\statements\corp   HOSE_HPG
#  98.3% - step 9/10 HOSE_HPG 65q - did it land - balance_sheet       65 quarters   pdf=65   <- 65 from this run
#  98.3% - step 9/10 HOSE_HPG 65q - did it land - income_statement    65 quarters   missing=35  pdf=30   <- 30 from this run
#  98.3% - step 9/10 HOSE_HPG 65q - did it land - cash_flow           65 quarters   missing=10  pdf=55   <- 55 from this run

# %% [markdown]
# ## 11 · Repair one row — scoped, deliberate, read the diff first

# %%
# ── REPAIR ONE ROW — scoped, deliberate, and read the diff first ──────────
# ⚠️ THE ONLY WAY THIS NOTEBOOK OVERWRITES A GOOD-LOOKING `pdf` ROW. `pdf_ocr_merge` refuses a
# figure that DIFFERS from a `pdf` row on disk, because two runs disagreeing is not settled by
# preferring the newer one. That refusal is lifted here for the NAMED pairs only — never for the
# run — and `merge_run`'s own `periods`/`reports` filter is what scopes it.
# ⚠️ A BACKUP is taken before any write. Diff EVERY COLUMN afterwards, not the figures: three
# separate runs in this repo lost only a `publish_date` and a figures-only diff called each of
# them clean (CLAUDE.md §6-2-quatervicies, §6-2-quinvicies, §6-2-quadragies).
NB.begin("repair", f"{len(REPAIR)} scoped pair(s)   apply={REPAIR_APPLY}")
with NB.capture(nested=True):
    if LATEST is not None and REPAIR:
        from web_scraper import pdf_ocr_merge                 # noqa: E402

        HOW = "APPLY" if REPAIR_APPLY else "PLAN"
        print(f"{HOW} — {len(REPAIR)} scoped repair(s) from {LATEST.name}")
        print()
        for _period, _report in REPAIR:
            print(f"── {_period} {_report} " + "─" * 46)
            _rep = pdf_ocr_merge.merge_run(
                LATEST, apply=REPAIR_APPLY, periods=[_period], reports=[_report],
                force_differs=True, force_empty_band=FORCE_EMPTY_BAND)
            if getattr(_rep, "backup", None):
                print(f"   backup: {_rep.backup}")
        if not REPAIR_APPLY:
            print()
            print("nothing was written. Set REPAIR_APPLY = True to apply the plan above.")
    elif LATEST is not None:
        print("REPAIR is empty — no row already on disk was replaced.")
        print("  A statement this run parsed that disk already holds as `pdf` was refused as")
        print("  DIFFERS and left alone. That is the default and usually right; name the")
        print("  (quarter, statement) pair in REPAIR only once the FILING has settled which")
        print("  reading is correct.")
NB.done("end of the notebook")
# Out:
#  99.1% - step 10/10 HOSE_HPG 65q - repair one row - 0 scoped pair(s)   apply=False
#  99.1% - step 10/10 HOSE_HPG 65q - repair one row - REPAIR is empty — no row already on disk was replaced.
#  99.1% - step 10/10 HOSE_HPG 65q - repair one row - A statement this run parsed that disk already holds as `pdf` was refused as
#  99.1% - step 10/10 HOSE_HPG 65q - repair one row - DIFFERS and left alone. That is the default and usually right; name the
#  99.1% - step 10/10 HOSE_HPG 65q - repair one row - (quarter, statement) pair in REPAIR only once the FILING has settled which
#  99.1% - step 10/10 HOSE_HPG 65q - repair one row - reading is correct.
# 100.0% - step 10/10 HOSE_HPG 65q - repair one row - end of the notebook
